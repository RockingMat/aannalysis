# %%
import re
import utils
import spacy.lang.en as en

from tqdm import tqdm
from collections import defaultdict

# %%
nlp = en.English()
tokenizer = nlp.tokenizer
# Out:
# /home/km55359/.conda/envs/kmisra/lib/python3.11/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
postags = utils.read_file("/home/km55359/rawdata/babylm_data/babylm_100M/sents/postags.txt")
sents = utils.read_file("/home/km55359/rawdata/babylm_data/babylm_100M/sents/babylm_sents.txt")

# %%
aadj_regex = re.compile(r"\bDT (JJ|JJR|JJS)")
anum_regex = re.compile(r"\bDT CD")
adjnum_regex = re.compile(r"\b(JJ|JJR|JJS) CD")

# %%
# def get_aadj():
#     aadj_sents = []
#     for i in range(len(postags)):
#         if aadj_regex.search(postags[i]):
#             aadj_sents.append(sents[i])
#     return aadj_sents
aadjs = []
anums = []
adjnums = []
aadjs_and_adjnums = []

for i, batch in enumerate(tqdm(zip(sents, postags))):
    sent, postag = batch
    sent_split, postag_split = [t.text for t in tokenizer(sent)], postag.split()
    
    aadj = aadj_regex.search(postag)
    if aadj:
        idx = len(postag[:aadj.start()].split())
        det = sent_split[idx]
        adj = sent_split[idx+1]
        if det.lower() in ["a", "an", "another"]:
            aadjs.append({
                'sentence_idx': i,
                'DT': det,
                'ADJ': adj,
                'sentence': sent
            })

    anum = anum_regex.search(postag)
    if anum:
        idx = len(postag[:anum.start()].split())
        det = sent_split[idx]
        num = sent_split[idx+1]
        if det.lower() in ["a", "an", "another"]:
            anums.append({
                'sentence_idx': i,
                'DT': det,
                'NUMERAL': num,
                'sentence': sent
            })
    
    adjnum = adjnum_regex.search(postag)
    if adjnum:
        idx = len(postag[:adjnum.start()].split())
        adj = sent_split[idx]
        num = sent_split[idx+1]
        adjnums.append({
            'sentence_idx': i,
            'ADJ': adj,
            'NUMERAL': num,
            'sentence': sent
        })

    if aadj and adjnum:
        if det.lower() in ["a", "an", "another"]:
            aadjs_and_adjnums.append({
                'sentence_idx': i,
                'DT': det,
                'ADJ': adj,
                'NUMERAL': num,
                'sentence': sent
            })
# Out:
# 0it [00:00, ?it/s]
# 11632617it [03:24, 56982.77it/s]

# %%
len(anums), len(aadjs), len(adjnums), len(aadjs_and_adjnums)
# Out:
# (42111, 613985, 42777, 7108)

# %%
613985 - 42111
# Out:
# 571874

# %%
'''
Maybe AANNs are learned because AA is more frequent than AN --> so what if we remove AAs such that there are equal number of AAs and ANs?
'''
# aadjs_and_adjnums
# Out:
# '\nMaybe AANNs are learned because AA is more frequent than AN --> so what if we remove AAs such that there are equal number of AAs and ANs?\n'

# %%
''' 
Count numerals from anums and adjs from aadjs, such that the number of times the most frequent numeral succeeds the indef article is the same as the number of times the most frequent adjective succeeds the indef article.
'''

frequency = utils.read_csv_dict("../data/babylm-analysis/babylm-unigrams.csv")
freq_table = {}
for entry in frequency:
    freq_table[entry['word']] = int(entry['count'])

# %%
freq_table['hundred']
# Out:
# 17810

# %%
by_nums = defaultdict(list)
by_adjs = defaultdict(list)

for entry in aadjs:
    by_adjs[entry['ADJ'].lower()].append(entry)

for entry in anums:
    by_nums[entry['NUMERAL'].lower()].append(entry)

by_nums = dict(by_nums)
by_adjs = dict(by_adjs)

# by_num_freq = {k: len(v) for k, v in by_nums.items()}
# by_adj_freq = {k: len(v) for k, v in by_adjs.items()}

sorted_by_nums = sorted(by_nums.items(), key = lambda x: len(x[1]), reverse=True)
sorted_by_adjs = sorted(by_adjs.items(), key = lambda x: len(x[1]), reverse=True)

# %%
def get_frequency(word):
    try:
        return freq_table[word]
    except: 
        return 0

# %%
import random

random.seed(42)

sampled_adjs = []

for ordered_adj, ordered_num in tqdm(zip(sorted_by_adjs, sorted_by_nums)):
    to_sample = min(len(ordered_adj[1]), len(ordered_num[1]))
    if to_sample == 0:
        continue
    sampled_adj = random.sample(ordered_adj[1], to_sample)
    obj = (ordered_adj[0], sampled_adj)
    sampled_adjs.append(obj)
# Out:
# 2129it [00:00, 110803.74it/s]

# %%
len(sampled_adjs)
# Out:
# 2129

# %%
flattened_adjs = []
for sa in sampled_adjs:
    flattened_adjs.extend(sa[1])

len(flattened_adjs)
# Out:
# 42111

# %%
flattened_nums = []
for sn in sorted_by_nums:
    flattened_nums.extend(sn[1])

len(flattened_nums)
# Out:
# 42111

# %%
flattened_nums
# Out:
# [{'sentence_idx': 5359,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'a hundred projects that will disappear in three months.'},
#  {'sentence_idx': 8208,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Jerry is on his way to Tokyo to check them out, and probably every geisha within a hundred miles.'},
#  {'sentence_idx': 9551,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'I support that a hundred percent.'},
#  {'sentence_idx': 13369,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Jerry is on his way to Tokyo to check them out, and probably every geisha within a hundred miles.'},
#  {'sentence_idx': 13783,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Erm the first thing I'm,I I would like t t to draw out is that at the end of the year we made a profit of a hundred sixty thousand pounds."},
#  {'sentence_idx': 13791,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and ninety.'},
#  {'sentence_idx': 13801,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and ninety.'},
#  {'sentence_idx': 13804,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and ninety thousand'},
#  {'sentence_idx': 13829,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and ninety thousand pounds.'},
#  {'sentence_idx': 15061,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'profit for the group is a hundred and ninety thousand pounds.'},
#  {'sentence_idx': 15344,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And the graduates initially were only putting in about a hundred and thirty three thousand and they came out as four and a half.'},
#  {'sentence_idx': 16057,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Staff numbers statement erm  and, and we look at the right hand column, you will find that we have a hundred and thirty nine fee earning people, and fifty eight support.'},
#  {'sentence_idx': 16922,
#   'DT': 'A',
#   'NUMERAL': 'Hundred',
#   'sentence': 'Starting in the 1910s and continuing steadily almost until his death in 1966, these translations started with poetry, such as "A Hundred and Seventy Chinese Poems" (1918) and "Japanese Poetry: The Uta" (1919), then an equally wide range of novels, such as "The Tale of Genji" (1925–26), an 11th-century Japanese work, and "Monkey", from 16th-century China.'},
#  {'sentence_idx': 17074,
#   'DT': 'A',
#   'NUMERAL': 'Hundred',
#   'sentence': 'His many translations include "A Hundred and Seventy Chinese Poems" (1918), "Japanese Poetry: The Uta" (1919), "The No Plays of Japan" (1921), "The Tale of Genji" (published in 6 volumes from 1921–33), "The Pillow Book of Sei Shōnagon" (1928), The "Kutune Shirka" (1951), "Monkey" (1942, an abridged version of "Journey to the West"), "The Poetry and Career of Li Po" (1959) and "The Secret History of the Mongols and Other Pieces" (1964).'},
#  {'sentence_idx': 17501,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Three feet from the lens, in the center of the foreground, was another face, and then, over a hundred yards away was the rear wall of the studio, showing telephone wires and architectural details.'},
#  {'sentence_idx': 19947,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'with the eagerness of youth, and with a hundred blunders, and with love'},
#  {'sentence_idx': 19966,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Er  let's say a hundred and fifty pounds a month towards a pension and er maybe fifty pounds towards life protection."},
#  {'sentence_idx': 23103,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'high-road, a hundred years ago, was not that grass-grown desert of the'},
#  {'sentence_idx': 23706,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I mean basically he's put that into account and then it's how much will they need on top of that  so he total that he would need would be three hundred and seventy thousand pounds of which there is a hundred seventy thousand so the shortfall's twenty thousand, or two hundred thousand."},
#  {'sentence_idx': 27564,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There was the jewel case, silver clasped; and a hundred'},
#  {'sentence_idx': 28547,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It's a hundred dollars."},
#  {'sentence_idx': 28800,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“Sometimes, indeed, the neighbours thought it strange that the rich Miller never gave little Hans anything in return, though he had a hundred sacks of flour stored away in his mill, and six milch cows, and a large flock of woolly sheep; but Hans never troubled his head about these things, and nothing gave him greater pleasure than to listen to all the wonderful things the Miller used to say about the unselfishness of true friendship.'},
#  {'sentence_idx': 29824,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The end of it was that the king and queen had to sit down alone , one at each end of a very long table , arrayed with plates and glasses for a hundred guests -- for a hundred guests who never came !'},
#  {'sentence_idx': 31726,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It was certainly rather cool of him to say to the Emperor's daughter, “Will you have me?” But so he did; for his name was renowned far and wide; and there were a hundred princesses who would have answered, “Yes!” and “Thank you kindly.” We shall see what this princess said."},
#  {'sentence_idx': 32322,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“He will have a hundred kisses from the Princess!” said the lady who had been to ask.'},
#  {'sentence_idx': 32362,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': '“A hundred kisses from the Princess,” said he, “or else let everyone keep his own!”'},
#  {'sentence_idx': 33819,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and twenty eight pages.'},
#  {'sentence_idx': 33872,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Oh, he is a hundred times happier than I!”'},
#  {'sentence_idx': 33966,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'the letter, and she tore the paper into a hundred fragments, which she'},
#  {'sentence_idx': 35018,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "If you take your T V in, a lot of these T V repair places will say, well, I'll repair your T V for a hundred dollars,"},
#  {'sentence_idx': 35065,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Now, if he comes in and says, you know, I'll repair your, your V C R, or somebody else's V C R, for a hundred dollars, gets in there,"},
#  {'sentence_idx': 35441,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But the Remora , hissing terribly , and visibly melting away in places , yet held his ground ; and the prince could see his cold white folds climbing slowly up the hoofs of the Firedrake -- up and up , till they reached his knees , and the great burning beast roared like a hundred bulls with the pain .'},
#  {'sentence_idx': 35776,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Tönnies was best known for playing for MSV Duisburg, playing in 179 league games and scoring over a hundred goals.'},
#  {'sentence_idx': 36083,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Send her a hundred pound."'},
#  {'sentence_idx': 36163,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'That night, when Amelia kissed her father, she put a bill for a hundred'},
#  {'sentence_idx': 36907,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Higher and higher still they flew, nearer and nearer to the stars, when suddenly the mirror shook so terribly with grinning, that it flew out of their hands and fell to the earth, where it was dashed in a hundred million and more pieces.'},
#  {'sentence_idx': 37067,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He made a hundred blunders, and showed his'},
#  {'sentence_idx': 37496,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Gluckstein is a hundred leagues from here , and how sayest thou that thou slewest the monster , and camest hither in a few hours ' space ? '"},
#  {'sentence_idx': 37531,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'seized him and embraced him a hundred times.'},
#  {'sentence_idx': 38938,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Beside them, on laths and perches, sat nearly a hundred pigeons, all asleep, seemingly; but yet they moved a little when the robber maiden came.'},
#  {'sentence_idx': 39183,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'You have more than a hundred miles to go before you get to Finland; there the Snow Queen has her country-house, and burns blue lights every evening.'},
#  {'sentence_idx': 39458,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There were more than a hundred halls there, according as the snow was driven by the winds.'},
#  {'sentence_idx': 40398,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And the boy grew up to be a lad, and was to go forth in the wide world-far, far away to warm lands, where the coffee-tree grows; but at his departure the little maiden took an Elder-blossom from her bosom, and gave it him to keep; and it was placed between the leaves of his Prayer-Book; and when in foreign lands he opened the book, it was always at the place where the keepsake-flower lay; and the more he looked at it, the fresher it became; he felt as it were, the fragrance of the Danish groves; and from among the leaves of the flowers he could distinctly see the little maiden, peeping forth with her bright blue eyes and then she whispered, “It is delightful here in Spring, Summer, Autumn, and Winter”; and a hundred visions glided before his mind.'},
#  {'sentence_idx': 41652,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The end of it was that the king and queen had to sit down alone , one at each end of a very long table , arrayed with plates and glasses for a hundred guests -- for a hundred guests who never came !'},
#  {'sentence_idx': 41758,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“At a hundred human paces from here there sits a little snail in her house, on a gooseberry bush; she is quite lonely, and old enough to be married.'},
#  {'sentence_idx': 41759,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'It is only a hundred human paces!”'},
#  {'sentence_idx': 47080,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But the Remora , hissing terribly , and visibly melting away in places , yet held his ground ; and the prince could see his cold white folds climbing slowly up the hoofs of the Firedrake -- up and up , till they reached his knees , and the great burning beast roared like a hundred bulls with the pain .'},
#  {'sentence_idx': 47284,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He rode up to it, and saw a little old woman, who appeared to be at least a hundred years old.'},
#  {'sentence_idx': 48937,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred times she asked Bellissima if anything was the matter with her; but she always said that there was nothing.'},
#  {'sentence_idx': 48974,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Gluckstein is a hundred leagues from here , and how say est thou that thou slewest the molester , and earnest hither in a few hours ' space ? '"},
#  {'sentence_idx': 49842,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When she found that the King did not return, she hastened out to look for him, and reached the shore, with a hundred of the ladies of her train, loaded with splendid presents for him.'},
#  {'sentence_idx': 50634,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The Princess shall indeed pierce her hand with a spindle; but, instead of dying, she shall only fall into a profound sleep, which shall last a hundred years, at the expiration of which a king’s son shall come and awake her.”'},
#  {'sentence_idx': 50741,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The good Fairy who had saved her life by condemning her to sleep a hundred years was in the kingdom of Matakin, twelve thousand leagues off, when this accident befell the Princess; but she was instantly informed of it by a little dwarf, who had boots of seven leagues, that is, boots with which he could tread over seven leagues of ground in one stride.'},
#  {'sentence_idx': 50785,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When a hundred years were gone and passed the son of the King then reigning, and who was of another family from that of the sleeping Princess, being gone a-hunting on that side of the country, asked:'},
#  {'sentence_idx': 50799,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And he had a hundred and four fever.'},
#  {'sentence_idx': 50847,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“May it please your royal highness, it is now about fifty years since I heard from my father, who heard my grandfather say, that there was then in this castle a princess, the most beautiful was ever seen; that she must sleep there a hundred years, and should be waked by a king’s son, for whom she was reserved.”'},
#  {'sentence_idx': 50951,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'They went into the great hall of looking-glasses, where they supped, and were served by the Princess’s officers, the violins and hautboys played old tunes, but very excellent, though it was now above a hundred years since they had played; and after supper, without losing any time, the lord almoner married them in the chapel of the castle, and the chief lady of honor drew the curtains.'},
#  {'sentence_idx': 51239,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'However, Cinderella, notwithstanding her mean apparel, was a hundred times handsomer than her sisters, though they were always dressed very richly.'},
#  {'sentence_idx': 51778,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'pleased and endowed him with a hundred fanciful graces; but, in truth, in'},
#  {'sentence_idx': 53184,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'All that he had left was a little house in a desolate place at least a hundred leagues from the town in which he had lived, and to this he was forced to retreat with his children, who were in despair at the idea of leading such a different life.'},
#  {'sentence_idx': 56300,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“Would to heaven that each of you had a hundred stomachs!'},
#  {'sentence_idx': 58119,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And a huge amount of harm and social injustice gets done and then we learn to sort of tolerate it, thinking well, a hundred years from now it will be better.'},
#  {'sentence_idx': 58401,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred chariots followed, each drawn by eight horses, and filled with officers in splendid uniforms, and a thousand guards surrounded the procession.'},
#  {'sentence_idx': 58591,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "And I'm hoping it's not going to be like, a hundred -- &amp;gt;&amp;gt; Oh no, it's already -- it's already in main stream medicine, just -- just not here."},
#  {'sentence_idx': 58771,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Sue's just gone past at a hundred miles per hour."},
#  {'sentence_idx': 60147,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He had a splendid carriage made for his ambassador, and gave him more than a hundred horses and a hundred servants, and told him to be sure and bring the Princess back with him.'},
#  {'sentence_idx': 61005,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He is going to the cavern alone, though if he had a hundred men with him he could not succeed.'},
#  {'sentence_idx': 61009,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'His body was yellow and green, and his claws scarlet, and his tail was so long that it lay in a hundred coils.'},
#  {'sentence_idx': 62248,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Nearly a hundred other sheep were scattered about, not eating the grass, but some drinking coffee, lemonade, or sherbet, others eating ices, strawberries and cream, or sweetmeats, while others, again, were playing games.'},
#  {'sentence_idx': 62820,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'From time to time, indeed, one regains his own proper form and goes back again to his place in the upper world; but the other beings whom you saw are the rivals or the enemies of Ragotte, whom she has imprisoned for a hundred years or so; though even they will go back at last.'},
#  {'sentence_idx': 62997,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Short as Miranda’s absence had been, it had seemed like a hundred years to the King of the Sheep.'},
#  {'sentence_idx': 64084,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He went out, and, having run over a vast deal of ground, both on this side and that, he came at last into the very road where the poor children were, and not above a hundred paces from their father’s house.'},
#  {'sentence_idx': 64848,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'It was not more than a hundred yards to'},
#  {'sentence_idx': 66152,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "She's a hundred and two."},
#  {'sentence_idx': 66176,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "She'll be a hundred and three in August."},
#  {'sentence_idx': 66243,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'She, even though she is a hundred and two, she still has all of her faculties.'},
#  {'sentence_idx': 66462,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'barkless windfall that had once been a hundred-foot fir.'},
#  {'sentence_idx': 67626,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Uh, luckily, if we could be like your grandmother, I, uh you know, I would love to live to a hundred and two if I were okay.'},
#  {'sentence_idx': 68250,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'While he lay there the people came, and looking him all over read on his girdle: “Seven at a blow.” “Oh!” they said, “what can this great hero of a hundred fights want in our peaceful land?'},
#  {'sentence_idx': 68551,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But the creatures ran off a second time before I could seize them, whereupon there was a great shout, and in an instant I felt above a hundred arrows discharged on my left hand, which pricked me like so many needles.'},
#  {'sentence_idx': 68559,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He understood me very well, and, descending from the stage, commanded that several ladders should be set against my sides, on which more than a hundred of the inhabitants mounted, and walked toward my mouth with baskets full of food, which had been sent by the King’s orders when he first received tidings of me.'},
#  {'sentence_idx': 68939,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'For as to what we have heard you say, that there are other kingdoms in the world, inhabited by human creatures as large as yourself, our philosophers are very doubtful, and rather conjecture that you dropped from the moon, or one of the stars, because a hundred mortals of your size would soon destroy all the fruit and cattle of his Majesty’s dominions.'},
#  {'sentence_idx': 69377,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'hundred and seventy pounds without his clothes, Molly a hundred and'},
#  {'sentence_idx': 71079,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The galloping horsemen were not a hundred paces from the stringer when'},
#  {'sentence_idx': 71906,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Oh they had yes, they had a lot yesterday but most of them were over a hundred pounds.'},
#  {'sentence_idx': 72198,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He rode up to it , and saw a little old woman , who appeared to be at least a hundred years old .'},
#  {'sentence_idx': 73361,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But, for all  practical purpose, you are almost a hundred percent covered.'},
#  {'sentence_idx': 76350,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred times she asked Bellissima if anything was the matter with her ; but she always said that there was nothing .'},
#  {'sentence_idx': 78141,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When she found that the King did not return , she hastened out to look for him , and reached the shore , with a hundred of the ladies of her train , loaded with splendid presents for him .'},
#  {'sentence_idx': 79341,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "The Princess shall indeed pierce her hand with a spindle ; but , instead of dying , she shall only fall into a profound sleep , which shall last a hundred years , at the expiration of which a king 's son shall come and awake her . ''"},
#  {'sentence_idx': 79551,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The good Fairy who had saved her life by condemning her to sleep a hundred years was in the kingdom of Matakin , twelve thousand leagues off , when this accident befell the Princess ; but she was instantly informed of it by a little dwarf , who had boots of seven leagues , that is , boots with which he could tread over seven leagues of ground in one stride .'},
#  {'sentence_idx': 79677,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When a hundred years were gone and passed the son of the King then reigning , and who was of another family from that of the sleeping Princess , being gone a-hunting on that side of the country , asked : What those towers were which he saw in the middle of a great thick wood ?'},
#  {'sentence_idx': 79724,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "The Prince was at a stand , not knowing what to believe , when a very good countryman spake to him thus : `` May it please your royal highness , it is now about fifty years since I heard from my father , who heard my grandfather say , that there was then in this castle a princess , the most beautiful was ever seen ; that she must sleep there a hundred years , and should be waked by a king 's son , for whom she was reserved . ''"},
#  {'sentence_idx': 79907,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "They went into the great hall of looking-glasses , where they supped , and were served by the Princess 's officers , the violins and hautboys played old tunes , but very excellent , though it was now above a hundred years since they had played ; and after supper , without losing any time , the lord almoner married them in the chapel of the castle , and the chief lady of honor drew the curtains ."},
#  {'sentence_idx': 80553,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'However , Cinderella , notwithstanding her mean apparel , was a hundred times handsomer than her sisters , though they were always dressed very richly .'},
#  {'sentence_idx': 81895,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Got video's down here a hundred and fifty pound ."},
#  {'sentence_idx': 86239,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'so, he was a hundred and twenty pounds,'},
#  {'sentence_idx': 87886,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There will be more than a hundred of us!”'},
#  {'sentence_idx': 88652,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'All that he had left was a little house in a desolate place at least a hundred leagues from the town in which he had lived , and to this he was forced to retreat with his children , who were in despair at the idea of leading such a different life .'},
#  {'sentence_idx': 92936,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'They had not taken a hundred steps when they saw two rough-looking individuals sitting on a stone begging for alms.'},
#  {'sentence_idx': 96814,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '`` Would to heaven that each of you had a hundred stomachs !'},
#  {'sentence_idx': 100263,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Or two for a hundred and fifty or'},
#  {'sentence_idx': 100527,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred chariots followed , each drawn by eight horses , and filled with officers in splendid uniforms , and a thousand guards surrounded the procession .'},
#  {'sentence_idx': 100771,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He then said to his agent, "Now I know what a hundred million dollars at the box office reads like."'},
#  {'sentence_idx': 106746,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He had a splendid carriage made for his ambassador , and gave him more than a hundred horses and a hundred servants , and told him to be sure and bring the Princess back with him .'},
#  {'sentence_idx': 108663,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He is going to the cavern alone , though if he had a hundred men with him he could not succeed .'},
#  {'sentence_idx': 108754,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'His body was yellow and green , and his claws scarlet , and his tail was so long that it lay in a hundred coils .'},
#  {'sentence_idx': 109044,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'So that one would come out then at erm just over a hundred pounds.'},
#  {'sentence_idx': 112041,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Nearly a hundred other sheep were scattered about , not eating the grass , but some drinking coffee , lemonade , or sherbet , others eating ices , strawberries and cream , or sweetmeats , while others , again , were playing games .'},
#  {'sentence_idx': 112064,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and seventeen eighty.'},
#  {'sentence_idx': 112753,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Certainly at the time of our  taking over, the  the number of operatives would have been  not far short of a hundred.'},
#  {'sentence_idx': 113106,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'From time to time , indeed , one regains his own proper form and goes back again to his place in the upper world ; but the other beings whom you saw are the rivals or the enemies of Ragotte , whom she has imprisoned for a hundred years or so ; though even they will go back at last .'},
#  {'sentence_idx': 113605,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Short as Miranda 's absence had been , it had seemed like a hundred years to the King of the Sheep ."},
#  {'sentence_idx': 113851,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "when teeing off I'll go probably a hundred feet across the ground"},
#  {'sentence_idx': 114426,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I'm usually around a hundred."},
#  {'sentence_idx': 114436,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Around a hundred.'},
#  {'sentence_idx': 115038,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'They were all shocked; but the twelfth, whose good wish still remained unspoken, came forward, and as she could not undo the evil sentence, but only soften it, she said, “It shall not be death, but a deep sleep of a hundred years, into which the princess shall fall.”'},
#  {'sentence_idx': 115089,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'After long, long years a King’s son came again to that country, and heard an old man talking about the thorn-hedge, and that a castle was said to stand behind it in which a wonderfully beautiful princess, named Briar-rose, had been asleep for a hundred years; and that the King and Queen and the whole court were asleep likewise.'},
#  {'sentence_idx': 115723,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "He went out , and , having run over a vast deal of ground , both on this side and that , he came at last into the very road where the poor children were , and not above a hundred paces from their father 's house ."},
#  {'sentence_idx': 116867,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Then he fell into a rage, and tapped his knapsack until a hundred and fifty men stood before him armed from head to foot.'},
#  {'sentence_idx': 118968,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Next day when the wedding was to take place, the huntsman said at mid-day to the inn-keeper, “Do you believe, sir host, that I while with you here to-day shall eat bread from the King’s own table?” “Nay,” said the host, “I would bet a hundred pieces of gold that that will not come true.” The huntsman accepted the wager, and set against it a purse with just the same number of gold pieces.'},
#  {'sentence_idx': 120684,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Next day there is a fair in the neighboring town, so the youth says to his father, “I will now change myself into a beautiful horse, and you can sell me; but when you have sold me, you must take off my bridle, or I cannot become a man again.” Then the father goes with the horse to the fair, and the master-thief comes and buys the horse for a hundred thalers, but the father forgets, and does not take off the bridle.'},
#  {'sentence_idx': 120918,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When he was within a hundred paces of it he was not held fast, but walked on to the door.'},
#  {'sentence_idx': 121607,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“I am master of a hundred arts, and have into the bargain a sackful of cunning.'},
#  {'sentence_idx': 124905,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There was once upon a time a rich King who had three daughters, who daily went to walk in the palace garden, and the King was a great lover of all kinds of fine trees, but there was one for which he had such an affection, that if anyone gathered an apple from it he wished him a hundred fathoms underground.'},
#  {'sentence_idx': 125335,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The giant said, “I have two hours’ time, during which I will carry you into the neighbourhood, but after that I must be at home to suckle the child that we have.” So the giant carried the man to about a hundred leagues from the castle, and said, “Thou canst very well walk the rest of the way alone.” And he turned back, but the man went onwards day and night, until at length he came to the golden castle of Stromberg.'},
#  {'sentence_idx': 125704,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Erm a hundred and twenty four'},
#  {'sentence_idx': 126628,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It's done a hundred and eight thousand mile!"},
#  {'sentence_idx': 126637,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Then he said to the son, “Go and sell thy damaged axe, and see what thou canst get for it, and I must earn the difference, in order to pay the neighbour.” The son took the axe, and carried it into town to a goldsmith, who tested it, laid it in the scales, and said, “It is worth four hundred thalers, I have not so much as that by me.” The son said, “Give me what thou hast, I will lend you the rest.” The goldsmith gave him three hundred thalers, and remained a hundred in his debt.'},
#  {'sentence_idx': 126638,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The son thereupon went home and said, “Father, I have got the money, go and ask the neighbour what he wants for the axe.” “I know that already,” answered the old man, “one thaler, six groschen.” “Then give him two thalers, twelve groschen, that is double and enough; see, I have money in plenty,” and he gave the father a hundred thalers, and said, “You shall never know want, live as comfortably as you like.” “Good heavens!” said the father, “how hast thou come by these riches?” The scholar then told how all had come to pass, and how he, trusting in his luck, had made such a good hit.'},
#  {'sentence_idx': 128173,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'No one can imagine how magnificent the crown was; when the sun shone on it, it gleamed like a hundred thousand carbuncles.'},
#  {'sentence_idx': 129834,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But, you know I've got a hundred and twenty-five thousand miles on the Charger."},
#  {'sentence_idx': 130520,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He allows her a hundred a'},
#  {'sentence_idx': 130935,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But, uh, my great-grandfather was put in a nursing home when he was a hundred and three.'},
#  {'sentence_idx': 131060,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'A Lynx will only do a hundred and eighty mile an hour!'},
#  {'sentence_idx': 131143,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The huntsman thanked the wise woman, and thought to himself, “Those are fine things that she has promised me, if all does but come true.” And verily when he had walked about a hundred paces, he heard in the branches above him such a screaming and twittering that he looked up and saw there a crowd of birds who were tearing a piece of cloth about with their beaks and claws, and tugging and fighting as if each wanted to have it all to himself.'},
#  {'sentence_idx': 132195,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'they said , `` what can this great hero of a hundred fights want in our peaceful land ?'},
#  {'sentence_idx': 133819,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But the creatures ran off a second time before I could seize them , whereupon there was a great shout , and in an instant I felt above a hundred arrows discharged on my left hand , which pricked me like so many needles .'},
#  {'sentence_idx': 133978,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "He understood me very well , and , descending from the stage , commanded that several ladders should be set against my sides , on which more than a hundred of the inhabitants mounted , and walked toward my mouth with baskets full of food , which had been sent by the King 's orders when he first received tidings of me ."},
#  {'sentence_idx': 134439,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'was now paying his enemy an annuity of a hundred a year.'},
#  {'sentence_idx': 135509,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "For as to what we have heard you say , that there are other kingdoms in the world , inhabited by human creatures as large as yourself , our philosophers are very doubtful , and rather conjecture that you dropped from the moon , or one of the stars , because a hundred mortals of your size would soon destroy all the fruit and cattle of his Majesty 's dominions ."},
#  {'sentence_idx': 135516,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and fifty mile an hour right?'},
#  {'sentence_idx': 135565,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and fifty mile an hour!'},
#  {'sentence_idx': 135583,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Now road testing, the bloke said look you can take your hands off the wheel at a hundred and fifty!'},
#  {'sentence_idx': 135587,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Well I ca , I can do a hundred and twenty odd in that thing in four and a half.'},
#  {'sentence_idx': 136169,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There I saw a lean old goat which carried about a hundred cart-loads of fat on his body, and sixty loads of salt.'},
#  {'sentence_idx': 137442,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The King saw it from afar, but would not give his daughter to Hans yet, and said he must first take a hundred hares out to pasture from early morning until late evening, and if one of them got away, he should not have his daughter.'},
#  {'sentence_idx': 137457,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He said he had to watch over a hundred hares and see that none of them ran away, and then he might marry the King’s daughter and be King.'},
#  {'sentence_idx': 137458,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '“Good,” said the little man, “there is a whistle for thee, and if one of them runs away, just whistle with it, and then it will come back again.” When the King’s daughter came, Hans gave her a hare into her apron; but when she had gone about a hundred steps with it, he whistled, and the hare jumped out of the apron, and before she could turn round was back to the flock again.'},
#  {'sentence_idx': 137460,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The King wondered how Hans had been able to take a hundred hares to graze without losing any of them; he would, however, not give him his daughter yet, and said he must now bring him a feather from the Griffin’s tail.'},
#  {'sentence_idx': 137606,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The next spring, Hans said, “Keep all the money and get a walking-stick that weighs a hundred-weight made for me that I may go a-travelling.” When the wished-for stick was ready, he left his father’s house, went forth, and came to a deep, dark forest.'},
#  {'sentence_idx': 137760,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Then said Saint Peter, “By no means, thou art just as dear to us as any one else, and wilt enjoy every heavenly delight that the rich man enjoys, but poor fellows like thee come to heaven every day, but a rich man like this does not come more than once in a hundred years!”'},
#  {'sentence_idx': 141981,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "You get it for three hundred and fifty, it's a hundred and fifty odd pounds saved innit?"},
#  {'sentence_idx': 147081,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Now, if there should be a famine, I should certainly make a hundred rupees by it.'},
#  {'sentence_idx': 148868,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And yet though he could have made a hundred excuses to leave'},
#  {'sentence_idx': 149068,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'She lost a hundred hearts to him , and signed to her nurse to bring him to her presence .'},
#  {'sentence_idx': 149915,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "If you had a hundred lives you would not bring one out safe from this journey . '"},
#  {'sentence_idx': 151215,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Presently a girl of such moon-like beauty opened a window that the prince lost to her a hundred hearts .'},
#  {'sentence_idx': 151665,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "She turned to him a hundred hearts , took his hand and seated him beside her , and said : ' O youth !"},
#  {'sentence_idx': 151667,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Miss Bubbles was a hundred times too good for such a fellow,'},
#  {'sentence_idx': 154733,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The king ordered a hundred stripes to be laid on her tender body ; she sighed a long sigh .'},
#  {'sentence_idx': 157732,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There were about a hundred gallons of oil in this caldron, and the fire was burning beneath it.'},
#  {'sentence_idx': 163481,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The young storks, to be sure, thought he was at least a hundred, for he was much bigger than their parents, and, besides, what did they know about the ages of either children or grown men?'},
#  {'sentence_idx': 163523,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Trout , salmon , turbot , soles , and a hundred other fishes whose names he did not know , lay boiled , fried , and grilled within reach of his hands .'},
#  {'sentence_idx': 167306,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Just to sort of flag up jobs which were over a hundred thousand pounds and that had finished or are  well on their way this year.'},
#  {'sentence_idx': 167671,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'What I, my remit to Ken was to go through with Duncan er projects which were over a hundred thousand pounds.'},
#  {'sentence_idx': 168544,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The dolphins sported in the waves, and the great whales spouted water from their nostrils till it seemed as if a hundred fountains were playing in every direction.'},
#  {'sentence_idx': 168545,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It's  it we we took about fifty or so jobs that that were over a hundred thousand pounds, and then we knocked off  erm  the BES jobs and and jobs which were outside party, jobs where we hadn't actually done the design work."},
#  {'sentence_idx': 168648,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Even if they're over a hundred thousand?"},
#  {'sentence_idx': 168783,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There was music and song on board, and as darkness came on, a hundred colored lanterns were lighted, as if the flags of all nations waved in the air.'},
#  {'sentence_idx': 168791,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The sailors were dancing on deck, and when the prince came out of the cabin, more than a hundred rockets rose in the air, making it as bright as day.'},
#  {'sentence_idx': 169407,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'They looked like serpents with a hundred heads, growing out of the ground.'},
#  {'sentence_idx': 169659,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "there's a hundred thousand pounds worth of claims th then there are more fees that we would be entitled to."},
#  {'sentence_idx': 173442,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "and I'm sitting there making a hundred dollars a week, you know"},
#  {'sentence_idx': 173491,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"We\'ll wager you a ton of coined gold, a hundred pounds to the hundredweight."'},
#  {'sentence_idx': 175111,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'YOU know, surely, what the microscope is that wonderful little glass which makes everything appear a hundred times larger than it really is.'},
#  {'sentence_idx': 175365,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'But he was renowned far and wide, and there were a hundred princesses who would have answered, "Yes," and, "Thank you kindly."'},
#  {'sentence_idx': 175888,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"He will have a hundred kisses from the princess," said the lady who had been to ask.'},
#  {'sentence_idx': 175946,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': '"A hundred kisses from the princess," said he, "or else let every one keep his own."'},
#  {'sentence_idx': 177050,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'A second pig was drawn by the side of the first, and this looked a hundred times better.'},
#  {'sentence_idx': 178400,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'MORE than a hundred years ago, behind the wood and by a deep lake, stood an old baronial mansion.'},
#  {'sentence_idx': 178666,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred years passed away, and the place presented a much-changed aspect.'},
#  {'sentence_idx': 184557,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred million tablets have been consumed every year for the last twenty three years'},
#  {'sentence_idx': 185712,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"I am master of a hundred arts, and I have a sackful of cunning tricks in addition.'},
#  {'sentence_idx': 188744,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Many of the schools have histories dating back several hundred years, and the Old Boy forms may have been in use for a hundred years or more.'},
#  {'sentence_idx': 193588,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'Away down the river,     A hundred miles or more,   Other little children     Shall bring my boats ashore.'},
#  {'sentence_idx': 194483,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Kasetsart University, Kamphaeng Saen Campus (Botanical Garden) In the university compound, there are number of projects to educate farmers and the general public that include scaled-down projects such as an agricultural technology project, an irrigation system initiated along with the Royal project, an Entomological Park where various species of butterflies are housed, a pilot vegetable plantation plot, and Suan Saen Palm (garden of a hundred thousand palms), which collects various kinds of ornamental palms.'},
#  {'sentence_idx': 194969,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'the work of ten men can feed a hundred?'},
#  {'sentence_idx': 201167,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "And you know yourself that , only last week , when I sent him to buy a cask of butter , he returned driving a hundred and fifty ducks which someone had induced him to take , and not one of them would lay . '"},
#  {'sentence_idx': 201335,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"Do not cry so, dear Queen; I cannot quite undo my cousin\'s wicked enchantment, but I can promise you that your daughter shall not die, but only fall asleep for a hundred years.'},
#  {'sentence_idx': 201580,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Well, and so the years went on, and on, and on, until a hundred years had passed, and the palace and the story of it were all but forgotten.'},
#  {'sentence_idx': 201601,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Then the old man told him that there was a legend that beyond the wood was an enchanted palace where a beautiful Princess had lain sleeping for a hundred years, and whom a Prince was to awaken with a kiss.'},
#  {'sentence_idx': 201675,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Everything, in short, went on exactly as though the spell had lasted a hundred seconds instead of years.'},
#  {'sentence_idx': 203017,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I ain't going to keep that hoss, and I'll pay a hundred"},
#  {'sentence_idx': 204263,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred fairies danced last night,     And the harpers they were nine;"'},
#  {'sentence_idx': 208401,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'looked at it a hundred times a day and come near tearing it up every'},
#  {'sentence_idx': 211363,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"About five feet and five inches, must weigh around a hundred and'},
#  {'sentence_idx': 213464,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But what I'm saying is some schools  they might be here seventy five days out of a hundred  but for twenty of those"},
#  {'sentence_idx': 214369,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'All around the walls hung pictures, and by the great stove stood large Chinese vases with lions on the covers; there were rocking-chairs, silken sofas, great tables covered with picture books, and toys worth a hundred times a hundred dollars, at least the children said so.'},
#  {'sentence_idx': 214374,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'On one branch they hung little nets, cut out of colored paper; every net was filled with sweetmeats; golden apples and walnuts hung down, as if they grew there, and more than a hundred little candles, red, white, and blue, were fastened to the different boughs.'},
#  {'sentence_idx': 215613,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "why you must be a hundred at least ! '"},
#  {'sentence_idx': 217930,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'More than a hundred lamps are burning.'},
#  {'sentence_idx': 218034,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Up the tree climbed the soldier, into the tree he crept through the hole at the top, and down, down the hollow inside he slipped, and there he was, in a wide passage, lighted, as the witch had said, by a hundred burning lamps.'},
#  {'sentence_idx': 218727,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I must have been flowing here a hundred years and more and no one has ever yet come by . '"},
#  {'sentence_idx': 220937,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But the shepherd broke in with , ' I do not fear a hundred deaths , and I will only say it if I may have the princess for my wife . '"},
#  {'sentence_idx': 220962,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "` Then go to a hundred deaths ! '"},
#  {'sentence_idx': 221090,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
# ...
#   'sentence': "and I think if I look back fifty or a hundred years I'd say, you know, back then there were the opium dens"},
#  {'sentence_idx': 1263720,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Yeah Were very particular about lights they I think it was about a hundred feet in the entrance that there were'},
#  {'sentence_idx': 1270166,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'In August 1950 a UIF military school was founded, with about a hundred armed UIF cadres as its first batch.'},
#  {'sentence_idx': 1277074,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "`` Little goose girl , who kept a hundred fat geese in the field , '' said Amy , when Sallie 's invention gave out ."},
#  {'sentence_idx': 1279210,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The historic center of the town is marked by large houses and other buildings, some over a hundred years old, with pitched roofs covered in red clay tile, as well as stone paved streets.'},
#  {'sentence_idx': 1279933,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He then told the court I had better not say she was an angel or no angel or the national press will have a hundred field days.'},
#  {'sentence_idx': 1286025,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The camp had over a hundred wood barracks.'},
#  {'sentence_idx': 1307239,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'We got about a hundred napkins  upstairs .'},
#  {'sentence_idx': 1310308,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'During the next fifteen minutes she looked more like a rose than ever , for everyone availed themselves of their privileges to the fullest extent , from Mr. Laurence to old Hannah , who , adorned with a headdress fearfully and wonderfully made , fell upon her in the hall , crying with a sob and a chuckle , `` Bless you , deary , a hundred times !'},
#  {'sentence_idx': 1313780,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Six weeks is a long time to wait , and a still longer time for a girl to keep a secret , but Jo did both , and was just beginning to give up all hope of ever seeing her manuscript again , when a letter arrived which almost took her breath away , for on opening it , a check for a hundred dollars fell into her lap .'},
#  {'sentence_idx': 1319653,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Ganim also campaigned on a law and order platform, promising to hire a hundred new city police officers to combat crime.'},
#  {'sentence_idx': 1324591,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'As a poet, he has a firm belief that "a hundred ideas and a hundred sentiments" can be expressed "even with a single poetic line."'},
#  {'sentence_idx': 1326937,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'About a hundred and thirty nine return I think.'},
#  {'sentence_idx': 1333493,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I thanked him as well as I could , and talk now about ` my library ' , as if I had a hundred books ."},
#  {'sentence_idx': 1334701,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Here was got a hundred and forty million dollar project.'},
#  {'sentence_idx': 1334951,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "If we'd have put in a price based on A C scaled fees, we would have overspent by a hundred and fifty five percent."},
#  {'sentence_idx': 1337968,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "And what was found was that the new technology didn't produce a hundred percent wonderfulness."},
#  {'sentence_idx': 1339317,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Erm we have twenty people in, in a group and we go around and ask then how much post school technical and professional training they've had, we would come out with an average  group of a total of about a hundred years of post school professional and technical training."},
#  {'sentence_idx': 1342968,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'On the other hand, in West Bengal, more than a hundred Puttsun factories were operating on the Hugli River Cup.'},
#  {'sentence_idx': 1344702,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And now, the English King was here, no more than a hundred yards away.'},
#  {'sentence_idx': 1345253,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"For as long as but a hundred of us remain alive,'},
#  {'sentence_idx': 1358278,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'I come to the table a hundred percent.'},
#  {'sentence_idx': 1358312,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Do you come a hundred percent?'},
#  {'sentence_idx': 1358322,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "You may say, 'I don't know what a hundred percent looks like'."},
#  {'sentence_idx': 1359607,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred ways to make flour look like flowers.'},
#  {'sentence_idx': 1360601,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'In total more than a hundred immigrants stopped eating'},
#  {'sentence_idx': 1363034,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "but when you go easy a hundred seventy at my height, um, I'm five eleven you need just take it easy."},
#  {'sentence_idx': 1367649,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "boy, he doesn't go in and out of the tent a hundred times ."},
#  {'sentence_idx': 1371054,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But Belle still shook her head and watched the smiling face before her with wondering eyes , till the girl added , with sudden color in her cheeks : `` Ah , you 've done so many kind things in your life , you do n't remember the little errand girl from Madame Tifany 's who stole a rose in your hall , and how you gave her rubber boots and cake and flowers , and were so good to her she could n't forget it if she lived to be a hundred . ''"},
#  {'sentence_idx': 1371156,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"Upon a hundred leagues of floor'},
#  {'sentence_idx': 1374344,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'When it starts costing you fifty or a hundred dollars to go to a game'},
#  {'sentence_idx': 1379123,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred yards away the main herd went by, gigantic in the mist.'},
#  {'sentence_idx': 1388774,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "that's what it did report was a hundred and thirty relocating down to McKinney."},
#  {'sentence_idx': 1391028,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'erm a hundred  like erm twenty erm  but Joe'},
#  {'sentence_idx': 1391083,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'reasonable to suppose that he had marched them a hundred and twenty'},
#  {'sentence_idx': 1391098,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'miles just to march them back a hundred and twenty miles?'},
#  {'sentence_idx': 1392136,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "We've got to have more than a hundred lights on the tree otherwise it's not properly lit."},
#  {'sentence_idx': 1392163,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "We haven't got a hundred and twenty and a hundred thirty and last year one of the sets which we've had since we got married  we couldn't them to go no matter what we tried."},
#  {'sentence_idx': 1394432,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'draw them accurately with a hundred and ten thousand Yankees lying'},
#  {'sentence_idx': 1397960,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'my sleep every night for a hundred years!'},
#  {'sentence_idx': 1398753,
#   'DT': 'an',
#   'NUMERAL': 'hundred',
#   'sentence': 'away, McClellan must number an hundred and ten thousand.'},
#  {'sentence_idx': 1400330,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It's a hundred and fifty"},
#  {'sentence_idx': 1401740,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Code in more than a hundred files throughout the system was found to be unlicensed, ambiguously licensed or in use against the terms of the license.'},
#  {'sentence_idx': 1403238,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred times past these six months.'},
#  {'sentence_idx': 1404118,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred years is long enough to prove that success cannot be attained by such means."'},
#  {'sentence_idx': 1411522,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'plateau answered with a hundred-pounder.'},
#  {'sentence_idx': 1413224,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "`` Done it a hundred times , and I 'd just like to show you what I can do ."},
#  {'sentence_idx': 1417060,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': "`` A hundred miles away , and no clue but this man 's story ?"},
#  {'sentence_idx': 1417168,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "You've got a total income coming in, er a total amount of benefit there of a hundred and three pounds thirty  for this family."},
#  {'sentence_idx': 1417744,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': '`` A hundred wiles off ?'},
#  {'sentence_idx': 1419083,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred times I called him a tyrant.'},
#  {'sentence_idx': 1422748,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'He had something like a hundred thousand men.'},
#  {'sentence_idx': 1423503,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Come, smash the altar into a hundred scattered pieces.'},
#  {'sentence_idx': 1424768,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': '"Keyboard" magazine said of the album, "In a hundred years, it could well be studied as the first major electronic work of the new millennium."'},
#  {'sentence_idx': 1431212,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "It's still a hundred gram jar as the same as that."},
#  {'sentence_idx': 1443794,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'And then I do fifty push-ups and do a hundred sit ups'},
#  {'sentence_idx': 1444260,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'I do a hundred then'},
#  {'sentence_idx': 1444264,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'and then I do about a hundred before supper and about a hundred before I go to bed.'},
#  {'sentence_idx': 1444652,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "and during the summer, I'll do, you know, at least seventy-five miles a week and when I really was doing it maybe a hundred and fifty,"},
#  {'sentence_idx': 1446574,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "And even if they cost a hundred, two hundred, five hundred thousand dollars, at, uh, roughly a thousand dollars every half hour, uh, that's ridiculous."},
#  {'sentence_idx': 1446655,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Fifty, a hundred dollars.'},
#  {'sentence_idx': 1452616,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Lord , I 've done more of it than if I 'd had a hundred children of my own , believe ME !"},
#  {'sentence_idx': 1452731,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But she was a hundred years old , and I 'd always promised myself that I 'd go to her funeral . ''"},
#  {'sentence_idx': 1453323,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "She was as foolish when she was a hundred as when she was ten . ''"},
#  {'sentence_idx': 1453376,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I 'd rather live fifty sensible years than a hundred foolish ones . ''"},
#  {'sentence_idx': 1455461,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'If Satya raises his eyes, a hundred girls will be at his feet'},
#  {'sentence_idx': 1456184,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'The woods call to us with a hundred voices , but the sea has one only -- a mighty voice that drowns our souls in its majestic music .'},
#  {'sentence_idx': 1456839,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "actually, if we find something for, uh, I'd say less than a hundred and twenty thousand, we'll be doing all right, you know."},
#  {'sentence_idx': 1467380,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'On looking over a hundred and fifty different lines of'},
#  {'sentence_idx': 1472090,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "`` You 'll see a hundred , '' said Marshall Elliott ."},
#  {'sentence_idx': 1476270,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'They could be a hundred kilometers from here by now.'},
#  {'sentence_idx': 1477256,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "That's where you can smoke and a hundred  and fifty a day !"},
#  {'sentence_idx': 1486626,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'some of them, they used to be a hundred dollars'},
#  {'sentence_idx': 1487002,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "i figure we'll give her a hundred ."},
#  {'sentence_idx': 1487790,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I 've dandled her a hundred times ."},
#  {'sentence_idx': 1490475,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'memory of more than a hundred men who had been lost in a September gale'},
#  {'sentence_idx': 1491096,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Gonzales masterminded the theft of over a hundred million credit card and ATM numbers, the largest such fraud in history.'},
#  {'sentence_idx': 1491338,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "But when Aaron writes a script that says download download download, a hundred times in a second, there's no obvious damage to anybody."},
#  {'sentence_idx': 1491535,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Anne pleased herself with a hundred fancies as she wandered through the mist .'},
#  {'sentence_idx': 1495701,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'There was like a hundred representative swing.'},
#  {'sentence_idx': 1498448,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "looked death in the face a hundred times, that foolhardiness doesn't"},
#  {'sentence_idx': 1499772,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred grand.'},
#  {'sentence_idx': 1500625,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': 'A hundred and forty five sixty two?'},
#  {'sentence_idx': 1503199,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "Now what I'm really looking at there is that our basic trade stand space i is about a hundred pound."},
#  {'sentence_idx': 1503294,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I don't know, if I had been born a hundred years ago and were looking at this time, I might not like it,"},
#  {'sentence_idx': 1506263,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "I was gonna ask you to pay a hundred but I'll talk about that."},
#  {'sentence_idx': 1506360,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'Sorry I I thought I thought you quoted a price of a hundred and said that'},
#  {'sentence_idx': 1506364,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "No I said  space is a hundred pound and we'll give you twice that size for that."},
#  {'sentence_idx': 1508145,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "clearing a hundred miles from home and I'd match 'em man for man with"},
#  {'sentence_idx': 1512322,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'bitterly, “without dragging me away into the woods fifty or a hundred'},
#  {'sentence_idx': 1517982,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "“But I'll bet you a hundred dollars to a toothpick you never knew what"},
#  {'sentence_idx': 1521936,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': 'First of all British troops have been in in Northern Ireland for a hundred and ninety five years since eighteen hundred.'},
#  {'sentence_idx': 1523283,
#   'DT': 'A',
#   'NUMERAL': 'hundred',
#   'sentence': "A hundred men were ranged on the long benches called “deacons' seats,”"},
#  {'sentence_idx': 1523802,
#   'DT': 'a',
#   'NUMERAL': 'hundred',
#   'sentence': "turn over the page to page six  paragraph eight, item D eight D  strategy, the figure's is a hundred and six and it should be one, five, six"},
#  ...]

# %%
adj_and_num_ids = [f['sentence_idx'] for f in flattened_adjs] + [f['sentence_idx'] for f in flattened_nums]

adjs_to_remove = [entry for entry in aadjs if entry['sentence_idx'] not in adj_and_num_ids]

# %%
len(adjs_to_remove)
# Out:
# 568876

# %%
adjs_and_nums = [entry for entry in aadjs if entry['sentence_idx'] in adj_and_num_ids]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 adjs_and_nums = [entry for entry in aadjs if entry['sentence_idx'] in adj_and_num_ids]
#
# Cell In[27], line 1, in <listcomp>(.0)
# ----> 1 adjs_and_nums = [entry for entry in aadjs if entry['sentence_idx'] in adj_and_num_ids]
#
# KeyboardInterrupt:

# %%
adj_and_num_ids
# Out:
# [10668887,
#  1536384,
#  311290,
#  4508480,
#  3917794,
#  3478885,
#  2050852,
#  1371143,
#  11354072,
#  8976860,
#  1131128,
#  9823550,
#  6911535,
#  388992,
#  366230,
#  1228590,
#  3360993,
#  3672108,
#  8231332,
#  10014696,
#  324419,
#  9263961,
#  3039296,
#  10868707,
#  8970657,
#  6864068,
#  3405926,
#  7341510,
#  9805990,
#  4566974,
#  83904,
#  2387555,
#  6933596,
#  5684478,
#  4561161,
#  2316618,
#  3304691,
#  5620320,
#  1366545,
#  1219858,
#  6288060,
#  1273372,
#  5988051,
#  5742114,
#  10051511,
#  4318650,
#  541334,
#  7485779,
#  8800638,
#  1782899,
#  6270636,
#  1005724,
#  9112073,
#  4828642,
#  10445835,
#  10274753,
#  6024060,
#  9575167,
#  2967488,
#  892553,
#  577391,
#  11048564,
#  3569146,
#  4762936,
#  1015656,
#  3673795,
#  1343423,
#  6291430,
#  4563521,
#  7402234,
#  10597350,
#  6064645,
#  2458119,
#  6140560,
#  5928161,
#  3193764,
#  11208749,
#  4373140,
#  11460367,
#  10823974,
#  914030,
#  10125240,
#  10583089,
#  2618666,
#  8758961,
#  3914538,
#  2471783,
#  7533804,
#  6281111,
#  4428315,
#  10677987,
#  11533597,
#  9180875,
#  3380596,
#  11476494,
#  5413774,
#  725699,
#  3599743,
#  392415,
#  5253173,
#  6597590,
#  4394167,
#  855610,
#  3220838,
#  9382945,
#  5243317,
#  3248511,
#  10946792,
#  8111935,
#  6525059,
#  10725733,
#  7476564,
#  2111674,
#  4327096,
#  2051896,
#  3952138,
#  9264328,
#  8848404,
#  4282657,
#  9721661,
#  7035292,
#  9692580,
#  6574842,
#  6028692,
#  3375250,
#  2025286,
#  8300946,
#  8018311,
#  1199440,
#  593531,
#  1505089,
#  2284340,
#  10426635,
#  2391344,
#  11417545,
#  6916437,
#  9921721,
#  824156,
#  6378145,
#  6322589,
#  9911592,
#  7608184,
#  8660600,
#  4044853,
#  9125123,
#  137549,
#  11414380,
#  1593179,
#  11436140,
#  8816136,
#  4369236,
#  10696140,
#  5684012,
#  1544076,
#  4838127,
#  7135137,
#  2362054,
#  7406688,
#  46510,
#  4294548,
#  8140914,
#  2763109,
#  8268126,
#  1438735,
#  10385609,
#  4943895,
#  10656476,
#  8267922,
#  10123305,
#  3039834,
#  6195059,
#  2433346,
#  8860168,
#  8683875,
#  10436,
#  9957529,
#  5411025,
#  7919884,
#  232191,
#  1550056,
#  6039577,
#  5121653,
#  3796558,
#  748704,
#  3826654,
#  9386485,
#  1005229,
#  1109783,
#  7882014,
#  890028,
#  8731069,
#  1806553,
#  1861801,
#  11016644,
#  7693353,
#  9068607,
#  2501543,
#  4330983,
#  8625868,
#  10089653,
#  6940980,
#  3233012,
#  8857968,
#  11572197,
#  3070190,
#  5192724,
#  6567947,
#  11238325,
#  6190152,
#  7183384,
#  8447760,
#  7366325,
#  1714621,
#  3981656,
#  3520252,
#  830666,
#  5644262,
#  251440,
#  9789630,
#  9134610,
#  3623783,
#  9790409,
#  3396336,
#  93856,
#  909595,
#  10499270,
#  761138,
#  3597046,
#  869303,
#  384133,
#  5516477,
#  908583,
#  8389553,
#  3765263,
#  4574072,
#  11195770,
#  7865013,
#  3284154,
#  8857103,
#  1929629,
#  9453038,
#  9553549,
#  7659230,
#  3871622,
#  7664634,
#  6672305,
#  2936618,
#  1236658,
#  1274924,
#  11003811,
#  7069444,
#  5917018,
#  6948681,
#  6737782,
#  7596944,
#  705348,
#  11281675,
#  10919794,
#  10788502,
#  1297290,
#  783810,
#  6613267,
#  5670536,
#  1499168,
#  3991148,
#  2956016,
#  2934570,
#  8801469,
#  7332134,
#  2063033,
#  6910337,
#  2841265,
#  4577098,
#  7538497,
#  4016793,
#  956522,
#  7255368,
#  9081451,
#  1288917,
#  648843,
#  10908583,
#  8879730,
#  174743,
#  1224682,
#  3735080,
#  2526215,
#  6660048,
#  7870032,
#  7802493,
#  3275004,
#  6595956,
#  756210,
#  2493610,
#  6275912,
#  36266,
#  6466914,
#  4334558,
#  7427409,
#  4708863,
#  6939690,
#  9164077,
#  11057402,
#  7890251,
#  2307728,
#  2929632,
#  4912140,
#  3343474,
#  754469,
#  9601056,
#  8908963,
#  788947,
#  5227134,
#  741551,
#  642372,
#  9708839,
#  7713222,
#  8180980,
#  8699096,
#  2351271,
#  738603,
#  8269644,
#  1020530,
#  2880461,
#  882921,
#  9898954,
#  877174,
#  11325074,
#  3720895,
#  6623255,
#  1692261,
#  9432709,
#  3944019,
#  9596403,
#  9890921,
#  482473,
#  10286071,
#  1048492,
#  6857456,
#  10982717,
#  9695137,
#  9340728,
#  8530859,
#  5264450,
#  4241838,
#  3116779,
#  11204404,
#  5235702,
#  3778284,
#  4346034,
#  6527074,
#  1912018,
#  10773960,
#  4975095,
#  7455649,
#  5260644,
#  927000,
#  117520,
#  7470348,
#  10311630,
#  9295410,
#  1323194,
#  932118,
#  8828035,
#  3261567,
#  8238724,
#  1931418,
#  5834178,
#  885197,
#  3901995,
#  6132140,
#  4704314,
#  2354525,
#  7184187,
#  8939165,
#  5023079,
#  10158744,
#  10922610,
#  8655246,
#  101433,
#  11170435,
#  9150323,
#  4962310,
#  11087264,
#  1391133,
#  1960129,
#  4317635,
#  1610010,
#  1453133,
#  2316287,
#  4463586,
#  4641301,
#  10063561,
#  3216247,
#  5721293,
#  3111786,
#  11520470,
#  10571447,
#  4307738,
#  8232524,
#  7919200,
#  4040671,
#  652905,
#  1216045,
#  10571673,
#  4542978,
#  550322,
#  50166,
#  5564257,
#  1911317,
#  10625633,
#  4266355,
#  2433771,
#  7240291,
#  9105165,
#  7023592,
#  9259376,
#  120365,
#  954333,
#  11593548,
#  2231607,
#  8984184,
#  440666,
#  6129117,
#  9669094,
#  9117945,
#  2214076,
#  7055441,
#  1839309,
#  516258,
#  5134185,
#  6062564,
#  483652,
#  5969929,
#  3205907,
#  11442963,
#  4012038,
#  11148387,
#  1375715,
#  5904244,
#  9237148,
#  6659711,
#  10306805,
#  2305141,
#  3739012,
#  2454118,
#  2734234,
#  6756148,
#  306542,
#  2774644,
#  5546744,
#  6747954,
#  11205968,
#  3986157,
#  4369195,
#  2378585,
#  1478672,
#  6339271,
#  471990,
#  7639546,
#  3460870,
#  3046747,
#  7500328,
#  5845077,
#  5084490,
#  3563504,
#  3472285,
#  292170,
#  11022309,
#  2980351,
#  6559958,
#  5488744,
#  4577833,
#  891686,
#  4596404,
#  5864289,
#  10703546,
#  8296290,
#  6578842,
#  11404210,
#  8800470,
#  5526067,
#  337329,
#  1608372,
#  4251352,
#  2761971,
#  9629375,
#  4342009,
#  466349,
#  1483664,
#  9923503,
#  7131840,
#  5774872,
#  5227611,
#  7160669,
#  10083086,
#  8334232,
#  1612633,
#  6389277,
#  9563541,
#  2932884,
#  4116173,
#  555263,
#  7152972,
#  32131,
#  8487251,
#  8836701,
#  11510276,
#  11218314,
#  3022525,
#  6058737,
#  7071589,
#  899093,
#  11104731,
#  5512967,
#  10341848,
#  5231726,
#  1779384,
#  4979753,
#  8259086,
#  5149205,
#  11147921,
#  6699877,
#  5454024,
#  6609924,
#  4891011,
#  9146611,
#  1835894,
#  2960635,
#  6882702,
#  11118459,
#  6277619,
#  11360595,
#  2670795,
#  10222558,
#  9418365,
#  4988218,
#  6654268,
#  9036721,
#  4896,
#  5046688,
#  4731692,
#  3208832,
#  7055996,
#  9611339,
#  10090395,
#  10936252,
#  5373536,
#  7580441,
#  7236213,
#  7242109,
#  11330215,
#  3273949,
#  8330003,
#  7666096,
#  2592931,
#  11002258,
#  1098182,
#  4678464,
#  8411341,
#  11098727,
#  10533076,
#  10284318,
#  5592838,
#  1225805,
#  3719866,
#  11271842,
#  5169357,
#  3518655,
#  3042523,
#  2201892,
#  300568,
#  580951,
#  3916563,
#  7690690,
#  10152899,
#  928860,
#  7434066,
#  6795774,
#  10467668,
#  9545549,
#  2993522,
#  6367399,
#  8024714,
#  6578716,
#  3893468,
#  2205828,
#  10963353,
#  11522283,
#  73543,
#  1441121,
#  6973434,
#  3366609,
#  2708897,
#  8453867,
#  7570387,
#  643097,
#  9189959,
#  4005513,
#  1720221,
#  7449368,
#  1944630,
#  7571095,
#  11164528,
#  8699114,
#  9222283,
#  9903753,
#  5281258,
#  7248295,
#  10171276,
#  8217143,
#  7002964,
#  9032860,
#  7292449,
#  2377825,
#  7687143,
#  7350408,
#  4210193,
#  3965354,
#  10636904,
#  4549571,
#  8505885,
#  7853480,
#  10417463,
#  3791156,
#  4499013,
#  7206693,
#  990231,
#  4715264,
#  3714753,
#  4456886,
#  5605197,
#  5337705,
#  8875559,
#  1025625,
#  2026754,
#  2252537,
#  3645478,
#  6349139,
#  2284105,
#  3277604,
#  832065,
#  6805215,
#  6681959,
#  5521037,
#  8921271,
#  7588593,
#  6818555,
#  806463,
#  3142641,
#  6876474,
#  6453745,
#  9706682,
#  232450,
#  9545636,
#  6296147,
#  7721611,
#  77356,
#  5872383,
#  4948598,
#  6461221,
#  6851798,
#  8834074,
#  8997943,
#  10040211,
#  3408522,
#  7910198,
#  3377045,
#  4471300,
#  7149729,
#  7870778,
#  358906,
#  6442443,
#  5610260,
#  11193459,
#  11400589,
#  6632773,
#  2500941,
#  7601434,
#  1842220,
#  10332551,
#  8758681,
#  329483,
#  6510072,
#  9847621,
#  9321249,
#  11076796,
#  331126,
#  1080216,
#  10723924,
#  7038077,
#  1975883,
#  7522984,
#  2809168,
#  643470,
#  4229804,
#  6277200,
#  5474217,
#  3230771,
#  7422786,
#  5464870,
#  5634389,
#  6277444,
#  4568782,
#  6904454,
#  4069881,
#  1047488,
#  7635102,
#  231805,
#  8860954,
#  671363,
#  5847665,
#  3508078,
#  10873962,
#  883800,
#  10902216,
#  488387,
#  378428,
#  3966403,
#  3044510,
#  244609,
#  10314206,
#  2277441,
#  3777119,
#  1816525,
#  7669039,
#  11202662,
#  1591171,
#  9315828,
#  3350021,
#  7580479,
#  4144994,
#  6125563,
#  2551358,
#  10078420,
#  10094077,
#  1593040,
#  2478490,
#  5181619,
#  9589501,
#  318151,
#  5197119,
#  9547012,
#  11360824,
#  6221586,
#  6535064,
#  3034849,
#  962892,
#  9851039,
#  11583324,
#  10422724,
#  3869289,
#  1359782,
#  5003073,
#  11468981,
#  9982426,
#  1715089,
#  9354504,
#  504898,
#  5797497,
#  8731637,
#  7034275,
#  11053958,
#  6144180,
#  887132,
#  8239584,
#  10811914,
#  5700173,
#  151150,
#  6873675,
#  7955341,
#  1425821,
#  7118877,
#  6030410,
#  10594376,
#  7491054,
#  2284955,
#  7143603,
#  2713667,
#  8512326,
#  10878776,
#  4429936,
#  10229230,
#  8833547,
#  7834381,
#  7576403,
#  7144771,
#  9856215,
#  4403844,
#  5375733,
#  3929366,
#  1126869,
#  4591666,
#  7360016,
#  3888795,
#  7572289,
#  9435872,
#  10141779,
#  11178535,
#  6275921,
#  5616321,
#  351942,
#  8024020,
#  5426026,
#  2810416,
#  7902006,
#  3237461,
#  5924483,
#  4189769,
#  5685657,
#  4610790,
#  9917687,
#  4534751,
#  9164747,
#  125245,
#  8434162,
#  2946949,
#  1109420,
#  3837332,
#  6660066,
#  7919695,
#  9156369,
#  3818544,
#  11581994,
#  7706772,
#  10782801,
#  7968205,
#  7325223,
#  202272,
#  1222636,
#  4858801,
#  3435701,
#  6633594,
#  11609329,
#  3876931,
#  5101886,
#  11100187,
#  9645947,
#  6127037,
#  7667181,
#  9128764,
#  8695895,
#  5736371,
#  6983001,
#  9082439,
#  5520345,
#  5873031,
#  7406692,
#  4444038,
#  5106554,
#  4044775,
#  3629331,
#  1708755,
#  2971825,
#  5253985,
#  1687931,
#  8795056,
#  11578674,
#  2870734,
#  2954712,
#  3317457,
#  7846534,
#  4539102,
#  9811168,
#  8574108,
#  9924802,
#  4665652,
#  1335964,
#  2990421,
#  4900739,
#  3561035,
#  6011946,
#  2776241,
#  5018493,
#  168390,
#  1824229,
#  4493954,
#  573751,
#  707801,
#  9126431,
#  4810041,
#  1817023,
#  10641349,
#  7969440,
#  1372278,
#  145278,
#  9515573,
#  4688490,
#  7621096,
#  7753054,
#  7214398,
#  5692192,
#  2857830,
#  661732,
#  4076498,
#  7735897,
#  1583485,
#  843342,
#  6591904,
#  7986056,
#  940870,
#  9570586,
#  10462939,
#  11504096,
#  693155,
#  2270504,
#  2233038,
#  9294529,
#  5046123,
#  1103969,
#  3987537,
#  1669114,
#  9199175,
#  6825450,
#  10084322,
#  9916234,
#  10273356,
#  3534078,
#  8528169,
#  7356451,
#  7251604,
#  4924552,
#  9791942,
#  7043906,
#  5088653,
#  9409080,
#  10309556,
#  779826,
#  10132673,
#  1309596,
#  3154951,
#  10392580,
#  3221152,
#  4319622,
#  11027394,
#  1033315,
#  2343167,
#  3806286,
#  2667403,
#  9111327,
#  950654,
#  2333137,
#  41269,
#  6701512,
#  11561362,
#  9878636,
#  7629904,
#  4791056,
#  400041,
#  3647691,
#  4743733,
#  4662345,
#  7411887,
#  912146,
#  11518877,
#  3687041,
#  4319072,
#  10381759,
#  9812990,
#  11046455,
#  3031060,
#  6973197,
#  1597576,
#  8965927,
#  3522906,
#  10813875,
#  2230883,
#  4346505,
#  2098681,
#  773173,
#  2514996,
#  5122620,
#  9422510,
#  4749293,
#  7195777,
#  1771184,
#  7616807,
#  11540897,
#  5050714,
#  6611881,
#  4461962,
#  8138828,
#  8874312,
#  8020342,
#  7179243,
#  1023587,
#  9944011,
#  483171,
#  7089180,
#  5376203,
#  10051501,
#  4024805,
#  319453,
#  1203850,
#  3596862,
#  11307989,
#  9538298,
#  9766355,
#  247359,
#  11254858,
#  4419805,
#  ...]

# %%
# import pandas as pd

# adjs_to_remove_df = pd.DataFramae(adjs_to_remove)

# adjs_to_remove_df.to_csv("../data/babylm-analysis/adjs_to_remove.csv", index=False)

# %%
adjs_to_remove_df
# Out:
#         sentence_idx  DT     ADJ  \
# 0                  6   a  single
# 1                 39   a  little
# 2                 46  an     old
# 3                 50   a  little
# 4                 75   a     few
# ...              ...  ..     ...
# 568871      11632367   A   FIRST
# 568872      11632408   A  PRETTY
# 568873      11632441   A    NICE
# 568874      11632442   A    NICE
# 568875      11632517   A    NICE
#
#                                                  sentence
# 0       This is because with this method you remain on...
# 1       So you kind of have to, a little bit, coddle t...
# 2       Watergate hearings, when he'd go, well, I'll j...
# 3       And so what we fraudsters do is we act a littl...
# 4       Out of a few hundred million dollars worth of ...
# ...                                                   ...
# 568871                              THIS MUST BE A FIRST.
# 568872   THESE PHOTOGRAPHS GIVE A PRETTY GRAPHIC PICTURE.
# 568873                            HE'S A NICE GUY, DAVID.
# 568874                            I KNOW HE'S A NICE GUY.
# 568875                            I HAD A NICE TIME, TOO!
#
# [568876 rows x 4 columns]

# %%
# import pandas as pd

# num_df = pd.DataFrame(flattened_nums)
# adj_df = pd.DataFrame(flattened_adjs)

# num_df.to_csv("../data/babylm-analysis/a_nums.csv", index=False)
# adj_df.to_csv("../data/babylm-analysis/a_adjs.csv", index=False)
# Out:
#        sentence_idx DT  NUMERAL  \
# 0              5359  a  hundred
# 1              8208  a  hundred
# 2              9551  a  hundred
# 3             13369  a  hundred
# 4             13783  a  hundred
# ...             ... ..      ...
# 42106      11518920  a   452.1C
# 42107      11561237  a     42.9
# 42108      11596406  a    1920s
# 42109      11620232  A      289
# 42110      11620583  a      337
#
#                                                 sentence
# 0      a hundred projects that will disappear in thre...
# 1      Jerry is on his way to Tokyo to check them out...
# 2                      I support that a hundred percent.
# 3      Jerry is on his way to Tokyo to check them out...
# 4      Erm the first thing I'm,I I would like t t to ...
# ...                                                  ...
# 42106  In fact, if Chief Pope were to identify these ...
# 42107            Dancing with a 42.9 degree temperature?
# 42108  Her new book included a 1920s essay about an I...
# 42109         A 289 with dual carbs and a pony interior.
# 42110  As some of you know... a 337 model E.E.V... cr...
#
# [42111 rows x 4 columns]

# %%
adjnums
# Out:
# [{'sentence_idx': 75,
#   'ADJ': 'few',
#   'NUMERAL': 'hundred',
#   'sentence': "Out of a few hundred million dollars worth of checks that were written, the auditors never saw one canceled cashier's check."},
#  {'sentence_idx': 241,
#   'ADJ': 'obvious',
#   'NUMERAL': 'one',
#   'sentence': 'Let me just state one super obvious one.'},
#  {'sentence_idx': 247,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': "The last two reasons I'm going to give you might sound a little flipping but, you know, I, I think there is more than a grain of truth to both of them."},
#  {'sentence_idx': 286,
#   'ADJ': 'final',
#   'NUMERAL': 'two',
#   'sentence': 'And you compute the final two partial products using the two and the one.'},
#  {'sentence_idx': 341,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'The first two digits of the four in x.'},
#  {'sentence_idx': 342,
#   'ADJ': 'other',
#   'NUMERAL': 'two',
#   'sentence': 'And then b would be the other two digits.'},
#  {'sentence_idx': 384,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'So, to be more specific, our first two recursive calls are shared with the previous recursive algorithm.'},
#  {'sentence_idx': 388,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': "And here is Gauss's trick for observation which is that the result of the third recursive call minus each of the first two, what happens?"},
#  {'sentence_idx': 884,
#   'ADJ': 'smaller',
#   'NUMERAL': 'three',
#   'sentence': "We haven't started that yet but it will more of a smaller three to four people one on one with the teacher."},
#  {'sentence_idx': 1427,
#   'ADJ': 'last',
#   'NUMERAL': 'eight',
#   'sentence': 'Under my administration, America is producing more oil today than at any time in the last eight years -- at any time.'},
#  {'sentence_idx': 1430,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': "Over the last three years, we've opened millions of acres of land in 23 different states for oil and gas exploration."},
#  {'sentence_idx': 1441,
#   'ADJ': 'last',
#   'NUMERAL': 'eight',
#   'sentence': 'We are producing more oil than any time in the last eight years.'},
#  {'sentence_idx': 1731,
#   'ADJ': 'negative',
#   'NUMERAL': '24',
#   'sentence': 'Z must then be negative 24.'},
#  {'sentence_idx': 1732,
#   'ADJ': 'negative',
#   'NUMERAL': '24',
#   'sentence': 'So the answer is 10, 13, negative 24.'},
#  {'sentence_idx': 3810,
#   'ADJ': 'last',
#   'NUMERAL': '2',
#   'sentence': "In the last 2 days, i-I've been mugged,"},
#  {'sentence_idx': 4892,
#   'ADJ': 'first',
#   'NUMERAL': 'three',
#   'sentence': "- you'll find that they're the first three chords you learn"},
#  {'sentence_idx': 5787,
#   'ADJ': 'juicy',
#   'NUMERAL': 'one',
#   'sentence': "Had this been a small fly or a beetle, she wouldn't have stayed, but she approves of this large, juicy one and, as she feasts on it, she allows the male to mate."},
#  {'sentence_idx': 6444,
#   'ADJ': 'best',
#   'NUMERAL': 'one',
#   'sentence': "But that's the best one among the many I've seen."},
#  {'sentence_idx': 6546,
#   'ADJ': 'other',
#   'NUMERAL': 'three',
#   'sentence': 'Where are the other three, cheapskate?'},
#  {'sentence_idx': 6572,
#   'ADJ': 'Central',
#   'NUMERAL': '24',
#   'sentence': 'Central 24 hours a day.'},
#  {'sentence_idx': 6998,
#   'ADJ': 'last',
#   'NUMERAL': 'eighteen',
#   'sentence': 'staff salaries have gone down over the last eighteen months'},
#  {'sentence_idx': 8214,
#   'ADJ': 'late',
#   'NUMERAL': '1941',
#   'sentence': 'In late 1941, Nebe was posted back to Berlin and resumed his career within the RSHA.'},
#  {'sentence_idx': 8342,
#   'ADJ': 'early',
#   'NUMERAL': '1932',
#   'sentence': 'In early 1932, Nebe and other Nazi detectives formed the NS (National Socialist) Civil Service Society of the Berlin Police.'},
#  {'sentence_idx': 8473,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'There was a dramatic increase in atrocities against Jews and other civilians in the last three months of 1941.'},
#  {'sentence_idx': 8713,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': "That is because of the way we've behaved over the last two years."},
#  {'sentence_idx': 9072,
#   'ADJ': 'last',
#   'NUMERAL': '32',
#   'sentence': 'In his second professional season he reached the last 32 or better in four tournaments, and a year later he reached the last 16 of the World Championship on his Crucible debut, to reach the top 32 of the rankings.'},
#  {'sentence_idx': 9075,
#   'ADJ': 'top',
#   'NUMERAL': '16',
#   'sentence': 'A year later he reached the top 16, despite not reaching a quarter-final in that season.'},
#  {'sentence_idx': 9084,
#   'ADJ': 'last',
#   'NUMERAL': '16',
#   'sentence': 'A run to the last 16 of the China Open was the highlight of Roe’s 2005/2006 season.'},
#  {'sentence_idx': 9086,
#   'ADJ': 'solid',
#   'NUMERAL': '2007/2008',
#   'sentence': 'In 2006/2007 his best were two last-32 runs, and another followed at the 2008 Welsh Open, the highlight of a solid 2007/2008 season.'},
#  {'sentence_idx': 9088,
#   'ADJ': 'low',
#   'NUMERAL': 'one',
#   'sentence': '62 in the rankings, carrying a very low one-year total of 4320 into 2009/2010.'},
#  {'sentence_idx': 9361,
#   'ADJ': 'last',
#   'NUMERAL': 'six',
#   'sentence': 'In the last few decades, but accentuating in the last six to eight years'},
#  {'sentence_idx': 9412,
#   'ADJ': 'last',
#   'NUMERAL': '35',
#   'sentence': 'In this country, we have seen imports increase from 5 percent of GDP to, what, 17 percent or so of GDP in the last 35 or so years'},
#  {'sentence_idx': 9423,
#   'ADJ': 'Yellow',
#   'NUMERAL': 'one',
#   'sentence': 'Yellow one.'},
#  {'sentence_idx': 9449,
#   'ADJ': 'early',
#   'NUMERAL': '1988',
#   'sentence': 'In early 1988, Warrior entered into his first real WWF feud with fellow strongman Hercules Hernandez.'},
#  {'sentence_idx': 9721,
#   'ADJ': 'inspirational',
#   'NUMERAL': '6×9',
#   'sentence': 'In 2012, he started selling "Weapons of Wisdom", inspirational 6×9 pieces of watercolor paper with drawings, quotes, and doodles on them by the Warrior himself.'},
#  {'sentence_idx': 10480,
#   'ADJ': 'top',
#   'NUMERAL': '64',
#   'sentence': 'These are the Snooker world rankings of 1994–1995: The professional world rankings for the top 64 snooker players in the 1994–1995 season are listed below.'},
#  {'sentence_idx': 10524,
#   'ADJ': 'closest',
#   'NUMERAL': '68,000',
#   'sentence': 'He also published the book "The Nearby Galaxies Catalog" in 1988 with 3D locations for the closest 68,000 galaxies to Earth.'},
#  {'sentence_idx': 10693,
#   'ADJ': 'late',
#   'NUMERAL': '1980s',
#   'sentence': 'Beginning in the late 1980s, it crossed over into civilian life, being embraced first by mostly young black males (see hi-top fade), then spread to other groups.'},
#  {'sentence_idx': 11143,
#   'ADJ': 'top',
#   'NUMERAL': '64',
#   'sentence': 'Snooker world rankings 1993/1994: The professional world rankings for the top 64 snooker players in the 1993/1994 season are listed below.'},
#  {'sentence_idx': 11259,
#   'ADJ': '-',
#   'NUMERAL': 'zero',
#   'sentence': 'Then there was another train of logic that we already learned, that any non-zero number--'},
#  {'sentence_idx': 11341,
#   'ADJ': 'top',
#   'NUMERAL': '32',
#   'sentence': 'Snooker world rankings 1992/1993: The professional world rankings for the top 32 snooker players and two others from the top 64 in the 1992/1993 season are listed below.'},
#  {'sentence_idx': 11346,
#   'ADJ': '-',
#   'NUMERAL': 'zero',
#   'sentence': 'So zero to any non-zero number, you are going to get zero.'},
#  {'sentence_idx': 11371,
#   'ADJ': 'first',
#   'NUMERAL': 'nineteen',
#   'sentence': 'The film happens in the last quarter of the 19th century and the first nineteen years of the twentieth, during the dictatorship of Porfirio Díaz, the presidency of Francisco I. Madero, the military revolt of Victoriano Huerta, the Convention of Generals and, finally, the death of Zapata, already in the constitutionalist stage of Venustiano Carranza.'},
#  {'sentence_idx': 11579,
#   'ADJ': 'other',
#   'NUMERAL': '9',
#   'sentence': "The district is nearly 4 times as large as the other 9 districts of Suriname combined; however, most of the Sipaliwini is unused (it was specifically stated when the district was formed that it would encompass the unused land in Suriname's south) except for the north and the west."},
#  {'sentence_idx': 11870,
#   'ADJ': 'first',
#   'NUMERAL': 'three',
#   'sentence': 'Magrs\' first three novels, "Marked for Life", "Does It Show?"'},
#  {'sentence_idx': 12251,
#   'ADJ': 'Top',
#   'NUMERAL': '10',
#   'sentence': 'According to "Forbes", in less than two months from the launch date, xoJane.com established itself as one of the "Top 10 Lifestyle Websites for Women."'},
#  {'sentence_idx': 12471,
#   'ADJ': 'past',
#   'NUMERAL': 'four',
#   'sentence': "well we've been trying to think how we could get the best out of Colin for the past four bloody years."},
#  {'sentence_idx': 12820,
#   'ADJ': 'top',
#   'NUMERAL': '64',
#   'sentence': 'Snooker world rankings 1991/1992: The professional world rankings for the top 64 snooker players in the 1991/1992 season are listed below.'},
#  {'sentence_idx': 12856,
#   'ADJ': 'further',
#   'NUMERAL': 'two',
#   'sentence': 'Kealy and other members of the team took up positions behind the sand-bag parapet on the roof of the BATT house, firing at the Adoo with L1A1 SLR battle rifles, with one man firing the Browning M2HB heavy machine gun, with a further two men on ground level operating and firing an infantry mortar surrounded by sand-bags.'},
#  {'sentence_idx': 12982,
#   'ADJ': 'early',
#   'NUMERAL': '1980s',
#   'sentence': 'The son of snooker professional Geoff Foulds, he began playing the game at the age of 11 and by the early 1980s was already one of the strongest players in his area.'},
#  {'sentence_idx': 12988,
#   'ADJ': 'last',
#   'NUMERAL': '16',
#   'sentence': 'Even more impressively however, he then defeated twice-champion Alex Higgins 10–9 in the first round before going down 13–9 to Doug Mountjoy in the last 16, a run that saw him enter the rankings at number 30.'},
#  {'sentence_idx': 13020,
#   'ADJ': 'aged',
#   'NUMERAL': '39',
#   'sentence': 'Though he was able to maintain a top 16 place until the end of the 1993/4 season, and a place on the tour until 2003, he played his final match as a Main Tour player on 13 January 2003 before retiring from competitive play aged 39.'},
#  {'sentence_idx': 13026,
#   'ADJ': 'aged',
#   'NUMERAL': '48',
#   'sentence': "Foulds made a brief reappearance as a player in November 2011 in the World Seniors (aged 48) before eventually losing to Dene O'Kane."},
#  {'sentence_idx': 13158,
#   'ADJ': 'late',
#   'NUMERAL': '1980s',
#   'sentence': 'Operation Spanner was a police investigation into same-sex male sadomasochism across the United Kingdom in the late 1980s.'},
#  {'sentence_idx': 13206,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'Over the next two years, 13 officers were jailed, earning the Obscene Publications Squad its nickname: The Dirty Squad.'},
#  {'sentence_idx': 13252,
#   'ADJ': 'unsolved',
#   'NUMERAL': '1985',
#   'sentence': 'An officer with Greater Manchester Police denied that the operation was related to snuff films but went on to falsely speculate that the investigation may be connected to an unsolved 1985 murder in Leeds.'},
#  {'sentence_idx': 13344,
#   'ADJ': 'last',
#   'NUMERAL': '20',
#   'sentence': 'Responding to a Home Office report which failed to find any link between pornography and sexual violence, Hames wrote that "everything I have learned [...] over the last 20 years tells me the opposite".'},
#  {'sentence_idx': 13717,
#   'ADJ': 'late',
#   'NUMERAL': '2005',
#   'sentence': 'In late 2005, a Canadian activist named Sarvy Emo proposed that March 28 be designated Parental Alienation Awareness Day.'},
#  {'sentence_idx': 13867,
#   'ADJ': 'aged',
#   'NUMERAL': '22',
#   'sentence': 'Johnson attended the University of Nottingham, where he qualified as a civil engineer, aged 22.'},
#  {'sentence_idx': 13913,
#   'ADJ': 'several',
#   'NUMERAL': 'hundred',
#   'sentence': 'Johnson and several hundred others were entrained for Cambridge and the 2 initial Training Wing.'},
#  {'sentence_idx': 13930,
#   'ADJ': 'past',
#   'NUMERAL': 'three',
#   'sentence': "That is because we've given them good service over the past three years."},
#  {'sentence_idx': 13993,
#   'ADJ': 'early',
#   'NUMERAL': '1941',
#   'sentence': 'Johnson returned to operational flying in early 1941 in 616 Squadron, which was forming part of the Tangmere Wing.'},
#  {'sentence_idx': 14041,
#   'ADJ': 'few',
#   'NUMERAL': 'hundred',
#   'sentence': 'Johnson spotted three Bf 109s a few hundred feet higher and travelling in the same direction.'},
#  {'sentence_idx': 14166,
#   'ADJ': 'other',
#   'NUMERAL': 'two',
#   'sentence': 'Suspecting it to be one of the three that had chased him, he searched for the other two.'},
#  {'sentence_idx': 14319,
#   'ADJ': 'busy',
#   'NUMERAL': 'one',
#   'sentence': 'The spring proved to be a busy one; Johnson claimed three Fw 190s damaged two days later.'},
#  {'sentence_idx': 14321,
#   'ADJ': 'further',
#   'NUMERAL': 'five',
#   'sentence': 'A further five victories against Fw 190s were achieved in June.'},
#  {'sentence_idx': 14504,
#   'ADJ': 'other',
#   'NUMERAL': 'four',
#   'sentence': 'Er I think tha that we need to look at  why there is such a significant difference in profitability, between the bridge and P Way, who are making what would appear to be a reasonable amount, er and the other four sections.'},
#  {'sentence_idx': 14557,
#   'ADJ': 'aged',
#   'NUMERAL': '85',
#   'sentence': 'On 30 January 2001, Johnson, aged 85 years, died from cancer.'},
#  {'sentence_idx': 14571,
#   'ADJ': 'further',
#   'NUMERAL': 'seven',
#   'sentence': "Johnson's wartime record was 515 sorties flown, 34 aircraft claimed destroyed with a further seven shared destroyed (three and one shared victories), three probable destroyed, 10 damaged, and one shared, destroyed on the ground."},
#  {'sentence_idx': 14685,
#   'ADJ': 'other',
#   'NUMERAL': '3',
#   'sentence': 'The vertex subset reached by both searches forms a strongly connected components, and the algorithm then recurses on the other 3 subsets.'},
#  {'sentence_idx': 14794,
#   'ADJ': 'first',
#   'NUMERAL': 'ten',
#   'sentence': 'In November 1930, the first issue of "Dance Gazette" was published containing a historical review of the Association\'s first ten years.'},
#  {'sentence_idx': 14906,
#   'ADJ': 'first',
#   'NUMERAL': '12',
#   'sentence': "In 1996, RAD President Antoinette Sibley was appointed a Dame in the Queen's New Year Honours List and the Academy's first 12 degree students attended their graduation at Durham Castle."},
#  {'sentence_idx': 14921,
#   'ADJ': 'first',
#   'NUMERAL': 'five',
#   'sentence': 'RAD Grades 1-8 and the first five levels of the Vocational Grades were accredited by the Office of Qualifications and Examinations Regulation (Ofqual) in England with the RAD as an Awarding Organisation, and the Academy also achieved SQA Accreditation (Scottish Qualifications Authority Accreditation) for RAD exams.'},
#  {'sentence_idx': 14937,
#   'ADJ': 'first',
#   'NUMERAL': 'five',
#   'sentence': 'Grades 1-8 and the first five levels of the Vocational Grades are accredited by the Office of Qualifications and Examinations Regulation (Ofqual) in England, the Department for Children, Education, Lifelong Learning and Skills (DCELLS) in Wales and the Council for the Curriculum, Examinations & Assessment (CCEA) in Northern Ireland.'},
#  {'sentence_idx': 15190,
#   'ADJ': 'male',
#   'NUMERAL': 'one',
#   'sentence': 'A 2006 study found law students were much likelier to assign a high-risk case to a female lead counsel rather than a male one.'},
#  {'sentence_idx': 15278,
#   'ADJ': 'late',
#   'NUMERAL': '1999',
#   'sentence': 'In late 1999, singer-songwriter Seymour Glass briefly joined on bass before leaving to front another local band, Miss Black America.'},
#  {'sentence_idx': 15325,
#   'ADJ': 'late',
#   'NUMERAL': '2005',
#   'sentence': 'The band changed its name to The Visions in late 2005, shortly after finishing recording their debut album in Wales with producer Chris Brown.'},
#  {'sentence_idx': 15829,
#   'ADJ': 'previous',
#   'NUMERAL': 'one',
#   'sentence': "The essential benefit achieved by using a rolling hash such as the Rabin fingerprint is that it is possible to compute the hash value of the next substring from the previous one by doing only a constant number of operations, independent of the substrings' lengths."},
#  {'sentence_idx': 15986,
#   'ADJ': 'early',
#   'NUMERAL': '1950s',
#   'sentence': 'Another engineered version of the system was deployed by Amalgamated Wireless Australasia Limited in the early 1950s operating in the 200 MHz VHF band.'},
#  {'sentence_idx': 16576,
#   'ADJ': 'extra',
#   'NUMERAL': 'two',
#   'sentence': 'With an extra two to three people?'},
#  {'sentence_idx': 16618,
#   'ADJ': 'top',
#   'NUMERAL': '32',
#   'sentence': 'Snooker world rankings 1990/1991: The professional world rankings for the top 32 snooker players and five others from the top 64 in the 1990/1991 season are listed below.'},
#  {'sentence_idx': 17130,
#   'ADJ': 'national',
#   'NUMERAL': 'under-16',
#   'sentence': "After winning the national under-16 title in 1975, his world ranking peaked at number six in 1989–90, after his only ranking tournament victory at the 1989 Hong Kong Open in which he beat Dene O'Kane 9–8."},
#  {'sentence_idx': 17169,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': "At the start of the 2011/12 season Hallett entered the Players Tour Championship and after winning his first two matches against Duane Jones 4-3 and Elliot Slessor also 4-3, he played Ronnie O'Sullivan and managed to take two frames in losing 4-2."},
#  {'sentence_idx': 17430,
#   'ADJ': 'top',
#   'NUMERAL': '33',
#   'sentence': 'Snooker world rankings 1982/1983: The professional world rankings for the top 33 snooker players in the 1982/1983 season are listed below.'},
#  {'sentence_idx': 17453,
#   'ADJ': 'top',
#   'NUMERAL': '10',
#   'sentence': 'Toland was voted as one of the top 10 (actually 11 with a tie) most influential cinematographers in the history of films by the International Cinematographers Guild in 2003.'},
#  {'sentence_idx': 17591,
#   'ADJ': 'technicolor',
#   'NUMERAL': 'three',
#   'sentence': 'This was possible because several elements of technology came together at once: the technicolor three strip process, which required the development of more powerful lights, had been developed and the more powerful Carbon Arc light was beginning to be used.'},
#  {'sentence_idx': 17675,
#   'ADJ': 'top',
#   'NUMERAL': 'ten',
#   'sentence': "The results of a survey conducted in 2003 by the International Cinematographers Guild placed Toland in the top ten of history's most influential cinematographers."},
#  {'sentence_idx': 17769,
#   'ADJ': 'largest',
#   'NUMERAL': 'two',
#   'sentence': 'Southwest is one of the largest two-year colleges operated by the Tennessee Board of Regents.'},
#  {'sentence_idx': 18115,
#   'ADJ': 'full',
#   'NUMERAL': 'three',
#   'sentence': 'The popular nature of the revolt is evident in the fact that posters and notices were being handed out a full three days before the substantive acts of the revolution occurred on 12 January 1848.'},
#  {'sentence_idx': 18481,
#   'ADJ': 'first',
#   'NUMERAL': 'one',
#   'sentence': 'He was the first one from Southern Italy.'},
#  {'sentence_idx': 19625,
#   'ADJ': 'cruel',
#   'NUMERAL': 'one',
#   'sentence': 'There was no way out of his scrape, but the usual cruel one,'},
#  {'sentence_idx': 19865,
#   'ADJ': 'early',
#   'NUMERAL': '2000s',
#   'sentence': 'He was involved in a directorial role for World Snooker in the early 2000s.'},
#  {'sentence_idx': 19874,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Unfortunately I can do nothing about the first two but it is my responsibility to protect your salary so that your wife and family are looked after.'},
#  {'sentence_idx': 19884,
#   'ADJ': 'extra',
#   'NUMERAL': 'three',
#   'sentence': "So if she needs around ten thousand pounds  where's the extra three thousand pounds a year gonna come from?"},
#  {'sentence_idx': 21665,
#   'ADJ': 'worth',
#   'NUMERAL': 'two',
#   'sentence': "So we've got the Pru wh which is worth two thousand, when was that started?"},
#  {'sentence_idx': 21796,
#   'ADJ': 'other',
#   'NUMERAL': 'two',
#   'sentence': "So that, that's the Pru one, what, what are the other two?"},
#  {'sentence_idx': 22011,
#   'ADJ': 'joint',
#   'NUMERAL': 'one',
#   'sentence': "Obviously they're,th the mortgage one actually is a, is a, is a joint one so having said it's eighty thousand really as far as, as you're concerned it's ten, ten thousand pounds there for you and, and seventy thousand on a, on a joint life first death basis so"},
#  {'sentence_idx': 22845,
#   'ADJ': 'subsequent',
#   'NUMERAL': '1976',
#   'sentence': 'Wiley received his doctoral degree in biophysics in 1971 from Harvard University, where he worked under the direction of the subsequent 1976 chemistry Nobel Prize winner William N. Lipscomb, Jr.'},
#  {'sentence_idx': 22925,
#   'ADJ': 'top',
#   'NUMERAL': '32',
#   'sentence': 'Snooker world rankings 1983/1984: The professional world rankings for the top 32 snooker players in the 1983/1984 season are listed below.'},
#  {'sentence_idx': 22963,
#   'ADJ': 'first',
#   'NUMERAL': 'three',
#   'sentence': 'Which was good from the point of view that you took thirteen minutes to do the first three and then two minutes to do the last, last three.'},
#  {'sentence_idx': 23107,
#   'ADJ': 'late',
#   'NUMERAL': '1974',
#   'sentence': "Allende's appointed army chief, Augusto Pinochet, rose to supreme power within a year of the coup and formally assumed power in late 1974."},
#  {'sentence_idx': 23272,
#   'ADJ': 'latter',
#   'NUMERAL': 'two',
#   'sentence': "Allende attempted to follow Castro's advice, but the latter two recommendations proved difficult."},
#  {'sentence_idx': 23743,
#   'ADJ': 'several',
#   'NUMERAL': 'hundred',
#   'sentence': 'Of these approximately 40,000 to 50,000 perfunctory arrests, several hundred individuals would later be detained, questioned, tortured, and in some cases murdered.'},
#  {'sentence_idx': 23825,
#   'ADJ': 'only',
#   'NUMERAL': 'two',
#   'sentence': 'The only two newspapers that were allowed to continue publishing after the military takeover were "El Mercurio" and "La Tercera de la Hora", both of which were anti-Allende under his leadership.'},
#  {'sentence_idx': 23871,
#   'ADJ': 'less',
#   'NUMERAL': 'two',
#   'sentence': "three quarters of your gross less two nine one seven and that's, and then divide it by fifty two to get your weekly benefit."},
#  {'sentence_idx': 23907,
#   'ADJ': 'late',
#   'NUMERAL': '2014',
#   'sentence': 'Beginning in late 2014 in response to a request by then Senate Armed Services Committee Chair Carl Levin, United States Southern Command (USSOUTHCOM) William J. Perry Center for Hemispheric Defense Studies (CHDS), located at the National Defense University in Washington, D.C., has been under investigation by the Department of Defense Office of Inspector General.'},
#  {'sentence_idx': 24264,
#   'ADJ': 'early',
#   'NUMERAL': '1920s',
#   'sentence': '"Furious" was briefly laid up after the war before she was reconstructed with a full-length flight deck in the early 1920s.'},
#  {'sentence_idx': 24272,
#   'ADJ': 'early',
#   'NUMERAL': '1940',
#   'sentence': 'This changed dramatically during the Norwegian Campaign in early 1940 when her aircraft provided air support to British troops ashore in addition to attacking German shipping.'},
#  {'sentence_idx': 24462,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Her design was based on experience gained with the first two British carriers, and , although this was very limited as "Argus" was less than three years old and "Eagle" had carried out only 143 deck landings during her preliminary sea trials in 1920.'},
#  {'sentence_idx': 24539,
#   'ADJ': 'original',
#   'NUMERAL': 'eleven',
#   'sentence': '"Furious" retained ten of her original eleven breech-loading guns, five on each side, for self-defence from enemy warships.'},
#  {'sentence_idx': 24544,
#   'ADJ': 'forward',
#   'NUMERAL': '4',
#   'sentence': 'During "Furious"s September 1930 – February 1932 refit, her anti-aircraft outfit was reinforced by the addition of two eight-barrel QF 2-pounder Mark V pom-pom mounts where the forward 4-inch guns on the flying-off deck had been removed earlier.'},
#  {'sentence_idx': 24553,
#   'ADJ': 'early',
#   'NUMERAL': '1939',
#   'sentence': 'The 5.5-inch and 4-inch guns were replaced during her refit in early 1939 by a dozen QF 4-inch Mk XVI guns in six twin dual-purpose Mark XIX mounts.'},
#  {'sentence_idx': 24554,
#   'ADJ': 'other',
#   'NUMERAL': 'four',
#   'sentence': 'One mount each was on the former flying-off deck and the quarterdeck while the other four were mounted two per side.'},
#  {'sentence_idx': 24638,
#   'ADJ': 'early',
#   'NUMERAL': '1934',
#   'sentence': 'Hawker Osprey fighters replaced the Flycatchers in early 1934 and the Nimrods were withdrawn in October 1936.'},
#  {'sentence_idx': 24768,
#   'ADJ': 'least',
#   'NUMERAL': 'fourteen',
#   'sentence': 'She had to make and receive at least fourteen presents, to'},
#  {'sentence_idx': 24858,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': '"Furious" spent the next three months after her return working up.'},
#  {'sentence_idx': 25036,
#   'ADJ': 'further',
#   'NUMERAL': 'three',
#   'sentence': 'As of June 2019, there are eighteen Accredited European Schools located in thirteen EU countries, with a further three schools engaged in the accreditation process.'},
#  {'sentence_idx': 25064,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'On 12 October 1954, the first two years of the secondary school began to operate.'},
#  {'sentence_idx': 25159,
#   'ADJ': 'formal',
#   'NUMERAL': 'two',
#   'sentence': 'So let me just rewrite this kind of formal two column proof so we know AB is equal to AC so this is statement 1 and this is given'},
#  {'sentence_idx': 25160,
#   'ADJ': 'mere',
#   'NUMERAL': '8',
#   'sentence': 'The historical significance of the first European School, founded a mere 8 years after the end of World War II, was not lost on its architects.'},
#  {'sentence_idx': 25474,
#   'ADJ': 'further',
#   'NUMERAL': 'three',
#   'sentence': 'As of June 2019, there are eighteen Accredited European Schools located in thirteen EU countries, with a further three schools engaged in the accreditation process.'},
#  {'sentence_idx': 25573,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'On September 14 of at Fenway Park, Nieman hit two home runs in his first two major league at-bats.'},
#  {'sentence_idx': 25578,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Also, Nieman is one of two players in MLB history to homer in each of his first two big league at bats.'},
#  {'sentence_idx': 25639,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'On July 6, he homered in his second at-bat, becoming only the second player in MLB history to hit home runs in each of his first two big league at bats.'},
#  {'sentence_idx': 25881,
#   'ADJ': 'little',
#   'NUMERAL': 'one',
#   'sentence': 'little one without cause.'},
#  {'sentence_idx': 26041,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'first two or three rounds of this famous combat; at the commencement of'},
#  {'sentence_idx': 26186,
#   'ADJ': 'interesting',
#   'NUMERAL': 'one',
#   'sentence': "That's an interesting one."},
#  {'sentence_idx': 26262,
#   'ADJ': 'second',
#   'NUMERAL': 'two',
#   'sentence': "So what I want to suggest is that the second two categories I've mentioned, that's the vocal channel and the body language channel can actually be very important in communication."},
#  {'sentence_idx': 26266,
#   'ADJ': 'second',
#   'NUMERAL': 'two',
#   'sentence': "What I'd like you to do now is er, just for a couple of minutes, informally with the people sitting next to you, see if you can list as many channels as you can under those second two headings, okay?"},
#  {'sentence_idx': 26346,
#   'ADJ': 'critical',
#   'NUMERAL': 'one',
#   'sentence': 'Very very critical one, intonation of tone.'},
#  {'sentence_idx': 26361,
#   'ADJ': 'wide',
#   'NUMERAL': 'one',
#   'sentence': 'This makes it harder for the heart to pump blood through the lungs, much as it is harder to make water flow through a narrow pipe as opposed to a wide one.'},
#  {'sentence_idx': 26586,
#   'ADJ': 'critical',
#   'NUMERAL': 'one',
#   'sentence': 'Facial expression, very very critical one.'},
#  {'sentence_idx': 26693,
#   'ADJ': 'interesting',
#   'NUMERAL': 'one',
#   'sentence': "Erm smell's an interesting one."},
#  {'sentence_idx': 27186,
#   'ADJ': 'average',
#   'NUMERAL': 'two',
#   'sentence': 'Twenty-one plenary meetings were held between 1999 and 2015: one each year from 1999 to 2002, and 2007 to 2008; and on average two each year thereafter.'},
#  {'sentence_idx': 27283,
#   'ADJ': 'low',
#   'NUMERAL': 'one',
#   'sentence': 'The room was a low one, and once, when'},
#  {'sentence_idx': 27747,
#   'ADJ': 'total',
#   'NUMERAL': '75',
#   'sentence': 'The league played fall and spring seasons in 1937 (c. 100-game schedule, in total) and 1938 (total 75-game schedule), adding one new team each year.'},
#  {'sentence_idx': 27818,
#   'ADJ': 'rival',
#   'NUMERAL': 'four',
#   'sentence': 'A rival four-team league, known as the , played a 30-game summer season in 1947.'},
#  {'sentence_idx': 28729,
#   'ADJ': 'entire',
#   'NUMERAL': '1988',
#   'sentence': 'Commissioner Peter Ueberroth suspended him for the entire 1988 season after he relapsed, but he was reinstated before the All-Star break after completing a drug rehabilitation program.'},
#  {'sentence_idx': 28845,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'Meanwhile, he was also publishing historical works of his own, including "A History of England" (1831), "The Rise and Progress of the English Commonwealth" (1832), "An Essay on the Original Authority of the King\'s Council" (1834), "Truths and Fictions of the Middle Ages: the Merchant and the Friar" (1837) and "The History of Normandy and England" (1851–64, 4 volumes, of which the last two appeared posthumously).'},
#  {'sentence_idx': 29085,
#   'ADJ': 'worth',
#   'NUMERAL': 'twenty',
#   'sentence': "Do you think it's worth twenty five pounds?"},
#  {'sentence_idx': 29386,
#   'ADJ': 'inaugural',
#   'NUMERAL': '1947',
#   'sentence': 'From the inaugural 1947 tournament through 1956, there were predominantly U.S.-based teams, usually eight, competing in a single-elimination format.'},
#  {'sentence_idx': 29414,
#   'ADJ': 'top',
#   'NUMERAL': 'two',
#   'sentence': 'Teams competed round-robin within their own pool, with the top two teams of each pool advancing to single-elimination play for a spot in the U.S. final or international final, followed by the U.S champion and international champion meeting in the World Championship game.'},
#  {'sentence_idx': 29423,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Additionally, each team in the tournament played a minimum of three games, as any team that lost its first two games would play in a consolation U.S. vs. international game.'},
#  {'sentence_idx': 29550,
#   'ADJ': 'first',
#   'NUMERAL': 'four',
#   'sentence': "Let's lock both ends of the chain of the first four bubbles in one lock twist."},
#  {'sentence_idx': 29620,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist a chain of the next three bubbles.'},
#  {'sentence_idx': 29666,
#   'ADJ': 'last',
#   'NUMERAL': 'four',
#   'sentence': 'Lock both ends of the chain of the last four or the last six bubbles in one lock twist.'},
#  {'sentence_idx': 29672,
#   'ADJ': 'first',
#   'NUMERAL': 'four',
#   'sentence': 'We have to force the end of the balloon through the loop of the chain of the first four bubbles.'},
#  {'sentence_idx': 29684,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'For the next three days everybody went about saying, “White rose, Red rose, Red rose, White rose”; and the King gave orders that the Page’s salary was to be doubled.'},
#  {'sentence_idx': 29703,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist a chain of the next three bubbles.'},
#  {'sentence_idx': 29728,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Lock the free end of the chain of the last three bubbles between the next two bubbles in the center of the square.'},
#  {'sentence_idx': 29837,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Coverage of the qualifying games has increased substantially in the US within the past decade: as of 2018, all regional group games (with the exception of the Southwest region) are available via subscription online through the ESPN+ platform, with the last three games of each regional tournament on an ESPN network.'},
#  {'sentence_idx': 29856,
#   'ADJ': 'other',
#   'NUMERAL': 'eleven',
#   'sentence': "Each of the other eleven divisions of Little League Baseball has its own World Series format (including three in boys' softball)."},
#  {'sentence_idx': 29894,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist a chain of the next three bubbles.'},
#  {'sentence_idx': 29896,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Lock the free end of the chain of the last three bubbles between the next two bubbles in the center of the square.'},
#  {'sentence_idx': 29919,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist a chain of the next three bubbles.'},
#  {'sentence_idx': 29960,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Lock the free end of the chain of the last three bubbles between the next two bubbles at the center of the square.'},
#  {'sentence_idx': 29994,
#   'ADJ': 'last',
#   'NUMERAL': 'sixteen',
#   'sentence': 'We actually locked both ends of the chain of the last sixteen bubbles in one lock twist.'},
#  {'sentence_idx': 30118,
#   'ADJ': 'fastest',
#   'NUMERAL': '300,250,200',
#   'sentence': 'He holds the massive Indian record of scoring the fastest 300,250,200 and 150 in Test cricket.'},
#  {'sentence_idx': 30197,
#   'ADJ': 'next',
#   'NUMERAL': 'sixty',
#   'sentence': 'The township of Kelmscott was gazetted in 1830, and for the next sixty years was the administrative and social hub for those colonists who took up land between present-day Kelmscott and Byford.'},
#  {'sentence_idx': 30226,
#   'ADJ': 'late',
#   'NUMERAL': '1846',
#   'sentence': "In late 1846 the Swan River Colony's first mine was established in the area now known as Armadale."},
#  {'sentence_idx': 30323,
#   'ADJ': 'first',
#   'NUMERAL': 'six',
#   'sentence': "Let's twist a chain of the first six bubbles."},
#  {'sentence_idx': 30407,
#   'ADJ': 'early',
#   'NUMERAL': '1900s',
#   'sentence': 'A collection of artefacts recovered from beneath the earliest parts of the school during the move are held by History House Museum and provide tangible insights into school life at Armadale during the early 1900s.'},
#  {'sentence_idx': 30415,
#   'ADJ': 'first',
#   'NUMERAL': 'six',
#   'sentence': 'Here is the chain of the first six bubbles.'},
#  {'sentence_idx': 30427,
#   'ADJ': 'last',
#   'NUMERAL': 'four',
#   'sentence': "Let's lock both ends of the chain of the last four bubbles in one lock twist."},
#  {'sentence_idx': 30437,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'Twist the chain of the next two bubbles.'},
#  {'sentence_idx': 30480,
#   'ADJ': 'first',
#   'NUMERAL': 'eight',
#   'sentence': 'And now we lock both ends of the chain of the first eight bubbles in one lock twist.'},
#  {'sentence_idx': 30489,
#   'ADJ': 'aged',
#   'NUMERAL': '89',
#   'sentence': 'Lyallpuri died at his home in Mumbai, India on 22 January 2017 from complications of a hip fracture, aged 89.'},
#  {'sentence_idx': 30571,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist a chain of the next three bubbles.'},
#  {'sentence_idx': 30588,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Lock the free end of the chain of the last three bubbles between nearest two bubbles of the small rectangle.'},
#  {'sentence_idx': 30644,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'Now we twist the chain of the next two bubbles.'},
#  {'sentence_idx': 30686,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'Lock the free end of the chain of the last two bubbles between the third and the fourth bubble.'},
#  {'sentence_idx': 30714,
#   'ADJ': 'early',
#   'NUMERAL': '1990s',
#   'sentence': 'In the early 1990s, as The Tazmaniac, he wrestled for International World Class Championship Wrestling (IWCCW) and held its Light Heavyweight Championship for six months in 1991.'},
#  {'sentence_idx': 30723,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': "But the king was not ill-pleased : `` for , '' thought he , `` of course my three sons must go after the brute , the eldest first ; and , as usual , it will kill the first two , and be beaten by the youngest ."},
#  {'sentence_idx': 30742,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Now we twist the chain of the next three bubbles.'},
#  {'sentence_idx': 30807,
#   'ADJ': 'last',
#   'NUMERAL': 'three',
#   'sentence': 'Lock the free end of the chain of the last three bubbles between the nearest two bubbles of the small rectangle.'},
#  {'sentence_idx': 30855,
#   'ADJ': 'early',
#   'NUMERAL': '1995',
#   'sentence': 'This was the first time they had been in the ring together since early 1995.'},
#  {'sentence_idx': 30918,
#   'ADJ': 'late',
#   'NUMERAL': '1997',
#   'sentence': 'Throughout late 1997, Taz began feuding with The Triple Threat in addition to Sabu and Van Dam, where he sometimes teamed up with Tommy Dreamer during the feud.'},
#  {'sentence_idx': 30970,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist the chain of the next three bubbles.'},
#  {'sentence_idx': 30986,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'Lock the free end between the next two bubbles at the center.'},
#  {'sentence_idx': 31016,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'Twist the chain of the next two bubbles.'},
#  {'sentence_idx': 31031,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'Lock the free end of the chain of the last two bubbles.'},
#  {'sentence_idx': 31053,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': 'Twist the chain of the next three bubbles.'},
#  {'sentence_idx': 31067,
#   'ADJ': 'first',
#   'NUMERAL': 'twenty',
#   'sentence': 'At the end we lock both ends of the chain of the first twenty four bubbles in one lock twist.'},
#  {'sentence_idx': 31178,
#   'ADJ': 'early',
#   'NUMERAL': '2007',
#   'sentence': 'He also hosted a talk show on 92.3 Free FM at sporadic intervals between late summer 2006 and early 2007, but it was not picked up and the station changed formats, replacing all post morning programming with music.'},
#  {'sentence_idx': 31437,
#   'ADJ': 'Raw',
#   'NUMERAL': '2009',
#   'sentence': 'Raw 2009".'},
#  {'sentence_idx': 31461,
#   'ADJ': 'following',
#   'NUMERAL': '18',
#   'sentence': 'The following 18 political parties are in parliament:'},
#  {'sentence_idx': 31740,
#   'ADJ': 'youngest',
#   'NUMERAL': 'two',
#   'sentence': 'and then my youngest two have never been.'},
#  {'sentence_idx': 31852,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'Lock the free end of the chain of the last two yellow bubbles between the nearest two blue bubbles of the square.'},
#  {'sentence_idx': 31931,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'Now we lock the free end of the chain of the last two yellow bubbles at the corner between the two bubbles ...hm...at the short side of the rectangle.'},
#  {'sentence_idx': 31943,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Recorded to celebrate 21 years of involvement in music, the album comprised new recordings of songs from their early cassette albums and the first two CD albums, along with new material.'},
#  {'sentence_idx': 31972,
#   'ADJ': 'aged',
#   'NUMERAL': '84',
#   'sentence': 'Canfield died in Rochester on January 24, 2017 from natural causes, aged 84.'},
#  {'sentence_idx': 32136,
#   'ADJ': 'aged',
#   'NUMERAL': '89',
#   'sentence': "Dobell died in New York City on January 21, 2017 from complications of Parkinson's disease, aged 89."},
#  {'sentence_idx': 32458,
#   'ADJ': 'worth',
#   'NUMERAL': 'fifty',
#   'sentence': 'shawls were worth fifty guineas apiece, at the very least, as Mrs. Sedley'},
#  {'sentence_idx': 32700,
#   'ADJ': 'early',
#   'NUMERAL': '1960s',
#   'sentence': 'Drumchapel did not get its first shopping centre until the early 1960s.'},
#  {'sentence_idx': 32731,
#   'ADJ': 'old',
#   'NUMERAL': 'one',
#   'sentence': 'Here sat two female figures, a young and an old one.'},
#  {'sentence_idx': 32828,
#   'ADJ': 'aged',
#   'NUMERAL': '86',
#   'sentence': 'Mathews died on January 25, 2017 at his home in Key West, Florida from natural causes, aged 86.'},
#  {'sentence_idx': 32879,
#   'ADJ': 'aged',
#   'NUMERAL': '71',
#   'sentence': 'Saint Phalle died on 21 May 2002 in San Diego, California from emphysema, aged 71.'},
#  {'sentence_idx': 33036,
#   'ADJ': 'next',
#   'NUMERAL': 'three',
#   'sentence': "And I'm really happy to be here for the next three days."},
#  {'sentence_idx': 33163,
#   'ADJ': 'single',
#   'NUMERAL': 'one',
#   'sentence': "It's about every single one of us, and in some sense what the potential is, as the slide says, for living your moments as if they really mattered."},
#  {'sentence_idx': 33305,
#   'ADJ': 'aged',
#   'NUMERAL': '90',
#   'sentence': 'Mendelsohn died of lung cancer on the evening of January 25, 2017, aged 90.'},
#  {'sentence_idx': 33389,
#   'ADJ': 'early',
#   'NUMERAL': '1980s',
#   'sentence': 'The Epiphone Spirit and Special were produced in the early 1980s in Kalamazoo.'},
#  {'sentence_idx': 33935,
#   'ADJ': 'Danish',
#   'NUMERAL': '[',
#   'sentence': "The sun's light wants eight minutes and some seconds to perform a journey of more than twenty million of our Danish [*] miles; borne by electricity, the soul wants even some minutes less to accomplish the same flight."},
#  {'sentence_idx': 34131,
#   'ADJ': 'late',
#   'NUMERAL': '2012',
#   'sentence': 'In late 2012, an inquiry against the Canning City Council launched by the State Government\'s Department of Local Government resulted in a 476-page report "pointing to widespread dysfunction, micromanagement and alleged serious governance irregularities."'},
#  {'sentence_idx': 34165,
#   'ADJ': 'aged',
#   'NUMERAL': '93',
#   'sentence': 'Ravaglia died on 26 January 2017 in Dovadola, Italy, aged 93.'},
#  {'sentence_idx': 34538,
#   'ADJ': 'aged',
#   'NUMERAL': '84',
#   'sentence': 'Holiday died on January 27, 2017 at his home in Hawley, Pennsylvania, aged 84.'},
#  {'sentence_idx': 34614,
#   'ADJ': 'Anglican',
#   'NUMERAL': '21.3',
#   'sentence': 'The most common responses for religion were No Religion 32.2%, Anglican 21.3% and Catholic 19.1%.'},
#  {'sentence_idx': 35382,
#   'ADJ': 'new',
#   'NUMERAL': '.40',
#   'sentence': 'This included several using the new .40 S&amp;W cartridge.'},
#  {'sentence_idx': 35701,
#   'ADJ': 'first',
#   'NUMERAL': 'five',
#   'sentence': "In the first five years of the Board's existence most of its members served on the Fremantle Town Council."},
#  {'sentence_idx': 35863,
#   'ADJ': 'aged',
#   'NUMERAL': '92',
#   'sentence': 'La Grange died in Paris on 27 January 2017 from complications of pneumonia, aged 92.'},
#  {'sentence_idx': 35894,
#   'ADJ': 'aged',
#   'NUMERAL': '78',
#   'sentence': 'Bland died on 28 January 2017 in Clanville, Hampshire from complications of prostate cancer, aged 78.'},
#  {'sentence_idx': 35998,
#   'ADJ': 'many',
#   'NUMERAL': 'hundred',
#   'sentence': 'We peeped through the windows, and saw them planted in the middle of the warm room and ornamented with the most splendid things, with gilded apples, with gingerbread, with toys, and many hundred lights!”'},
#  {'sentence_idx': 36242,
#   'ADJ': 'aged',
#   'NUMERAL': '81',
#   'sentence': 'Streuli died in Greensboro, North Carolina on January 19, 2017, aged 81.'},
#  {'sentence_idx': 36346,
#   'ADJ': 'aged',
#   'NUMERAL': '86',
#   'sentence': 'Giunashvili died on 21 January 2017 in Tbilisi, Georgia, aged 86.'},
#  {'sentence_idx': 36507,
#   'ADJ': 'Anglican',
#   'NUMERAL': '22.6',
#   'sentence': 'The most common responses for religion were No Religion 36.4%, Anglican 22.6% and Catholic 19.3%.'},
#  {'sentence_idx': 36563,
#   'ADJ': 'last',
#   'NUMERAL': '110',
#   'sentence': "Historically the beach and its panorama are reflections of the changes in the last 110 years of Perth's history."},
#  {'sentence_idx': 36572,
#   'ADJ': 'aged',
#   'NUMERAL': '94',
#   'sentence': 'Salas died on 26 January 2017 in Kaori, New Zealand, aged 94.'},
#  {'sentence_idx': 36621,
#   'ADJ': 'aged',
#   'NUMERAL': '70',
#   'sentence': 'Kirov died on 27 January 2017 in Sofia from a heart attack, aged 70.'},
#  {'sentence_idx': 36789,
#   'ADJ': 'aged',
#   'NUMERAL': '74',
#   'sentence': 'Mosher died of prostate cancer under hospice care in Irasburg, Vermont, aged 74.'},
#  {'sentence_idx': 37032,
#   'ADJ': 'early',
#   'NUMERAL': '1990s',
#   'sentence': 'Industry in the form of brickworks were introduced to Beckenham in the early 1990s.'},
#  {'sentence_idx': 37485,
#   'ADJ': 'dead',
#   'NUMERAL': 'three',
#   'sentence': 'She was found dead three and a half years later.'},
#  {'sentence_idx': 37603,
#   'ADJ': 'last',
#   'NUMERAL': 'one',
#   'sentence': 'He held several political posts like government minister of Development Cooperation and an alderman and mayor of Wavre (last one still incumbent).'},
#  {'sentence_idx': 37706,
#   'ADJ': 'only',
#   'NUMERAL': 'two',
#   'sentence': 'Those are the only two tones.'},
#  {'sentence_idx': 37847,
#   'ADJ': 'stronger',
#   'NUMERAL': 'three',
#   'sentence': 'A sweet fragrance was smelt, and the maidens vanished in the wood; the fragrance grew stronger three coffins, and in them three lovely maidens, glided out of the forest and across the lake: the shining glow-worms flew around like little floating lights.'},
#  {'sentence_idx': 38010,
#   'ADJ': 'top',
#   'NUMERAL': 'two',
#   'sentence': 'Spencer worked systematically from top to bottom on the canvas but had only completed the top two-thirds of the picture when he had to leave it in 1915.'},
#  {'sentence_idx': 38100,
#   'ADJ': 'first',
#   'NUMERAL': 'one',
#   'sentence': 'In February 1927 Spencer held his first one-man exhibition at the Goupil Gallery.'},
#  {'sentence_idx': 38241,
#   'ADJ': 'Turkish',
#   'NUMERAL': 'Windows",(1934',
#   'sentence': '"The Turkish Windows",(1934), and "Love Among the Nations",(1935), were designed as long friezes for the nave of the Church-House.'},
#  {'sentence_idx': 38363,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'The first two of these, "Burners" and "Caulkers" were completed by the end of August 1940.'},
#  {'sentence_idx': 38723,
#   'ADJ': 'aged',
#   'NUMERAL': '92',
#   'sentence': 'She had died at her home in Halland, aged 92.'},
#  {'sentence_idx': 38746,
#   'ADJ': 'bipartisan',
#   'NUMERAL': '54–45',
#   'sentence': "On April 7, 2017, the Senate confirmed Gorsuch's nomination to the Supreme Court with a bipartisan 54–45 affirmative vote with three Democratic Senators joining all of the Republican Senators."},
#  {'sentence_idx': 38791,
#   'ADJ': 'first',
#   'NUMERAL': 'three',
#   'sentence': 'The Raven of the woods, who was now married, accompanied her for the first three miles.'},
#  {'sentence_idx': 38817,
#   'ADJ': 'latter',
#   'NUMERAL': 'three',
#   'sentence': 'In "Mario Bros.", "Wrecking Crew", "Super Mario Bros.", "Super Mario Bros. 3", "Super Mario World", "Super Mario Bros. Deluxe" (except in the "Super Mario All-Stars" versions of the latter three, as well the "Super Mario Advance" series), "Mario is Missing!"'},
#  {'sentence_idx': 38905,
#   'ADJ': 'bipartisan',
#   'NUMERAL': '54–45',
#   'sentence': "On April 7, 2017, the Senate confirmed Gorsuch's nomination to the Supreme Court with a bipartisan 54–45 affirmative vote with three Democratic Senators joining all of the Republican Senators."},
#  {'sentence_idx': 39240,
#   'ADJ': 'little',
#   'NUMERAL': 'eighteen',
#   'sentence': 'Master Todd, godson of Mr. Osborne, received a little eighteen-penny'},
#  {'sentence_idx': 39464,
#   'ADJ': 'only',
#   'NUMERAL': 'one',
#   'sentence': 'In the middle of this lake sat the Snow Queen when she was at home; and then she said she was sitting in the Mirror of Understanding, and that this was the only one and the best thing in the world.'},
#  {'sentence_idx': 39931,
#   'ADJ': 'top',
#   'NUMERAL': 'five',
#   'sentence': "Cuellar, nicknamed Crazy Horse while with the Orioles, ranks among Baltimore's top five career leaders in wins (143), strikeouts (1,011), shutouts (30) and innings pitched (2,028), and trails only Dave McNally among left-handers in wins and shutouts."},
#  {'sentence_idx': 40048,
# ...
#   'sentence': 'Redknapp has received significant attention for his repeated overuse and misuse of the word "literally", in quotes such as "he literally chopped him in half in that challenge", "Alonso and Sissoko have been picked to literally sit in front of the back four", "Drogba literally destroyed Senderos today", "in his youth, Michael Owen was literally a greyhound", "he had to cut back inside onto his left, because he literally hasn\'t got a right foot", "Martin Jol\'s head is literally on the chopping block" and "these balls now – they literally explode off your feet".'},
#  {'sentence_idx': 134596,
#   'ADJ': 'early',
#   'NUMERAL': '1941',
#   'sentence': 'In early 1941, she had measles.'},
#  {'sentence_idx': 134600,
#   'ADJ': 'French',
#   'NUMERAL': '200',
#   'sentence': 'On 6 October she broke the French 200m freestyle record with a time of 2:39.5 she swam in Marseille.'},
#  {'sentence_idx': 134608,
#   'ADJ': 'French',
#   'NUMERAL': '400',
#   'sentence': 'In August 1942 she became for the second time French national champion in both the 100 metre freestyle (in 1:13.7) and 400 metre freestyle (in 6:07.4) On 2 September she broke the French 400 metre freestyle record with a time of 5:44.6 she swam in Marseille.'},
#  {'sentence_idx': 134841,
#   'ADJ': 'final',
#   'NUMERAL': 'ten',
#   'sentence': 'For the final ten years of his life he lived in Germany.'},
#  {'sentence_idx': 134936,
#   'ADJ': 'rich',
#   'NUMERAL': 'one',
#   'sentence': 'The rich one, however, gave nothing to the poor one, and he gained a scanty living by trading in corn, and often did so badly that he had no bread for his wife and children.'},
#  {'sentence_idx': 135075,
#   'ADJ': 'late',
#   'NUMERAL': '1970',
#   'sentence': "The first wave of this music appeared in the late 1970's in the United Kingdom with bands."},
#  {'sentence_idx': 135167,
#   'ADJ': 'noble',
#   'NUMERAL': 'one',
#   'sentence': 'He, however, was unwilling, and said, “I am no common stable-ass, I am a noble one.” Then they said, “If that is what thou art, seat thyself with the men of war.” “No,” said he, “I will sit by the King.” The King smiled, and said good-humouredly, “Yes, it shall be as thou wilt, little ass, come here to me.” Then he asked, “Little ass, how does my daughter please thee?” The donkey turned his head towards her, looked at her, nodded and said, “I like her above measure, I have never yet seen anyone so beautiful as she is.” “Well, then, thou shalt sit next her too,” said the King.'},
#  {'sentence_idx': 135223,
#   'ADJ': 'Only',
#   'NUMERAL': 'One',
#   'sentence': 'In 1997, they reached number one on the UK Singles Chart with "I Wanna Be the Only One", which won them the 1997 Mobo Award for Best Single.'},
#  {'sentence_idx': 135275,
#   'ADJ': 'poor',
#   'NUMERAL': 'one',
#   'sentence': 'Then the poor one, to escape from his poverty, put off his soldier’s coat, and turned farmer.'},
#  {'sentence_idx': 135297,
#   'ADJ': 'late',
#   'NUMERAL': '1960s',
#   'sentence': 'In the late 1960s, groups such as the Mothers of Invention, the Velvet Underground, the Fugs, the Beatles, and the Jimi Hendrix Experience began incorporating elements such as avant-garde music, sound collage, and poetry in their work.'},
#  {'sentence_idx': 135307,
#   'ADJ': 'Only',
#   'NUMERAL': 'One',
#   'sentence': 'In 1997, Eternal achieved their first ever UK number one, a duet with BeBe Winans, "I Wanna Be the Only One", which became the second most played song on UK Radio in 1997, and stayed at the top spot for one week.'},
#  {'sentence_idx': 135350,
#   'ADJ': 'early',
#   'NUMERAL': '1990s',
#   'sentence': "Heartland rock faded away as a recognized genre by the early 1990s, as rock music in general lost influence with younger audiences and as heartland's artists turned to more personal works."},
#  {'sentence_idx': 135378,
#   'ADJ': 'top',
#   'NUMERAL': 'ten',
#   'sentence': 'In 1978, Springsteen returned with "Darkness on the Edge of Town", which reached the top ten in the US and then the number one album "The River" (1980), which continued the themes of economic and personal dissolution, produced a series of hit singles.'},
#  {'sentence_idx': 135405,
#   'ADJ': 'late',
#   'NUMERAL': '2013',
#   'sentence': 'Eternal officially confirmed in late 2013 that they would be reforming for the ITV2 documentary "The Big Reunion", although original member Louise Redknapp would not be rejoining the group.'},
#  {'sentence_idx': 135411,
#   'ADJ': 'Only',
#   'NUMERAL': 'One',
#   'sentence': 'The group reformed to perform a concert at the Hammersmith Apollo in March 2014, where they performed alongside BeBe Winans for their hit single "I Wanna Be the Only One".'},
#  {'sentence_idx': 135642,
#   'ADJ': 'early',
#   'NUMERAL': '1980s',
#   'sentence': 'Vanity 6 was an American girl group that gained popularity in the early 1980s.'},
#  {'sentence_idx': 135873,
#   'ADJ': 'other',
#   'NUMERAL': '540',
#   'sentence': '121 games were released in both regions, 18 games only in North America and the other 540 games only in Japan.'},
#  {'sentence_idx': 135892,
#   'ADJ': 'several',
#   'NUMERAL': 'thousand',
#   'sentence': 'Meanwhile the enemy discharged several thousand arrows , many of which stuck in my hands and face .'},
#  {'sentence_idx': 136238,
#   'ADJ': 'other',
#   'NUMERAL': '2',
#   'sentence': 'The Highways contine south and east until Red lake when MN State 1 Leaves and The other 2 highways contine south to Island Lake and Scribner.'},
#  {'sentence_idx': 136250,
#   'ADJ': 'lame',
#   'NUMERAL': 'one',
#   'sentence': 'First, the blind man saw the hare running across the field, the dumb one called to the lame one, and the lame one seized it by the neck.'},
#  {'sentence_idx': 136295,
#   'ADJ': 'only',
#   'NUMERAL': 'one',
#   'sentence': 'The band has had many members, with Santana being the only one to stay in it since it was made.'},
#  {'sentence_idx': 136313,
#   'ADJ': 'top',
#   'NUMERAL': 'ten',
#   'sentence': '14 of them went into the top ten on the "Billboard" 200 music chart.'},
#  {'sentence_idx': 136350,
#   'ADJ': 'top',
#   'NUMERAL': 'ten',
#   'sentence': 'A single from the album, "Evil Ways", was top ten on music charts in the United States.'},
#  {'sentence_idx': 136493,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Pop Smoke became the first artist in history to have his first two albums posthumously debut at number one on the "Billboard" 200.'},
#  {'sentence_idx': 136740,
#   'ADJ': 'great',
#   'NUMERAL': 'one',
#   'sentence': 'Oh that was great one.'},
#  {'sentence_idx': 136945,
#   'ADJ': 'top',
#   'NUMERAL': 'five',
#   'sentence': 'It reached the top five in several countries, while reaching number one in Canada and the United States.'},
#  {'sentence_idx': 136989,
#   'ADJ': 'full',
#   'NUMERAL': 'four',
#   'sentence': 'Roger Ebert of the "Chicago Sun-Times" lauded the film, awarding it a full four stars and describing it as "unflinchingly honest, and so well acted that for most of the film I abandoned any detachment and just watched it as if I were observing the lives of real people."'},
#  {'sentence_idx': 137004,
#   'ADJ': 'cruel',
#   'NUMERAL': 'one',
#   'sentence': 'Richard Harrington of "The Washington Post" heralded the film\'s aesthetic elements, writing that it "is so beautifully filmed by Bojan Bazelli, and so skillfully edited, that its art house surface belies its exploitation content, making this a trip through a cool world rather than a cruel one."'},
#  {'sentence_idx': 137109,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': "But there had not been much hay in the barn for the last two years , for every St. John 's eve , when the grass was in the height of its vigor , it was all eaten clean up , just as if a whole flock of sheep had gnawed it down to the ground during the night ."},
#  {'sentence_idx': 137117,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': "This happened once , and it happened twice , but then the man got tired of losing his crop , and said to his sons -- he had three of them , and the third was called Cinderlad -- that one of them must go and sleep in the barn on St. John 's night , for it was absurd to let the grass be eaten up again , blade and stalk , as it had been the last two years , and the one who went to watch must keep a sharp look-out , the man said ."},
#  {'sentence_idx': 137202,
#   'ADJ': 'last',
#   'NUMERAL': 'two',
#   'sentence': 'So when evening came he went to the barn , and lay down to sleep , but when night was drawing near there was such a rumbling and such an earthquake that the walls and roof shook again , and the lad jumped up and took to his heels as fast as he could , and never even looked back , and the barn remained empty that year just as it had been for the last two .'},
#  {'sentence_idx': 137287,
#   'ADJ': 'right',
#   'NUMERAL': 'one',
#   'sentence': "`` Well , you are just the right one to watch the hay , you who have never learned anything but how to sit among the ashes and bake yourself ! ''"},
#  {'sentence_idx': 137405,
#   'ADJ': 'first',
#   'NUMERAL': 'one',
#   'sentence': 'It is also the first one from the album "In the Zone" in October 2003.'},
#  {'sentence_idx': 137487,
#   'ADJ': 'top',
#   'NUMERAL': '20',
#   'sentence': 'The track also went top 20 on both the Top 40 Mainstream and Top 40 Tracks charts.'},
#  {'sentence_idx': 137794,
#   'ADJ': 'Late',
#   'NUMERAL': 'one',
#   'sentence': 'Late one night, he hears strange noises emanating from the basement of his new and rather odd neighbors, the Klopeks.'},
#  {'sentence_idx': 137808,
#   'ADJ': 'top',
#   'NUMERAL': '5',
#   'sentence': "He's one of the top 5 in the world."},
#  {'sentence_idx': 138204,
#   'ADJ': 'early',
#   'NUMERAL': '1970s',
#   'sentence': 'The word "krautrock" was applied to the experimental German rock movement of the late 1960s and early 1970s by the British music press, and was retained by its practitioners.'},
#  {'sentence_idx': 138225,
#   'ADJ': 'seminal',
#   'NUMERAL': '12',
#   'sentence': 'For example, while one of the main groups originally tagged as krautrock, Faust, recorded a seminal 12-minute track they titled "Krautrock".'},
#  {'sentence_idx': 138251,
#   'ADJ': 'next',
#   'NUMERAL': 'two',
#   'sentence': 'for instance, if you ask a farmer here, he will tell you he has 10 acres of land but then he is not able to organise food even for the next two months.'},
#  {'sentence_idx': 138442,
#   'ADJ': 'weak',
#   'NUMERAL': 'one',
#   'sentence': 'None of them turned aside for the others, but all swam to the right or the left as they fancied, or darted between those who wanted to stay together, or got into their way; and a strong one gave a weak one a blow with its tail, which drove it away, or else swallowed it up without more ado.'},
#  {'sentence_idx': 138583,
#   'ADJ': 'new',
#   'NUMERAL': '2',
#   'sentence': 'Factory re-released the film on Blu-ray with a new 2K scan of the inter-positive and the majority of the special features from the 2014 Arrow release from the UK.'},
#  {'sentence_idx': 138788,
#   'ADJ': 'initial',
#   'NUMERAL': 'six',
#   'sentence': 'It was because of his talent for directing comedy that he was chosen to handle the second series of "Fawlty Towers" in 1979, which already had an enormous reputation on the basis of its initial six episodes in 1975, and it won him his first BAFTA award.'},
#  {'sentence_idx': 138880,
#   'ADJ': 'first',
#   'NUMERAL': 'thirty',
#   'sentence': 'The first thirty are his human years, which are soon gone; then is he healthy, merry, works with pleasure, and is glad of his life.'},
#  {'sentence_idx': 139243,
#   'ADJ': 'first',
#   'NUMERAL': 'thirty',
#   'sentence': 'The prints were very successful, and Hokusai made ten more after the first thirty-six.'},
#  {'sentence_idx': 139862,
#   'ADJ': 'little',
#   'NUMERAL': 'two',
#   'sentence': "But they, they can do a much better job since they don't have to chop it into little two minute stories."},
#  {'sentence_idx': 140493,
#   'ADJ': 'other',
#   'NUMERAL': 'two',
#   'sentence': "Prince Ahmed no sooner perceived himself in Nouronnihar 's chamber than he rose off the tapestry , as did also the other two Princes , and went to the bedside , and put the apple under her nose ; some moments after the Princess opened her eyes , and turned her head from one side to another , looking at the persons who stood about her ; and then rose up in the bed , and asked to be dressed , just as if she had waked out of a sound sleep ."},
#  {'sentence_idx': 140504,
#   'ADJ': 'early',
#   'NUMERAL': '1989',
#   'sentence': 'System V Release 4.0 was announced on October 18, 1988 and was incorporated into a variety of commercial Unix products from early 1989 onwards.'},
#  {'sentence_idx': 140632,
#   'ADJ': 'late',
#   'NUMERAL': '1993',
#   'sentence': 'Release 4.2MP, completed late 1993, added support for multiprocessing and it was released as UnixWare 2 in 1995.'},
#  {'sentence_idx': 140693,
#   'ADJ': 'late',
#   'NUMERAL': '1994',
#   'sentence': 'In late 1994, Eric S. Raymond discontinued his "PC-clone UNIX Software Buyer\'s Guide" on USENET, stating, "The reason I am dropping this is that I run Linux now, and I no longer find the SVr4 market interesting or significant."'},
#  {'sentence_idx': 140814,
#   'ADJ': 'first',
#   'NUMERAL': 'three',
#   'sentence': 'the first three days, I was glued to the television.'},
#  {'sentence_idx': 140855,
#   'ADJ': 'beloved',
#   'NUMERAL': 'one',
#   'sentence': 'And now she lived as a herdswoman, guarded her herd, and was very sad and full of longing for her beloved one; she had a little calf which she taught to know her, and fed it out of her own hand, and when she said,'},
#  {'sentence_idx': 140913,
#   'ADJ': 'top',
#   'NUMERAL': '500',
#   'sentence': 'In a November 2015 survey of the top 500 supercomputers, Unix was used by only 1.2% (all running IBM AIX), while Linux was used by 98.8%; the same survey in November 2017 reports 100% of them using Linux.'},
#  {'sentence_idx': 141271,
#   'ADJ': 'poor',
#   'NUMERAL': 'one',
#   'sentence': 'He was not to choose a poor one, and did not want to have a rich one.'},
#  {'sentence_idx': 141780,
#   'ADJ': 'early',
#   'NUMERAL': '2018',
#   'sentence': "Following the first issue the series was placed on temporary hiatus due to a serious medical emergency in Broussard's family, resuming production in early 2018 with new artists Ryan Benjamin and Richard Friend."},
#  {'sentence_idx': 141794,
#   'ADJ': 'first',
#   'NUMERAL': 'two',
#   'sentence': 'Given the abundance of source material, the current plan is to produce as many as seven seasons, without revisiting the source material that was adapted into the first two films.'},
#  {'sentence_idx': 142136,
#   'ADJ': 'alone',
#   'NUMERAL': 'one',
#   'sentence': 'A young drummer went out quite alone one evening into the country, and came to a lake on the shore of which he perceived three pieces of white linen lying.'},
#  {'sentence_idx': 142294,
#   'ADJ': 'autobiographical',
#   'NUMERAL': 'one',
#   'sentence': 'His big break came in 1988 with the premiere of his autobiographical one-man show, "A Bronx Tale," which he wrote after being fired from a club for refusing entry to talent agent Swifty Lazar; Robert De Niro later developed and directed a film version (1993).'},
#  {'sentence_idx': 142380,
#   'ADJ': 'semiautobiographical',
#   'NUMERAL': 'one',
#   'sentence': 'Palminteri starred on Broadway in "A Bronx Tale", the semiautobiographical one-man show he first performed (as "A Bronx Play") at Theatre West in Los Angeles in 1989.'},
#  {'sentence_idx': 142851,
#   'ADJ': 'several',
#   'NUMERAL': 'hundred',
#   'sentence': 'It took several hundred years for European scientists and physicians to reach the same conclusions that al-Nafis had.'},
#  {'sentence_idx': 143033,
#   'ADJ': 'late',
#   'NUMERAL': '1930s',
#   'sentence': 'One of six children, he worked in coal mines during his youth before becoming a professional boxer in the late 1930s.'},
#  {'sentence_idx': 143062,
#   'ADJ': 'unknown',
#   'NUMERAL': '1981',
#   'sentence': 'Long familiar to Springsteen fans from its distribution years earlier to rock radio stations, it had previously been released on the fairly unknown 1981 children\'s album "In Harmony 2"; now in time for the Christmas season it was being issued again.'},
#  ...]
