# %%
import glob
import re
import spacy
import unicodedata
import csv

import pandas as pd

from collections import defaultdict
from minicons.utils import find_pattern
from spacy.lang.en import English
from tqdm import tqdm

import utils
import config
import minicons.utils as mu

from nltk.tokenize import sent_tokenize

from minicons import utils as mu
import inflect
from constructions import AANN

inflector = inflect.engine()
import editors

# %%
nlp = English()
tokenizer = nlp.tokenizer

def tokenize(string):
    return [t.text for t in tokenizer(string)]
# Out:
# /home/km55359/.conda/envs/kmisra/lib/python3.11/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
sent_dir = "/home/km55359/rawdata/babylm_data/babylm_100M/sents/"
# sent_dir = "/Users/kanishka/rawdata/babylm-sents-and-postags/"
sents = utils.read_file(f"{sent_dir}/babylm_sents.txt")
postags = utils.read_file(f"{sent_dir}/postags.txt")

sent_tokens = [tokenize(sent) for sent in sents]

# %%
non_numerals = ['few', 'dozen', 'couple', 'several', 'many', 'more']

CURRENT_FEW = r'\bARTICLE\s(((HYPH|,)\s))?((((RB|CC|IN)\s)+)?((JJ|JJR|JJS|VBN|RECORD|((NN CC NN |NN HYPH )+(JJ|JJR|JJS|VBN|RECORD)))((\s(HYPH|,))?)\s))+(((RB)\s)+)?(((HYPH|,)\s))?((UH)\s)?(((NN|CC)\s)+)?((CD|FEW)(\s(TO|CC|(HYPH|,))(\s(HYPH|,))?)?\s)+(((HYPH|,)\s))?((JJR|JJ|VBN)\s)?(ARTICLE\s)?((NNS|NNPS|(NN\sNNS)|((NN|NNS) IN NNS)))+'

def detect_aann_basic(sent_toks, pos):
    p_replaced = []
    for st, pt in zip(sent_toks, pos.split(" ")):
        if st.lower() not in non_numerals + ["a", "an", "another", "an", "-a", "-an"] + ['record']:
            p_replaced.append(pt)
        else:
            if st.lower() in ["a", "another", "an", "-a", "-an"]:
                p_replaced.append("ARTICLE")
            elif st.lower() in non_numerals:
                p_replaced.append("FEW")
            elif st.lower() in ["record"]:
                p_replaced.append("RECORD")
            else:
                p_replaced.append(pt)
        # if st.lower() in non_numerals:
        #     p_replaced.append("FEW")
        # else:
        #     p_replaced.append(pt)
        # if st.lower() in ["a", "another", "an", "-a", "-an"]:
        #     p_replaced.append("ARTICLE")
        # else:
        #     p_replaced.append(pt)
    postag_seq = " ".join(p_replaced)
    # print(postag_seq)
    searched = re.search(CURRENT_FEW, postag_seq)
    result = (False, "", "")
    if searched:
        span = searched.span()
        construction_pattern = postag_seq[span[0] : span[1]]
        construction_pattern_span = find_pattern(
            construction_pattern.split(), postag_seq.split()
        )
        if sent_toks != []:
            try:
                sent_span = sent_toks[construction_pattern_span[0] : construction_pattern_span[1]]
                result = (True, " ".join(sent_span), construction_pattern)
            except:
                pass
    return result

# %%
new_idx = []
new_entries = []

for i, (s, st, p) in enumerate(tqdm(zip(sents, sent_tokens, postags))):
    # if i in old_idx:
    #     continue
    detected, span, pattern = detect_aann_basic(st, p)
    if detected:
        new_idx.append(i)
        new_entries.append((i, span, pattern))
# Out:
# 11632617it [00:52, 220785.44it/s]

# %%
new_entries
# Out:
# [(884, 'a smaller three to four people', 'ARTICLE JJR CD TO CD NNS'),
#  (2481, 'a good few seasons', 'ARTICLE JJ FEW NNS'),
#  (12856, 'a further two men', 'ARTICLE JJ CD NNS'),
#  (12974,
#   'an English former professional snooker player and six - times',
#   'ARTICLE JJ JJ JJ NN NN CC CD HYPH NNS'),
#  (14222, 'an uneventful few months', 'ARTICLE JJ FEW NNS'),
#  (14321, 'A further five victories', 'ARTICLE JJ CD NNS'),
#  (16576, 'an extra two to three people', 'ARTICLE JJ CD TO CD NNS'),
#  (18115, 'a full three days', 'ARTICLE JJ CD NNS'),
#  (25036, 'a further three schools', 'ARTICLE JJ CD NNS'),
#  (25160, 'a mere 8 years', 'ARTICLE JJ CD NNS'),
#  (25474, 'a further three schools', 'ARTICLE JJ CD NNS'),
#  (28788, 'a great many friends', 'ARTICLE JJ FEW NNS'),
#  (29044, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (29553, 'a great many good points', 'ARTICLE JJ FEW JJ NNS'),
#  (29793, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (34347, 'a great many persons', 'ARTICLE JJ FEW NNS'),
#  (38009,
#   'a small oil study and several drawings',
#   'ARTICLE JJ NN NN CC FEW NNS'),
#  (40066, 'a career - high 15 strikeouts', 'ARTICLE NN HYPH JJ CD NNS'),
#  (40111, 'a club - record 109 games', 'ARTICLE NN HYPH RECORD CD NNS'),
#  (45860, 'a final few moments', 'ARTICLE JJ FEW NNS'),
#  (47983, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (48239, 'a great many children', 'ARTICLE JJ FEW NNS'),
#  (52634, 'A good many years', 'ARTICLE JJ FEW NNS'),
#  (54935,
#   'a professional basketball arena and many other sport facilities',
#   'ARTICLE JJ NN NN CC FEW JJ NN NNS'),
#  (56273,
#   'an old cap or two , a pair of boots',
#   'ARTICLE JJ NN CC CD , ARTICLE NN IN NNS'),
#  (56462, 'a great many cunning tricks', 'ARTICLE JJ FEW JJ NNS'),
#  (56953, 'an estimated 400 people', 'ARTICLE VBN CD NNS'),
#  (57401, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (57750, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (58229, 'a special 100 naira', 'ARTICLE JJ CD NNS'),
#  (58320, 'An estimated 20 % of children', 'ARTICLE VBN CD NN IN NNS'),
#  (58949, 'an old woman and three maidens', 'ARTICLE JJ NN CC CD NNS'),
#  (60004, 'a good many difficult things', 'ARTICLE JJ FEW JJ NNS'),
#  (63518, 'a great many others', 'ARTICLE JJ FEW NNS'),
#  (64435, 'a great many journeys', 'ARTICLE JJ FEW NNS'),
#  (66356, 'a mere 0.02 seconds', 'ARTICLE JJ CD NNS'),
#  (66370, 'a manual 14.8 seconds', 'ARTICLE JJ CD NNS'),
#  (67870, 'a heavy heart and many sighs', 'ARTICLE JJ NN CC FEW NNS'),
#  (68769, 'an additional seven to eight feet', 'ARTICLE JJ CD TO CD NNS'),
#  (70282, 'a great many young children', 'ARTICLE JJ FEW JJ NNS'),
#  (70295, 'a great many persons', 'ARTICLE JJ FEW NNS'),
#  (71366, 'A great many officers', 'ARTICLE JJ FEW NNS'),
#  (71914, 'a good many other folks', 'ARTICLE JJ FEW JJ NNS'),
#  (72747, 'a great many doors', 'ARTICLE JJ FEW NNS'),
#  (74097, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (75040, 'a great many children', 'ARTICLE JJ FEW NNS'),
#  (80323, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (83662, 'a career - high 30 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (86713, 'a quick two minutes', 'ARTICLE JJ CD NNS'),
#  (87096, 'a hulking 261 pounds', 'ARTICLE JJ CD NNS'),
#  (88015, 'a further six weeks', 'ARTICLE JJ CD NNS'),
#  (90331, 'a good few years', 'ARTICLE JJ FEW NNS'),
#  (91528, 'a new site 65 meters', 'ARTICLE JJ NN CD NNS'),
#  (97078, 'a great many cunning tricks', 'ARTICLE JJ FEW JJ NNS'),
#  (97924, 'a record 32 teams', 'ARTICLE RECORD CD NNS'),
#  (98452, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (100994, 'a little girl three years', 'ARTICLE JJ NN CD NNS'),
#  (102023, 'a heavy heart and many sighs', 'ARTICLE JJ NN CC FEW NNS'),
#  (102160, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (102464, 'an old woman and three maidens', 'ARTICLE JJ NN CC CD NNS'),
#  (105793, 'a further 75,000 immigrants', 'ARTICLE JJR CD NNS'),
#  (110319, 'a further 250,000 copies', 'ARTICLE JJ CD NNS'),
#  (110402, 'a mere 25,000 copies', 'ARTICLE JJ CD NNS'),
#  (111512, 'a career - high 20 goals', 'ARTICLE NN HYPH JJ CD NNS'),
#  (114635, 'a great many others', 'ARTICLE JJ FEW NNS'),
#  (115579, 'a reported four children', 'ARTICLE VBN CD NNS'),
#  (117952, 'a further three charges', 'ARTICLE JJ CD NNS'),
#  (118242, 'a great many journeys', 'ARTICLE JJ FEW NNS'),
#  (121316, 'a certain fatal three days', 'ARTICLE JJ JJ CD NNS'),
#  (121793, 'an extra two and a half hours', 'ARTICLE JJ CD CC ARTICLE NN NNS'),
#  (126657, 'an additional 3,000 supporters', 'ARTICLE JJ CD NNS'),
#  (129123, 'a heavy heart and many sighs', 'ARTICLE JJ NN CC FEW NNS'),
#  (129427, 'a great many little earth', 'ARTICLE JJ FEW JJ NNS'),
#  (131301, 'a large head and two thick ears', 'ARTICLE JJ NN CC CD JJ NNS'),
#  (132365, 'a great deal more stamping of feet', 'ARTICLE JJ NN FEW NN IN NNS'),
#  (132656, 'Another fucking few minutes', 'ARTICLE JJ FEW NNS'),
#  (136087, 'a great many sparrows', 'ARTICLE JJ FEW NNS'),
#  (136989, 'a full four stars', 'ARTICLE JJ CD NNS'),
#  (140385, 'a great many young children', 'ARTICLE JJ FEW JJ NNS'),
#  (140934, 'a great festival three days', 'ARTICLE JJ NN CD NNS'),
#  (143563, 'A great many officers', 'ARTICLE JJ FEW NNS'),
#  (144287, 'a great many other weapons', 'ARTICLE JJ FEW JJ NNS'),
#  (144425, 'a great many salaams', 'ARTICLE JJ FEW NNS'),
#  (144993, 'A great many Rajas', 'ARTICLE JJ FEW NNPS'),
#  (146886, 'a great many doors', 'ARTICLE JJ FEW NNS'),
#  (148046, 'a great many rupees', 'ARTICLE JJ FEW NNS'),
#  (148355, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (148447, 'an additional ten states', 'ARTICLE JJ CD NNS'),
#  (149538, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (155767, 'a great many rupees', 'ARTICLE JJ FEW NNS'),
#  (155933, 'a great many salaams', 'ARTICLE JJ FEW NNS'),
#  (156403, 'A great many Kings', 'ARTICLE JJ FEW NNPS'),
#  (156623, 'a great many birds', 'ARTICLE JJ FEW NNS'),
#  (156938, 'a great many sepoys', 'ARTICLE JJ FEW NNS'),
#  (156939, 'a great many miles', 'ARTICLE JJ FEW NNS'),
#  (157113, 'a great many salaams', 'ARTICLE JJ FEW NNS'),
#  (159152, 'a cumulated 300 ECTS credits', 'ARTICLE VBN CD NN NNS'),
#  (162483, 'a whole forty five minutes', 'ARTICLE JJ CD CD NNS'),
#  (164678, 'a record 26 times', 'ARTICLE RECORD CD NNS'),
#  (165613, 'a great many pieces', 'ARTICLE JJ FEW NNS'),
#  (167186, 'An estimated 1,700 people', 'ARTICLE VBN CD NNS'),
#  (167399, 'an estimated 100,000 people', 'ARTICLE VBN CD NNS'),
#  (169156, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (169271, 'a great many slippers', 'ARTICLE JJ FEW NNS'),
#  (169902, 'an average sixty - six immigrants', 'ARTICLE JJ CD HYPH CD NNS'),
#  (170562, 'a great many children', 'ARTICLE JJ FEW NNS'),
#  (173662, 'an additional six months', 'ARTICLE JJ CD NNS'),
#  (175893, 'a very impressive 32 goals', 'ARTICLE RB JJ CD NNS'),
#  (179606, 'a good two years', 'ARTICLE JJ CD NNS'),
#  (182028, 'a further ten frames', 'ARTICLE JJ CD NNS'),
#  (183594, 'a cumulated 300 ECTS credits', 'ARTICLE VBN CD NN NNS'),
#  (183850, 'a future Four Lands', 'ARTICLE JJ CD NNPS'),
#  (186938, 'a mere nineteen lines', 'ARTICLE JJ CD NNS'),
#  (189145, 'a new 10,000 m', 'ARTICLE JJ CD NNS'),
#  (189241, 'a standard three or four sheets', 'ARTICLE JJ CD CC CD NNS'),
#  (193686,
#   'a separate one thousand five hundred pounds',
#   'ARTICLE JJ CD CD CD CD NNS'),
#  (204737,
#   'a miniature sleigh and eight tiny reindeer',
#   'ARTICLE JJ NN CC CD JJ NNS'),
#  (205972, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (207905,
#   'a nationally known icon and many businesses',
#   'ARTICLE RB VBN NN CC FEW NNS'),
#  (209357, 'a mere 360 metres', 'ARTICLE JJ CD NNS'),
#  (209550, 'a mere 360 metres', 'ARTICLE JJ CD NNS'),
#  (212846, 'A great many birds', 'ARTICLE JJ FEW NNS'),
#  (214928, 'a great many more Mice', 'ARTICLE JJ FEW FEW NNPS'),
#  (215963, 'a good forty minutes', 'ARTICLE JJ CD NNS'),
#  (217172, 'a round dozen blocks', 'ARTICLE JJ FEW NNS'),
#  (218494, 'a great many friends', 'ARTICLE JJ FEW NNS'),
#  (219701, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (220064, 'a petty officer and four seamen', 'ARTICLE JJ NN CC CD NNS'),
#  (220990, 'an estimated five million bricks', 'ARTICLE VBN CD CD NNS'),
#  (222931, 'a combined 5 minutes', 'ARTICLE VBN CD NNS'),
#  (223653, 'a good many cross', 'ARTICLE JJ FEW NNS'),
#  (229447, 'a full 15 games', 'ARTICLE JJ CD NNS'),
#  (229503, 'a distant 30 games', 'ARTICLE JJ CD NNS'),
#  (232264, 'an estimated 600,000 daily passengers', 'ARTICLE VBN CD JJ NNS'),
#  (232367, 'an estimated 500,000 riders', 'ARTICLE VBN CD NNS'),
#  (233354, 'a great many windings', 'ARTICLE JJ FEW NNS'),
#  (234129, 'a great many hits', 'ARTICLE JJ FEW NNS'),
#  (259194, 'a young soldier and two women', 'ARTICLE JJ NN CC CD NNS'),
#  (261780, 'a great many brains', 'ARTICLE JJ FEW NNS'),
#  (265006, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (265405, 'a great many pins', 'ARTICLE JJ FEW NNS'),
#  (265511, 'a huge surf eighty miles', 'ARTICLE JJ NN CD NNS'),
#  (269338, 'an estimated 110,000 tons', 'ARTICLE VBN CD NNS'),
#  (269339, 'an estimated 8,300 premature deaths', 'ARTICLE VBN CD JJ NNS'),
#  (269340, 'an estimated 360,000 asthma attacks', 'ARTICLE VBN CD NN NNS'),
#  (269489, 'an annualized 15 billion gallons', 'ARTICLE VBN CD CD NNS'),
#  (271759, 'an estimated 250,000 shearwater burrows', 'ARTICLE VBN CD NN NNS'),
#  (272286, 'a great pillar four days', 'ARTICLE JJ NN CD NNS'),
#  (275060, 'a constant sometimes eight colors', 'ARTICLE JJ RB CD NNS'),
#  (276710, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (278022, 'a swift 12 feet', 'ARTICLE JJ CD NNS'),
#  (279427, 'a sudden , three themes', 'ARTICLE JJ , CD NNS'),
#  (283322, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (286540, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (286591, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (288176, 'an orange dwarf star 37 light years', 'ARTICLE JJ NN NN CD NN NNS'),
#  (289262, 'A wizened little man and two ladies', 'ARTICLE JJ JJ NN CC CD NNS'),
#  (289334, 'a great many wolves', 'ARTICLE JJ FEW NNS'),
#  (296380, 'a good eight minutes', 'ARTICLE JJ CD NNS'),
#  (303658, 'a heavy man and two big rocks', 'ARTICLE JJ NN CC CD JJ NNS'),
#  (308631, 'a further nine years', 'ARTICLE JJ CD NNS'),
#  (312575, 'a good wow f forty five minutes', 'ARTICLE JJ UH NN CD CD NNS'),
#  (313443,
#   'a little rowan tree and four alder bushes',
#   'ARTICLE JJ NN NN CC CD NN NNS'),
#  (318938, 'a great many kangaroos', 'ARTICLE JJ FEW NNS'),
#  (323410,
#   'a rich cultural heritage and many locations',
#   'ARTICLE JJ JJ NN CC FEW NNS'),
#  (324283, 'a twinkling twenty miles', 'ARTICLE JJ CD NNS'),
#  (326636, 'an estimated 90,000 African slaves', 'ARTICLE VBN CD JJ NNS'),
#  (327652, 'a full ten inches', 'ARTICLE JJ CD NNS'),
#  (327972, 'an additional 124 officers', 'ARTICLE JJ CD NNS'),
#  (328094, 'a further 124 officers', 'ARTICLE JJ CD NNS'),
#  (328308, 'a further 878 army officers', 'ARTICLE JJR CD NN NNS'),
#  (329442, 'a great many other people', 'ARTICLE JJ FEW JJ NNS'),
#  (330751, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (331869, 'a great many roses', 'ARTICLE JJ FEW NNS'),
#  (332341, 'an estimated 523 Japanese soldiers', 'ARTICLE VBN CD JJ NNS'),
#  (334740, 'a cumulated 300 ECTS credits', 'ARTICLE VBN CD NN NNS'),
#  (335274, 'an estimated 100–240 black people', 'ARTICLE VBN CD JJ NNS'),
#  (343998, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (345060, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (347369, 'A further 15000 ha', 'ARTICLE JJ CD NNS'),
#  (347616, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (349194, 'a full ten years', 'ARTICLE JJ CD NNS'),
#  (351781, 'A good thirty yards', 'ARTICLE JJ CD NNS'),
#  (352538, 'an additional 16 months', 'ARTICLE JJ CD NNS'),
#  (353288, 'a great many singular things', 'ARTICLE JJ FEW JJ NNS'),
#  (353833, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (354309, 'An estimated 81 million total viewers', 'ARTICLE VBN CD CD JJ NNS'),
#  (354384, 'a great many questions', 'ARTICLE JJ FEW NNS'),
#  (354995, 'an elongated oval form 12.5 km', 'ARTICLE JJ JJ NN CD NNS'),
#  (360393, 'a chilly 248 degrees', 'ARTICLE JJ CD NNS'),
#  (360764, 'a colossal 5 stories', 'ARTICLE JJ CD NNS'),
#  (360882, 'a record seven times', 'ARTICLE RECORD CD NNS'),
#  (360886, 'a record 7 hours', 'ARTICLE RECORD CD NNS'),
#  (362374, 'an additional three years', 'ARTICLE JJ CD NNS'),
#  (363222, 'an estimated 4,694 times', 'ARTICLE JJ CD NNS'),
#  (364347, 'a good fifteen feet', 'ARTICLE JJ CD NNS'),
#  (365566, 'a great many weavers', 'ARTICLE JJ FEW NNS'),
#  (366993, 'a scant three yards', 'ARTICLE JJ CD NNS'),
#  (367449, 'a full six yards', 'ARTICLE JJ CD NNS'),
#  (368422, 'an estimated 1600 students', 'ARTICLE VBN CD NNS'),
#  (368554,
#   'an iron - bound club three or four feet',
#   'ARTICLE NN HYPH VBN NN CD CC CD NNS'),
#  (374969, 'a great many clouds', 'ARTICLE JJ FEW NNS'),
#  (375150, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (379409, 'an initial 13 issues', 'ARTICLE JJ CD NNS'),
#  (379511, 'an additional 22 issues', 'ARTICLE JJ CD NNS'),
#  (380199, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (381428, 'a very young 20 years', 'ARTICLE RB JJ CD NNS'),
#  (387630,
#   'a real estate developer and several others',
#   'ARTICLE JJ NN NN CC FEW NNS'),
#  (388051, 'a great log twenty or thirty steps', 'ARTICLE JJ NN CD CC CD NNS'),
#  (388434, 'a dead spider five times', 'ARTICLE JJ NN CD NNS'),
#  (388668, 'a great many skiffs', 'ARTICLE JJ FEW NNS'),
#  (388982, 'a long twelve or fifteen minutes', 'ARTICLE JJ CD CC CD NNS'),
#  (390650, 'a career - high 20 starts', 'ARTICLE NN HYPH JJ CD NNS'),
#  (394798, 'a married man 40 years', 'ARTICLE JJ NN CD NNS'),
#  (401200,
#   'a whole candle and three or four pieces',
#   'ARTICLE JJ NN CC CD CC CD NNS'),
#  (402649, 'a little , three or four days', 'ARTICLE JJ , CD CC CD NNS'),
#  (402955,
#   'a steep clay hill twenty or thirty feet',
#   'ARTICLE JJ NN NN CD CC CD NNS'),
#  (404724, 'an optional 48 bits', 'ARTICLE JJ CD NNS'),
#  (405109, 'a great many desirable things', 'ARTICLE JJ FEW JJ NNS'),
#  (405355, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (405357, 'a great many more things', 'ARTICLE JJ FEW FEW NNS'),
#  (406685, 'a public service 2 nights', 'ARTICLE JJ NN CD NNS'),
#  (412972, 'a half dozen buildings', 'ARTICLE JJ FEW NNS'),
#  (413441, 'a great many disagreeable things', 'ARTICLE JJ FEW JJ NNS'),
#  (414367, 'an estimated 50,000 spectators', 'ARTICLE VBN CD NNS'),
#  (414709, 'a record five times', 'ARTICLE RECORD CD NNS'),
#  (415235, 'an atomic bomb test 10 years', 'ARTICLE JJ NN NN CD NNS'),
#  (422094, 'an unheard - of 39 times', 'ARTICLE JJ HYPH JJ CD NNS'),
#  (424372, 'an even 300 wins', 'ARTICLE JJ CD NNS'),
#  (424843,
#   'a record 11 straight postseason wins',
#   'ARTICLE RECORD CD JJ NN NNS'),
#  (424861, 'a low APR score several seasons', 'ARTICLE JJ NN NN FEW NNS'),
#  (425642, 'an estimated 4,000 people', 'ARTICLE VBN CD NNS'),
#  (430484, 'a good many tears', 'ARTICLE JJ FEW NNS'),
#  (431147, 'a great many hungry days', 'ARTICLE JJ FEW JJ NNS'),
#  (433980,
#   'an annual world convention and four symposia',
#   'ARTICLE JJ NN NN CC CD NNS'),
#  (434159,
#   'a full - time official eleven years',
#   'ARTICLE JJ HYPH NN NN CD NNS'),
#  (434527, 'a weekly basis two years', 'ARTICLE JJ NN CD NNS'),
#  (434755, 'a further three fifties', 'ARTICLE JJ CD NNS'),
#  (434954, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (435586, 'a great many shapes', 'ARTICLE JJ FEW NNS'),
#  (436941, 'a record eight Players', 'ARTICLE RECORD CD NNPS'),
#  (436950, 'a good many comforts', 'ARTICLE JJ FEW NNS'),
#  (437232, 'an unprecedented five consecutive Grand', 'ARTICLE JJ CD JJ NNPS'),
#  (440735, 'a good many little gifts', 'ARTICLE JJ FEW JJ NNS'),
#  (441862, 'a good many bitter tears', 'ARTICLE JJ FEW JJ NNS'),
#  (444509, 'a great kingdom and three sons', 'ARTICLE JJ NN CC CD NNS'),
#  (445951, 'a little body and two little hands', 'ARTICLE JJ NN CC CD JJ NNS'),
#  (452023, 'an additional 100,000 men', 'ARTICLE JJ CD NNS'),
#  (457058, 'a good many hard times', 'ARTICLE JJ FEW JJ NNS'),
#  (457169, 'a great many friends', 'ARTICLE JJ FEW NNS'),
#  (457254, 'a total 21 films', 'ARTICLE JJ CD NNS'),
#  (462122,
#   'a fine picture or two , a stand of flowers',
#   'ARTICLE JJ NN CC CD , ARTICLE NN IN NNS'),
#  (464743, 'a giant triangle and three squares', 'ARTICLE JJ NN CC CD NNS'),
#  (467322, 'a record 264 grade games', 'ARTICLE RECORD CD NN NNS'),
#  (467939, 'a good many hard knocks', 'ARTICLE JJ FEW JJ NNS'),
#  (471819, 'a record 58 goals', 'ARTICLE RECORD CD NNS'),
#  (476521,
#   'a grim papa and three grimmer maiden aunts',
#   'ARTICLE JJ NN CC CD JJR NN NNS'),
#  (480233, 'a good many miracles', 'ARTICLE JJ FEW NNS'),
#  (481055, 'a mere 2 days', 'ARTICLE JJ CD NNS'),
#  (486266, 'a great many holidays', 'ARTICLE JJ FEW NNS'),
#  (495188, 'a further 700 years', 'ARTICLE JJ CD NNS'),
#  (506053, 'a protracted three or four years', 'ARTICLE JJ CD CC CD NNS'),
#  (511111, 'a fine beast fourteen hands', 'ARTICLE JJ NN CD NNS'),
#  (511331, 'a record 14 years', 'ARTICLE RECORD CD NNS'),
#  (517682,
#   'a fair and beloved wife and several lovely children',
#   'ARTICLE JJ CC JJ NN CC FEW JJ NNS'),
#  (518355, 'a paling six feet', 'ARTICLE JJ CD NNS'),
#  (519587, 'a great many various stores', 'ARTICLE JJ FEW JJ NNS'),
#  (519711, 'a record twelve national titles', 'ARTICLE RECORD CD JJ NNS'),
#  (524206, 'a good many trials', 'ARTICLE JJ FEW NNS'),
#  (524450, 'an additional two years', 'ARTICLE JJ CD NNS'),
#  (541074, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (545161, 'an unheard - of 50 men', 'ARTICLE JJ HYPH JJ CD NNS'),
#  (549224, 'a record seven times', 'ARTICLE RECORD CD NNS'),
#  (551416, 'a little town fifteen miles', 'ARTICLE JJ NN CD NNS'),
#  (554282,
#   'a new control system and more levels',
#   'ARTICLE JJ NN NN CC FEW NNS'),
#  (554300,
#   'a poor lame wife and thirteen children',
#   'ARTICLE JJ JJ NN CC CD NNS'),
#  (555150, 'a great many petroglyphs', 'ARTICLE JJ FEW NNS'),
#  (555805, 'a great many masters', 'ARTICLE JJ FEW NNS'),
#  (556885, 'a great many dead bodies', 'ARTICLE JJ FEW JJ NNS'),
#  (558281, 'a half dozen men', 'ARTICLE JJ FEW NNS'),
#  (563535, 'a little provincial town three months', 'ARTICLE JJ JJ NN CD NNS'),
#  (569678, 'an additional 2 miles', 'ARTICLE JJ CD NNS'),
#  (571603, 'a measly thousand pounds', 'ARTICLE JJ CD NNS'),
#  (573585, 'a reported 6,000 apartments', 'ARTICLE VBN CD NNS'),
#  (575112, 'An estimated 15 % of citizens', 'ARTICLE VBN CD NN IN NNS'),
#  (577024, 'a record four times', 'ARTICLE RECORD CD NNS'),
#  (579655, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (579861, 'a career - high 8.7 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (580230, 'a further 23,000 men', 'ARTICLE JJR CD NNS'),
#  (581081, 'an extra 2,600 men', 'ARTICLE JJ CD NNS'),
#  (581321, 'a further 46,750 tons', 'ARTICLE JJ CD NNS'),
#  (584500, 'an additional 1,000 sorties', 'ARTICLE JJ CD NNS'),
#  (591689,
#   'a cheap hall bedroom and two art lessons',
#   'ARTICLE JJ NN NN CC CD NN NNS'),
#  (592091, 'a great many facts', 'ARTICLE JJ FEW NNS'),
#  (592465, 'a record 25 playoff games', 'ARTICLE RECORD CD NN NNS'),
#  (599547, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (601584, 'A great many local names', 'ARTICLE JJ FEW JJ NNS'),
#  (601658, 'a small plateau 1798 m', 'ARTICLE JJ NN CD NNS'),
#  (606747, 'A half - dozen roughs', 'ARTICLE JJ HYPH FEW NNS'),
#  (606899, 'a career - best 220 wickets', 'ARTICLE NN HYPH JJ CD NNS'),
#  (607049, 'a combined 18 weeks', 'ARTICLE VBN CD NNS'),
#  (608321, 'a fine eighteen months', 'ARTICLE JJ CD NNS'),
#  (609189, 'A half - dozen postal cards', 'ARTICLE JJ HYPH FEW JJ NNS'),
#  (616060, 'A half - dozen sailors', 'ARTICLE JJ HYPH FEW NNS'),
#  (619017, 'a collective 8,000 spots', 'ARTICLE JJ CD NNS'),
#  (622773,
#   'a difficult question sentence answer sentence question sentence length three marks',
#   'ARTICLE JJ NN NN NN NN NN NN NN CD NNS'),
#  (626784, 'a half dozen ragged porters', 'ARTICLE JJ FEW JJ NNS'),
#  (629698, 'a further 11 goals', 'ARTICLE JJ CD NNS'),
#  (629791, 'a half dozen years', 'ARTICLE JJ FEW NNS'),
#  (630595,
#   'an estimated 250 million phonograph records',
#   'ARTICLE VBN CD CD NN NNS'),
#  (632815, 'a half - dozen armlets', 'ARTICLE JJ HYPH FEW NNS'),
#  (634169, 'a record 50 points', 'ARTICLE RECORD CD NNS'),
#  (634562, 'a combined 319 yards', 'ARTICLE JJ CD NNS'),
#  (637382, 'a second one eighteen months', 'ARTICLE JJ NN CD NNS'),
#  (638444, 'a prominent hill 1.5 miles', 'ARTICLE JJ NN CD NNS'),
#  (639201, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (639812, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (643629, 'an international 60 metres', 'ARTICLE JJ CD NNS'),
#  (647892, 'a further four years', 'ARTICLE JJ CD NNS'),
#  (649647, 'a vast many smart beaux', 'ARTICLE JJ FEW JJ NNS'),
#  (649710, 'a combined 20 league games', 'ARTICLE VBN CD NN NNS'),
#  (655855, 'An estimated 500 settlers', 'ARTICLE VBN CD NNS'),
#  (659440, 'a great many conquests', 'ARTICLE JJ FEW NNS'),
#  (659461, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (661854, 'a further eight motor coaches', 'ARTICLE JJ CD NN NNS'),
#  (674688, 'a record 67 doubles', 'ARTICLE RECORD CD NNS'),
#  (676196, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (676623,
#   'a high school and several other institutions',
#   'ARTICLE JJ NN CC FEW JJ NNS'),
#  (679288, 'an estimated 660 000 deaths', 'ARTICLE VBN CD CD NNS'),
#  (680569, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (683041, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (683397, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (684417, 'a good many gallons', 'ARTICLE JJ FEW NNS'),
#  (684595, 'a great many ways', 'ARTICLE JJ FEW NNS'),
#  (685098, 'a good many snobs', 'ARTICLE JJ FEW NNS'),
#  (686286, 'A good many people', 'ARTICLE JJ FEW NNS'),
#  (689299, 'an additional 700 miles', 'ARTICLE JJ CD NNS'),
#  (690564, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (690769,
#   'a recumbent half - moon and two stars',
#   'ARTICLE JJ JJ HYPH NN CC CD NNS'),
#  (691359,
#   'an estimated one hundred and sixty three , six forty pounds',
#   'ARTICLE VBN CD CD CC CD CD , CD CD NNS'),
#  (692650, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (693440, 'a great many other things', 'ARTICLE JJ FEW JJ NNS'),
#  (699298, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (700170, 'an extra eleven million pounds', 'ARTICLE JJ CD CD NNS'),
#  (701738, 'a possible two points', 'ARTICLE JJ CD NNS'),
#  (707369, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (707979, 'a further 168 men', 'ARTICLE JJ CD NNS'),
#  (711502, 'a good thousand feet', 'ARTICLE JJ CD NNS'),
#  (711598, 'an accumulative 44 years', 'ARTICLE JJ CD NNS'),
#  (713081, 'an additional 18 episodes', 'ARTICLE JJ CD NNS'),
#  (713538, 'a possible ten marks', 'ARTICLE JJ CD NNS'),
#  (713796, 'a great many arguments', 'ARTICLE JJ FEW NNS'),
#  (714734, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (716317, 'An astonishing 98 people', 'ARTICLE JJ CD NNS'),
#  (717335, 'a huge old brown trout ten times', 'ARTICLE JJ JJ NN NN CD NNS'),
#  (718048, 'a great many other folks', 'ARTICLE JJ FEW JJ NNS'),
#  (719099, 'a good many fine gentlemen', 'ARTICLE JJ FEW JJ NNS'),
#  (719411, 'a great many other people', 'ARTICLE JJ FEW JJ NNS'),
#  (719667, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (720549, 'A full hundred yards', 'ARTICLE JJ CD NNS'),
#  (721225, 'a half - dozen men', 'ARTICLE JJ HYPH FEW NNS'),
#  (721557, 'A great many years', 'ARTICLE JJ FEW NNS'),
#  (723243, 'a good many other people', 'ARTICLE JJ FEW JJ NNS'),
#  (723808, 'a narrow crack ten yards', 'ARTICLE JJ NN CD NNS'),
#  (724504, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (725296, 'a mammoth four tons', 'ARTICLE JJ CD NNS'),
#  (727922, 'a great many fox -', 'ARTICLE JJ FEW NN NNS'),
#  (728005, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (729549, 'a great many hundred years', 'ARTICLE JJ FEW CD NNS'),
#  (730597, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (730756, 'A half - dozen times', 'ARTICLE JJ HYPH FEW NNS'),
#  (731502, 'a small town twelve miles', 'ARTICLE JJ NN CD NNS'),
#  (732571, 'A great many members', 'ARTICLE JJ FEW NNS'),
#  (733253,
#   'a large parent comet several centuries',
#   'ARTICLE JJ NN NN FEW NNS'),
#  (733392, 'a good many folks', 'ARTICLE JJ FEW NNS'),
#  (733988, 'a full three years', 'ARTICLE JJ CD NNS'),
#  (734988, 'a good few drinks', 'ARTICLE JJ FEW NNS'),
#  (735836, 'a good many Foxes', 'ARTICLE JJ FEW NNPS'),
#  (735855, 'An estimated 500 children', 'ARTICLE VBN CD NNS'),
#  (736969, 'a negative 8x times', 'ARTICLE JJ CD NNS'),
#  (743145, 'a great many strange things', 'ARTICLE JJ FEW JJ NNS'),
#  (743641, 'a good fifteen miles', 'ARTICLE JJ CD NNS'),
#  (753679,
#   'a very good forcep two or three punches',
#   'ARTICLE RB JJ NN CD CC CD NNS'),
#  (755444, 'a tournament - best seven goals', 'ARTICLE NN HYPH JJS CD NNS'),
#  (760028, 'a great many armed men', 'ARTICLE JJ FEW JJ NNS'),
#  (760100, 'A great many people', 'ARTICLE JJ FEW NNS'),
#  (760639, 'a good many jokes', 'ARTICLE JJ FEW NNS'),
#  (761101, 'an additional 17 years', 'ARTICLE JJ CD NNS'),
#  (762439, 'a great many mistakes', 'ARTICLE JJ FEW NNS'),
#  (770255, 'a great many mistakes', 'ARTICLE JJ FEW NNS'),
#  (771428, 'a whole lot more things', 'ARTICLE JJ NN FEW NNS'),
#  (772627, 'a perfect five stars', 'ARTICLE JJ CD NNS'),
#  (772629, 'a perfect five stars', 'ARTICLE JJ CD NNS'),
#  (772742, 'a perfect five stars', 'ARTICLE JJ CD NNS'),
#  (773602, 'a good three , four weeks', 'ARTICLE JJ CD , CD NNS'),
#  (773978, 'a total 98 episodes', 'ARTICLE JJ CD NNS'),
#  (778592, 'a great many responsibilities', 'ARTICLE JJ FEW NNS'),
#  (778896, 'a record eight consecutive stages', 'ARTICLE RECORD CD JJ NNS'),
#  (779012, 'a good many mild days', 'ARTICLE JJ FEW JJ NNS'),
#  (779707, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (780300, 'a great many huge flies', 'ARTICLE JJ FEW JJ NNS'),
#  (780327, 'a great many species', 'ARTICLE JJ FEW NNS'),
#  (780468, 'a great many more deaths', 'ARTICLE JJ FEW FEW NNS'),
#  (780470, 'a great many nobles', 'ARTICLE JJ FEW NNS'),
#  (781012, 'a good many hours', 'ARTICLE JJ FEW NNS'),
#  (781996, 'a great many huge flies', 'ARTICLE JJ FEW JJ NNS'),
#  (782018, 'a great many species', 'ARTICLE JJ FEW NNS'),
#  (785670, 'a crucial three points', 'ARTICLE JJ CD NNS'),
#  (788282,
#   'a small village and parish situated 8 miles',
#   'ARTICLE JJ NN CC NN VBN CD NNS'),
#  (788832, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (790887, 'A good many women', 'ARTICLE JJ FEW NNS'),
#  (791649, 'an audacious shot 30 yards', 'ARTICLE JJ NN CD NNS'),
#  (792088, 'a good many boys', 'ARTICLE JJ FEW NNS'),
#  (794624, 'A great many adventurers', 'ARTICLE JJ FEW NNS'),
#  (797089, 'a further 360 people', 'ARTICLE JJ CD NNS'),
#  (800215, 'An additional seven awards', 'ARTICLE JJ CD NNS'),
#  (801302, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (801306, 'a great many other people', 'ARTICLE JJ FEW JJ NNS'),
#  (803227, 'a great many good friends', 'ARTICLE JJ FEW JJ NNS'),
#  (805611, 'a great many personal sacrifices', 'ARTICLE JJ FEW JJ NNS'),
#  (805856, 'a confirmed drunkard twenty years', 'ARTICLE VBN NN CD NNS'),
#  (808707, 'A great many fair ones', 'ARTICLE JJ FEW JJ NNS'),
#  (810797, 'an additional 1,000 miles', 'ARTICLE JJ CD NNS'),
#  (811179, 'a very pretty lake several miles', 'ARTICLE RB JJ NN FEW NNS'),
#  (812215, 'a long gun and several swivel guns', 'ARTICLE JJ NN CC FEW JJ NNS'),
#  (815055, 'a possible 45 games', 'ARTICLE JJ CD NNS'),
#  (815402, 'a good many bears', 'ARTICLE JJ FEW NNS'),
#  (815596, 'another little boy many years', 'ARTICLE JJ NN FEW NNS'),
#  (816535, 'a good many fairies', 'ARTICLE JJ FEW NNS'),
#  (824964, 'a great many creatures', 'ARTICLE JJ FEW NNS'),
#  (825394, 'a good many other efforts', 'ARTICLE JJ FEW JJ NNS'),
#  (828872, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (829036, 'a good many fairies', 'ARTICLE JJ FEW NNS'),
#  (831688, 'a great many pets', 'ARTICLE JJ FEW NNS'),
#  (834155, 'a good thirty dollars', 'ARTICLE JJ CD NNS'),
#  (836618, 'A great many children', 'ARTICLE JJ FEW NNS'),
#  (836977, 'a fucking few minutes', 'ARTICLE JJ FEW NNS'),
#  (837469, 'a marvelous like two nights', 'ARTICLE JJ UH CD NNS'),
#  (844769, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (848917, 'a mere eighteen days', 'ARTICLE JJ CD NNS'),
#  (851342, 'a great many Turkeys', 'ARTICLE JJ FEW NNPS'),
#  (852154, 'an extra 9 experiences', 'ARTICLE JJ CD NNS'),
#  (852985, 'a great many other things', 'ARTICLE JJ FEW JJ NNS'),
#  (853395,
#   'a season - high 12 combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (853601, 'a great many women', 'ARTICLE JJ FEW NNS'),
#  (854752,
#   'an inner bridge and two outer bridges',
#   'ARTICLE JJ NN CC CD JJ NNS'),
#  (855167, 'a great many workmen', 'ARTICLE JJ FEW NNS'),
#  (856239, 'a great many sick men', 'ARTICLE JJ FEW JJ NNS'),
#  (860617, 'a round dozen reviews', 'ARTICLE JJ FEW NNS'),
#  (864747,
#   'a direct current overhead power supply 600 Volts',
#   'ARTICLE JJ JJ JJ NN NN CD NNS'),
#  (864780, 'a great many windings', 'ARTICLE JJ FEW NNS'),
#  (866580, 'a great many doors', 'ARTICLE JJ FEW NNS'),
#  (866896, 'a possible 45 votes', 'ARTICLE JJ CD NNS'),
#  (868150, 'a clear ten years', 'ARTICLE JJ CD NNS'),
#  (868864, 'a large waggon and eight horses', 'ARTICLE JJ NN CC CD NNS'),
#  (870572, 'a fair wife and two children', 'ARTICLE JJ NN CC CD NNS'),
#  (876055, 'a mere three years', 'ARTICLE JJ CD NNS'),
#  (879399, 'a very good few seasons', 'ARTICLE RB JJ FEW NNS'),
#  (882136, 'a personal best 30 rebounds', 'ARTICLE JJ JJS CD NNS'),
#  (883710, 'a safe anchorage fifteen miles', 'ARTICLE JJ NN CD NNS'),
#  (884736,
#   'A little further out , two bear cubs',
#   'ARTICLE JJ RB RB , CD NN NNS'),
#  (886534, 'a scandalous divorce six years', 'ARTICLE JJ NN CD NNS'),
#  (888596, 'an unexpected twelve months', 'ARTICLE JJ CD NNS'),
#  (889514, 'a mere five minutes', 'ARTICLE JJ CD NNS'),
#  (894084,
#   'a season - high ten combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (897449, 'a round twenty years', 'ARTICLE JJ CD NNS'),
#  (900754, 'a great many other things', 'ARTICLE JJ FEW JJ NNS'),
#  (904249, 'a great many voices', 'ARTICLE JJ FEW NNS'),
#  (904634, 'an additional thirteen minutes', 'ARTICLE JJ CD NNS'),
#  (905191, 'a combined ten seasons', 'ARTICLE JJ CD NNS'),
#  (905657, 'a great many curious ones', 'ARTICLE JJ FEW JJ NNS'),
#  (905842, 'a combined 14 seasons', 'ARTICLE JJ CD NNS'),
#  (906022, 'a total 16 finals', 'ARTICLE JJ CD NNS'),
#  (906344, 'A Little Less Sixteen Candles', 'ARTICLE JJ JJR CD NNS'),
#  (906527, 'a whole lot more questions', 'ARTICLE JJ NN FEW NNS'),
#  (912569, 'a popular Top 40 outlet for years', 'ARTICLE JJ NN CD NN IN NNS'),
#  (918115, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (918182, 'an impressive 30 appearances', 'ARTICLE JJ CD NNS'),
#  (918241, 'a superb 94 league appearances', 'ARTICLE JJ CD NN NNS'),
#  (919708, 'a great many brave deeds', 'ARTICLE JJ FEW JJ NNS'),
#  (919766, 'a good many young men', 'ARTICLE JJ FEW JJ NNS'),
#  (920178, 'a great many strange things', 'ARTICLE JJ FEW JJ NNS'),
#  (920576, 'a great many Nymphs', 'ARTICLE JJ FEW NNPS'),
#  (922300, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (922301, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (923817, 'a good many mild days', 'ARTICLE JJ FEW JJ NNS'),
#  (924449, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (924922, 'a great many huge flies', 'ARTICLE JJ FEW JJ NNS'),
#  (924936, 'a great many species', 'ARTICLE JJ FEW NNS'),
#  (925782, 'a good many hours', 'ARTICLE JJ FEW NNS'),
#  (926144, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (926892, 'a great many strange adventures', 'ARTICLE JJ FEW JJ NNS'),
#  (927899, 'a great many friends', 'ARTICLE JJ FEW NNS'),
#  (929614, 'a quiet and delightful hundred years', 'ARTICLE JJ CC JJ CD NNS'),
#  (930519, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (930670, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (930930, 'a great many hundred years', 'ARTICLE JJ FEW CD NNS'),
#  (931194, 'a great many playful leaps', 'ARTICLE JJ FEW JJ NNS'),
#  (933162, 'a great many tender feelings', 'ARTICLE JJ FEW JJ NNS'),
#  (933324, 'an estimated 65 % of customers', 'ARTICLE VBN CD NN IN NNS'),
#  (934404, 'an audio CD and several DVDs', 'ARTICLE JJ NN CC FEW NNS'),
#  (935360, 'a great many Giants', 'ARTICLE JJ FEW NNPS'),
#  (935809, 'a great many thousand Pygmies', 'ARTICLE JJ FEW CD NNPS'),
#  (935959, 'a great many centuries', 'ARTICLE JJ FEW NNS'),
#  (936697, 'a particular few types', 'ARTICLE JJ FEW NNS'),
#  (937766, 'a vast many rows', 'ARTICLE JJ FEW NNS'),
#  (937870, 'a total 51 episodes', 'ARTICLE JJ CD NNS'),
#  (937950, 'a great many trumpeters', 'ARTICLE JJ FEW NNS'),
#  (938271, 'a great many hurricanes', 'ARTICLE JJ FEW NNS'),
#  (939937, 'a great many yards', 'ARTICLE JJ FEW NNS'),
#  (940501, 'a great many beautiful shells', 'ARTICLE JJ FEW JJ NNS'),
#  (940606, 'a great many flowers', 'ARTICLE JJ FEW NNS'),
#  (941399, 'a vast many tender fears', 'ARTICLE JJ FEW JJ NNS'),
#  (941811, 'a great many other accomplishments', 'ARTICLE JJ FEW JJ NNS'),
#  (941945, 'a great many little children', 'ARTICLE JJ FEW JJ NNS'),
#  (942569, 'a great many misfortunes', 'ARTICLE JJ FEW NNS'),
#  (942739, 'a great many tears', 'ARTICLE JJ FEW NNS'),
#  (943976, 'an initial 150 specialty stores', 'ARTICLE JJ CD NN NNS'),
#  (944877, 'a great many years', 'ARTICLE JJ FEW NNS'),
#  (957031, 'a great many ladies', 'ARTICLE JJ FEW NNS'),
#  (957682, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (957846, 'a great many baskets', 'ARTICLE JJ FEW NNS'),
#  (962360, 'a good many words', 'ARTICLE JJ FEW NNS'),
#  (962753, 'a combined 41 official reigns', 'ARTICLE VBN CD JJ NNS'),
#  (962826, 'A great many empty bottles', 'ARTICLE JJ FEW JJ NNS'),
#  (964063, 'a good many trifling pieces', 'ARTICLE JJ FEW NN NNS'),
#  (965431, 'An additional 3,400 commuters', 'ARTICLE JJ CD NNS'),
#  (965500, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (965975, 'an additional eight strings', 'ARTICLE JJ CD NNS'),
#  (968836, 'a career - high seven tackles', 'ARTICLE NN HYPH JJ CD NNS'),
#  (970597, 'a different color-- 1.35 times', 'ARTICLE JJ NN CD NNS'),
#  (971038, 'a different color-- 2 times', 'ARTICLE JJ NN CD NNS'),
#  (971044, 'a further three seats', 'ARTICLE JJ CD NNS'),
#  (971240, 'a great many good points', 'ARTICLE JJ FEW JJ NNS'),
#  (973136, 'a half dozen finishing cuts', 'ARTICLE JJ FEW JJ NNS'),
#  (974647, 'a good many children', 'ARTICLE JJ FEW NNS'),
#  (977985, 'a - dozen little ones', 'ARTICLE JJ FEW JJ NNS'),
#  (980028, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (984670, 'An estimated 700,000 people', 'ARTICLE VBN CD NNS'),
#  (985167, 'an extra thirty minutes', 'ARTICLE JJ CD NNS'),
#  (987321, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (987955, 'an impressive 24 goals', 'ARTICLE JJ CD NNS'),
#  (996623, 'a vague idea 50 years', 'ARTICLE JJ NN CD NNS'),
#  (997177, 'a great many little ones', 'ARTICLE JJ FEW JJ NNS'),
#  (1001689, 'an extra three hundred miles', 'ARTICLE JJ CD CD NNS'),
#  (1003403, 'a potential 40,000 secondary jobs', 'ARTICLE JJ CD JJ NNS'),
#  (1003762,
#   'a superior geographical environment and many railways',
#   'ARTICLE JJ JJ NN CC FEW NNS'),
#  (1008623, 'a great many feelings', 'ARTICLE JJ FEW NNS'),
#  (1012452, 'A scant six years', 'ARTICLE JJ CD NNS'),
#  (1014465,
#   'a vast cake and several pumpkin pies',
#   'ARTICLE JJ NN CC FEW NN NNS'),
#  (1015402, 'a good forty feet', 'ARTICLE JJ CD NNS'),
#  (1016600, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (1018828, 'a half - dozen boys', 'ARTICLE JJ HYPH FEW NNS'),
#  (1021740, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (1021799, 'a great many places', 'ARTICLE JJ FEW NNS'),
#  (1025773, 'an old father and two fryars', 'ARTICLE JJ NN CC CD NNS'),
#  (1028306,
#   'a half - dozen pink thimble cakes',
#   'ARTICLE JJ HYPH FEW JJ NN NNS'),
#  (1030929, 'a great many garments', 'ARTICLE JJ FEW NNS'),
#  (1034449, 'a large pine and several birches', 'ARTICLE JJ NN CC FEW NNS'),
#  (1035750, 'a monumental facade and two floors', 'ARTICLE JJ NN CC CD NNS'),
#  (1037633, 'a good many months', 'ARTICLE JJ FEW NNS'),
#  (1038906, 'a combined nine points', 'ARTICLE VBN CD NNS'),
#  (1046039, 'a really nice three hours', 'ARTICLE RB JJ CD NNS'),
#  (1049746, 'an additional five awards', 'ARTICLE JJ CD NNS'),
#  (1057216,
#   'a court - appointed guardian three years',
#   'ARTICLE NN HYPH VBN NN CD NNS'),
#  (1057381, 'a new 150 meters', 'ARTICLE JJ CD NNS'),
#  (1057955, 'a then career - high 12 points', 'ARTICLE RB NN HYPH JJ CD NNS'),
#  (1058036, 'a then career - high 21 points', 'ARTICLE RB NN HYPH JJ CD NNS'),
#  (1058041, 'a career - high 24 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1058053, 'a season - high 16 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1058056, 'a career - high 27 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1058060, 'a season - high 19 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1058303, 'an additional 5 years', 'ARTICLE JJ CD NNS'),
#  (1061024, 'an additional nine seconds', 'ARTICLE JJ CD NNS'),
#  (1061041, 'an estimated four million times', 'ARTICLE VBN CD CD NNS'),
#  (1061807, 'a mere 11 kilometres', 'ARTICLE JJ CD NNS'),
#  (1062593, 'a wind - aided 12.06 seconds', 'ARTICLE NN HYPH VBN CD NNS'),
#  (1063867, 'a record 25 applicants', 'ARTICLE RECORD CD NNS'),
#  (1065671, 'a good few notes', 'ARTICLE JJ FEW NNS'),
#  (1070028, 'a little bit more communications', 'ARTICLE JJ NN FEW NNS'),
#  (1072311, 'an additional 100 children', 'ARTICLE JJ CD NNS'),
#  (1072891, 'an additional four officers', 'ARTICLE JJ CD NNS'),
#  (1077122, 'an estimated 10,000 illegal aliens', 'ARTICLE VBN CD JJ NNS'),
#  (1078134, 'a good few notes', 'ARTICLE JJ FEW NNS'),
#  (1083946, 'A further seven taxa', 'ARTICLE JJ CD NNS'),
#  (1084798, 'a further two seasons', 'ARTICLE JJ CD NNS'),
#  (1085428, 'a further 33 points', 'ARTICLE JJ CD NNS'),
#  (1085629,
#   'a season - high seven combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (1085640, 'a season - high six solo tackles', 'ARTICLE NN HYPH JJ CD JJ NNS'),
#  (1085641,
#   'a season - high seven combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (1085659,
#   'a season - high three combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (1085660,
#   'a season - high four combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (1085675,
#   'a season - high two pass deflections',
#   'ARTICLE NN HYPH JJ CD NN NNS'),
#  (1085676,
#   'a career - high nine combined tackles',
#   'ARTICLE NN HYPH JJ CD VBN NNS'),
#  (1096680,
#   'an outstanding second half fightback and five unanswered tries',
#   'ARTICLE JJ JJ NN NN CC CD JJ NNS'),
#  (1096683, 'A modest 4 wins', 'ARTICLE JJ CD NNS'),
#  (1104143, 'a career - best 20 games', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1104938, 'a further 15 games', 'ARTICLE JJ CD NNS'),
#  (1105876, 'an estimated 5,000 Jews', 'ARTICLE VBN CD NNPS'),
#  (1106692, 'an extra five days', 'ARTICLE JJ CD NNS'),
#  (1106724, 'an extra five days', 'ARTICLE JJ CD NNS'),
#  (1106873, 'a massive 2.5 kilograms', 'ARTICLE JJ CD NNS'),
#  (1110967, 'an extra 1,500 francs', 'ARTICLE JJ CD NNS'),
#  (1111131, 'an extra 2,000 francs', 'ARTICLE JJ CD NNS'),
#  (1122189,
#   'A red oval - shaped embroidered item 1 3/8 inches',
#   'ARTICLE JJ NN HYPH JJ VBN NN CD CD NNS'),
#  (1122715, 'a season - high 21 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1122722, 'a season - high 18 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1122769, 'a career - high 30 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1122891, 'a career - high 32 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1125252, 'an additional 27,000 customers', 'ARTICLE JJ CD NNS'),
#  (1125271, 'an estimated 20 acres', 'ARTICLE VBN CD NNS'),
#  (1125302, 'an additional 300 acres', 'ARTICLE JJ CD NNS'),
#  (1127481, 'a further six consecutive seasons', 'ARTICLE JJ CD JJ NNS'),
#  (1127485, 'a further two seasons', 'ARTICLE JJ CD NNS'),
#  (1127488, 'a further 27 goals', 'ARTICLE JJ CD NNS'),
#  (1139340, 'an estimated 90 German soldiers', 'ARTICLE VBN CD JJ NNS'),
#  (1145432, 'a career - high 39 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1148433, 'a cold few days', 'ARTICLE JJ FEW NNS'),
#  (1149912, 'a further 25 dependent translators', 'ARTICLE JJR CD JJ NNS'),
#  (1152914, 'An estimated five million people', 'ARTICLE VBN CD CD NNS'),
#  (1155432, 'an extra four packets', 'ARTICLE JJ CD NNS'),
#  (1156125, 'a further three years', 'ARTICLE JJ CD NNS'),
#  (1159094, 'an additional 300 men', 'ARTICLE JJ CD NNS'),
#  (1166495,
#   'a broken leg and two or three bullets',
#   'ARTICLE VBN NN CC CD CC CD NNS'),
#  (1177119, 'a last few words', 'ARTICLE JJ FEW NNS'),
#  (1177730, 'a further four victories', 'ARTICLE JJ CD NNS'),
#  (1177744, 'a further three victories', 'ARTICLE JJ CD NNS'),
#  (1180348, 'a grueling 10 - round points', 'ARTICLE JJ CD HYPH NN NNS'),
#  (1180786, 'a possible four stars', 'ARTICLE JJ CD NNS'),
#  (1184006, 'a further 13 victories', 'ARTICLE JJ CD NNS'),
#  (1189492, 'a similar project several years', 'ARTICLE JJ NN FEW NNS'),
#  (1191070, 'a tough final two years', 'ARTICLE JJ JJ CD NNS'),
#  (1193835, 'an additional 20,000 people', 'ARTICLE JJ CD NNS'),
#  (1196176, 'a further 36 hectares', 'ARTICLE JJR CD NNS'),
#  (1200004, 'an extra twenty eight days', 'ARTICLE JJ CD CD NNS'),
#  (1200028, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1205026, 'a white blaze and three white feet', 'ARTICLE JJ NN CC CD JJ NNS'),
#  (1209325, 'a record 78–76 , 30 games', 'ARTICLE RECORD CD , CD NNS'),
#  (1210569,
#   'a career - high and franchise record 525 passing yards',
#   'ARTICLE NN HYPH NN CC NN RECORD CD NN NNS'),
#  (1218790, 'a good 25 pounds', 'ARTICLE JJ CD NNS'),
#  (1219318, 'a great many days', 'ARTICLE JJ FEW NNS'),
#  (1220924, 'a good many times', 'ARTICLE JJ FEW NNS'),
#  (1221481, 'A good many thoughts', 'ARTICLE JJ FEW NNS'),
#  (1223015,
#   'a further two and a half lengths',
#   'ARTICLE JJ CD CC ARTICLE NN NNS'),
#  (1225595, 'a further three lengths', 'ARTICLE JJ CD NNS'),
#  (1226354, 'a good many little scenes', 'ARTICLE JJ FEW JJ NNS'),
#  (1227520, 'an improvised speech several hours', 'ARTICLE VBN NN FEW NNS'),
#  (1232712, 'a good many cries', 'ARTICLE JJ FEW NNS'),
#  (1238708, 'a combined five times', 'ARTICLE VBN CD NNS'),
#  (1240447, 'a large arena and many people', 'ARTICLE JJ NN CC FEW NNS'),
#  (1243449, 'an additional 4,000 seats', 'ARTICLE JJ CD NNS'),
#  (1247908, 'a positive ten pounds', 'ARTICLE JJ CD NNS'),
#  (1248622, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (1249753, 'a further 21 appearances', 'ARTICLE JJ CD NNS'),
#  (1250299, 'a career - high 44 tackles', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1251794, 'a further two months', 'ARTICLE JJ CD NNS'),
#  (1252512, 'A good few years', 'ARTICLE JJ FEW NNS'),
#  (1252921, 'a good many comforts', 'ARTICLE JJ FEW NNS'),
#  (1256782,
#   'an American ship and three British ships',
#   'ARTICLE JJ NN CC CD JJ NNS'),
#  (1257167, 'a good 20 minutes', 'ARTICLE JJ CD NNS'),
#  (1257272, 'a good ten minutes', 'ARTICLE JJ CD NNS'),
#  (1257647, 'a small town 16 kilometers', 'ARTICLE JJ NN CD NNS'),
#  (1260656, 'a good many little gifts', 'ARTICLE JJ FEW JJ NNS'),
#  (1263094, 'a good many bitter tears', 'ARTICLE JJ FEW JJ NNS'),
#  (1263995, 'an awful three years', 'ARTICLE JJ CD NNS'),
#  (1264078, 'a white star three times', 'ARTICLE JJ NN CD NNS'),
#  (1264321, 'an estimated 2,998,235 people', 'ARTICLE VBN CD NNS'),
#  (1266036, 'an extra three laps', 'ARTICLE JJ CD NNS'),
#  (1266128, 'a record 15 cautions', 'ARTICLE RECORD CD NNS'),
#  (1266185, 'a record 140 laps', 'ARTICLE RECORD CD NNS'),
#  (1267577, 'a scheduled flight four times', 'ARTICLE VBN NN CD NNS'),
#  (1270300, 'A deep trench 3×5 metres', 'ARTICLE JJ NN CD NNS'),
#  (1270302, 'a single room 8×3 metres', 'ARTICLE JJ NN CD NNS'),
#  (1271309, 'a single character or two characters', 'ARTICLE JJ NN CC CD NNS'),
#  (1279650, 'an estimated 700,000 apple trees', 'ARTICLE VBN CD NN NNS'),
#  (1287087, 'an additional 100 million tonnes', 'ARTICLE JJ CD CD NNS'),
#  (1289407, 'an expected 18,831 dwellings', 'ARTICLE JJ CD NNS'),
#  (1290643,
#   'a broad , low gradient glacier 8 nautical miles',
#   'ARTICLE JJ , JJ NN NN CD JJ NNS'),
#  (1292132, 'an intensive 20 hours', 'ARTICLE JJ CD NNS'),
#  (1292318, 'a total 1000 kW', 'ARTICLE JJ CD NNS'),
#  (1292682,
#   'a narrow deeply entrenched glacier 9 nautical miles',
#   'ARTICLE JJ RB VBN NN CD JJ NNS'),
#  (1292963,
#   'a low , snow - covered promontory 7 nautical miles',
#   'ARTICLE JJ , NN HYPH VBN NN CD JJ NNS'),
#  (1293042,
#   'a small ice escarpment 7 nautical miles',
#   'ARTICLE JJ NN NN CD JJ NNS'),
#  (1295945, 'a small township 15 minutes', 'ARTICLE JJ NN CD NNS'),
#  (1297192, 'a good many hard times', 'ARTICLE JJ FEW JJ NNS'),
#  (1297362, 'a great many friends', 'ARTICLE JJ FEW NNS'),
#  (1299445, 'a record 60 weeks', 'ARTICLE RECORD CD NNS'),
#  (1299959, 'a career - best 16 goals', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1305404, 'a combined two goals', 'ARTICLE VBN CD NNS'),
#  (1307441,
#   'a fine picture or two , a stand of flowers',
#   'ARTICLE JJ NN CC CD , ARTICLE NN IN NNS'),
#  (1310978, 'a symmetrical three bays', 'ARTICLE JJ CD NNS'),
#  (1321965, 'a good many hard knocks', 'ARTICLE JJ FEW JJ NNS'),
#  (1329914, 'a good 12 hours', 'ARTICLE JJ CD NNS'),
#  (1336876, 'a perfect record , 16 wins', 'ARTICLE JJ RECORD , CD NNS'),
#  (1342394,
#   'a grim papa and three grimmer maiden aunts',
#   'ARTICLE JJ NN CC CD JJR NN NNS'),
#  (1345777, 'a very different document 24 years', 'ARTICLE RB JJ NN CD NNS'),
#  (1346335, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (1346381, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (1347728, 'a modest 14 points', 'ARTICLE JJ CD NNS'),
#  (1351024, 'a good many miracles', 'ARTICLE JJ FEW NNS'),
#  (1362853, 'a full seven minutes', 'ARTICLE JJ CD NNS'),
#  (1364520, 'an estimated two thirds', 'ARTICLE VBN CD NNS'),
#  (1365758,
#   'an armored brigade commander and two regimental commanders',
#   'ARTICLE JJ NN NN CC CD JJ NNS'),
#  (1366495, 'a reported 150,000 prisoners', 'ARTICLE VBN CD NNS'),
#  (1369257, 'a full lectureship three years', 'ARTICLE JJ NN CD NNS'),
#  (1377451, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1384107, 'a combined 15 points', 'ARTICLE JJ CD NNS'),
#  (1385650, 'An estimated 80 % of schools', 'ARTICLE VBN CD NN IN NNS'),
#  (1391015, 'an estimated 250,000 adherents', 'ARTICLE VBN CD NNS'),
#  (1398519, 'a brand new baby twenty years', 'ARTICLE RB JJ NN CD NNS'),
#  (1399312, 'an estimated three years', 'ARTICLE VBN CD NNS'),
#  (1404734, 'a good many fine ladies', 'ARTICLE JJ FEW JJ NNS'),
#  (1407457, 'an estimated 70 million people', 'ARTICLE VBN CD CD NNS'),
#  (1415853, 'a half dozen educational conferences', 'ARTICLE JJ FEW JJ NNS'),
#  (1418995, 'an approximate 1.8 million people', 'ARTICLE JJ CD CD NNS'),
#  (1421006, 'a half - billion dollars', 'ARTICLE JJ HYPH CD NNS'),
#  (1422770, 'an estimated 5,350 tons', 'ARTICLE VBN CD NNS'),
#  (1424174, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1426437, 'a simple two - axis', 'ARTICLE JJ CD HYPH NNS'),
#  (1428678, 'a further 4,830 Germans', 'ARTICLE JJ CD NNPS'),
#  (1429064,
#   'a shared room or two separate rooms',
#   'ARTICLE VBN NN CC CD JJ NNS'),
#  (1437605, 'a further 35 partners', 'ARTICLE JJR CD NNS'),
#  (1448322, 'An estimated 343,000 people', 'ARTICLE VBN CD NNS'),
#  (1449796, 'an estimated 38,000 bushes', 'ARTICLE VBN CD NNS'),
#  (1452280, 'an additional 53,300 cellular phones', 'ARTICLE JJ CD JJ NNS'),
#  (1455166, 'an estimated 4,560,000 viewers', 'ARTICLE VBN CD NNS'),
#  (1462528, 'an additional four primary schools', 'ARTICLE JJ CD JJ NNS'),
#  (1468894, 'an additional six years', 'ARTICLE JJ CD NNS'),
#  (1474066, 'a select few bioreporters', 'ARTICLE JJ FEW NNS'),
#  (1477206, 'a mere two hours', 'ARTICLE JJ CD NNS'),
#  (1481999, 'a further two goals', 'ARTICLE JJ CD NNS'),
#  (1483274, 'a massive 26 weeks', 'ARTICLE JJ CD NNS'),
#  (1486939, 'a good seven minutes', 'ARTICLE JJ CD NNS'),
#  (1487488, 'a local nursing home eight days', 'ARTICLE JJ NN NN CD NNS'),
#  (1489449, 'a half hundred enthusiastic youngsters', 'ARTICLE JJ CD JJ NNS'),
#  (1493174, 'a cold deck three times', 'ARTICLE JJ NN CD NNS'),
#  (1495013, 'a combined 52 league appearances', 'ARTICLE VBN CD NN NNS'),
#  (1495512, 'an additional 20 years', 'ARTICLE JJ CD NNS'),
#  (1495557, 'an additional 20 years', 'ARTICLE JJ CD NNS'),
#  (1502688, 'a great many flowers', 'ARTICLE JJ FEW NNS'),
#  (1504424,
#   'an older brother and two younger sisters',
#   'ARTICLE JJR NN CC CD JJR NNS'),
#  (1505615, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (1507775, 'a good many years', 'ARTICLE JJ FEW NNS'),
#  (1507894, 'a reported 14 million dollars', 'ARTICLE JJ CD CD NNS'),
#  (1508563, 'a career - high 46 tackles', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1510160, 'a minimum 40 trams', 'ARTICLE JJ CD NNS'),
# ...
#  (1539670, 'a career - best 17.6 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1539691, 'a season - high 26 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1540683, 'a career - high 237 strikeouts', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1550393, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1551831,
#   'a good many more and worse disappointments',
#   'ARTICLE JJ FEW FEW CC JJR NNS'),
#  (1557201, 'a little bit more hands', 'ARTICLE JJ NN FEW NNS'),
#  (1558223,
#   'a record 22 confirmed championship defenses',
#   'ARTICLE RECORD CD VBN NN NNS'),
#  (1564595, 'a full four years', 'ARTICLE JJ CD NNS'),
#  (1568800, 'a scant three quarters', 'ARTICLE JJ CD NNS'),
#  (1571540, 'an optimum 30 degrees', 'ARTICLE JJ CD NNS'),
#  (1572466, "a chemical weapon- 1 t 's", 'ARTICLE JJ NN CD NN NNS'),
#  (1574231, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1575335, 'a mere five league wins', 'ARTICLE JJ CD NN NNS'),
#  (1575856, 'a further two years', 'ARTICLE JJ CD NNS'),
#  (1577339, 'A good many plums', 'ARTICLE JJ FEW NNS'),
#  (1581586, 'a further two weeks', 'ARTICLE JJ CD NNS'),
#  (1582467, 'a naval fleet and 5,000 troops', 'ARTICLE JJ NN CC CD NNS'),
#  (1583842, 'A further 9 members', 'ARTICLE JJ CD NNS'),
#  (1588567, 'a good two hours', 'ARTICLE JJ CD NNS'),
#  (1594815, 'a further several thousand planters', 'ARTICLE JJ FEW CD NNS'),
#  (1598812, 'a possible ten years', 'ARTICLE JJ CD NNS'),
#  (1599455, 'a combined five points', 'ARTICLE VBN CD NNS'),
#  (1600687, 'an astounding 1022 points', 'ARTICLE JJ CD NNS'),
#  (1601049, 'a little village 15 kilometres', 'ARTICLE JJ NN CD NNS'),
#  (1606136, 'a team - record 71 points', 'ARTICLE NN HYPH RECORD CD NNS'),
#  (1606843, 'a long time and 299 hotel rooms', 'ARTICLE JJ NN CC CD NN NNS'),
#  (1607332, 'an estimated 95 million people', 'ARTICLE VBN CD CD NNS'),
#  (1607728, 'a combined 200 points', 'ARTICLE VBN CD NNS'),
#  (1608243, 'a franchise - high 252 goals', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1609071, 'a club - low 726 penalty minutes', 'ARTICLE NN HYPH JJ CD NN NNS'),
#  (1609098, 'a league - high five players', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1613585,
#   'a planar structure and three - fold rotation axes',
#   'ARTICLE JJ NN CC CD HYPH JJ NN NNS'),
#  (1613896, 'an additional 30 years', 'ARTICLE JJ CD NNS'),
#  (1620198, 'an additional three awards', 'ARTICLE JJ CD NNS'),
#  (1624687, 'a school - record 46 tackles', 'ARTICLE NN HYPH RECORD CD NNS'),
#  (1628672, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1634021, 'a further six appearances', 'ARTICLE JJ CD NNS'),
#  (1638126, 'a busy two days', 'ARTICLE JJ CD NNS'),
#  (1639950, 'a further 10 years', 'ARTICLE JJR CD NNS'),
#  (1641968, 'a giant whirlpool and four continents', 'ARTICLE JJ NN CC CD NNS'),
#  (1643988, 'a bad ten minutes', 'ARTICLE JJ CD NNS'),
#  (1644880, 'an unmatched 334 goals', 'ARTICLE JJ CD NNS'),
#  (1648226, 'a mere two years', 'ARTICLE JJ CD NNS'),
#  (1651742, 'an additional eight seasons', 'ARTICLE JJ CD NNS'),
#  (1652337, 'a scant four yards', 'ARTICLE JJ CD NNS'),
#  (1655663, 'a much shorter version two years', 'ARTICLE RB JJR NN CD NNS'),
#  (1657079, 'a decimal point two places', 'ARTICLE JJ NN CD NNS'),
#  (1657466, 'an estimated 49 thousand cases', 'ARTICLE VBN CD CD NNS'),
#  (1658032, 'a decimal point two places', 'ARTICLE JJ NN CD NNS'),
#  (1662887, 'a good ten minutes', 'ARTICLE JJ CD NNS'),
#  (1667230, 'a further three times', 'ARTICLE JJ CD NNS'),
#  (1667405, 'an additional three times', 'ARTICLE JJ CD NNS'),
#  (1669448, 'a healthy hundred yards', 'ARTICLE JJ CD NNS'),
#  (1672494,
#   'a record seven hundred thousand Brits',
#   'ARTICLE RECORD CD CD CD NNPS'),
#  (1674793,
#   'an unnamed potential backer three days',
#   'ARTICLE JJ JJ NN CD NNS'),
#  (1675652, 'a further 1,700 men', 'ARTICLE JJR CD NNS'),
#  (1677474, 'a local estimate ten years', 'ARTICLE JJ NN CD NNS'),
#  (1679525, 'a regular 26 episodes', 'ARTICLE JJ CD NNS'),
#  (1679679, 'a splendid four years', 'ARTICLE JJ CD NNS'),
#  (1682227, 'a good two inches', 'ARTICLE JJ CD NNS'),
#  (1689328, 'a career - best 26 goals', 'ARTICLE NN HYPH JJS CD NNS'),
#  (1689362, 'a further two promotions', 'ARTICLE JJ CD NNS'),
#  (1691778, 'a good few hands', 'ARTICLE JJ FEW NNS'),
#  (1693730,
#   'a further seventeen million road users',
#   'ARTICLE JJR CD CD NN NNS'),
#  (1696960, 'a claimed 48 hours', 'ARTICLE VBN CD NNS'),
#  (1705932, 'an additional 120 years', 'ARTICLE JJ CD NNS'),
#  (1725273, 'a possible 156 points', 'ARTICLE JJ CD NNS'),
#  (1725851, 'a great many greenhouses', 'ARTICLE JJ FEW NNS'),
#  (1726988, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1728757, 'a great many parts', 'ARTICLE JJ FEW NNS'),
#  (1731919, 'a great many ladies', 'ARTICLE JJ FEW NNS'),
#  (1732183, 'A red hypergiant 1,212 times', 'ARTICLE JJ NN CD NNS'),
#  (1735919, 'a great many doors', 'ARTICLE JJ FEW NNS'),
#  (1735964, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1736427,
#   'an explosive decompression fourteen minutes',
#   'ARTICLE JJ NN CD NNS'),
#  (1736861, 'a red ribbon 1.25 inches', 'ARTICLE JJ NN CD NNS'),
#  (1740595, 'a minimal 1.6 watts', 'ARTICLE JJ CD NNS'),
#  (1742792, 'a known six men', 'ARTICLE VBN CD NNS'),
#  (1746336, 'a happy three weeks', 'ARTICLE JJ CD NNS'),
#  (1747117,
#   'a blue main sequence star 3.5 times',
#   'ARTICLE JJ JJ NN NN CD NNS'),
#  (1747748,
#   'a new and more cautious approach towards dangers',
#   'ARTICLE JJ CC FEW JJ NN IN NNS'),
#  (1755223, 'a career - high 266 yards', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1756711, 'a further six months', 'ARTICLE JJ CD NNS'),
#  (1761166, 'a final two years', 'ARTICLE JJ CD NNS'),
#  (1767329, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (1773829,
#   'an anti poll strategy and two hundred and eight thousand pounds',
#   'ARTICLE JJ JJ NN CC CD CD CC CD CD NNS'),
#  (1775785, 'A further three years', 'ARTICLE JJ CD NNS'),
#  (1782914,
#   'a further one hundred and eight people',
#   'ARTICLE JJ CD CD CC CD NNS'),
#  (1785856, 'a lowly 35 metres', 'ARTICLE JJ CD NNS'),
#  (1785911, 'a further two seasons', 'ARTICLE JJ CD NNS'),
#  (1789096, 'a further five years', 'ARTICLE JJ CD NNS'),
#  (1792370, 'a final eight games', 'ARTICLE JJ CD NNS'),
#  (1794386,
#   'An estimated 100 to 120 thousand Jews',
#   'ARTICLE VBN CD TO CD CD NNPS'),
#  (1809173, 'an added 37 cubic metres', 'ARTICLE VBN CD JJ NNS'),
#  (1810121, 'a mere 20 years', 'ARTICLE JJ CD NNS'),
#  (1810492,
#   'a Japanese professional three - cushion billiards',
#   'ARTICLE JJ JJ CD HYPH NN NNS'),
#  (1814168,
#   'a breached caldera and two small summit craters',
#   'ARTICLE VBN NN CC CD JJ NN NNS'),
#  (1814607, 'an extra 8 games', 'ARTICLE JJ CD NNS'),
#  (1814720, 'a great many mysterious hints', 'ARTICLE JJ FEW JJ NNS'),
#  (1815523, 'a long friendship and many years', 'ARTICLE JJ NN CC FEW NNS'),
#  (1817395, 'an estimated three minutes', 'ARTICLE VBN CD NNS'),
#  (1818451, 'an estimated 800 Jewish people', 'ARTICLE VBN CD JJ NNS'),
#  (1820898, 'another full year and three months', 'ARTICLE JJ NN CC CD NNS'),
#  (1822181, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (1823198, 'a little baby six months', 'ARTICLE JJ NN CD NNS'),
#  (1824353, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1831622, 'a mere 3 points', 'ARTICLE JJ CD NNS'),
#  (1837798, 'a great many letters', 'ARTICLE JJ FEW NNS'),
#  (1838477, 'an allied attack two weeks', 'ARTICLE JJ NN CD NNS'),
#  (1839593, 'a good many folks', 'ARTICLE JJ FEW NNS'),
#  (1839792, 'an estimated 10 million Brazilians', 'ARTICLE VBN CD CD NNPS'),
#  (1843103,
#   'an intense search and rescue operation several months',
#   'ARTICLE JJ NN CC NN NN FEW NNS'),
#  (1843842, 'an extra 36–48 hours', 'ARTICLE JJ CD NNS'),
#  (1845304, 'a further 62 league appearances', 'ARTICLE JJ CD NN NNS'),
#  (1846580, 'an estimated 600 indigenous people', 'ARTICLE VBN CD JJ NNS'),
#  (1857828, 'a further seven years', 'ARTICLE JJ CD NNS'),
#  (1864284, 'an estimated 5.2 million speakers', 'ARTICLE VBN CD CD NNS'),
#  (1865530, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1868208,
#   'a forlorn little trading station fifteen miles',
#   'ARTICLE JJ JJ NN NN CD NNS'),
#  (1869616, 'a half dozen forces', 'ARTICLE JJ FEW NNS'),
#  (1870280, 'an estimated 217 mosques', 'ARTICLE VBN CD NNS'),
#  (1873866, 'an estimated 130 churches', 'ARTICLE VBN CD NNS'),
#  (1875470, 'an estimated 33,000 sculptures', 'ARTICLE VBN CD NNS'),
#  (1879911, 'a great many people', 'ARTICLE JJ FEW NNS'),
#  (1880352, 'a career - high 36 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1880360, 'a season - high 28 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (1883002, 'a great many things', 'ARTICLE JJ FEW NNS'),
#  (1884709, 'a very creative fifteen minutes', 'ARTICLE RB JJ CD NNS'),
#  (1886034, 'a great many new discoveries', 'ARTICLE JJ FEW JJ NNS'),
#  (1886901, 'a planned five volumes', 'ARTICLE VBN CD NNS'),
#  (1887666, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (1888143, 'An estimated 111.3 million people', 'ARTICLE VBN CD CD NNS'),
#  (1888284, 'An estimated 167 million people', 'ARTICLE VBN CD CD NNS'),
#  (1888409, 'An estimated 114.4 million people', 'ARTICLE VBN CD CD NNS'),
#  (1888480, 'an estimated 10.4 million viewers', 'ARTICLE VBN CD CD NNS'),
#  (1891880, 'an estimated 275 K people', 'ARTICLE VBN CD CD NNS'),
#  (1895359, 'a great deal more people', 'ARTICLE JJ NN FEW NNS'),
#  (1896189, 'a successful two days', 'ARTICLE JJ CD NNS'),
#  (1897498,
#   'a larger , more complex coat of arms',
#   'ARTICLE JJR , FEW JJ NN IN NNS'),
#  (1899943, 'a new color so three x', 'ARTICLE JJ NN CC CD NNS'),
#  (1909361, 'another scant two miles', 'ARTICLE JJ CD NNS'),
#  (1911041, 'an old chap but three tables', 'ARTICLE JJ NN CC CD NNS'),
#  (1912757, 'an additional 194 kg', 'ARTICLE JJ CD NNS'),
#  (1912775, 'an additional 194 kg', 'ARTICLE JJ CD NNS'),
#  (1919369, 'a massive structure 18 metres', 'ARTICLE JJ NN CD NNS'),
#  (1920253, 'a half - dozen city cousins', 'ARTICLE JJ HYPH FEW NN NNS'),
#  (1920550, 'a Scottish woman two thousand pounds', 'ARTICLE JJ NN CD CD NNS'),
#  (1923298, 'an additional six months', 'ARTICLE JJ CD NNS'),
#  (1927211, 'a fucking million years', 'ARTICLE JJ CD NNS'),
#  (1929068, 'a good seven hours', 'ARTICLE JJ CD NNS'),
#  (1929226, 'a good 17 years', 'ARTICLE JJ CD NNS'),
#  (1931095, 'a good many notions', 'ARTICLE JJ FEW NNS'),
#  (1931491, 'an additional two years', 'ARTICLE JJ CD NNS'),
#  (1937533, 'a staggering 22 years', 'ARTICLE JJ CD NNS'),
#  (1941652, 'A further 468 men', 'ARTICLE JJ CD NNS'),
#  (1945219, 'a staggering 22 years', 'ARTICLE JJ CD NNS'),
#  (1950760, 'a full two weeks', 'ARTICLE JJ CD NNS'),
#  (1952645, 'a record four consecutive finals', 'ARTICLE RECORD CD JJ NNS'),
#  (1954074,
#   'a further two hundred and fifty thousand pounds',
#   'ARTICLE JJ CD CD CC CD CD NNS'),
#  (1954091,
#   'a further two hundred and fifty thousand pounds',
#   'ARTICLE JJ CD CD CC CD CD NNS'),
#  (1954207, 'a further three appearances', 'ARTICLE JJ CD NNS'),
#  (1956424, 'a half dozen coaches', 'ARTICLE JJ FEW NNS'),
#  (1959669, 'a further 24 hours', 'ARTICLE JJR CD NNS'),
#  (1966371, 'an estimated 600 globulars', 'ARTICLE VBN CD NNS'),
#  (1968148, 'a record fifteen starters', 'ARTICLE RECORD CD NNS'),
#  (1969351, 'a further ten years', 'ARTICLE JJ CD NNS'),
#  (1983620, 'a further 24 hours', 'ARTICLE JJR CD NNS'),
#  (1985835, 'a further 600 metres', 'ARTICLE JJ CD NNS'),
#  (2009275, 'an additional 17 people', 'ARTICLE JJ CD NNS'),
#  (2010479, 'a career - high 42 points', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2010755, 'a great many times', 'ARTICLE JJ FEW NNS'),
#  (2016055, 'a blufftop location several miles', 'ARTICLE JJ NN FEW NNS'),
#  (2019810, 'a career - high 3 sacks', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2023740, 'a glorified seven hundred people', 'ARTICLE JJ CD CD NNS'),
#  (2025590, 'a grander effort three decades', 'ARTICLE JJR NN CD NNS'),
#  (2026778, 'a scoreless 90 minutes', 'ARTICLE JJ CD NNS'),
#  (2028820, 'a further 1,000 vehicles', 'ARTICLE JJ CD NNS'),
#  (2029014, 'an additional 140 MRV', 'ARTICLE JJ CD NNS'),
#  (2030380, 'a full 90 minutes', 'ARTICLE JJ CD NNS'),
#  (2030455, 'a healthy nation but more people', 'ARTICLE JJ NN CC FEW NNS'),
#  (2031841,
#   'a vast circular structure several stories',
#   'ARTICLE JJ JJ NN FEW NNS'),
#  (2031887, 'an additional two shovels', 'ARTICLE JJ CD NNS'),
#  (2035319, 'a further seven years', 'ARTICLE JJ CD NNS'),
#  (2040946, 'a little bit more luxuries', 'ARTICLE JJ NN FEW NNS'),
#  (2044539, 'a constant 5 degrees', 'ARTICLE JJ CD NNS'),
#  (2052904, 'a fantastic ten years', 'ARTICLE JJ CD NNS'),
#  (2064184, 'a double - double 15 points', 'ARTICLE JJ HYPH NN CD NNS'),
#  (2064983, 'a single parent and two grandparents', 'ARTICLE JJ NN CC CD NNS'),
#  (2065192,
#   'an automatic and two seven - round clips',
#   'ARTICLE JJ CC CD CD HYPH NN NNS'),
#  (2065655,
#   'a record - high 185 underclassed draft prospects',
#   'ARTICLE RECORD HYPH JJ CD JJ NN NNS'),
#  (2072101, 'a record 63 tournaments', 'ARTICLE RECORD CD NNS'),
#  (2073928, 'a record four consecutive times', 'ARTICLE RECORD CD JJ NNS'),
#  (2078326,
#   'a public road and several rural lanes',
#   'ARTICLE JJ NN CC FEW JJ NNS'),
#  (2079926, 'an estimated 360 casualties', 'ARTICLE VBN CD NNS'),
#  (2082082,
#   'a new artwork and three extra songs',
#   'ARTICLE JJ NN CC CD JJ NNS'),
#  (2083668, 'an additional 6000 scudi', 'ARTICLE JJ CD NNS'),
#  (2086653, 'a hard five years', 'ARTICLE JJ CD NNS'),
#  (2086934, 'a good two inches', 'ARTICLE JJ CD NNS'),
#  (2087316, 'a faded plaid two inches', 'ARTICLE JJ NN CD NNS'),
#  (2097036, 'a record 195 games', 'ARTICLE RECORD CD NNS'),
#  (2102619, 'a whopping 254 pounds', 'ARTICLE JJ CD NNS'),
#  (2104037, 'a second ring two feet', 'ARTICLE JJ NN CD NNS'),
#  (2104608, 'a further nine retrograde steps', 'ARTICLE JJ CD JJ NNS'),
#  (2106675, 'an estimated 1.4 times', 'ARTICLE VBN CD NNS'),
#  (2109726, 'a further 59 appearances', 'ARTICLE JJ CD NNS'),
#  (2112412, 'a further two spells', 'ARTICLE JJ CD NNS'),
#  (2113246, 'a bad ten minutes', 'ARTICLE JJ CD NNS'),
#  (2114327, 'a career - high 5 receptions', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2114329,
#   'a career - high 55 receiving yards',
#   'ARTICLE NN HYPH JJ CD NN NNS'),
#  (2114332, 'a career - high 26 receptions', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2115824, 'an estimated 10 casualties', 'ARTICLE VBN CD NNS'),
#  (2118099, 'a terrible hurt ten years', 'ARTICLE JJ NN CD NNS'),
#  (2120410, 'a mere twenty years', 'ARTICLE JJ CD NNS'),
#  (2124311, 'a good many things', 'ARTICLE JJ FEW NNS'),
#  (2128587, 'a second round two weeks', 'ARTICLE JJ NN CD NNS'),
#  (2131869,
#   'a central cupola and two rear dormers',
#   'ARTICLE JJ NN CC CD JJ NNS'),
#  (2134338, 'a further six times', 'ARTICLE JJ CD NNS'),
#  (2134340, 'a further two defeats', 'ARTICLE JJ CD NNS'),
#  (2138893, 'a fierce engagement two days', 'ARTICLE JJ NN CD NNS'),
#  (2147526, 'a team - high 11 goals', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2148023, 'a good many people', 'ARTICLE JJ FEW NNS'),
#  (2148355, 'a career - high three touchdowns', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2154138, 'a new world post nine eleven days', 'ARTICLE JJ NN NN CD CD NNS'),
#  (2156035, 'an amazing 82 years', 'ARTICLE JJ CD NNS'),
#  (2158024, 'a popular 22 episodes', 'ARTICLE JJ CD NNS'),
#  (2161061, 'a mere eight months', 'ARTICLE JJ CD NNS'),
#  (2163799,
#   'a very very long twenty odd minutes',
#   'ARTICLE RB RB JJ CD JJ NNS'),
#  (2164187, 'a mere 65 - koku', 'ARTICLE JJ CD HYPH NNS'),
#  (2168097, 'An estimated 140 people', 'ARTICLE VBN CD NNS'),
#  (2177329, 'An additional 2,776 people', 'ARTICLE JJ CD NNS'),
#  (2178479, 'a select few establishments', 'ARTICLE JJ FEW NNS'),
#  (2180261,
#   'an estimated 10 000 to 15 000 men',
#   'ARTICLE VBN CD CD TO CD CD NNS'),
#  (2180427, 'an additional six smaller searchlights', 'ARTICLE JJ CD JJR NNS'),
#  (2181852, 'an additional 0.7 miles', 'ARTICLE JJ CD NNS'),
#  (2183668, 'an additional eight weeks', 'ARTICLE JJ CD NNS'),
#  (2183896, 'a combined 11 games', 'ARTICLE VBN CD NNS'),
#  (2184575, 'a career - high 51 tackles', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2184699, 'a season - high four stops', 'ARTICLE NN HYPH JJ CD NNS'),
#  (2185725, 'a good twenty - five miles', 'ARTICLE JJ CD CD CD NNS'),
#  (2186327, 'a second time six weeks', 'ARTICLE JJ NN CD NNS'),
#  ...]

# %%
decomposed = []
for entry in new_entries:
    idx, span, pos_span = entry
    
    article_span = re.search(r"ARTICLE\s(((HYPH|,)\s))?", pos_span).group(0)
    article_idx = mu.find_pattern(article_span.split(), pos_span.split())
    article_phrase = " ".join(span.split()[article_idx[0]:article_idx[1]])
    # articles.append((idx, article_phrase))

    num_span = re.search(r"((CD|FEW)(\s(TO|CC|(HYPH|,))(\s(HYPH|,))?)?\s)+(((HYPH|,)\s))?", pos_span).group(0)
    num_idx = mu.find_pattern(num_span.split(), pos_span.split())
    num_phrase = " ".join(span.split()[num_idx[0]:num_idx[1]])

    adj_idx = article_idx[-1], num_idx[0]
    adj_phrase = " ".join(span.split()[adj_idx[0]:adj_idx[1]])

    noun_phrase = " ".join(span.split()[num_idx[1]:])

    decomposed.append((idx, span, pos_span, article_phrase, adj_phrase, num_phrase, noun_phrase))

# %%
with open("../data/babylm-aanns/aanns_new_decomposed.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["idx", "sentence", "pos", "DT", "ADJ", "NUMERAL", "NOUN"])
    writer.writerows(decomposed)
decomposed
# Out:
# [(884,
#   'a smaller three to four people',
#   'ARTICLE JJR CD TO CD NNS',
#   'a',
#   'smaller',
#   'three to four',
#   'people'),
#  (2481,
#   'a good few seasons',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'few',
#   'seasons'),
#  (12856,
#   'a further two men',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'two',
#   'men'),
#  (12974,
#   'an English former professional snooker player and six - times',
#   'ARTICLE JJ JJ JJ NN NN CC CD HYPH NNS',
#   'an',
#   'English former professional snooker player and',
#   'six -',
#   'times'),
#  (14222,
#   'an uneventful few months',
#   'ARTICLE JJ FEW NNS',
#   'an',
#   'uneventful',
#   'few',
#   'months'),
#  (14321,
#   'A further five victories',
#   'ARTICLE JJ CD NNS',
#   'A',
#   'further',
#   'five',
#   'victories'),
#  (16576,
#   'an extra two to three people',
#   'ARTICLE JJ CD TO CD NNS',
#   'an',
#   'extra',
#   'two to three',
#   'people'),
#  (18115,
#   'a full three days',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'three',
#   'days'),
#  (25036,
#   'a further three schools',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'three',
#   'schools'),
#  (25160, 'a mere 8 years', 'ARTICLE JJ CD NNS', 'a', 'mere', '8', 'years'),
#  (25474,
#   'a further three schools',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'three',
#   'schools'),
#  (28788,
#   'a great many friends',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'friends'),
#  (29044,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (29553,
#   'a great many good points',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'good points'),
#  (29793,
#   'a great many times',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'times'),
#  (34347,
#   'a great many persons',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'persons'),
#  (38009,
#   'a small oil study and several drawings',
#   'ARTICLE JJ NN NN CC FEW NNS',
#   'a',
#   'small oil study and',
#   'several',
#   'drawings'),
#  (40066,
#   'a career - high 15 strikeouts',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '15',
#   'strikeouts'),
#  (40111,
#   'a club - record 109 games',
#   'ARTICLE NN HYPH RECORD CD NNS',
#   'a',
#   'club - record',
#   '109',
#   'games'),
#  (45860,
#   'a final few moments',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'final',
#   'few',
#   'moments'),
#  (47983,
#   'a great many days',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'days'),
#  (48239,
#   'a great many children',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'children'),
#  (52634,
#   'A good many years',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'good',
#   'many',
#   'years'),
#  (54935,
#   'a professional basketball arena and many other sport facilities',
#   'ARTICLE JJ NN NN CC FEW JJ NN NNS',
#   'a',
#   'professional basketball arena and',
#   'many',
#   'other sport facilities'),
#  (56273,
#   'an old cap or two , a pair of boots',
#   'ARTICLE JJ NN CC CD , ARTICLE NN IN NNS',
#   'a',
#   '',
#   'two ,',
#   'a pair of boots'),
#  (56462,
#   'a great many cunning tricks',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'cunning tricks'),
#  (56953,
#   'an estimated 400 people',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '400',
#   'people'),
#  (57401,
#   'a great many days',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'days'),
#  (57750,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (58229,
#   'a special 100 naira',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'special',
#   '100',
#   'naira'),
#  (58320,
#   'An estimated 20 % of children',
#   'ARTICLE VBN CD NN IN NNS',
#   'An',
#   'estimated',
#   '20',
#   '% of children'),
#  (58949,
#   'an old woman and three maidens',
#   'ARTICLE JJ NN CC CD NNS',
#   'an',
#   'old woman and',
#   'three',
#   'maidens'),
#  (60004,
#   'a good many difficult things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'difficult things'),
#  (63518,
#   'a great many others',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'others'),
#  (64435,
#   'a great many journeys',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'journeys'),
#  (66356,
#   'a mere 0.02 seconds',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   '0.02',
#   'seconds'),
#  (66370,
#   'a manual 14.8 seconds',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'manual',
#   '14.8',
#   'seconds'),
#  (67870,
#   'a heavy heart and many sighs',
#   'ARTICLE JJ NN CC FEW NNS',
#   'a',
#   'heavy heart and',
#   'many',
#   'sighs'),
#  (68769,
#   'an additional seven to eight feet',
#   'ARTICLE JJ CD TO CD NNS',
#   'an',
#   'additional',
#   'seven to eight',
#   'feet'),
#  (70282,
#   'a great many young children',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'young children'),
#  (70295,
#   'a great many persons',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'persons'),
#  (71366,
#   'A great many officers',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'officers'),
#  (71914,
#   'a good many other folks',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'other folks'),
#  (72747,
#   'a great many doors',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'doors'),
#  (74097,
#   'a great many days',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'days'),
#  (75040,
#   'a great many children',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'children'),
#  (80323,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (83662,
#   'a career - high 30 points',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '30',
#   'points'),
#  (86713,
#   'a quick two minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'quick',
#   'two',
#   'minutes'),
#  (87096,
#   'a hulking 261 pounds',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'hulking',
#   '261',
#   'pounds'),
#  (88015,
#   'a further six weeks',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'six',
#   'weeks'),
#  (90331,
#   'a good few years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'few',
#   'years'),
#  (91528,
#   'a new site 65 meters',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'new site',
#   '65',
#   'meters'),
#  (97078,
#   'a great many cunning tricks',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'cunning tricks'),
#  (97924,
#   'a record 32 teams',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '32',
#   'teams'),
#  (98452,
#   'a great many days',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'days'),
#  (100994,
#   'a little girl three years',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'little girl',
#   'three',
#   'years'),
#  (102023,
#   'a heavy heart and many sighs',
#   'ARTICLE JJ NN CC FEW NNS',
#   'a',
#   'heavy heart and',
#   'many',
#   'sighs'),
#  (102160,
#   'a great many days',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'days'),
#  (102464,
#   'an old woman and three maidens',
#   'ARTICLE JJ NN CC CD NNS',
#   'an',
#   'old woman and',
#   'three',
#   'maidens'),
#  (105793,
#   'a further 75,000 immigrants',
#   'ARTICLE JJR CD NNS',
#   'a',
#   'further',
#   '75,000',
#   'immigrants'),
#  (110319,
#   'a further 250,000 copies',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '250,000',
#   'copies'),
#  (110402,
#   'a mere 25,000 copies',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   '25,000',
#   'copies'),
#  (111512,
#   'a career - high 20 goals',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '20',
#   'goals'),
#  (114635,
#   'a great many others',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'others'),
#  (115579,
#   'a reported four children',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'reported',
#   'four',
#   'children'),
#  (117952,
#   'a further three charges',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'three',
#   'charges'),
#  (118242,
#   'a great many journeys',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'journeys'),
#  (121316,
#   'a certain fatal three days',
#   'ARTICLE JJ JJ CD NNS',
#   'a',
#   'certain fatal',
#   'three',
#   'days'),
#  (121793,
#   'an extra two and a half hours',
#   'ARTICLE JJ CD CC ARTICLE NN NNS',
#   'a',
#   '',
#   'two and',
#   'a half hours'),
#  (126657,
#   'an additional 3,000 supporters',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '3,000',
#   'supporters'),
#  (129123,
#   'a heavy heart and many sighs',
#   'ARTICLE JJ NN CC FEW NNS',
#   'a',
#   'heavy heart and',
#   'many',
#   'sighs'),
#  (129427,
#   'a great many little earth',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'little earth'),
#  (131301,
#   'a large head and two thick ears',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'large head and',
#   'two',
#   'thick ears'),
#  (132365,
#   'a great deal more stamping of feet',
#   'ARTICLE JJ NN FEW NN IN NNS',
#   'a',
#   'great deal',
#   'more',
#   'stamping of feet'),
#  (132656,
#   'Another fucking few minutes',
#   'ARTICLE JJ FEW NNS',
#   'Another',
#   'fucking',
#   'few',
#   'minutes'),
#  (136087,
#   'a great many sparrows',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'sparrows'),
#  (136989,
#   'a full four stars',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'four',
#   'stars'),
#  (140385,
#   'a great many young children',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'young children'),
#  (140934,
#   'a great festival three days',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'great festival',
#   'three',
#   'days'),
#  (143563,
#   'A great many officers',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'officers'),
#  (144287,
#   'a great many other weapons',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other weapons'),
#  (144425,
#   'a great many salaams',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'salaams'),
#  (144993,
#   'A great many Rajas',
#   'ARTICLE JJ FEW NNPS',
#   'A',
#   'great',
#   'many',
#   'Rajas'),
#  (146886,
#   'a great many doors',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'doors'),
#  (148046,
#   'a great many rupees',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'rupees'),
#  (148355,
#   'a great many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'years'),
#  (148447,
#   'an additional ten states',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'ten',
#   'states'),
#  (149538,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (155767,
#   'a great many rupees',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'rupees'),
#  (155933,
#   'a great many salaams',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'salaams'),
#  (156403,
#   'A great many Kings',
#   'ARTICLE JJ FEW NNPS',
#   'A',
#   'great',
#   'many',
#   'Kings'),
#  (156623,
#   'a great many birds',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'birds'),
#  (156938,
#   'a great many sepoys',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'sepoys'),
#  (156939,
#   'a great many miles',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'miles'),
#  (157113,
#   'a great many salaams',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'salaams'),
#  (159152,
#   'a cumulated 300 ECTS credits',
#   'ARTICLE VBN CD NN NNS',
#   'a',
#   'cumulated',
#   '300',
#   'ECTS credits'),
#  (162483,
#   'a whole forty five minutes',
#   'ARTICLE JJ CD CD NNS',
#   'a',
#   'whole',
#   'forty five',
#   'minutes'),
#  (164678,
#   'a record 26 times',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '26',
#   'times'),
#  (165613,
#   'a great many pieces',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'pieces'),
#  (167186,
#   'An estimated 1,700 people',
#   'ARTICLE VBN CD NNS',
#   'An',
#   'estimated',
#   '1,700',
#   'people'),
#  (167399,
#   'an estimated 100,000 people',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '100,000',
#   'people'),
#  (169156,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (169271,
#   'a great many slippers',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'slippers'),
#  (169902,
#   'an average sixty - six immigrants',
#   'ARTICLE JJ CD HYPH CD NNS',
#   'an',
#   'average',
#   'sixty - six',
#   'immigrants'),
#  (170562,
#   'a great many children',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'children'),
#  (173662,
#   'an additional six months',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'six',
#   'months'),
#  (175893,
#   'a very impressive 32 goals',
#   'ARTICLE RB JJ CD NNS',
#   'a',
#   'very impressive',
#   '32',
#   'goals'),
#  (179606,
#   'a good two years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'two',
#   'years'),
#  (182028,
#   'a further ten frames',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'ten',
#   'frames'),
#  (183594,
#   'a cumulated 300 ECTS credits',
#   'ARTICLE VBN CD NN NNS',
#   'a',
#   'cumulated',
#   '300',
#   'ECTS credits'),
#  (183850,
#   'a future Four Lands',
#   'ARTICLE JJ CD NNPS',
#   'a',
#   'future',
#   'Four',
#   'Lands'),
#  (186938,
#   'a mere nineteen lines',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   'nineteen',
#   'lines'),
#  (189145, 'a new 10,000 m', 'ARTICLE JJ CD NNS', 'a', 'new', '10,000', 'm'),
#  (189241,
#   'a standard three or four sheets',
#   'ARTICLE JJ CD CC CD NNS',
#   'a',
#   'standard',
#   'three or four',
#   'sheets'),
#  (193686,
#   'a separate one thousand five hundred pounds',
#   'ARTICLE JJ CD CD CD CD NNS',
#   'a',
#   'separate',
#   'one thousand five hundred',
#   'pounds'),
#  (204737,
#   'a miniature sleigh and eight tiny reindeer',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'miniature sleigh and',
#   'eight',
#   'tiny reindeer'),
#  (205972,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (207905,
#   'a nationally known icon and many businesses',
#   'ARTICLE RB VBN NN CC FEW NNS',
#   'a',
#   'nationally known icon and',
#   'many',
#   'businesses'),
#  (209357,
#   'a mere 360 metres',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   '360',
#   'metres'),
#  (209550,
#   'a mere 360 metres',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   '360',
#   'metres'),
#  (212846,
#   'A great many birds',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'birds'),
#  (214928,
#   'a great many more Mice',
#   'ARTICLE JJ FEW FEW NNPS',
#   'a',
#   'great',
#   'many more',
#   'Mice'),
#  (215963,
#   'a good forty minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'forty',
#   'minutes'),
#  (217172,
#   'a round dozen blocks',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'round',
#   'dozen',
#   'blocks'),
#  (218494,
#   'a great many friends',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'friends'),
#  (219701,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (220064,
#   'a petty officer and four seamen',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'petty officer and',
#   'four',
#   'seamen'),
#  (220990,
#   'an estimated five million bricks',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'estimated',
#   'five million',
#   'bricks'),
#  (222931,
#   'a combined 5 minutes',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'combined',
#   '5',
#   'minutes'),
#  (223653,
#   'a good many cross',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'cross'),
#  (229447, 'a full 15 games', 'ARTICLE JJ CD NNS', 'a', 'full', '15', 'games'),
#  (229503,
#   'a distant 30 games',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'distant',
#   '30',
#   'games'),
#  (232264,
#   'an estimated 600,000 daily passengers',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '600,000',
#   'daily passengers'),
#  (232367,
#   'an estimated 500,000 riders',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '500,000',
#   'riders'),
#  (233354,
#   'a great many windings',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'windings'),
#  (234129,
#   'a great many hits',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'hits'),
#  (259194,
#   'a young soldier and two women',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'young soldier and',
#   'two',
#   'women'),
#  (261780,
#   'a great many brains',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'brains'),
#  (265006,
#   'a great many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'years'),
#  (265405,
#   'a great many pins',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'pins'),
#  (265511,
#   'a huge surf eighty miles',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'huge surf',
#   'eighty',
#   'miles'),
#  (269338,
#   'an estimated 110,000 tons',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '110,000',
#   'tons'),
#  (269339,
#   'an estimated 8,300 premature deaths',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '8,300',
#   'premature deaths'),
#  (269340,
#   'an estimated 360,000 asthma attacks',
#   'ARTICLE VBN CD NN NNS',
#   'an',
#   'estimated',
#   '360,000',
#   'asthma attacks'),
#  (269489,
#   'an annualized 15 billion gallons',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'annualized',
#   '15 billion',
#   'gallons'),
#  (271759,
#   'an estimated 250,000 shearwater burrows',
#   'ARTICLE VBN CD NN NNS',
#   'an',
#   'estimated',
#   '250,000',
#   'shearwater burrows'),
#  (272286,
#   'a great pillar four days',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'great pillar',
#   'four',
#   'days'),
#  (275060,
#   'a constant sometimes eight colors',
#   'ARTICLE JJ RB CD NNS',
#   'a',
#   'constant sometimes',
#   'eight',
#   'colors'),
#  (276710,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (278022, 'a swift 12 feet', 'ARTICLE JJ CD NNS', 'a', 'swift', '12', 'feet'),
#  (279427,
#   'a sudden , three themes',
#   'ARTICLE JJ , CD NNS',
#   'a',
#   'sudden ,',
#   'three',
#   'themes'),
#  (283322,
#   'a good many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'things'),
#  (286540,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (286591,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (288176,
#   'an orange dwarf star 37 light years',
#   'ARTICLE JJ NN NN CD NN NNS',
#   'an',
#   'orange dwarf star',
#   '37',
#   'light years'),
#  (289262,
#   'A wizened little man and two ladies',
#   'ARTICLE JJ JJ NN CC CD NNS',
#   'A',
#   'wizened little man and',
#   'two',
#   'ladies'),
#  (289334,
#   'a great many wolves',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'wolves'),
#  (296380,
#   'a good eight minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'eight',
#   'minutes'),
#  (303658,
#   'a heavy man and two big rocks',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'heavy man and',
#   'two',
#   'big rocks'),
#  (308631,
#   'a further nine years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'nine',
#   'years'),
#  (312575,
#   'a good wow f forty five minutes',
#   'ARTICLE JJ UH NN CD CD NNS',
#   'a',
#   'good wow f',
#   'forty five',
#   'minutes'),
#  (313443,
#   'a little rowan tree and four alder bushes',
#   'ARTICLE JJ NN NN CC CD NN NNS',
#   'a',
#   'little rowan tree and',
#   'four',
#   'alder bushes'),
#  (318938,
#   'a great many kangaroos',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'kangaroos'),
#  (323410,
#   'a rich cultural heritage and many locations',
#   'ARTICLE JJ JJ NN CC FEW NNS',
#   'a',
#   'rich cultural heritage and',
#   'many',
#   'locations'),
#  (324283,
#   'a twinkling twenty miles',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'twinkling',
#   'twenty',
#   'miles'),
#  (326636,
#   'an estimated 90,000 African slaves',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '90,000',
#   'African slaves'),
#  (327652,
#   'a full ten inches',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'ten',
#   'inches'),
#  (327972,
#   'an additional 124 officers',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '124',
#   'officers'),
#  (328094,
#   'a further 124 officers',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '124',
#   'officers'),
#  (328308,
#   'a further 878 army officers',
#   'ARTICLE JJR CD NN NNS',
#   'a',
#   'further',
#   '878',
#   'army officers'),
#  (329442,
#   'a great many other people',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other people'),
#  (330751,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (331869,
#   'a great many roses',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'roses'),
#  (332341,
#   'an estimated 523 Japanese soldiers',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '523',
#   'Japanese soldiers'),
#  (334740,
#   'a cumulated 300 ECTS credits',
#   'ARTICLE VBN CD NN NNS',
#   'a',
#   'cumulated',
#   '300',
#   'ECTS credits'),
#  (335274,
#   'an estimated 100–240 black people',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '100–240',
#   'black people'),
#  (343998,
#   'a good many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'things'),
#  (345060,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (347369,
#   'A further 15000 ha',
#   'ARTICLE JJ CD NNS',
#   'A',
#   'further',
#   '15000',
#   'ha'),
#  (347616,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (349194,
#   'a full ten years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'ten',
#   'years'),
#  (351781,
#   'A good thirty yards',
#   'ARTICLE JJ CD NNS',
#   'A',
#   'good',
#   'thirty',
#   'yards'),
#  (352538,
#   'an additional 16 months',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '16',
#   'months'),
#  (353288,
#   'a great many singular things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'singular things'),
#  (353833,
#   'a great many times',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'times'),
#  (354309,
#   'An estimated 81 million total viewers',
#   'ARTICLE VBN CD CD JJ NNS',
#   'An',
#   'estimated',
#   '81 million',
#   'total viewers'),
#  (354384,
#   'a great many questions',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'questions'),
#  (354995,
#   'an elongated oval form 12.5 km',
#   'ARTICLE JJ JJ NN CD NNS',
#   'an',
#   'elongated oval form',
#   '12.5',
#   'km'),
#  (360393,
#   'a chilly 248 degrees',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'chilly',
#   '248',
#   'degrees'),
#  (360764,
#   'a colossal 5 stories',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'colossal',
#   '5',
#   'stories'),
#  (360882,
#   'a record seven times',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   'seven',
#   'times'),
#  (360886,
#   'a record 7 hours',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '7',
#   'hours'),
#  (362374,
#   'an additional three years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'three',
#   'years'),
#  (363222,
#   'an estimated 4,694 times',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'estimated',
#   '4,694',
#   'times'),
#  (364347,
#   'a good fifteen feet',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'fifteen',
#   'feet'),
#  (365566,
#   'a great many weavers',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'weavers'),
#  (366993,
#   'a scant three yards',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'scant',
#   'three',
#   'yards'),
#  (367449,
#   'a full six yards',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'six',
#   'yards'),
#  (368422,
#   'an estimated 1600 students',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '1600',
#   'students'),
#  (368554,
#   'an iron - bound club three or four feet',
#   'ARTICLE NN HYPH VBN NN CD CC CD NNS',
#   'an',
#   'iron - bound club',
#   'three or four',
#   'feet'),
#  (374969,
#   'a great many clouds',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'clouds'),
#  (375150,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (379409,
#   'an initial 13 issues',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'initial',
#   '13',
#   'issues'),
#  (379511,
#   'an additional 22 issues',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '22',
#   'issues'),
#  (380199,
#   'a great many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'years'),
#  (381428,
#   'a very young 20 years',
#   'ARTICLE RB JJ CD NNS',
#   'a',
#   'very young',
#   '20',
#   'years'),
#  (387630,
#   'a real estate developer and several others',
#   'ARTICLE JJ NN NN CC FEW NNS',
#   'a',
#   'real estate developer and',
#   'several',
#   'others'),
#  (388051,
#   'a great log twenty or thirty steps',
#   'ARTICLE JJ NN CD CC CD NNS',
#   'a',
#   'great log',
#   'twenty or thirty',
#   'steps'),
#  (388434,
#   'a dead spider five times',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'dead spider',
#   'five',
#   'times'),
#  (388668,
#   'a great many skiffs',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'skiffs'),
#  (388982,
#   'a long twelve or fifteen minutes',
#   'ARTICLE JJ CD CC CD NNS',
#   'a',
#   'long',
#   'twelve or fifteen',
#   'minutes'),
#  (390650,
#   'a career - high 20 starts',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '20',
#   'starts'),
#  (394798,
#   'a married man 40 years',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'married man',
#   '40',
#   'years'),
#  (401200,
#   'a whole candle and three or four pieces',
#   'ARTICLE JJ NN CC CD CC CD NNS',
#   'a',
#   'whole candle and',
#   'three or four',
#   'pieces'),
#  (402649,
#   'a little , three or four days',
#   'ARTICLE JJ , CD CC CD NNS',
#   'a',
#   'little ,',
#   'three or four',
#   'days'),
#  (402955,
#   'a steep clay hill twenty or thirty feet',
#   'ARTICLE JJ NN NN CD CC CD NNS',
#   'a',
#   'steep clay hill',
#   'twenty or thirty',
#   'feet'),
#  (404724,
#   'an optional 48 bits',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'optional',
#   '48',
#   'bits'),
#  (405109,
#   'a great many desirable things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'desirable things'),
#  (405355,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (405357,
#   'a great many more things',
#   'ARTICLE JJ FEW FEW NNS',
#   'a',
#   'great',
#   'many more',
#   'things'),
#  (406685,
#   'a public service 2 nights',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'public service',
#   '2',
#   'nights'),
#  (412972,
#   'a half dozen buildings',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'half',
#   'dozen',
#   'buildings'),
#  (413441,
#   'a great many disagreeable things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'disagreeable things'),
#  (414367,
#   'an estimated 50,000 spectators',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '50,000',
#   'spectators'),
#  (414709,
#   'a record five times',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   'five',
#   'times'),
#  (415235,
#   'an atomic bomb test 10 years',
#   'ARTICLE JJ NN NN CD NNS',
#   'an',
#   'atomic bomb test',
#   '10',
#   'years'),
#  (422094,
#   'an unheard - of 39 times',
#   'ARTICLE JJ HYPH JJ CD NNS',
#   'an',
#   'unheard - of',
#   '39',
#   'times'),
#  (424372,
#   'an even 300 wins',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'even',
#   '300',
#   'wins'),
#  (424843,
#   'a record 11 straight postseason wins',
#   'ARTICLE RECORD CD JJ NN NNS',
#   'a',
#   'record',
#   '11',
#   'straight postseason wins'),
#  (424861,
#   'a low APR score several seasons',
#   'ARTICLE JJ NN NN FEW NNS',
#   'a',
#   'low APR score',
#   'several',
#   'seasons'),
#  (425642,
#   'an estimated 4,000 people',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '4,000',
#   'people'),
#  (430484,
#   'a good many tears',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'tears'),
#  (431147,
#   'a great many hungry days',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'hungry days'),
#  (433980,
#   'an annual world convention and four symposia',
#   'ARTICLE JJ NN NN CC CD NNS',
#   'an',
#   'annual world convention and',
#   'four',
#   'symposia'),
#  (434159,
#   'a full - time official eleven years',
#   'ARTICLE JJ HYPH NN NN CD NNS',
#   'a',
#   'full - time official',
#   'eleven',
#   'years'),
#  (434527,
#   'a weekly basis two years',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'weekly basis',
#   'two',
#   'years'),
#  (434755,
#   'a further three fifties',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'three',
#   'fifties'),
#  (434954,
#   'a good many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'years'),
#  (435586,
#   'a great many shapes',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'shapes'),
#  (436941,
#   'a record eight Players',
#   'ARTICLE RECORD CD NNPS',
#   'a',
#   'record',
#   'eight',
#   'Players'),
#  (436950,
#   'a good many comforts',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'comforts'),
#  (437232,
#   'an unprecedented five consecutive Grand',
#   'ARTICLE JJ CD JJ NNPS',
#   'an',
#   'unprecedented',
#   'five',
#   'consecutive Grand'),
#  (440735,
#   'a good many little gifts',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'little gifts'),
#  (441862,
#   'a good many bitter tears',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'bitter tears'),
#  (444509,
#   'a great kingdom and three sons',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'great kingdom and',
#   'three',
#   'sons'),
#  (445951,
#   'a little body and two little hands',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'little body and',
#   'two',
#   'little hands'),
#  (452023,
#   'an additional 100,000 men',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '100,000',
#   'men'),
#  (457058,
#   'a good many hard times',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'hard times'),
#  (457169,
#   'a great many friends',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'friends'),
#  (457254,
#   'a total 21 films',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'total',
#   '21',
#   'films'),
#  (462122,
#   'a fine picture or two , a stand of flowers',
#   'ARTICLE JJ NN CC CD , ARTICLE NN IN NNS',
#   'a',
#   '',
#   'two ,',
#   'a stand of flowers'),
#  (464743,
#   'a giant triangle and three squares',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'giant triangle and',
#   'three',
#   'squares'),
#  (467322,
#   'a record 264 grade games',
#   'ARTICLE RECORD CD NN NNS',
#   'a',
#   'record',
#   '264',
#   'grade games'),
#  (467939,
#   'a good many hard knocks',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'hard knocks'),
#  (471819,
#   'a record 58 goals',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '58',
#   'goals'),
#  (476521,
#   'a grim papa and three grimmer maiden aunts',
#   'ARTICLE JJ NN CC CD JJR NN NNS',
#   'a',
#   'grim papa and',
#   'three',
#   'grimmer maiden aunts'),
#  (480233,
#   'a good many miracles',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'miracles'),
#  (481055, 'a mere 2 days', 'ARTICLE JJ CD NNS', 'a', 'mere', '2', 'days'),
#  (486266,
#   'a great many holidays',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'holidays'),
#  (495188,
#   'a further 700 years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '700',
#   'years'),
#  (506053,
#   'a protracted three or four years',
#   'ARTICLE JJ CD CC CD NNS',
#   'a',
#   'protracted',
#   'three or four',
#   'years'),
#  (511111,
#   'a fine beast fourteen hands',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'fine beast',
#   'fourteen',
#   'hands'),
#  (511331,
#   'a record 14 years',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '14',
#   'years'),
#  (517682,
#   'a fair and beloved wife and several lovely children',
#   'ARTICLE JJ CC JJ NN CC FEW JJ NNS',
#   'a',
#   'fair and beloved wife and',
#   'several',
#   'lovely children'),
#  (518355,
#   'a paling six feet',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'paling',
#   'six',
#   'feet'),
#  (519587,
#   'a great many various stores',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'various stores'),
#  (519711,
#   'a record twelve national titles',
#   'ARTICLE RECORD CD JJ NNS',
#   'a',
#   'record',
#   'twelve',
#   'national titles'),
#  (524206,
#   'a good many trials',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'trials'),
#  (524450,
#   'an additional two years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'two',
#   'years'),
#  (541074,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (545161,
#   'an unheard - of 50 men',
#   'ARTICLE JJ HYPH JJ CD NNS',
#   'an',
#   'unheard - of',
#   '50',
#   'men'),
#  (549224,
#   'a record seven times',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   'seven',
#   'times'),
#  (551416,
#   'a little town fifteen miles',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'little town',
#   'fifteen',
#   'miles'),
#  (554282,
#   'a new control system and more levels',
#   'ARTICLE JJ NN NN CC FEW NNS',
#   'a',
#   'new control system and',
#   'more',
#   'levels'),
#  (554300,
#   'a poor lame wife and thirteen children',
#   'ARTICLE JJ JJ NN CC CD NNS',
#   'a',
#   'poor lame wife and',
#   'thirteen',
#   'children'),
#  (555150,
#   'a great many petroglyphs',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'petroglyphs'),
#  (555805,
#   'a great many masters',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'masters'),
#  (556885,
#   'a great many dead bodies',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'dead bodies'),
#  (558281,
#   'a half dozen men',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'half',
#   'dozen',
#   'men'),
#  (563535,
#   'a little provincial town three months',
#   'ARTICLE JJ JJ NN CD NNS',
#   'a',
#   'little provincial town',
#   'three',
#   'months'),
#  (569678,
#   'an additional 2 miles',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '2',
#   'miles'),
#  (571603,
#   'a measly thousand pounds',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'measly',
#   'thousand',
#   'pounds'),
#  (573585,
#   'a reported 6,000 apartments',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'reported',
#   '6,000',
#   'apartments'),
#  (575112,
#   'An estimated 15 % of citizens',
#   'ARTICLE VBN CD NN IN NNS',
#   'An',
#   'estimated',
#   '15',
#   '% of citizens'),
#  (577024,
#   'a record four times',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   'four',
#   'times'),
#  (579655,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (579861,
#   'a career - high 8.7 points',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '8.7',
#   'points'),
#  (580230,
#   'a further 23,000 men',
#   'ARTICLE JJR CD NNS',
#   'a',
#   'further',
#   '23,000',
#   'men'),
#  (581081,
#   'an extra 2,600 men',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'extra',
#   '2,600',
#   'men'),
#  (581321,
#   'a further 46,750 tons',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '46,750',
#   'tons'),
#  (584500,
#   'an additional 1,000 sorties',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '1,000',
#   'sorties'),
#  (591689,
#   'a cheap hall bedroom and two art lessons',
#   'ARTICLE JJ NN NN CC CD NN NNS',
#   'a',
#   'cheap hall bedroom and',
#   'two',
#   'art lessons'),
#  (592091,
#   'a great many facts',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'facts'),
#  (592465,
#   'a record 25 playoff games',
#   'ARTICLE RECORD CD NN NNS',
#   'a',
#   'record',
#   '25',
#   'playoff games'),
#  (599547,
#   'a good many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'years'),
#  (601584,
#   'A great many local names',
#   'ARTICLE JJ FEW JJ NNS',
#   'A',
#   'great',
#   'many',
#   'local names'),
#  (601658,
#   'a small plateau 1798 m',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'small plateau',
#   '1798',
#   'm'),
#  (606747,
#   'A half - dozen roughs',
#   'ARTICLE JJ HYPH FEW NNS',
#   'A',
#   'half -',
#   'dozen',
#   'roughs'),
#  (606899,
#   'a career - best 220 wickets',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - best',
#   '220',
#   'wickets'),
#  (607049,
#   'a combined 18 weeks',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'combined',
#   '18',
#   'weeks'),
#  (608321,
#   'a fine eighteen months',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'fine',
#   'eighteen',
#   'months'),
#  (609189,
#   'A half - dozen postal cards',
#   'ARTICLE JJ HYPH FEW JJ NNS',
#   'A',
#   'half -',
#   'dozen',
#   'postal cards'),
#  (616060,
#   'A half - dozen sailors',
#   'ARTICLE JJ HYPH FEW NNS',
#   'A',
#   'half -',
#   'dozen',
#   'sailors'),
#  (619017,
#   'a collective 8,000 spots',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'collective',
#   '8,000',
#   'spots'),
#  (622773,
#   'a difficult question sentence answer sentence question sentence length three marks',
#   'ARTICLE JJ NN NN NN NN NN NN NN CD NNS',
#   'a',
#   'difficult question sentence answer sentence question sentence length',
#   'three',
#   'marks'),
#  (626784,
#   'a half dozen ragged porters',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'half',
#   'dozen',
#   'ragged porters'),
#  (629698,
#   'a further 11 goals',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '11',
#   'goals'),
#  (629791,
#   'a half dozen years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'half',
#   'dozen',
#   'years'),
#  (630595,
#   'an estimated 250 million phonograph records',
#   'ARTICLE VBN CD CD NN NNS',
#   'an',
#   'estimated',
#   '250 million',
#   'phonograph records'),
#  (632815,
#   'a half - dozen armlets',
#   'ARTICLE JJ HYPH FEW NNS',
#   'a',
#   'half -',
#   'dozen',
#   'armlets'),
#  (634169,
#   'a record 50 points',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '50',
#   'points'),
#  (634562,
#   'a combined 319 yards',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'combined',
#   '319',
#   'yards'),
#  (637382,
#   'a second one eighteen months',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'second one',
#   'eighteen',
#   'months'),
#  (638444,
#   'a prominent hill 1.5 miles',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'prominent hill',
#   '1.5',
#   'miles'),
#  (639201,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (639812,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (643629,
#   'an international 60 metres',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'international',
#   '60',
#   'metres'),
#  (647892,
#   'a further four years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'four',
#   'years'),
#  (649647,
#   'a vast many smart beaux',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'vast',
#   'many',
#   'smart beaux'),
#  (649710,
#   'a combined 20 league games',
#   'ARTICLE VBN CD NN NNS',
#   'a',
#   'combined',
#   '20',
#   'league games'),
#  (655855,
#   'An estimated 500 settlers',
#   'ARTICLE VBN CD NNS',
#   'An',
#   'estimated',
#   '500',
#   'settlers'),
#  (659440,
#   'a great many conquests',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'conquests'),
#  (659461,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (661854,
#   'a further eight motor coaches',
#   'ARTICLE JJ CD NN NNS',
#   'a',
#   'further',
#   'eight',
#   'motor coaches'),
#  (674688,
#   'a record 67 doubles',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '67',
#   'doubles'),
#  (676196,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (676623,
#   'a high school and several other institutions',
#   'ARTICLE JJ NN CC FEW JJ NNS',
#   'a',
#   'high school and',
#   'several',
#   'other institutions'),
#  (679288,
#   'an estimated 660 000 deaths',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'estimated',
#   '660 000',
#   'deaths'),
#  (680569,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (683041,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (683397,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (684417,
#   'a good many gallons',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'gallons'),
#  (684595,
#   'a great many ways',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'ways'),
#  (685098,
#   'a good many snobs',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'snobs'),
#  (686286,
#   'A good many people',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'good',
#   'many',
#   'people'),
#  (689299,
#   'an additional 700 miles',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '700',
#   'miles'),
#  (690564,
#   'a great many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'years'),
#  (690769,
#   'a recumbent half - moon and two stars',
#   'ARTICLE JJ JJ HYPH NN CC CD NNS',
#   'a',
#   'recumbent half - moon and',
#   'two',
#   'stars'),
#  (691359,
#   'an estimated one hundred and sixty three , six forty pounds',
#   'ARTICLE VBN CD CD CC CD CD , CD CD NNS',
#   'an',
#   'estimated',
#   'one hundred and sixty three , six forty',
#   'pounds'),
#  (692650,
#   'a great many times',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'times'),
#  (693440,
#   'a great many other things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other things'),
#  (699298,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (700170,
#   'an extra eleven million pounds',
#   'ARTICLE JJ CD CD NNS',
#   'an',
#   'extra',
#   'eleven million',
#   'pounds'),
#  (701738,
#   'a possible two points',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'possible',
#   'two',
#   'points'),
#  (707369,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (707979,
#   'a further 168 men',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '168',
#   'men'),
#  (711502,
#   'a good thousand feet',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'thousand',
#   'feet'),
#  (711598,
#   'an accumulative 44 years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'accumulative',
#   '44',
#   'years'),
#  (713081,
#   'an additional 18 episodes',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '18',
#   'episodes'),
#  (713538,
#   'a possible ten marks',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'possible',
#   'ten',
#   'marks'),
#  (713796,
#   'a great many arguments',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'arguments'),
#  (714734,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (716317,
#   'An astonishing 98 people',
#   'ARTICLE JJ CD NNS',
#   'An',
#   'astonishing',
#   '98',
#   'people'),
#  (717335,
#   'a huge old brown trout ten times',
#   'ARTICLE JJ JJ NN NN CD NNS',
#   'a',
#   'huge old brown trout',
#   'ten',
#   'times'),
#  (718048,
#   'a great many other folks',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other folks'),
#  (719099,
#   'a good many fine gentlemen',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'fine gentlemen'),
#  (719411,
#   'a great many other people',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other people'),
#  (719667,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (720549,
#   'A full hundred yards',
#   'ARTICLE JJ CD NNS',
#   'A',
#   'full',
#   'hundred',
#   'yards'),
#  (721225,
#   'a half - dozen men',
#   'ARTICLE JJ HYPH FEW NNS',
#   'a',
#   'half -',
#   'dozen',
#   'men'),
#  (721557,
#   'A great many years',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'years'),
#  (723243,
#   'a good many other people',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'other people'),
#  (723808,
#   'a narrow crack ten yards',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'narrow crack',
#   'ten',
#   'yards'),
#  (724504,
#   'a good many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'things'),
#  (725296,
#   'a mammoth four tons',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mammoth',
#   'four',
#   'tons'),
#  (727922,
#   'a great many fox -',
#   'ARTICLE JJ FEW NN NNS',
#   'a',
#   'great',
#   'many',
#   'fox -'),
#  (728005,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (729549,
#   'a great many hundred years',
#   'ARTICLE JJ FEW CD NNS',
#   'a',
#   'great',
#   'many hundred',
#   'years'),
#  (730597,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (730756,
#   'A half - dozen times',
#   'ARTICLE JJ HYPH FEW NNS',
#   'A',
#   'half -',
#   'dozen',
#   'times'),
#  (731502,
#   'a small town twelve miles',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'small town',
#   'twelve',
#   'miles'),
#  (732571,
#   'A great many members',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'members'),
#  (733253,
#   'a large parent comet several centuries',
#   'ARTICLE JJ NN NN FEW NNS',
#   'a',
#   'large parent comet',
#   'several',
#   'centuries'),
#  (733392,
#   'a good many folks',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'folks'),
#  (733988,
#   'a full three years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'three',
#   'years'),
#  (734988,
#   'a good few drinks',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'few',
#   'drinks'),
#  (735836,
#   'a good many Foxes',
#   'ARTICLE JJ FEW NNPS',
#   'a',
#   'good',
#   'many',
#   'Foxes'),
#  (735855,
#   'An estimated 500 children',
#   'ARTICLE VBN CD NNS',
#   'An',
#   'estimated',
#   '500',
#   'children'),
#  (736969,
#   'a negative 8x times',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'negative',
#   '8x',
#   'times'),
#  (743145,
#   'a great many strange things',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'strange things'),
#  (743641,
#   'a good fifteen miles',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'fifteen',
#   'miles'),
#  (753679,
#   'a very good forcep two or three punches',
#   'ARTICLE RB JJ NN CD CC CD NNS',
#   'a',
#   'very good forcep',
#   'two or three',
#   'punches'),
#  (755444,
#   'a tournament - best seven goals',
#   'ARTICLE NN HYPH JJS CD NNS',
#   'a',
#   'tournament - best',
#   'seven',
#   'goals'),
#  (760028,
#   'a great many armed men',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'armed men'),
#  (760100,
#   'A great many people',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'people'),
#  (760639,
#   'a good many jokes',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'jokes'),
#  (761101,
#   'an additional 17 years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '17',
#   'years'),
#  (762439,
#   'a great many mistakes',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'mistakes'),
#  (770255,
#   'a great many mistakes',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'mistakes'),
#  (771428,
#   'a whole lot more things',
#   'ARTICLE JJ NN FEW NNS',
#   'a',
#   'whole lot',
#   'more',
#   'things'),
#  (772627,
#   'a perfect five stars',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'perfect',
#   'five',
#   'stars'),
#  (772629,
#   'a perfect five stars',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'perfect',
#   'five',
#   'stars'),
#  (772742,
#   'a perfect five stars',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'perfect',
#   'five',
#   'stars'),
#  (773602,
#   'a good three , four weeks',
#   'ARTICLE JJ CD , CD NNS',
#   'a',
#   'good',
#   'three , four',
#   'weeks'),
#  (773978,
#   'a total 98 episodes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'total',
#   '98',
#   'episodes'),
#  (778592,
#   'a great many responsibilities',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'responsibilities'),
#  (778896,
#   'a record eight consecutive stages',
#   'ARTICLE RECORD CD JJ NNS',
#   'a',
#   'record',
#   'eight',
#   'consecutive stages'),
#  (779012,
#   'a good many mild days',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'good',
#   'many',
#   'mild days'),
#  (779707,
#   'a great many times',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'times'),
#  (780300,
#   'a great many huge flies',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'huge flies'),
#  (780327,
#   'a great many species',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'species'),
#  (780468,
#   'a great many more deaths',
#   'ARTICLE JJ FEW FEW NNS',
#   'a',
#   'great',
#   'many more',
#   'deaths'),
#  (780470,
#   'a great many nobles',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'nobles'),
#  (781012,
#   'a good many hours',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'hours'),
#  (781996,
#   'a great many huge flies',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'huge flies'),
#  (782018,
#   'a great many species',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'species'),
#  (785670,
#   'a crucial three points',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'crucial',
#   'three',
#   'points'),
#  (788282,
#   'a small village and parish situated 8 miles',
#   'ARTICLE JJ NN CC NN VBN CD NNS',
#   'a',
#   'small village and parish situated',
#   '8',
#   'miles'),
#  (788832,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (790887,
#   'A good many women',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'good',
#   'many',
#   'women'),
#  (791649,
#   'an audacious shot 30 yards',
#   'ARTICLE JJ NN CD NNS',
#   'an',
#   'audacious shot',
#   '30',
#   'yards'),
#  (792088,
#   'a good many boys',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'boys'),
#  (794624,
#   'A great many adventurers',
#   'ARTICLE JJ FEW NNS',
#   'A',
#   'great',
#   'many',
#   'adventurers'),
#  (797089,
#   'a further 360 people',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '360',
#   'people'),
#  (800215,
#   'An additional seven awards',
#   'ARTICLE JJ CD NNS',
#   'An',
#   'additional',
#   'seven',
#   'awards'),
#  (801302,
#   'a great many years',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'years'),
#  (801306,
#   'a great many other people',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'other people'),
#  (803227,
#   'a great many good friends',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'good friends'),
#  (805611,
#   'a great many personal sacrifices',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'personal sacrifices'),
#  (805856,
#   'a confirmed drunkard twenty years',
#   'ARTICLE VBN NN CD NNS',
#   'a',
#   'confirmed drunkard',
#   'twenty',
#   'years'),
#  (808707,
#   'A great many fair ones',
#   'ARTICLE JJ FEW JJ NNS',
#   'A',
#   'great',
#   'many',
#   'fair ones'),
#  (810797,
#   'an additional 1,000 miles',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '1,000',
#   'miles'),
#  (811179,
#   'a very pretty lake several miles',
#   'ARTICLE RB JJ NN FEW NNS',
#   'a',
#   'very pretty lake',
#   'several',
#   'miles'),
#  (812215,
#   'a long gun and several swivel guns',
#   'ARTICLE JJ NN CC FEW JJ NNS',
#   'a',
#   'long gun and',
#   'several',
#   'swivel guns'),
#  (815055,
#   'a possible 45 games',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'possible',
#   '45',
#   'games'),
#  (815402,
#   'a good many bears',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'bears'),
#  (815596,
#   'another little boy many years',
#   'ARTICLE JJ NN FEW NNS',
#   'another',
#   'little boy',
#   'many',
#   'years'),
#  (816535,
#   'a good many fairies',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
# ...
#   'another',
#   'full year and',
#   'three',
#   'months'),
#  (1822181,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (1823198,
#   'a little baby six months',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'little baby',
#   'six',
#   'months'),
#  (1824353,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (1831622, 'a mere 3 points', 'ARTICLE JJ CD NNS', 'a', 'mere', '3', 'points'),
#  (1837798,
#   'a great many letters',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'letters'),
#  (1838477,
#   'an allied attack two weeks',
#   'ARTICLE JJ NN CD NNS',
#   'an',
#   'allied attack',
#   'two',
#   'weeks'),
#  (1839593,
#   'a good many folks',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'folks'),
#  (1839792,
#   'an estimated 10 million Brazilians',
#   'ARTICLE VBN CD CD NNPS',
#   'an',
#   'estimated',
#   '10 million',
#   'Brazilians'),
#  (1843103,
#   'an intense search and rescue operation several months',
#   'ARTICLE JJ NN CC NN NN FEW NNS',
#   'an',
#   'intense search and rescue operation',
#   'several',
#   'months'),
#  (1843842,
#   'an extra 36–48 hours',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'extra',
#   '36–48',
#   'hours'),
#  (1845304,
#   'a further 62 league appearances',
#   'ARTICLE JJ CD NN NNS',
#   'a',
#   'further',
#   '62',
#   'league appearances'),
#  (1846580,
#   'an estimated 600 indigenous people',
#   'ARTICLE VBN CD JJ NNS',
#   'an',
#   'estimated',
#   '600',
#   'indigenous people'),
#  (1857828,
#   'a further seven years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'seven',
#   'years'),
#  (1864284,
#   'an estimated 5.2 million speakers',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'estimated',
#   '5.2 million',
#   'speakers'),
#  (1865530,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (1868208,
#   'a forlorn little trading station fifteen miles',
#   'ARTICLE JJ JJ NN NN CD NNS',
#   'a',
#   'forlorn little trading station',
#   'fifteen',
#   'miles'),
#  (1869616,
#   'a half dozen forces',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'half',
#   'dozen',
#   'forces'),
#  (1870280,
#   'an estimated 217 mosques',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '217',
#   'mosques'),
#  (1873866,
#   'an estimated 130 churches',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '130',
#   'churches'),
#  (1875470,
#   'an estimated 33,000 sculptures',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '33,000',
#   'sculptures'),
#  (1879911,
#   'a great many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'people'),
#  (1880352,
#   'a career - high 36 points',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '36',
#   'points'),
#  (1880360,
#   'a season - high 28 points',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'season - high',
#   '28',
#   'points'),
#  (1883002,
#   'a great many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'things'),
#  (1884709,
#   'a very creative fifteen minutes',
#   'ARTICLE RB JJ CD NNS',
#   'a',
#   'very creative',
#   'fifteen',
#   'minutes'),
#  (1886034,
#   'a great many new discoveries',
#   'ARTICLE JJ FEW JJ NNS',
#   'a',
#   'great',
#   'many',
#   'new discoveries'),
#  (1886901,
#   'a planned five volumes',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'planned',
#   'five',
#   'volumes'),
#  (1887666,
#   'a good many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'things'),
#  (1888143,
#   'An estimated 111.3 million people',
#   'ARTICLE VBN CD CD NNS',
#   'An',
#   'estimated',
#   '111.3 million',
#   'people'),
#  (1888284,
#   'An estimated 167 million people',
#   'ARTICLE VBN CD CD NNS',
#   'An',
#   'estimated',
#   '167 million',
#   'people'),
#  (1888409,
#   'An estimated 114.4 million people',
#   'ARTICLE VBN CD CD NNS',
#   'An',
#   'estimated',
#   '114.4 million',
#   'people'),
#  (1888480,
#   'an estimated 10.4 million viewers',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'estimated',
#   '10.4 million',
#   'viewers'),
#  (1891880,
#   'an estimated 275 K people',
#   'ARTICLE VBN CD CD NNS',
#   'an',
#   'estimated',
#   '275 K',
#   'people'),
#  (1895359,
#   'a great deal more people',
#   'ARTICLE JJ NN FEW NNS',
#   'a',
#   'great deal',
#   'more',
#   'people'),
#  (1896189,
#   'a successful two days',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'successful',
#   'two',
#   'days'),
#  (1897498,
#   'a larger , more complex coat of arms',
#   'ARTICLE JJR , FEW JJ NN IN NNS',
#   'a',
#   'larger ,',
#   'more',
#   'complex coat of arms'),
#  (1899943,
#   'a new color so three x',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'new color so',
#   'three',
#   'x'),
#  (1909361,
#   'another scant two miles',
#   'ARTICLE JJ CD NNS',
#   'another',
#   'scant',
#   'two',
#   'miles'),
#  (1911041,
#   'an old chap but three tables',
#   'ARTICLE JJ NN CC CD NNS',
#   'an',
#   'old chap but',
#   'three',
#   'tables'),
#  (1912757,
#   'an additional 194 kg',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '194',
#   'kg'),
#  (1912775,
#   'an additional 194 kg',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '194',
#   'kg'),
#  (1919369,
#   'a massive structure 18 metres',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'massive structure',
#   '18',
#   'metres'),
#  (1920253,
#   'a half - dozen city cousins',
#   'ARTICLE JJ HYPH FEW NN NNS',
#   'a',
#   'half -',
#   'dozen',
#   'city cousins'),
#  (1920550,
#   'a Scottish woman two thousand pounds',
#   'ARTICLE JJ NN CD CD NNS',
#   'a',
#   'Scottish woman',
#   'two thousand',
#   'pounds'),
#  (1923298,
#   'an additional six months',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'six',
#   'months'),
#  (1927211,
#   'a fucking million years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'fucking',
#   'million',
#   'years'),
#  (1929068,
#   'a good seven hours',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'seven',
#   'hours'),
#  (1929226, 'a good 17 years', 'ARTICLE JJ CD NNS', 'a', 'good', '17', 'years'),
#  (1931095,
#   'a good many notions',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'notions'),
#  (1931491,
#   'an additional two years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'two',
#   'years'),
#  (1937533,
#   'a staggering 22 years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'staggering',
#   '22',
#   'years'),
#  (1941652,
#   'A further 468 men',
#   'ARTICLE JJ CD NNS',
#   'A',
#   'further',
#   '468',
#   'men'),
#  (1945219,
#   'a staggering 22 years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'staggering',
#   '22',
#   'years'),
#  (1950760,
#   'a full two weeks',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   'two',
#   'weeks'),
#  (1952645,
#   'a record four consecutive finals',
#   'ARTICLE RECORD CD JJ NNS',
#   'a',
#   'record',
#   'four',
#   'consecutive finals'),
#  (1954074,
#   'a further two hundred and fifty thousand pounds',
#   'ARTICLE JJ CD CD CC CD CD NNS',
#   'a',
#   'further',
#   'two hundred and fifty thousand',
#   'pounds'),
#  (1954091,
#   'a further two hundred and fifty thousand pounds',
#   'ARTICLE JJ CD CD CC CD CD NNS',
#   'a',
#   'further',
#   'two hundred and fifty thousand',
#   'pounds'),
#  (1954207,
#   'a further three appearances',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'three',
#   'appearances'),
#  (1956424,
#   'a half dozen coaches',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'half',
#   'dozen',
#   'coaches'),
#  (1959669,
#   'a further 24 hours',
#   'ARTICLE JJR CD NNS',
#   'a',
#   'further',
#   '24',
#   'hours'),
#  (1966371,
#   'an estimated 600 globulars',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '600',
#   'globulars'),
#  (1968148,
#   'a record fifteen starters',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   'fifteen',
#   'starters'),
#  (1969351,
#   'a further ten years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'ten',
#   'years'),
#  (1983620,
#   'a further 24 hours',
#   'ARTICLE JJR CD NNS',
#   'a',
#   'further',
#   '24',
#   'hours'),
#  (1985835,
#   'a further 600 metres',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '600',
#   'metres'),
#  (2009275,
#   'an additional 17 people',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '17',
#   'people'),
#  (2010479,
#   'a career - high 42 points',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '42',
#   'points'),
#  (2010755,
#   'a great many times',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'great',
#   'many',
#   'times'),
#  (2016055,
#   'a blufftop location several miles',
#   'ARTICLE JJ NN FEW NNS',
#   'a',
#   'blufftop location',
#   'several',
#   'miles'),
#  (2019810,
#   'a career - high 3 sacks',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '3',
#   'sacks'),
#  (2023740,
#   'a glorified seven hundred people',
#   'ARTICLE JJ CD CD NNS',
#   'a',
#   'glorified',
#   'seven hundred',
#   'people'),
#  (2025590,
#   'a grander effort three decades',
#   'ARTICLE JJR NN CD NNS',
#   'a',
#   'grander effort',
#   'three',
#   'decades'),
#  (2026778,
#   'a scoreless 90 minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'scoreless',
#   '90',
#   'minutes'),
#  (2028820,
#   'a further 1,000 vehicles',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '1,000',
#   'vehicles'),
#  (2029014,
#   'an additional 140 MRV',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '140',
#   'MRV'),
#  (2030380,
#   'a full 90 minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'full',
#   '90',
#   'minutes'),
#  (2030455,
#   'a healthy nation but more people',
#   'ARTICLE JJ NN CC FEW NNS',
#   'a',
#   'healthy nation but',
#   'more',
#   'people'),
#  (2031841,
#   'a vast circular structure several stories',
#   'ARTICLE JJ JJ NN FEW NNS',
#   'a',
#   'vast circular structure',
#   'several',
#   'stories'),
#  (2031887,
#   'an additional two shovels',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'two',
#   'shovels'),
#  (2035319,
#   'a further seven years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'seven',
#   'years'),
#  (2040946,
#   'a little bit more luxuries',
#   'ARTICLE JJ NN FEW NNS',
#   'a',
#   'little bit',
#   'more',
#   'luxuries'),
#  (2044539,
#   'a constant 5 degrees',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'constant',
#   '5',
#   'degrees'),
#  (2052904,
#   'a fantastic ten years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'fantastic',
#   'ten',
#   'years'),
#  (2064184,
#   'a double - double 15 points',
#   'ARTICLE JJ HYPH NN CD NNS',
#   'a',
#   'double - double',
#   '15',
#   'points'),
#  (2064983,
#   'a single parent and two grandparents',
#   'ARTICLE JJ NN CC CD NNS',
#   'a',
#   'single parent and',
#   'two',
#   'grandparents'),
#  (2065192,
#   'an automatic and two seven - round clips',
#   'ARTICLE JJ CC CD CD HYPH NN NNS',
#   'an',
#   'automatic and',
#   'two seven -',
#   'round clips'),
#  (2065655,
#   'a record - high 185 underclassed draft prospects',
#   'ARTICLE RECORD HYPH JJ CD JJ NN NNS',
#   'a',
#   'record - high',
#   '185',
#   'underclassed draft prospects'),
#  (2072101,
#   'a record 63 tournaments',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '63',
#   'tournaments'),
#  (2073928,
#   'a record four consecutive times',
#   'ARTICLE RECORD CD JJ NNS',
#   'a',
#   'record',
#   'four',
#   'consecutive times'),
#  (2078326,
#   'a public road and several rural lanes',
#   'ARTICLE JJ NN CC FEW JJ NNS',
#   'a',
#   'public road and',
#   'several',
#   'rural lanes'),
#  (2079926,
#   'an estimated 360 casualties',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '360',
#   'casualties'),
#  (2082082,
#   'a new artwork and three extra songs',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'new artwork and',
#   'three',
#   'extra songs'),
#  (2083668,
#   'an additional 6000 scudi',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '6000',
#   'scudi'),
#  (2086653,
#   'a hard five years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'hard',
#   'five',
#   'years'),
#  (2086934,
#   'a good two inches',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'good',
#   'two',
#   'inches'),
#  (2087316,
#   'a faded plaid two inches',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'faded plaid',
#   'two',
#   'inches'),
#  (2097036,
#   'a record 195 games',
#   'ARTICLE RECORD CD NNS',
#   'a',
#   'record',
#   '195',
#   'games'),
#  (2102619,
#   'a whopping 254 pounds',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'whopping',
#   '254',
#   'pounds'),
#  (2104037,
#   'a second ring two feet',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'second ring',
#   'two',
#   'feet'),
#  (2104608,
#   'a further nine retrograde steps',
#   'ARTICLE JJ CD JJ NNS',
#   'a',
#   'further',
#   'nine',
#   'retrograde steps'),
#  (2106675,
#   'an estimated 1.4 times',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '1.4',
#   'times'),
#  (2109726,
#   'a further 59 appearances',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   '59',
#   'appearances'),
#  (2112412,
#   'a further two spells',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'two',
#   'spells'),
#  (2113246,
#   'a bad ten minutes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'bad',
#   'ten',
#   'minutes'),
#  (2114327,
#   'a career - high 5 receptions',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '5',
#   'receptions'),
#  (2114329,
#   'a career - high 55 receiving yards',
#   'ARTICLE NN HYPH JJ CD NN NNS',
#   'a',
#   'career - high',
#   '55',
#   'receiving yards'),
#  (2114332,
#   'a career - high 26 receptions',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '26',
#   'receptions'),
#  (2115824,
#   'an estimated 10 casualties',
#   'ARTICLE VBN CD NNS',
#   'an',
#   'estimated',
#   '10',
#   'casualties'),
#  (2118099,
#   'a terrible hurt ten years',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'terrible hurt',
#   'ten',
#   'years'),
#  (2120410,
#   'a mere twenty years',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   'twenty',
#   'years'),
#  (2124311,
#   'a good many things',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'things'),
#  (2128587,
#   'a second round two weeks',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'second round',
#   'two',
#   'weeks'),
#  (2131869,
#   'a central cupola and two rear dormers',
#   'ARTICLE JJ NN CC CD JJ NNS',
#   'a',
#   'central cupola and',
#   'two',
#   'rear dormers'),
#  (2134338,
#   'a further six times',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'six',
#   'times'),
#  (2134340,
#   'a further two defeats',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'further',
#   'two',
#   'defeats'),
#  (2138893,
#   'a fierce engagement two days',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'fierce engagement',
#   'two',
#   'days'),
#  (2147526,
#   'a team - high 11 goals',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'team - high',
#   '11',
#   'goals'),
#  (2148023,
#   'a good many people',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'good',
#   'many',
#   'people'),
#  (2148355,
#   'a career - high three touchdowns',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   'three',
#   'touchdowns'),
#  (2154138,
#   'a new world post nine eleven days',
#   'ARTICLE JJ NN NN CD CD NNS',
#   'a',
#   'new world post',
#   'nine eleven',
#   'days'),
#  (2156035,
#   'an amazing 82 years',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'amazing',
#   '82',
#   'years'),
#  (2158024,
#   'a popular 22 episodes',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'popular',
#   '22',
#   'episodes'),
#  (2161061,
#   'a mere eight months',
#   'ARTICLE JJ CD NNS',
#   'a',
#   'mere',
#   'eight',
#   'months'),
#  (2163799,
#   'a very very long twenty odd minutes',
#   'ARTICLE RB RB JJ CD JJ NNS',
#   'a',
#   'very very long',
#   'twenty',
#   'odd minutes'),
#  (2164187,
#   'a mere 65 - koku',
#   'ARTICLE JJ CD HYPH NNS',
#   'a',
#   'mere',
#   '65 -',
#   'koku'),
#  (2168097,
#   'An estimated 140 people',
#   'ARTICLE VBN CD NNS',
#   'An',
#   'estimated',
#   '140',
#   'people'),
#  (2177329,
#   'An additional 2,776 people',
#   'ARTICLE JJ CD NNS',
#   'An',
#   'additional',
#   '2,776',
#   'people'),
#  (2178479,
#   'a select few establishments',
#   'ARTICLE JJ FEW NNS',
#   'a',
#   'select',
#   'few',
#   'establishments'),
#  (2180261,
#   'an estimated 10 000 to 15 000 men',
#   'ARTICLE VBN CD CD TO CD CD NNS',
#   'an',
#   'estimated',
#   '10 000 to 15 000',
#   'men'),
#  (2180427,
#   'an additional six smaller searchlights',
#   'ARTICLE JJ CD JJR NNS',
#   'an',
#   'additional',
#   'six',
#   'smaller searchlights'),
#  (2181852,
#   'an additional 0.7 miles',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   '0.7',
#   'miles'),
#  (2183668,
#   'an additional eight weeks',
#   'ARTICLE JJ CD NNS',
#   'an',
#   'additional',
#   'eight',
#   'weeks'),
#  (2183896,
#   'a combined 11 games',
#   'ARTICLE VBN CD NNS',
#   'a',
#   'combined',
#   '11',
#   'games'),
#  (2184575,
#   'a career - high 51 tackles',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'career - high',
#   '51',
#   'tackles'),
#  (2184699,
#   'a season - high four stops',
#   'ARTICLE NN HYPH JJ CD NNS',
#   'a',
#   'season - high',
#   'four',
#   'stops'),
#  (2185725,
#   'a good twenty - five miles',
#   'ARTICLE JJ CD CD CD NNS',
#   'a',
#   'good',
#   'twenty - five',
#   'miles'),
#  (2186327,
#   'a second time six weeks',
#   'ARTICLE JJ NN CD NNS',
#   'a',
#   'second time',
#   'six',
#   'weeks'),
#  ...]
