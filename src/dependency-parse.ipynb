# %%
import glob
import re
import spacy

from collections import defaultdict
from utils import read_babylm
from tqdm import tqdm

from joblib import Parallel, delayed
from multiprocessing import Manager

import pickle

# %%
nlp = spacy.load("en_core_web_sm")

sentences = [
    "A few days should be enough for that task!",
    "A hundred dollars is a lot of money.",
    "A few hundred dollars is all we need for this mission.",
    "The hundred dollars I spent ended up being a lot of money.",
    "Five days is a long time to wait for a response.",
    "Seven weeks of thesis writing takes a toll on one's body.",
    "A year is a long time to wait.",
    "Five people is a not a huge number of attendees.",
    "Revenue exceeded twelve billion dollars, with a loss of $1b.",
    "Net income was $9.4 million compared to the prior year of $2.7 million.",
    "Five people is a not a huge number of attendees.",
    "A dozen eggs is too many.",
]

# %%
def is_plural_noun(token):
    return token.pos_ == "NOUN" and (token.tag_ == "NNS" or token.tag_ == "NNPS")

def get_number(token):
    '''get the number of the token from its morph representation'''
    morph = token.morph
    if morph.get("Number") == "Sing":
        return "sg"
    elif morph.get("Number") == "Plur":
        return "pl"
    else:
        return False

# %%
relevant_sentences = []
for sentence in sentences:
    doc = nlp(sentence)
    found = False
    for token in doc:
        print(token.text, [(child.text, child.dep_) for child in token.children], [(ancestor.text, ancestor.dep_) for ancestor in token.ancestors])
        # print(token.text, token.pos_, token.dep_, token.head.text)
    #     head = token.head
    #     if token.dep_ == "amod" or token.dep_ == "nummod":
    #         if is_plural_noun(head) and head.:
    #             found=True
    #             relevant_sentences.append(sentence)
    #             # break
    #         # print(head.text, token.text, token.dep_, token.head.text)
    print("")
# Out:
# A [] [('days', 'nsubj'), ('be', 'ROOT')]
# few [] [('days', 'nsubj'), ('be', 'ROOT')]
# days [('A', 'det'), ('few', 'amod')] [('be', 'ROOT')]
# should [] [('be', 'ROOT')]
# be [('days', 'nsubj'), ('should', 'aux'), ('enough', 'acomp'), ('!', 'punct')] []
# enough [('for', 'prep')] [('be', 'ROOT')]
# for [('task', 'pobj')] [('enough', 'acomp'), ('be', 'ROOT')]
# that [] [('task', 'pobj'), ('for', 'prep'), ('enough', 'acomp'), ('be', 'ROOT')]
# task [('that', 'det')] [('for', 'prep'), ('enough', 'acomp'), ('be', 'ROOT')]
# ! [] [('be', 'ROOT')]
#
# A [] [('hundred', 'nummod'), ('dollars', 'nsubj'), ('is', 'ROOT')]
# hundred [('A', 'quantmod')] [('dollars', 'nsubj'), ('is', 'ROOT')]
# dollars [('hundred', 'nummod')] [('is', 'ROOT')]
# is [('dollars', 'nsubj'), ('lot', 'attr'), ('.', 'punct')] []
# a [] [('lot', 'attr'), ('is', 'ROOT')]
# lot [('a', 'det'), ('of', 'prep')] [('is', 'ROOT')]
# of [('money', 'pobj')] [('lot', 'attr'), ('is', 'ROOT')]
# money [] [('of', 'prep'), ('lot', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# A [] [('hundred', 'nummod'), ('dollars', 'nsubj'), ('is', 'ROOT')]
# few [] [('hundred', 'nummod'), ('dollars', 'nsubj'), ('is', 'ROOT')]
# hundred [('A', 'quantmod'), ('few', 'amod')] [('dollars', 'nsubj'), ('is', 'ROOT')]
# dollars [('hundred', 'nummod')] [('is', 'ROOT')]
# is [('dollars', 'nsubj'), ('all', 'attr'), ('.', 'punct')] []
# all [('need', 'relcl')] [('is', 'ROOT')]
# we [] [('need', 'relcl'), ('all', 'attr'), ('is', 'ROOT')]
# need [('we', 'nsubj'), ('for', 'prep')] [('all', 'attr'), ('is', 'ROOT')]
# for [('mission', 'pobj')] [('need', 'relcl'), ('all', 'attr'), ('is', 'ROOT')]
# this [] [('mission', 'pobj'), ('for', 'prep'), ('need', 'relcl'), ('all', 'attr'), ('is', 'ROOT')]
# mission [('this', 'det')] [('for', 'prep'), ('need', 'relcl'), ('all', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# The [] [('dollars', 'nsubj'), ('ended', 'ROOT')]
# hundred [] [('dollars', 'nsubj'), ('ended', 'ROOT')]
# dollars [('The', 'det'), ('hundred', 'nummod'), ('spent', 'relcl')] [('ended', 'ROOT')]
# I [] [('spent', 'relcl'), ('dollars', 'nsubj'), ('ended', 'ROOT')]
# spent [('I', 'nsubj')] [('dollars', 'nsubj'), ('ended', 'ROOT')]
# ended [('dollars', 'nsubj'), ('up', 'prt'), ('being', 'xcomp'), ('.', 'punct')] []
# up [] [('ended', 'ROOT')]
# being [('lot', 'attr')] [('ended', 'ROOT')]
# a [] [('lot', 'attr'), ('being', 'xcomp'), ('ended', 'ROOT')]
# lot [('a', 'det'), ('of', 'prep')] [('being', 'xcomp'), ('ended', 'ROOT')]
# of [('money', 'pobj')] [('lot', 'attr'), ('being', 'xcomp'), ('ended', 'ROOT')]
# money [] [('of', 'prep'), ('lot', 'attr'), ('being', 'xcomp'), ('ended', 'ROOT')]
# . [] [('ended', 'ROOT')]
#
# Five [] [('days', 'nsubj'), ('is', 'ROOT')]
# days [('Five', 'nummod')] [('is', 'ROOT')]
# is [('days', 'nsubj'), ('time', 'attr'), ('.', 'punct')] []
# a [] [('time', 'attr'), ('is', 'ROOT')]
# long [] [('time', 'attr'), ('is', 'ROOT')]
# time [('a', 'det'), ('long', 'amod'), ('wait', 'relcl')] [('is', 'ROOT')]
# to [] [('wait', 'relcl'), ('time', 'attr'), ('is', 'ROOT')]
# wait [('to', 'aux'), ('for', 'prep')] [('time', 'attr'), ('is', 'ROOT')]
# for [('response', 'pobj')] [('wait', 'relcl'), ('time', 'attr'), ('is', 'ROOT')]
# a [] [('response', 'pobj'), ('for', 'prep'), ('wait', 'relcl'), ('time', 'attr'), ('is', 'ROOT')]
# response [('a', 'det')] [('for', 'prep'), ('wait', 'relcl'), ('time', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# Seven [] [('weeks', 'nsubj'), ('takes', 'ROOT')]
# weeks [('Seven', 'nummod'), ('of', 'prep')] [('takes', 'ROOT')]
# of [('writing', 'pobj')] [('weeks', 'nsubj'), ('takes', 'ROOT')]
# thesis [] [('writing', 'pobj'), ('of', 'prep'), ('weeks', 'nsubj'), ('takes', 'ROOT')]
# writing [('thesis', 'compound')] [('of', 'prep'), ('weeks', 'nsubj'), ('takes', 'ROOT')]
# takes [('weeks', 'nsubj'), ('toll', 'dobj'), ('.', 'punct')] []
# a [] [('toll', 'dobj'), ('takes', 'ROOT')]
# toll [('a', 'det'), ('on', 'prep')] [('takes', 'ROOT')]
# on [('body', 'pobj')] [('toll', 'dobj'), ('takes', 'ROOT')]
# one [("'s", 'case')] [('body', 'pobj'), ('on', 'prep'), ('toll', 'dobj'), ('takes', 'ROOT')]
# 's [] [('one', 'poss'), ('body', 'pobj'), ('on', 'prep'), ('toll', 'dobj'), ('takes', 'ROOT')]
# body [('one', 'poss')] [('on', 'prep'), ('toll', 'dobj'), ('takes', 'ROOT')]
# . [] [('takes', 'ROOT')]
#
# A [] [('year', 'nsubj'), ('is', 'ROOT')]
# year [('A', 'det')] [('is', 'ROOT')]
# is [('year', 'nsubj'), ('time', 'attr'), ('.', 'punct')] []
# a [] [('time', 'attr'), ('is', 'ROOT')]
# long [] [('time', 'attr'), ('is', 'ROOT')]
# time [('a', 'det'), ('long', 'amod'), ('wait', 'relcl')] [('is', 'ROOT')]
# to [] [('wait', 'relcl'), ('time', 'attr'), ('is', 'ROOT')]
# wait [('to', 'aux')] [('time', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# Five [] [('people', 'nsubj'), ('is', 'ROOT')]
# people [('Five', 'nummod')] [('is', 'ROOT')]
# is [('people', 'nsubj'), ('number', 'attr'), ('.', 'punct')] []
# a [] [('number', 'attr'), ('is', 'ROOT')]
# not [] [('number', 'attr'), ('is', 'ROOT')]
# a [] [('number', 'attr'), ('is', 'ROOT')]
# huge [] [('number', 'attr'), ('is', 'ROOT')]
# number [('a', 'det'), ('not', 'neg'), ('a', 'det'), ('huge', 'amod'), ('of', 'prep')] [('is', 'ROOT')]
# of [('attendees', 'pobj')] [('number', 'attr'), ('is', 'ROOT')]
# attendees [] [('of', 'prep'), ('number', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# Revenue [] [('exceeded', 'ROOT')]
# exceeded [('Revenue', 'nsubj'), ('dollars', 'dobj'), (',', 'punct'), ('with', 'prep'), ('.', 'punct')] []
# twelve [] [('billion', 'nummod'), ('dollars', 'dobj'), ('exceeded', 'ROOT')]
# billion [('twelve', 'compound')] [('dollars', 'dobj'), ('exceeded', 'ROOT')]
# dollars [('billion', 'nummod')] [('exceeded', 'ROOT')]
# , [] [('exceeded', 'ROOT')]
# with [('loss', 'pobj')] [('exceeded', 'ROOT')]
# a [] [('loss', 'pobj'), ('with', 'prep'), ('exceeded', 'ROOT')]
# loss [('a', 'det'), ('of', 'prep')] [('with', 'prep'), ('exceeded', 'ROOT')]
# of [('1b', 'pobj')] [('loss', 'pobj'), ('with', 'prep'), ('exceeded', 'ROOT')]
# $ [] [('1b', 'pobj'), ('of', 'prep'), ('loss', 'pobj'), ('with', 'prep'), ('exceeded', 'ROOT')]
# 1b [('$', 'nmod')] [('of', 'prep'), ('loss', 'pobj'), ('with', 'prep'), ('exceeded', 'ROOT')]
# . [] [('exceeded', 'ROOT')]
#
# Net [] [('income', 'nsubj'), ('was', 'ROOT')]
# income [('Net', 'amod')] [('was', 'ROOT')]
# was [('income', 'nsubj'), ('million', 'attr'), ('compared', 'prep'), ('.', 'punct')] []
# $ [] [('million', 'attr'), ('was', 'ROOT')]
# 9.4 [] [('million', 'attr'), ('was', 'ROOT')]
# million [('$', 'quantmod'), ('9.4', 'compound')] [('was', 'ROOT')]
# compared [('to', 'prep')] [('was', 'ROOT')]
# to [('year', 'pobj')] [('compared', 'prep'), ('was', 'ROOT')]
# the [] [('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# prior [] [('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# year [('the', 'det'), ('prior', 'amod'), ('of', 'prep')] [('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# of [('million', 'pobj')] [('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# $ [] [('million', 'pobj'), ('of', 'prep'), ('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# 2.7 [] [('million', 'pobj'), ('of', 'prep'), ('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# million [('$', 'quantmod'), ('2.7', 'compound')] [('of', 'prep'), ('year', 'pobj'), ('to', 'prep'), ('compared', 'prep'), ('was', 'ROOT')]
# . [] [('was', 'ROOT')]
#
# Five [] [('people', 'nsubj'), ('is', 'ROOT')]
# people [('Five', 'nummod')] [('is', 'ROOT')]
# is [('people', 'nsubj'), ('number', 'attr'), ('.', 'punct')] []
# a [] [('number', 'attr'), ('is', 'ROOT')]
# not [] [('number', 'attr'), ('is', 'ROOT')]
# a [] [('number', 'attr'), ('is', 'ROOT')]
# huge [] [('number', 'attr'), ('is', 'ROOT')]
# number [('a', 'det'), ('not', 'neg'), ('a', 'det'), ('huge', 'amod'), ('of', 'prep')] [('is', 'ROOT')]
# of [('attendees', 'pobj')] [('number', 'attr'), ('is', 'ROOT')]
# attendees [] [('of', 'prep'), ('number', 'attr'), ('is', 'ROOT')]
# . [] [('is', 'ROOT')]
#
# A [] [('dozen', 'nummod'), ('eggs', 'nsubj'), ('is', 'ROOT')]
# dozen [('A', 'quantmod')] [('eggs', 'nsubj'), ('is', 'ROOT')]
# eggs [('dozen', 'nummod')] [('is', 'ROOT')]
# is [('eggs', 'nsubj'), ('many', 'acomp'), ('.', 'punct')] []
# too [] [('many', 'acomp'), ('is', 'ROOT')]
# many [('too', 'advmod')] [('is', 'ROOT')]
# . [] [('is', 'ROOT')]

# %%
relevant_sentences
# Out:
# ['A few days should be enough for that task!',
#  'A hundred dollars is a lot of money.',
#  'Five days is a long time to wait for a response.',
#  "Seven weeks of thesis writing takes a toll on one's body.",
#  'Five people is a not a huge number of attendees.',
#  'Revenue exceeded twelve billion dollars, with a loss of $1b.',
#  'Five people is a not a huge number of attendees.',
#  'A dozen eggs is too many.']

# %%
ddoc = nlp("five days of that is fun!")
for d in ddoc:
    if d.text == "days":
        break

# %%
list(d.children)[0].dep_
# Out:
# 'nummod'

# %%
d.head.dep_, d.dep_, list(d.ancestors)
# Out:
# ('ROOT', 'nsubj', [is])

# %%
'''
read all sentences and parse into batches --> store
run spacy through batches --> store all plural nouns of sentences one entry + sentence, if empty then we store empty things.
'''

# %%
def read_sents(path, batch_size=-1):
    batches = []
    with open(path) as f:
        batch = []
        for line in f:
            if batch_size < 0:
                batches.append(line.strip())
            else:
                batch.append(line.strip())
                if len(batch) == batch_size:
                    batches.append(batch)
                    batch = []
        if batch:
            batches.append(batch)
    return batches

# %%
babylm = read_sents("/home/km55359/rawdata/babylm_data/babylm_100M/sents/babylm_sents.txt")
len(babylm)
# Out:
# 11632017

# %%
1208821

# %%
# def sentence_tokenize(lst):
#     for item in lst:
#         sentences.extend(sent_tokenize(item))
#     return


# def sentence_tokenize_parallel(lst):
#     pbar = tqdm(lst)
#     _ = Parallel(n_jobs=10)(delayed(sentence_tokenize)(f) for f in pbar)
#     return

# %%
def retrieve_plural_nouns(doc):
    pl_nouns = []
    for token in doc:
        if is_plural_noun(token):
            pl_nouns.append(token)
    return pl_nouns

# %%
PL_NOUNS = []
for doc in tqdm(nlp.pipe(babylm, disable=["lemmatizer", "ner"], n_process=32)):
    pl_nouns = retrieve_plural_nouns(doc)
    PL_NOUNS.append(pl_nouns)
# Out:
# 11632017it [2:41:35, 1199.73it/s]

# %%
list(noun.ancestors)
# Out:
# [BE]

# %%
head.tag_
# Out:
# 'VB'

# %%
indices = set()
relevant = []
for i, nouns in enumerate(tqdm(PL_NOUNS)):
    # check if the noun has an ancestor verb that is singular
    for noun in nouns:
        head = noun.head
        morph = head.morph
        if (head.pos_ == "VERB" or head.pos_ == "AUX") and morph.get("Number") == ["Sing"]:
            indices.add(i)
            relevant.append((i, noun.text, head.text, noun.pos_, head.pos_, head.dep_, noun.dep_))
            break

nummods_indices = set()
relevant_nummods = []
for i, nouns in enumerate(tqdm(PL_NOUNS)):
    for noun in nouns:
        for child in noun.children:
            if child.dep_ == "nummod" or child.text == "few" or child.text == "dozen" or child.text == "couple":
                nummods_indices.add(i)
                relevant_nummods.append((i, noun.text, child.text, noun.pos_, child.pos_, child.dep_, noun.dep_))
                break
# Out:
#   0%|          | 0/11632017 [00:00<?, ?it/s]
# 100%|██████████| 11632017/11632017 [00:07<00:00, 1503995.23it/s]
# 100%|██████████| 11632017/11632017 [00:09<00:00, 1173938.12it/s]

# %%
intersect = indices.intersection(nummods_indices)

# %%
babylm[5898245]
# Out:
# 'The lesser roadrunner has zygodactyl feet, meaning it has two toes on the back of its feet and two toes on the front.'

# %%
# save both relevant values as csvs:
import pandas as pd
df = pd.DataFrame(relevant, columns=["idx", "noun", "verb", "noun_pos", "verb_pos", "verb_dep", "noun_dep"])
df.to_csv("../data/babylm-analysis/plural_nouns_with_singular_heads.csv", index=False)

df = pd.DataFrame(relevant_nummods, columns=["idx", "noun", "numeral", "noun_pos", "numeral_pos", "numeral_dep", "noun_dep"])
df.to_csv("../data/babylm-analysis/plural_nouns_with_nummods.csv", index=False)

# %%
list(sorted(list(indices)))[:10]
# Out:
# [36, 52, 158, 237, 293, 297, 300, 301, 377, 396]

# %%
babylm[537], relevant[10]
# Out:
# ('White has 2 options after this.', (406, 'kinds', "'s", 'relcl', 'ccomp'))

# %%
deps = defaultdict(list)
for entry in relevant:
    deps[entry[4]].append(list(entry)[:4])
deps = dict(deps)

# %%
babylm[7696]
# Out:
# '0n the open grasslands of central Asia, the steppes, lives an animal that issues invitations to prospective partners with a perfume.'

# %%
deps['nsubj']
# Out:
# [[158, 'messages', 'is', 'ROOT'],
#  [559, 'defends', 'works', 'ROOT'],
#  [1051, 'Euronews', 'has', 'ROOT'],
#  [1068, 'injections', 'is', 'ROOT'],
#  [1547, 'E', 'compares', 'ROOT'],
#  [2484, 'chips', "'s", 'ROOT'],
#  [2586, 'monkeys', "'s", 'ROOT'],
#  [6657, 'Economics', 'tends', 'ROOT'],
#  [7696, 'grasslands', 'lives', 'ROOT'],
#  [9379, 'peoples', 'was', 'ROOT'],
#  [10978, 'species', 'is', 'ROOT'],
#  [11108, 'injuries', 'leaves', 'ROOT'],
#  [12107, 'supervisors', 'does', 'advcl'],
#  [12402, 'remains', 'is', 'ROOT'],
#  [12616, 'Phascolarctos', 'is', 'ROOT'],
#  [12734, 'variations', 'is', 'ROOT'],
#  [12856, 'clothes', 'is', 'ROOT'],
#  [12955, 'azygos', 'means', 'ROOT'],
#  [13219, 'Contemplations', 'suggests', 'ROOT'],
#  [13534, 'pounds', 's', 'ccomp'],
#  [13916, 'Foulds', 'is', 'ROOT'],
#  [13924, 'codice_1', 'is', 'ROOT'],
#  [13948, 'codice_1', 'serves', 'ROOT'],
#  [14029, '1980s', 'was', 'ROOT'],
#  [14053, 'years', 'is', 'ccomp'],
#  [14246, 'clerks', 'is', 'ROOT'],
#  [14523, 'Bubbles', 'organizes', 'ROOT'],
#  [15417, 'appointments', 'is', 'ccomp'],
#  [15634, 'injuries', 'leaves', 'ROOT'],
#  [15905, 'recommendations', 'is', 'ROOT'],
#  [16322, 'locks', 'has', 'ROOT'],
#  [16416, 'pounds', 'is', 'ccomp'],
#  [16684, 'pounds', 'is', 'ccomp'],
#  [16789, 'pensions', 'is', 'ROOT'],
#  [16850, 'feelings', 'is', 'ccomp'],
#  [16879, 'muscles', 'is', 'ROOT'],
#  [17306, 'feet', 'was', 'ROOT'],
#  [18977, 'things', 'is', 'ccomp'],
#  [19207, 'injuries', 'leaves', 'ROOT'],
#  [20193, 'minutes', 'is', 'conj'],
#  [20317, 'impressions', 'obscures', 'relcl'],
#  [20347, 'loops', 'is', 'ROOT'],
#  [20681, 'data', 'is', 'ROOT'],
#  [21120, 'factors', "'s", 'ccomp'],
#  [21699, 'professionals', 'is', 'conj'],
#  [21853, 'categories', "'s", 'ccomp'],
#  [22810, 'groups', 'is', 'ccomp'],
#  [23004, 'arguments', 'is', 'ccomp'],
#  [23873, 'words', 'cries', 'ROOT'],
#  [24545, 'thirds', 'is', 'ccomp'],
#  [24939, 'sports', 'was', 'ROOT'],
#  [24966, 'Bridges', 'was', 'ROOT'],
#  [24987, 'Bridges', 'has', 'ROOT'],
#  [25017, 'Bridges', 'was', 'ccomp'],
#  [25018, 'Bridges', 'was', 'ccomp'],
#  [25593, 'men', 'was', 'ROOT'],
#  [25861, 'Estes', 'resides', 'ROOT'],
#  [26181, 'thirds', 'is', 'ccomp'],
#  [26757, 'examples', 'includes', 'ROOT'],
#  [27075, 'splits', 'enters', 'ROOT'],
#  [27144, 'species', 'is', 'ROOT'],
#  [27150, 'species', 'occurs', 'ROOT'],
#  [27868, 'People', 'is', 'ROOT'],
#  [30531, 'couches', 'sits', 'ROOT'],
#  [31048, 'things', 'is', 'conj'],
#  [31166, 'allies', 'was', 'ROOT'],
#  [31496, 'Wars', 'takes', 'ROOT'],
#  [31505, 'medias', 'res', 'pcomp'],
#  [31507, 'medias', 'res', 'pcomp'],
#  [31541, 'politics', 'determines', 'ROOT'],
#  [31861, 'managers', 'is', 'ROOT'],
#  [32012, 'ones', 'was', 'ROOT'],
#  [32045, 'systems', 'works', 'ROOT'],
#  [32307, 'Nichimen', 'was', 'ROOT'],
#  [34147, 'politics', 'is', 'ROOT'],
#  [34768, 'policies', 'is', 'ROOT'],
#  [35096, 'winners', 'titleholders', 'conj'],
#  [35259, 'years', 'is', 'ROOT'],
#  [35884, 'regio', 'is', 'ROOT'],
#  [36023, 'species', 'belongs', 'ROOT'],
#  [36492, 'deductions', 'is', 'ccomp'],
#  [36709, 'Princesses', 'was', 'ccomp'],
#  [37106, 'Jubei', 'manages', 'ROOT'],
#  [37108, 'Warriors', 'has', 'ROOT'],
#  [38119, 'parents', 'was', 'ROOT'],
#  [38272, 'Cattle', 'is', 'ROOT'],
#  [39099, 'data', 'states', 'ROOT'],
#  [39171, 'papa', 'was', 'ROOT'],
#  [39455, 'methinks', 'is', 'ROOT'],
#  [41197, 'pounds', 'is', 'ccomp'],
#  [41604, 'words', 'was', 'advcl'],
#  [41649, "d'épices", 'is', 'ROOT'],
#  [41767, 'Denbies', 'was', 'ccomp'],
#  [42397, 'grades', 'involves', 'ROOT'],
#  [42762, 'eyes', 'pierces', 'pcomp'],
#  [43038, 'degrees', 'is', 'ROOT'],
#  [43605, 'advertisements', 'guesses', 'ROOT'],
#  [43902, 'computers', 'was', 'ROOT'],
#  [44228, 'Figs', 'was', 'ROOT'],
#  [45326, 'data', 'is', 'ccomp'],
#  [45959, 'minutes', 'is', 'ccomp'],
#  [46340, 'Figs', 'was', 'ROOT'],
#  [46702, 'decays', 'stays', 'ROOT'],
#  [46736, 'pages', 'processes', 'advcl'],
#  [47275, 'seditions', 'corresponds', 'ROOT'],
#  [47356, 'decays', 'stays', 'ROOT'],
#  [47983, 'hours', 'is', 'ROOT'],
#  [48556, 'scissors', 'was', 'ccomp'],
#  [49887, 'Reviers', 'is', 'ROOT'],
#  [49904, 'things', 'is', 'advcl'],
#  [49909, 'Reviers', 'was', 'ROOT'],
#  [49946, 'hearts', 'was', 'ROOT'],
#  [50646, 'paces', 'lies', 'ROOT'],
#  [51094, 'Rots', 'is', 'ROOT'],
#  [51128, 'Roucamps', 'is', 'ROOT'],
#  [51165, 'Roullours', 'is', 'ROOT'],
#  [51597, 'Rouvres', 'is', 'ROOT'],
#  [51803, 'builders', 'is', 'ROOT'],
#  [54874, 'words', 'was', 'advcl'],
#  [55936, 'increases', 'is', 'acl'],
#  [56026, 'qualities', 'was', 'ccomp'],
#  [59234, 'Addams', 'was', 'ROOT'],
#  [60756, 'promises', 'recognizes', 'ROOT'],
#  [60816, 'tricks', 'was', 'ccomp'],
#  [60919, 'Cruickshanks', 'Is', 'ROOT'],
#  [61289, 'Innes', 'is', 'ROOT'],
#  [61296, 'Innes', 'is', 'ROOT'],
#  [61748, 'reports', 'was', 'ROOT'],
#  [62114, 'hours', 'is', 'ROOT'],
#  [62573, 'apples', "'s", 'ROOT'],
#  [62681, 'projects', 'is', 'ccomp'],
#  [63142, 'presidencies', 'was', 'ROOT'],
#  [64318, 'bacteria', 'creates', 'ROOT'],
#  [65493, 'rules', 'renders', 'ccomp'],
#  [65719, 'Rossenges', 'is', 'ROOT'],
#  [65787, 'species', 'guides', 'ccomp'],
#  [65835, 'biscuits', "'s", 'advcl'],
#  [66251, 'crimes', 'is', 'advcl'],
#  [66668, 'Waves', 'is', 'ROOT'],
#  [67053, 'bumpers', 'was', 'conj'],
#  [67398, 'morcillas', 'chorizos', 'parataxis'],
#  [68812, 'Syens', 'is', 'ROOT'],
#  [68832, 'reflexes', 'is', 'ccomp'],
#  [69069, 'responses', 'tends', 'ccomp'],
#  [69127, 'efforts', 'was', 'ROOT'],
#  [69394, 'Bones', 'shows', 'conj'],
#  [69971, 'rivers', 'is', 'ccomp'],
#  [70413, 'Goldilocks', 'was', 'ROOT'],
#  [70703, 'rebellions', 'is', 'ROOT'],
#  [71002, 'politics', 'goes', 'advcl'],
#  [71788, 'things', 'is', 'ROOT'],
#  [72156, 'muggins', 'does', 'ROOT'],
#  [73228, 'sheep', 'was', 'ROOT'],
#  [73568, 'Sanders', 'was', 'ROOT'],
#  [75099, 'plastics', 'is', 'ccomp'],
#  [75898, 'lessons', 'was', 'conj'],
#  [76223, 'parties', 'gives', 'ROOT'],
#  [76418, 'facilities', 'was', 'ROOT'],
#  [77007, 'groups', 'was', 'ROOT'],
#  [77108, 'Varzo', 'borders', 'ROOT'],
#  [77876, 'Briquettes', 'is', 'ROOT'],
#  [78892, 'families', 'was', 'ROOT'],
#  [79030, 'Ares', 'is', 'ROOT'],
#  [79500, 'necropolis', 'shows', 'ROOT'],
#  [79762, 'lots', "'s", 'ROOT'],
#  [79961, 'facts', 'is', 'ROOT'],
#  [80488, 'thoughts', 'was', 'ROOT'],
#  [80736, 'properties', 'is', 'ccomp'],
#  [80854, 'yards', 'was', 'ROOT'],
#  [81074, 'Scholes', 'was', 'ROOT'],
#  [81661, 'Scholes', 'is', 'ROOT'],
#  [81734, 'guys', 'yikes', 'relcl'],
#  [82074, 'taxes', 'says', 'ROOT'],
#  [82439, 'satisfies', 'satisfies', 'ROOT'],
#  [83093, 'moves', 'is', 'ROOT'],
#  [83384, 'characters', 'is', 'advcl'],
#  [83565, 'seizures', 'varies', 'ccomp'],
#  [83881, 'sarks', 'was', 'ccomp'],
#  [84155, 'Media', 'refers', 'ROOT'],
#  [84638, 'ladies', 'was', 'ccomp'],
#  [84892, 'Magnolias', 'has', 'acl'],
#  [85117, 'EAST', 'was', 'ROOT'],
#  [86074, 'Sellers', 'was', 'ROOT'],
#  [88259, 'classes', 'is', 'ROOT'],
#  [89383, 'Mokoš', 'was', 'ROOT'],
#  [90105, 'colors', 'denotes', 'relcl'],
#  [90663, 'Cargèse', 'is', 'ROOT'],
#  [91346, 'mountains', 'is', 'ROOT'],
#  [92116, 'vessels', 'gives', 'ROOT'],
#  [94165, 'Robotics', 'offers', 'ROOT'],
#  [95791, 'toes', "'s", 'relcl'],
#  [96001, 'trains', 'is', 'ROOT'],
#  [97995, 'members', 'sees', 'advcl'],
#  [98298, 'Langres', 'is', 'ROOT'],
#  [98524, 'Langres', 'is', 'ROOT'],
#  [98824, 'uncovers', 'remains', 'ROOT'],
#  [99056, 'reads', 'has', 'ROOT'],
#  [99379, 'tres', 'amores', 'ROOT'],
#  [100102, 'pupates', 'emerges', 'ROOT'],
#  [100168, 'Glyptapanteles', 'is', 'ROOT'],
#  [101182, 'pubescens', 'is', 'ROOT'],
#  [101975, 'Hippocrates', 'was', 'ROOT'],
#  [102689, 'Cells', 'is', 'ROOT'],
#  [102834, 'Cruickshanks', 'Is', 'ROOT'],
#  [103965, 'Northerners', 'seems', 'ROOT'],
#  [104199, 'tours', 'is', 'ROOT'],
#  [104556, 'blocks', 'is', 'ccomp'],
#  [105080, 'Rights', 'was', 'ROOT'],
#  [105264, 'subspecies', 'exists', 'ccomp'],
#  [105297, 'species', 'has', 'ROOT'],
#  [106152, 'Media', 'includes', 'ROOT'],
#  [106366, 'vanishes', 'is', 'ROOT'],
#  [106633, 'funerals', 'was', 'ROOT'],
#  [106881, 'groups', 'is', 'pcomp'],
#  [107065, 'gravitas', 'was', 'ROOT'],
#  [107178, 'sakes', 'is', 'ROOT'],
#  [107272, 'evergreens', 'was', 'ROOT'],
#  [107731, 'fauna', 'was', 'advcl'],
#  [107972, 'trucks', 'is', 'ROOT'],
#  [108006, 'materials', 'is', 'ROOT'],
#  [108022, 'folks', 'was', 'ccomp'],
#  [108493, 'islands', 'was', 'ROOT'],
#  [108679, 'species', 'was', 'ROOT'],
#  [108953, 'levels', 'causes', 'ROOT'],
#  [109001, 'asses', 'is', 'ROOT'],
#  [109257, 'dollars', 'was', 'ROOT'],
#  [109559, 'Epaye', 'works', 'ROOT'],
#  [110076, 'fields', 'lives', 'ROOT'],
#  [110831, 'spreads', 'is', 'ROOT'],
#  [111106, 'Wings', 'allows', 'ROOT'],
#  [111112, 'Wings', 'loads', 'ROOT'],
#  [112888, 'paymasters', 'is', 'ROOT'],
#  [112926, 'TnT', 'is', 'ccomp'],
#  [112960, 'cTnT', 'is', 'ROOT'],
#  [112976, 'cTnI', 'demonstrates', 'ROOT'],
#  [113536, 'intentions', 'is', 'ccomp'],
#  [115404, 'beads', 'dwarfs', 'ROOT'],
#  [116344, 'people', 'was', 'ccomp'],
#  [117027, 'days', 'is', 'ccomp'],
#  [117041, 'vacations', 'is', 'ccomp'],
#  [117660, 'ladies', 'is', 'ROOT'],
#  [118305, 'Socks', 'was', 'ROOT'],
#  [118801, 'Inscriptions', 'provides', 'ROOT'],
#  [119065, 'researches', 'was', 'ROOT'],
#  [119423, 'others', 'is', 'advcl'],
#  [119732, 'stars', 'is', 'advcl'],
#  [119984, 'scenes', 'is', 'ROOT'],
#  [120110, 'DANCES', 'was', 'ccomp'],
#  [121666, 'species', 'is', 'advcl'],
#  [121785, 'Béziers', 'is', 'ROOT'],
#  [121804, 'Béziers', 'is', 'ROOT'],
#  [121877, 'Béziers', 'was', 'ROOT'],
#  [121938, 'Béziers', 'was', 'ROOT'],
#  [121973, 'apartments', 'was', 'conj'],
#  [121991, 'Béziers', 'is', 'ROOT'],
#  [122120, 'Béziers', 'is', 'ROOT'],
#  [122209, 'men', 'is', 'ROOT'],
#  [122397, 'implementations', 'was', 'ROOT'],
#  [122416, 'species', 'is', 'ROOT'],
#  [122601, 'bytes', 'is', 'advcl'],
#  [123159, 'lines', 'has', 'ROOT'],
#  [123360, 'ones', 'is', 'ROOT'],
#  [123561, 'tubes', 'is', 'advcl'],
#  [124018, 'data', 'begins', 'ccomp'],
#  [124611, 'Goldilocks', 'was', 'ROOT'],
#  [128918, 'bills', 'is', 'ROOT'],
#  [128964, 'wires', 'is', 'ROOT'],
#  [129399, 'competitors', 'is', 'advcl'],
#  [129724, 'undertakes', 'turns', 'ccomp'],
#  [129976, 'people', "'s", 'ccomp'],
#  [131011, 'Hans', 'comes', 'ROOT'],
#  [131014, 'sheep', 'was', 'ROOT'],
#  [131027, 'Hans', 'says', 'ROOT'],
#  [131038, 'Hans', 'takes', 'ROOT'],
#  [131056, 'Hans', 'comes', 'ROOT'],
#  [131073, 'Hans', 'takes', 'ROOT'],
#  [131090, 'Hans', 'comes', 'ROOT'],
#  [131106, 'Hans', 'takes', 'ROOT'],
#  [131165, 'Hans', 'comes', 'ROOT'],
#  [131170, 'Hans', 'takes', 'ROOT'],
#  [131193, 'Hans', 'comes', 'ROOT'],
#  [131235, 'Hans', 'takes', 'ROOT'],
#  [131266, 'Hans', 'comes', 'ROOT'],
#  [131289, 'Hans', 'takes', 'ROOT'],
#  [131303, 'Dumas', 'gives', 'ROOT'],
#  [131718, 'EBV', 'infects', 'ROOT'],
#  [131719, 'EBV', 'stays', 'ROOT'],
#  [132429, 'Yours', 'is', 'ROOT'],
#  [132570, 'aye', 'aye', 'ROOT'],
#  [132737, 'things', 'is', 'parataxis'],
#  [133605, 'species', 'has', 'ROOT'],
#  [134459, 'sessions', 'takes', 'ccomp'],
#  [134460, 'lists', 'is', 'ROOT'],
#  [134556, 'dollars', 'reads', 'ccomp'],
#  [135017, 'begs', 'tosses', 'ROOT'],
#  [135770, 'cents', 'goes', 'ROOT'],
#  [136615, 'Pharmacokinetics', 'is', 'ROOT'],
#  [136616, 'Pharmacokinetics', 'looks', 'ROOT'],
#  [136618, 'drugs', 'affects', 'ccomp'],
#  [138465, 'protocols', 'involves', 'ROOT'],
#  [139940, 'Stacks', 'was', 'ROOT'],
#  [139992, 'names', 'is', 'ROOT'],
#  [140079, 'complications', 'is', 'ROOT'],
#  [140783, 'systems', 'is', 'ROOT'],
#  [141868, 'weapons', 'consists', 'ROOT'],
#  [143062, 'BEARD', 'was', 'ROOT'],
#  [143078, 'Data', 'rushes', 'ROOT'],
#  [143079, 'Data', 'manages', 'ROOT'],
#  [143080, 'departs', 'resumes', 'ROOT'],
#  [143187, 'sets', 'was', 'ccomp'],
#  [143209, 'caskets', 'is', 'ROOT'],
#  [143386, 'Hans', 'says', 'ROOT'],
#  [143470, 'Hans', 'goes', 'ROOT'],
#  [143789, 'Manetho', 'names', 'ROOT'],
#  [143850, 'twos', "'s", 'ROOT'],
#  [143864, 'wears', 'spurs', 'ccomp'],
#  [143955, 'Manetho', 'was', 'ROOT'],
#  [144316, 'Manetho', 'lists', 'ROOT'],
#  [144588, 'Richards', 'describes', 'ROOT'],
#  [144591, 'Richards', 'notes', 'ROOT'],
#  [144601, 'Richards', 'concludes', 'ROOT'],
#  [144897, 'Bubbles', 'was', 'ROOT'],
#  [145876, 'Hans', 'was', 'ROOT'],
#  [145943, 'stars', 'represents', 'parataxis'],
#  [147537, 'people', 'was', 'ROOT'],
#  [147821, 'ours', 'was', 'ccomp'],
#  [148116, 'Hans', 'was', 'ROOT'],
#  [148878, 'species', 'belongs', 'relcl'],
#  [149469, 'Pickles', 'was', 'ROOT'],
#  [149759, 'Kings', 'is', 'ROOT'],
#  [149760, 'Kings', 'was', 'ROOT'],
#  [150364, 'MERS', 'is', 'ROOT'],
#  [150964, 'species', 'is', 'ROOT'],
#  [151026, 'years', 'is', 'ccomp'],
#  [151148, 'helicopters', 'Does', 'ROOT'],
#  [151792, 'dishes', 'is', 'ROOT'],
#  [151954, 'Bubbles', 'interests', 'ROOT'],
#  [153699, 'commands', 'has', 'ccomp'],
#  [154349, 'thoughts', 'was', 'ROOT'],
#  [154927, 'properties', 'is', 'ccomp'],
#  [155433, 'women', 'is', 'ROOT'],
#  [156720, 'eyes', 'eats', 'ccomp'],
#  [156778, 'lyrics', 'was', 'advcl'],
#  [156824, 'Songs', 'was', 'auxpass'],
#  [156899, 'eyes', 'was', 'ccomp'],
#  [157116, 'eyes', 'was', 'ROOT'],
#  [158084, 'Sketches', 'includes', 'ROOT'],
#  [158319, 'fishies', "'s", 'relcl'],
#  [158375, 'pains', 'was', 'conj'],
#  [159003, 'Acres', 'was', 'ROOT'],
#  [159080, 'books', 'contains', 'ROOT'],
#  [159420, 'people', 'is', 'ccomp'],
#  [160012, 'days', 'was', 'ROOT'],
#  [161245, 'Weeks', 'has', 'ROOT'],
#  [161335, 'critics', 'was', 'ccomp'],
#  [162008, 'Hans', 'was', 'ccomp'],
#  [162044, 'Hans', 'was', 'ROOT'],
#  [162184, 'sarks', 'was', 'ccomp'],
#  [162276, 'Hans', 'was', 'ROOT'],
#  [162621, 'people', 'thinks', 'ROOT'],
#  [163981, 'distributions', 'suggests', 'ROOT'],
#  [164043, 'ladies', 'was', 'ccomp'],
#  [164114, 'emissions', 'exceeds', 'ROOT'],
#  [164860, 'hunchbacks', 'was', 'conj'],
#  [165000, 'coats', 'is', 'ROOT'],
#  [165272, 'Bubbles', 'was', 'parataxis'],
#  [165818, 'Sanders', 'states', 'ROOT'],
#  [166161, 'guys', 'satontheirasseswaitingforhandouts', 'advcl'],
#  [168148, 'fields', 'was', 'ROOT'],
#  [169509, 'Falguière', 'was', 'ROOT'],
#  [171704, 'authorities', 'was', 'ROOT'],
#  [172741, 'people', 'likes', 'ccomp'],
#  [172802, 'criteria', 'is', 'ROOT'],
#  [173554, 'gardens', 'includes', 'ROOT'],
#  [173654, 'forks', "'s", 'ccomp'],
#  [175124, 'Basso', 'resides', 'ROOT'],
#  [175940, 'cartloads', 'shows', 'ccomp'],
#  [176080, 'filmmakers', 'is', 'relcl'],
#  [176207, 'differences', 'works', 'ccomp'],
#  [176239, 'slippers', "'s", 'ROOT'],
#  [176348, 'films', 'is', 'ROOT'],
#  [176521, 'Nornes', 'indicates', 'ROOT'],
#  [176601, 'albums', 'Comes', 'ROOT'],
#  [176755, 'aerodynamics', 'was', 'ROOT'],
#  [177282, 'Goodies', 'is', 'ROOT'],
#  [178499, 'Bates', 'was', 'ROOT'],
#  [178501, 'Bates', 'was', 'ROOT'],
#  [178544, 'Bates', 'was', 'ROOT'],
#  [180524, 'Bihać', 'is', 'ROOT'],
#  [180547, 'rules', 'was', 'ccomp'],
#  [180585, 'Views', 'is', 'ROOT'],
#  [181103, 'kisses', 'comes', 'ROOT'],
#  [183683, 'Days', 'is', 'ROOT'],
#  [185591, 'Robotics', 'is', 'ROOT'],
#  [185995, 'tips', 'was', 'ccomp'],
#  [186038, 'remains', 'houses', 'ROOT'],
#  [186251, 'ones', 'is', 'ROOT'],
#  [187091, '(;', 'is', 'ROOT'],
#  [187157, 'students', 'is', 'ccomp'],
#  [187214, 'Bubbles', 'was', 'ROOT'],
#  [187245, 'Days', 'is', 'ROOT'],
#  [189650, 'fauna', 'includes', 'ROOT'],
#  [190115, 'attitudes', 'seems', 'ROOT'],
#  [190292, 'nests', 'is', 'ROOT'],
#  [191597, 'marathons', 'has', 'ROOT'],
#  [191801, 'species', 'is', 'ROOT'],
#  [193118, 'carrots', 'keeps', 'ROOT'],
#  [193450, 'affidavits', 'states', 'ROOT'],
#  [194592, 'species', 'is', 'advcl'],
#  [195613, 'Recommendations', 'is', 'ROOT'],
#  [197185, 'Days', 'is', 'ROOT'],
#  [197530, 'Wattles', 'was', 'ROOT'],
#  [198123, 'overreacts', 'allergens', 'advcl'],
#  [198276, 'sources', 'is', 'ROOT'],
#  [198363, 'details', "'s", 'ROOT'],
#  [198800, 'staves', 'knows', 'conj'],
#  [199618, 'actions', 'was', 'ccomp'],
#  [200303, 'Squires', 'was', 'ROOT'],
#  [200442, 'postscripts', 'was', 'ROOT'],
#  [200555, 'mechanics', 'is', 'ROOT'],
#  [200574, 'erm', 'Was', 'ROOT'],
#  [201048, 're', 'tells', 'advcl'],
#  [201052, 'Bubbles', 'does', 'ROOT'],
#  [202396, 'Nicknames', 'calls', 'ROOT'],
#  [202400, 'Acts', 'says', 'ccomp'],
#  [202554, 'Bubbles', 'was', 'ROOT'],
#  [202605, 'people', 'is', 'ROOT'],
#  [203106, 'years', 'is', 'ccomp'],
#  [203230, 'squares', 'is', 'ROOT'],
#  [203234, 'squares', 'is', 'ROOT'],
#  [203567, 'Acts', 'sounds', 'ccomp'],
#  [204169, 'Acts', 'is', 'ROOT'],
#  [204262, 'Nicknames', 'nicknames', 'ROOT'],
#  [204433, 'Acts', 'tries', 'advcl'],
#  [204476, 'Nicknames', 'means', 'ROOT'],
#  [204617, 'data', 'is', 'ROOT'],
#  [204756, 'Nicknames', 'calls', 'ROOT'],
#  [204863, 'counterparts', 'is', 'ROOT'],
#  [205654, 'juveniles', 'is', 'ccomp'],
#  [205806, 'prizes', 'is', 'ROOT'],
#  [205867, 'prizes', 'is', 'ROOT'],
#  [205928, 'places', 'does', 'ROOT'],
#  [206129, 'jurors', 'violates', 'ccomp'],
#  [206671, 'specimen', 'was', 'ccomp'],
#  [207205, 'Animals', "'s", 'ROOT'],
#  [207721, 'consanguineos', 'nepotes', 'parataxis'],
#  [208195, 'scab', 'has', 'ROOT'],
#  [208568, 'wives', 'sends', 'ROOT'],
#  [209297, 'Theophanes', 'identifies', 'ROOT'],
#  [210405, 'actions', 'remains', 'ccomp'],
#  [210747, 'Waye', 'was', 'ROOT'],
#  [211223, 'Citizens', 'is', 'ccomp'],
#  [211235, 'seas', 'was', 'ROOT'],
#  [211643, 'Divers', 'queries', 'nsubj'],
#  [211723, 'Goldilocks', 'was', 'ROOT'],
#  [211845, 'Goldilocks', 'was', 'ccomp'],
#  [211962, 'imports', 'was', 'ROOT'],
#  [213471, 'markets', 'hitherto', 'ROOT'],
#  [213495, 'Women', 'discourses', 'ROOT'],
#  [213559, 'armaments', 'ceases', 'advcl'],
#  [213967, 'nations', 'grows', 'ROOT'],
#  [214183, 'parents', 'was', 'advcl'],
#  [214607, 'sculptures', 'comes', 'ROOT'],
#  [214757, 'jobs', 'becomes', 'ROOT'],
#  [215950, 'stores', 'depends', 'ROOT'],
#  [216617, 'depicts', 'is', 'ROOT'],
#  [217355, 'pounds', 'seems', 'ccomp'],
#  [218595, 'rainfalls', 'goes', 'ROOT'],
#  [219298, 'zucchini', 'is', 'ccomp'],
#  [219305, 'Desilets', 'was', 'ROOT'],
#  [219633, 'heads', 'flows', 'ROOT'],
#  [219975, 'miltonis', 'is', 'ROOT'],
#  [219978, 'men', 'is', 'ROOT'],
#  [220261, 'manufactories', 'dies', 'ROOT'],
#  [220466, 'corners', 'is', 'ccomp'],
#  [221166, 'boys', 'seems', 'ROOT'],
#  [221487, 'Teachings', 'is', 'ROOT'],
#  [222057, 'crocodile&amp;lt;/i&amp;gt', 'wants', 'ROOT'],
#  [222394, 'dolls', 'does', 'ROOT'],
#  [222759, 'squares', 'is', 'ROOT'],
#  [223029, 'CAWS', 'includes', 'ROOT'],
#  [223077, 'MVSc', 'takes', 'ROOT'],
#  [223344, 'Swings', 'is', 'ROOT'],
#  [223862, 'finishers', 'is', 'ROOT'],
#  [224027, 'classes', 'knows', 'ROOT'],
#  [225754, 'wages', 'was', 'ccomp'],
#  [226684, 'Złotoryja', 'is', 'ROOT'],
#  [227210, 'authorities', 'was', 'ROOT'],
#  [227729, 'Hans', 'was', 'ROOT'],
#  [227753, 'inhabitants', 'has', 'ROOT'],
#  [229915, 'ears', 'does', 'ROOT'],
#  [229998, 'species', 'is', 'ROOT'],
#  [230020, 'species', 'grows', 'advcl'],
#  [230372, 'Swipes', 'writes', 'ROOT'],
#  [231171, 'people', 'calls', 'ROOT'],
#  [231481, 'inferences', 'is', 'ccomp'],
#  [231940, 'people', 'was', 'ROOT'],
#  [232039, 'whistles', 'does', 'ROOT'],
#  [232911, 'eggs', 'climbs', 'ccomp'],
#  [233041, 'hands', 'is', 'ROOT'],
#  [233167, 'functions', "'s", 'ROOT'],
#  [233215, 'minstrelsy', 'is', 'conj'],
#  [233396, 'numbers', 'is', 'conj'],
#  [233848, 'algebra', 'gives', 'ROOT'],
#  [234064, 'trousers', 'was', 'auxpass'],
#  [234579, 'folks', 'was', 'ccomp'],
#  [235003, 'Bees', 'is', 'ROOT'],
#  [235019, 'boys', 'is', 'advcl'],
#  [235514, 'cattle', 'endures', 'ROOT'],
#  [236484, 'Dargnies', 'is', 'ROOT'],
#  [236909, 'intervals', 'was', 'ROOT'],
#  [236975, 'Markides', 'lives', 'ROOT'],
#  [237116, 'rays', 'lights', 'ROOT'],
#  [237276, 'fields', 'is', 'ROOT'],
#  [237685, 'drugs', 'is', 'ROOT'],
#  [237709, 'figures', 'was', 'advcl'],
#  [238105, 'teeth', "'s", 'ROOT'],
#  [238610, 'years', 'is', 'pcomp'],
#  [238779, 'leanings', 'is', 'ccomp'],
#  [238821, 'Designs', 'offers', 'ccomp'],
#  [238877, 'Sirs', 'cries', 'ccomp'],
#  [239350, 'People', 'is', 'ROOT'],
#  [239451, 'Francks', 'was', 'ROOT'],
#  [239746, 'Fancypants', 'is', 'ROOT'],
#  [240386, 'fleurs', 'is', 'ROOT'],
#  [240442, 'Weeks', 'is', 'ROOT'],
#  [240666, 'statements', "'s", 'ROOT'],
#  [240993, 'kids', 'is', 'ROOT'],
#  [241144, 'maths', 'is', 'advcl'],
#  [241232, 'squeals', 'lowers', 'ROOT'],
#  [241618, 'protests', 'was', 'ROOT'],
#  [242502, 'sniffs', 'is', 'ROOT'],
#  [243681, 'doors', 'opens', 'advcl'],
#  [243861, 'people', "'s", 'ROOT'],
#  [243917, 'services', 'stops', 'ROOT'],
#  [244816, 'clothes', 'makes', 'ROOT'],
#  [244980, 'results', 'is', 'ccomp'],
#  [246895, 'boats', 'does', 'ccomp'],
#  [246953, 'kids', 'is', 'advcl'],
#  [247568, 'days', "'s", 'ROOT'],
#  [247945, 'colours', 'refers', 'ROOT'],
#  [247954, 'colours', 'refers', 'ROOT'],
#  [248614, 'muriqui', 'comes', 'ROOT'],
#  [249237, 'Examples', 'is', 'ROOT'],
#  [249352, 'mathematics', 'teaches', 'pcomp'],
#  [249414, 'attempts', 'gives', 'ROOT'],
#  [249600, 'times', 'is', 'conj'],
#  [249784, 'Gifts', 'was', 'ROOT'],
#  [250289, 'inches', 'falls', 'ROOT'],
#  [252566, 'avionics', 'incorporates', 'ROOT'],
#  [252994, 'Eyes', 'was', 'ccomp'],
#  [255668, 'increases', 'is', 'ccomp'],
#  [256415, 'systems', 'is', 'ccomp'],
#  [256649, 'years', 'is', 'ROOT'],
#  [256855, 'years', 'is', 'ROOT'],
#  [257144, 'years', 'is', 'ROOT'],
#  [257296, 'thirds', 'is', 'ccomp'],
#  [257357, 'TanYi', 'Is', 'ROOT'],
#  [257565, 'spaces', 'does', 'ROOT'],
#  [257860, 'talents', 'was', 'ccomp'],
#  [258340, 'emits', 'is', 'ccomp'],
#  [258917, 'caters', 'provides', 'ROOT'],
#  [259326, 'schools', 'trades', 'ROOT'],
#  [259342, 'Rannells', 'lives', 'ROOT'],
#  [259716, 'arts', 'promotes', 'ROOT'],
#  [259791, 'services', 'is', 'ROOT'],
#  [260588, 'Winter', 'brings', 'ROOT'],
#  [260810, 'Clockers', 'is', 'ROOT'],
#  [261425, 'prints', 'is', 'ROOT'],
#  [261726, 'Roots', 'was', 'ROOT'],
#  [263112, 'mechanisms', 'is', 'ROOT'],
#  [263134, 'issues', 'occurs', 'ROOT'],
#  [263355, 'Odds', 'splutters', 'ccomp'],
#  [264704, 'Karros', 'works', 'ROOT'],
#  [265764, 'children', 'housewives', 'ROOT'],
#  [265828, 'allies', 'was', 'ROOT'],
#  [266508, 'blocks', 'is', 'ROOT'],
#  [266509, 'blocks', 'is', 'ROOT'],
#  [266550, 'fishies', "'s", 'ROOT'],
#  [267048, 'People', 'gathers', 'ROOT'],
#  [267082, 'Parves', 'is', 'ROOT'],
#  [267495, 'Papers', 'is', 'ROOT'],
#  [268683, 'tears', 'was', 'conj'],
#  [269305, 'PUPPET', 'IS', 'ROOT'],
#  [269371, 'warriors', 'has', 'ROOT'],
#  [269638, 'veterans', 'was', 'ROOT'],
#  [272038, 'changes', 'was', 'ROOT'],
#  [272188, 'Teres', 'was', 'ROOT'],
#  [272229, 'yours', "'s", 'ROOT'],
#  [272290, 'gentlemen', 'assassins', 'ROOT'],
#  [273098, 'tributaries', 'joins', 'ROOT'],
#  [273354, 'waters', 'runs', 'ROOT'],
#  [275299, 'rankings', 'lists', 'conj'],
#  [275580, 'values', 'is', 'ROOT'],
#  [275663, 'implants', 'is', 'ROOT'],
#  [275713, 'implants', 'is', 'ccomp'],
#  [276018, 'BAIC', 'is', 'ROOT'],
#  [276576, 'harvests', 'was', 'ccomp'],
#  [276697, 'Hauts', 'is', 'ROOT'],
#  [276852, 'events', 'is', 'ROOT'],
#  [277449, 'Goosebumps', 'is', 'ROOT'],
#  [277971, 't’imagines', 'was', 'ROOT'],
#  [278540, 'ethics', 'means', 'ccomp'],
#  [278549, 'years', 'is', 'ROOT'],
#  [280165, 'Yours', 'is', 'ccomp'],
#  [280866, 'species', 'is', 'ROOT'],
#  [281967, 'hours', 'is', 'ROOT'],
#  [282602, 'Zombies', 'is', 'ROOT'],
#  [282643, 'aliens', 'was', 'ROOT'],
#  [282645, 'aliens', 'finds', 'ROOT'],
#  [282757, 'discoveries', 'shows', 'ROOT'],
#  [283225, 'Carvajal', 'writes', 'ROOT'],
#  [283320, 'correspondents', 'was', 'ROOT'],
#  [284215, 'prices', 'goes', 'advcl'],
#  [284557, 'effects', 'dominates', 'advcl'],
#  [285021, 'figures', 'was', 'ROOT'],
#  [285249, 'hours', 'was', 'ccomp'],
#  [285768, 'ViendoMovies', 'runs', 'ROOT'],
#  [286148, 'species', 'has', 'ROOT'],
#  [286156, 'paddles', 'dries', 'ROOT'],
#  [286173, 'shoes', 'swells', 'ROOT'],
#  [286218, 'species', 'is', 'ROOT'],
#  [286276, 'methods', 'varies', 'ROOT'],
#  [286449, 'networks', 'spans', 'ROOT'],
#  [286650, 'hours', 'is', 'ROOT'],
#  [286837, 'Starbucks', 'goes', 'ROOT'],
#  [286838, 'shoes', 'throws', 'ROOT'],
#  [287278, 'Semillitas', 'is', 'ROOT'],
#  [288030, 'Greenleaves', 'is', 'ROOT'],
#  [288031, 'Greenleaves', 'holds', 'ROOT'],
#  [289070, 'Swartruggens', 'is', 'ROOT'],
#  [289218, 'works', 'is', 'relcl'],
#  [289451, 'mocks', 'merits', 'ccomp'],
#  [289680, 'Economics', 'works', 'ROOT'],
#  [290497, 'Transformers', 'was', 'ROOT'],
#  [290582, 'animals', 'is', 'ROOT'],
#  [291004, 'sheep', 'was', 'ccomp'],
#  [291109, 'measures', 'has', 'ROOT'],
#  [291605, 'manners', "'s", 'ROOT'],
#  [291777, 'industries', 'is', 'ROOT'],
#  [291931, 'Forwards', 'argonauts', 'ROOT'],
#  [292008, 'species', 'flies', 'ROOT'],
#  [292247, 'seas', 'was', 'ROOT'],
#  [292500, '-', 'appears', 'ROOT'],
#  [292792, 'Nui', 'is', 'ROOT'],
#  [294050, 'Pre', 'involves', 'ROOT'],
#  [294131, 'Rhys', 'says', 'ROOT'],
#  [294656, 'classes', 'merges', 'ROOT'],
#  [295667, 'bricks', 'is', 'ccomp'],
#  [295876, 'data', 'provides', 'ROOT'],
#  [296145, 'Systems', 'works', 'ROOT'],
#  [296258, 'macrobotrys', 'is', 'ROOT'],
#  [296308, 'macrobotrys', 'is', 'ccomp'],
#  [296790, 'farmers', 'fields', 'ROOT'],
#  [296994, 'directions', 'is', 'ROOT'],
#  [297291, 'children', 'is', 'advcl'],
#  [298617, 'titles', 'was', 'conj'],
#  [299522, 'kinds', 'is', 'conj'],
#  [299683, 'estimates', 'is', 'relcl'],
#  [300438, 'outlets', 'buys', 'ccomp'],
#  [300755, 'subspecies', 'is', 'ROOT'],
#  [301351, 'studies', 'is', 'ROOT'],
#  [301805, 'puddings', 'was', 'ccomp'],
#  [302564, 'functions', 'is', 'ROOT'],
#  [302601, 'people', 'was', 'ccomp'],
#  [302659, 'guys', 'guys', 'ROOT'],
#  [302680, 'vehicles', 'was', 'ROOT'],
#  [302686, 'blocks', 'is', 'ROOT'],
#  [304082, 'Slums', 'is', 'ROOT'],
#  [304214, 'things', 'is', 'ROOT'],
#  [304671, 'Inches', 'says', 'conj'],
#  [305931, 'people', 'appears', 'ROOT'],
#  [306040, 'Women', "'s", 'ROOT'],
#  [306626, 'mathematics', 'is', 'acl'],
#  [307793, 'volts', 'is', 'ROOT'],
#  [308111, 'Teachers', 'is', 'ROOT'],
#  [309391, 'people', 'is', 'ROOT'],
#  [310417, 'eyes', "'s", 'ROOT'],
#  [310436, 'swans', 'was', 'ccomp'],
#  [310447, 'eyes', "'s", 'ROOT'],
#  [310589, 'brothers', 'is', 'ROOT'],
#  [311308, 'garages', 'is', 'ccomp'],
#  [311637, 'Eggers', 'has', 'ROOT'],
#  [311650, 'Eggers', 'is', 'ROOT'],
#  [311652, 'Eggers', 'talks', 'ROOT'],
#  [311653, 'Eggers', 'says', 'ROOT'],
#  [311681, 'Eggers', 'struggles', 'ROOT'],
#  [311690, 'Eggers', 'auditions', 'ROOT'],
#  [311701, 'Eggers', 'compresses', 'ROOT'],
#  [311705, 'Eggers', 'has', 'ROOT'],
#  [311708, 'Eggers', 'points', 'ROOT'],
#  [312165, 'ingredients', 'provides', 'ccomp'],
#  [313133, 'degrees', 'is', 'ROOT'],
#  [313148, 'Leaders', 'was', 'ROOT'],
#  [313399, 'Anandhi', 'is', 'ROOT'],
#  [313504, 'metres', 'is', 'ROOT'],
#  [314583, 'javelins', 'points', 'conj'],
#  [315148, 'sounds', 'was', 'ROOT'],
#  [315189, 'Sprats', 'Was', 'ROOT'],
#  [315346, 'ones', 'is', 'ROOT'],
#  [316516, 'codice_1', 'resets', 'ROOT'],
#  [317191, 'intersects', 'narrows', 'ROOT'],
#  [317350, 'Kids', 'continues', 'ROOT'],
#  [317382, 'Lots', 'feels', 'ROOT'],
#  [318055, 'Somers', 'is', 'ROOT'],
#  [319974, 'turns', 'comes', 'ROOT'],
#  [319977, 'sectors', 'consists', 'ROOT'],
#  [320112, 'sectors', 'was', 'ROOT'],
#  [322734, 'effects', 'lies', 'ROOT'],
#  [323001, 'traditions', 'is', 'ROOT'],
#  [323453, 'Brahms', 'is', 'ROOT'],
#  [323517, 'characters', 'was', 'ccomp'],
#  [323826, 'measures', 'centimeters', 'ROOT'],
#  [324232, 'complements', 'completes', 'relcl'],
#  [326376, 'miles', 'descends', 'ROOT'],
#  [326403, 'People', 'commutes', 'ROOT'],
#  [326870, 'species', 'is', 'ROOT'],
#  [326905, 'species', 'is', 'ROOT'],
#  [327366, 'nibs', "'s", 'advcl'],
#  [328159, 'bears', 'bears', 'ROOT'],
#  [328751, 'wreaths', 'kindles', 'ROOT'],
#  [328894, 'Achilles', 'advances', 'ROOT'],
#  [329078, 'nicholas', "'s", 'ROOT'],
#  [329132, 'Achilles', 'sends', 'ROOT'],
#  [329368, 'Achilles', 'falls', 'ccomp'],
#  [329455, 'effects', 'affects', 'ROOT'],
#  [329999, 'rates', 'is', 'ROOT'],
#  [331066, 'CCECPSCO', 'has', 'ROOT'],
#  [331079, 'CCECPSCO', 'conducts', 'ROOT'],
#  [331190, 'Parsons', 'is', 'ROOT'],
#  [331604, 'names', 'is', 'ROOT'],
#  [331922, 'instruments', 'comprises', 'ROOT'],
#  [332071, 'Charmauvillers', 'is', 'ROOT'],
#  [332196, 'Altsignals', 'is', 'ROOT'],
#  [332289, 'violins', 'strikes', 'ROOT'],
#  [332586, 'yours', "'s", 'ROOT'],
#  [332721, 'yours', "'s", 'ROOT'],
#  [333126, 'men', 'was', 'ROOT'],
#  [333206, 'returns', 'is', 'ROOT'],
#  [333559, 'Cattle', 'is', 'ROOT'],
#  [333577, 'cattle', 'was', 'ROOT'],
#  [334278, 'Indevillers', 'is', 'ROOT'],
#  [334688, 'economics', 'was', 'ROOT'],
#  [334751, 'horns', 'falls', 'ROOT'],
#  [334761, 'Courcelles', 'is', 'ROOT'],
#  [335682, 'Romeries', 'is', 'ROOT'],
#  [336309, 'Others', 'is', 'conj'],
#  [336621, 'themes', 'throws', 'ROOT'],
#  [337214, 'Leeds', 'is', 'ROOT'],
#  [337234, 'Cats', 'is', 'ROOT'],
#  [337459, 'Bruns', 'was', 'ccomp'],
#  [337789, 'paroxysm', 'rises', 'ROOT'],
#  [338029, 'Numbers', 'says', 'ROOT'],
#  [338470, 'Durnes', 'is', 'ROOT'],
#  [338494, 'Échenans', 'is', 'ROOT'],
#  [338541, 'Échevannes', 'is', 'ROOT'],
#  [339366, 'minutes', 'comes', 'ROOT'],
#  [339717, 'Diabetes', 'contributes', 'ROOT'],
#  [339755, 'Fertans', 'is', 'ROOT'],
#  [340081, 'Gentlemen', 'is', 'ROOT'],
#  [340089, 'vessels', 'is', 'ROOT'],
#  [340472, 'duchies', 'is', 'advcl'],
#  [340585, 'strings', 'rises', 'ROOT'],
#  [340855, 'cows', "'s", 'ROOT'],
#  [340931, 'minutes', 'has', 'ccomp'],
#  [341004, 'Days', 'is', 'ROOT'],
#  [341105, 'Days', 'is', 'ccomp'],
#  [341137, 'Villains', 'is', 'ROOT'],
#  [341402, 'Storks', 'is', 'ROOT'],
#  [341425, 'chucks', 'is', 'ROOT'],
#  [341427, 'cutters', 'ends', 'ccomp'],
#  [341726, 'Gennes', 'is', 'ROOT'],
#  [341747, 'Goils', 'is', 'ROOT'],
#  [341765, 'histories', 'is', 'ROOT'],
#  [341988, 'components', 'is', 'ROOT'],
#  [342074, 'specialists', 'is', 'ROOT'],
#  [342719, 'branches', 'is', 'ROOT'],
#  [342739, 'hours', 'was', 'ROOT'],
#  [343034, 'species', 'flies', 'ROOT'],
#  [343345, 'plants', 'is', 'pcomp'],
#  [343842, 'dollars', 'was', 'ROOT'],
#  [343955, 'men', 'was', 'ROOT'],
#  [343966, 'parcels', 'is', 'ROOT'],
#  [344015, 'meanings', 'is', 'ROOT'],
#  [345608, 'Pasiones', 'is', 'ROOT'],
#  [345910, 'cycles', 'exists', 'ROOT'],
#  [345932, 'ensues', 'is', 'ROOT'],
#  [346164, 'Astramadors', 'begs', 'ROOT'],
#  [346168, 'Astradamors', 'rises', 'ROOT'],
#  [346267, 'wails', 'announces', 'ROOT'],
#  [346486, 'shoes', "'s", 'ROOT'],
#  [346504, 'shoes', "'s", 'ROOT'],
#  [347275, 'swords', 'Is', 'ROOT'],
#  [347511, 'shoes', "'s", 'ROOT'],
#  [347753, 'Huggins', 'was', 'ROOT'],
#  [348036, 'fermions', 'renormalizes', 'ccomp'],
#  [348447, 'violas', 'follows', 'ROOT'],
#  [348656, 'eyes', "'s", 'ROOT'],
#  [348668, 'eyes', "'s", 'ROOT'],
#  [349419, 'depths', 'sounds', 'ROOT'],
#  [349770, 'strings', 'sounds', 'ROOT'],
#  [349958, 'strings', 'sounds', 'ROOT'],
#  [350159, 'pieces', 'is', 'ROOT'],
#  [350336, 'Days', 'is', 'ccomp'],
#  [351154, 'resources', 'depends', 'ROOT'],
#  [351698, 'sentences', "'s", 'conj'],
#  [351702, 'professors', 'says', 'advcl'],
#  [352013, 'horns', 'defines', 'ROOT'],
#  [352940, 'horns', 'is', 'ROOT'],
#  [352953, 'Sweepers', 'is', 'ROOT'],
#  [353672, 'facts', "'s", 'ROOT'],
#  [353746, 'differences', 'is', 'ccomp'],
#  [353801, '•,•', 'denotes', 'ROOT'],
#  [354088, 'Nhanes', 'stands', 'ROOT'],
#  [354245, 'Saunders', 'makes', 'ROOT'],
#  [354529, 'Backroads', 'is', 'ROOT'],
#  [354805, 'exploits', 'is', 'ROOT'],
#  [355365, 'scherzo', 'survives', 'ROOT'],
#  [355755, 'boys', 'was', 'conj'],
#  [356225, 'criteria', 'entails', 'ROOT'],
#  [356242, 'Mutations', 'hinders', 'ROOT'],
#  [356401, 'strings', 'descends', 'ROOT'],
#  [357147, 'descendants', 'is', 'ROOT'],
#  [357155, 'runs', 'is', 'ROOT'],
#  [357367, 'numbers', 'was', 'advcl'],
#  [357787, 'hours', 'was', 'ROOT'],
#  [357949, 'Daughters', 'is', 'ROOT'],
#  [358421, 'Links', 'offers', 'ROOT'],
#  [358448, 'movies', 'ends', 'ROOT'],
#  [358641, 'grounds', 'was', 'ROOT'],
#  [358997, 'Incidents', 'was', 'ROOT'],
#  [359181, 'flax', 'was', 'ccomp'],
#  [359722, 'Hants', 'was', 'ROOT'],
#  [359781, 'accounts', 'concur', 'conj'],
#  [360253, 'Kings', 'was', 'ROOT'],
#  [360345, 'miles', 'is', 'ccomp'],
#  [360351, 'miles', 'is', 'ccomp'],
#  [360637, 'implications', 'seems', 'ROOT'],
#  [360871, 'assurances', 'helps', 'ROOT'],
#  [361210, 'rossaferesae', 'is', 'ROOT'],
#  [361253, 'horizons', 'sees', 'ROOT'],
#  [361720, 'drivers', 'is', 'ROOT'],
#  [361915, 'Parya', 'is', 'ROOT'],
#  [362036, 'halves', 'is', 'ROOT'],
#  [362733, 'hesitates', 'comes', 'ROOT'],
#  [362755, 'legs', 'was', 'advcl'],
#  [363039, 'lords', 'bows', 'ROOT'],
#  [363161, 'tools', 'makes', 'ROOT'],
#  [363725, 'gents', 'is', 'ccomp'],
#  [364114, 'TILT', 'owns', 'ROOT'],
#  [364115, 'TILT', 'acts', 'ROOT'],
#  [364362, 'ogre', 'was', 'ccomp'],
#  [365509, 'ogre', 'was', 'ccomp'],
#  [365704, 'characteristics', 'is', 'advcl'],
#  [365890, 'interactions', 'has', 'conj'],
#  [365947, 'hands', 's', 'ROOT'],
#  [365982, 'ogre', 'lies', 'relcl'],
#  [365991, 'advantages', 'is', 'ROOT'],
#  [366130, 'daughters', 'is', 'relcl'],
#  [366146, 'annals', 'is', 'ROOT'],
#  [366895, 'Days', 'shows', 'conj'],
#  [367436, 'lorries', "'s", 'ccomp'],
#  [367446, 'margins', "'s", 'ROOT'],
#  [367843, 'uses', 'is', 'ROOT'],
#  [368174, 'crowns', "'s", 'ROOT'],
#  [369404, 'italics', 'is', 'ROOT'],
#  [369490, 'hopes', "'s", 'ROOT'],
#  [369497, 'italics', 'is', 'ROOT'],
#  [369587, 'goals', 'is', 'ROOT'],
#  [369589, 'animals', 'likes', 'ccomp'],
#  [369693, 'children', 'was', 'advcl'],
#  [369966, 'birds', 'comes', 'ccomp'],
#  [370084, 'Gonsans', 'is', 'ROOT'],
#  [370175, 'Gouhelans', 'is', 'ROOT'],
#  [370250, 'Yerres', 'is', 'ROOT'],
#  [370765, 'years', 'was', 'ROOT'],
#  [371104, 'Malans', 'is', 'ROOT'],
#  [371141, 'bells', 'knows', 'ROOT'],
#  [371142, 'foxes', 'shows', 'ccomp'],
#  [371155, 'Malans', 'is', 'ROOT'],
#  [371376, 'children', 'plays', 'ROOT'],
#  [371954, 'locations', 'is', 'ROOT'],
#  [372134, 'ones', 'goes', 'ROOT'],
#  [372604, 'Bondues', 'is', 'ROOT'],
#  [372957, 'bells', 'butterflies', 'compound'],
#  [373096, 'birds', 'likes', 'ccomp'],
#  [373188, 'Raynans', 'is', 'ROOT'],
#  [373466, 'years', 'was', 'ccomp'],
#  [373554, '37x', 'is', 'ccomp'],
#  [373568, '37x', 'is', 'ccomp'],
#  [373737, 'Students', 'class--', 'ROOT'],
#  [373805, 'Liebvillers', 'is', 'ROOT'],
#  [373963, 'pictures', "'s", 'ROOT'],
#  [374449, 'months', 'has', 'ROOT'],
#  [374567, 'Lives', 'lives', 'ROOT'],
#  [374900, 'minutes', 'gives', 'ROOT'],
#  [374945, 'games', 'is', 'ROOT'],
#  [375699, 'yours', "'s", 'ROOT'],
#  [376963, 'things', 'is', 'advcl'],
#  [377216, 'Birds', 'is', 'ROOT'],
#  [377824, 'ones', 'has', 'aux'],
#  [378047, 'snowdrops', 'is', 'ROOT'],
#  [378141, 'rabbits', 'does', 'advcl'],
#  [378462, 'ones', 'takes', 'ROOT'],
#  [378510, 'programs', 'has', 'ROOT'],
#  [378582, 'yours', 'sounds', 'ROOT'],
#  [378604, 'wins', 'succeeds', 'conj'],
#  [378655, 'Roots', 'is', 'ROOT'],
#  [379110, 'shoes', 'is', 'ROOT'],
#  [379164, 'eyes', 'is', 'ccomp'],
#  [379374, 'apples', "'s", 'ROOT'],
#  [379591, 'fellows', "'s", 'ccomp'],
#  [380625, 'functions', 'includes', 'ROOT'],
#  [380790, 'hands', 'hands', 'ROOT'],
#  [380848, 'Backers', 'studies', 'ROOT'],
#  [382100, 'Sanders', 'was', 'ROOT'],
#  [382214, 'Mouthparts', 'is', 'ROOT'],
#  [382986, 'roses', 'is', 'advcl'],
#  [383889, 'Glitters', 'is', 'ccomp'],
#  [384481, 'kids', 'lives', 'ccomp'],
#  [385047, 'buildin', 'is', 'ccomp'],
#  [385281, 'Folks', 'is', 'ROOT'],
#  [385324, 'Thanks', 'was', 'ROOT'],
#  [385418, 'hers', 'was', 'ccomp'],
#  [385419, 'eyes', 'is', 'advcl'],
#  [385431, 'years', 'was', 'ROOT'],
#  [385746, 'ours', 'seems', 'ROOT'],
#  [387178, 'Hysterics', 'makes', 'ROOT'],
#  [387897, 'Levins', 'was', 'ROOT'],
#  [387902, 'police', 'finds', 'advcl'],
#  [387948, 'leaves', 'is', 'ROOT'],
#  [389166, 'children', 'needs', 'ROOT'],
#  [389245, 'children', 'learns', 'csubj'],
#  [389766, 'creatures', '’s', 'ROOT'],
#  [390325, 'métiers', 'is', 'ROOT'],
#  [390831, 'schools', 'is', 'ROOT'],
#  [390993, 'products', 'has', 'ROOT'],
#  [391180, 'structures', 'is', 'ROOT'],
#  [391218, 'eggs', 'hatches', 'ROOT'],
#  [391788, 'drugs', 'seems', 'ROOT'],
#  [392095, 'conditions', 'was', 'ROOT'],
#  [392558, 'areas', 'is', 'ccomp'],
#  [393233, 'orders', 'was', 'ROOT'],
#  [393406, 'hut', 'was', 'ROOT'],
#  [393625, 'newspapers', 'cans', 'ROOT'],
#  [394103, 'ways', 'squirrels', 'conj'],
#  [394117, 'rats', 'was', 'ROOT'],
#  [394263, 'dickens', 'was', 'ccomp'],
#  [395176, 'taters', 'is', 'ROOT'],
#  [395345, 'children', 'likes', 'ccomp'],
#  [395429, 'Nothin', '’s', 'ROOT'],
#  [395515, 'Children', 'feels', 'ROOT'],
#  [395721, 'species', 'recruits', 'ROOT'],
#  [395873, 'eyes', "'s", 'ROOT'],
#  [396055, 'eyes', "'s", 'ROOT'],
#  [396063, 'Andras', 'was', 'ROOT'],
#  [396064, 'eyes', "'s", 'ROOT'],
#  [396635, 'eyes', "'s", 'ROOT'],
#  [397216, 'shoes', "'s", 'ROOT'],
#  [397667, 'skylarks', 'sings', 'ROOT'],
#  [397957, 'daggers', 'throws', 'ROOT'],
#  [398208, 'names', '’s', 'ccomp'],
#  [398848, 'courtiers', 'was', 'advcl'],
#  [398974, 'years', 'is', 'ROOT'],
#  [399719, 'people', 'knows', 'advcl'],
#  [400018, 'Mills', 'plays', 'ROOT'],
#  [400709, 'thousands', "'s", 'ROOT'],
#  [402048, 'hut', 'was', 'acl'],
#  [403375, 'dollars', 'was', 'ROOT'],
#  [404335, 'words', 'was', 'conj'],
#  [406077, 'Downs', 'lives', 'ROOT'],
#  [406346, 'Lyons', 'is', 'ROOT'],
#  [406686, 'Boots', 'is', 'ccomp'],
#  [406717, 'Boots', 'gets', 'ROOT'],
#  [406978, 'Boots', 'was', 'ROOT'],
#  [407420, 'sides', 'was', 'conj'],
#  [407657, 'students', 'is', 'ccomp'],
#  [408050, 'murders', 'is', 'acl'],
#  [408301, 'contents', 'moves', 'advcl'],
#  [408567, 'concerts', 'bands', 'ccomp'],
#  [408581, 'words', 'is', 'ccomp'],
#  [408769, 'Niles', 'is', 'ROOT'],
#  [408896, 'qualifications', 'is', 'ROOT'],
#  [410196, 'Yours', 'is', 'ROOT'],
#  [410566, 'eyes', "'s", 'ROOT'],
#  [410616, 'species', 'inhabits', 'ROOT'],
#  [410740, 'Travers', 'is', 'ROOT'],
#  [411416, 'hands', 'pops', 'ROOT'],
#  [411590, 'Singles', 'is', 'ROOT'],
#  [412089, 'mathematics', 'shows', 'ROOT'],
#  [412466, 'places', 'is', 'ROOT'],
#  [412910, 'people', 'is', 'ccomp'],
#  [413190, 'Eaglets', 'is', 'ROOT'],
#  [413330, 'ants', 'stems', 'ROOT'],
#  [413505, 'plains', 'is', 'ROOT'],
#  [413938, 'crisps', "'s", 'ROOT'],
#  [414557, 'windings', 'has', 'ROOT'],
#  [415023, 'crosswinds', 'is', 'ROOT'],
#  [415078, 'discs', 'is', 'ccomp'],
#  [416538, 'equations', 'contains', 'ROOT'],
#  ...]

# %%
len(deps), {k:len(v) for k, v in deps.items()}
# Out:
# (31,
#  {'dobj': 60213,
#   'attr': 37499,
#   'nsubj': 23181,
#   'ccomp': 870,
#   'conj': 4057,
#   'advcl': 956,
#   'npadvmod': 5644,
#   'dep': 1972,
#   'oprd': 120,
#   'acomp': 165,
#   'compound': 113,
#   'dative': 263,
#   'nmod': 9,
#   'intj': 136,
#   'poss': 10,
#   'appos': 130,
#   'pobj': 7,
#   'csubj': 31,
#   'cc': 6,
#   'punct': 173,
#   'prep': 17,
#   'xcomp': 28,
#   'parataxis': 50,
#   'relcl': 8,
#   'advmod': 52,
#   'neg': 1,
#   'mark': 1,
#   'nsubjpass': 5,
#   'prt': 1,
#   'amod': 1,
#   'meta': 1})

# %%
# manager = Manager()
# sentences = manager.list()
# Out:
# 'It may not look like much now but this is actually going to turn into one of the three student lounges which is a really big step up from our old campus.'

# %%
parsed = nlp(sentences[3])
for token in parsed:
    if is_plural(token):
        print(token, [(a, a.morph.get("Number")) for a in token.ancestors])
# Out:
# people [(is, ['Sing'])]
# attendees [(of, []), (number, ['Sing']), (is, ['Sing'])]

# %%
def singular_plural(parsed):
    found = False
    materials = []
    for token in parsed:
        if "VB" in token.tag_:
            morph = token.morph.to_dict()
            if "Number" in morph.keys():
                if morph['Number'] == 'Sing':
                    for child in token.children:
                        child_morph = child.morph.to_dict()
                        # check if child is noun
                        if child.pos_ == 'NOUN':
                            if child.dep_ == 'nsubj' and child_morph['Number'] == 'Plur':
                                materials.append([token.text, child.text])
                                found = True
                                break
    return found, materials

# only do pos tags and dependency parses
# for sentence in sentences:
#     doc = nlp(sentence)
#     if singular_plural(doc):
#         print(sentence)
docs = []
targets = []
for doc in tqdm(nlp.pipe(sentences, disable=["lemmatizer", "ner"], n_process=32, batch_size=10000)):
    docs.append(doc.text)
    if singular_plural(doc):
        targets.append(doc.text)
# Out:
# Five days is a long time to wait for a response.
# Seven weeks of thesis writing takes a toll on one's body.
# A year is a long time to wait.
# Five people is a not a huge number of attendees.
# Revenue exceeded twelve billion dollars, with a loss of $1b.
# Net income was $9.4 million compared to the prior year of $2.7 million.
# Five people is a not a huge number of attendees.

# %%
# corpus = read_babylm(f"/home/km55359/rawdata/babylm_data/babylm_100M/aochildes.train")
DIR = "/home/km55359/rawdata/babylm_data/babylm_100M/"
corpus = {}

# print(list(glob.glob(DIR)))

for file in glob.glob(f"{DIR}/*.train"):
    corpus_name = re.split(r"(/|.train)", file)[-3]
    sents = read_babylm(f"{DIR}/{corpus_name}.train")
    corpus[corpus_name] = sents

# %%
{corpus_name: len(corpus[corpus_name]) for corpus_name in corpus.keys()}
# Out:
# {'open_subtitles': 5440000,
#  'qed': 960000,
#  'bnc_spoken': 848989,
#  'wikipedia': 255000,
#  'gutenberg': 1130000,
#  'aochildes': 763989,
#  'simple_wikipedia': 686554,
#  'children_stories': 77760,
#  'cbt': 263519,
#  'switchboard': 161740}

# %%
target_sentences = defaultdict(list)
for corpus_name, sents in corpus.items():
    if corpus_name == "children_stories":
        for doc in tqdm(
            nlp.pipe(sents, disable=["lemmatizer", "ner"], n_process=32, batch_size=10000)
        ):
            found, materials = singular_plural(doc)
            if found:
                target_sentences[corpus_name].append((doc.text, materials))
# Out:
# 77760it [04:12, 307.87it/s]

# %%
target_sentences["children_stories"][10:20]
# Out:
# [('The sheep was as yet all raw and bloody; but he liked it the better for that. He sniffed about to the right and left, saying:',
#   [['was', 'sheep']]),
#  ('After Prince Houssain had run through that division, street by street, his thoughts fully employed on the riches he had seen, he was very much tired, which a merchant perceiving, civilly invited him to sit down in his shop, and he accepted; but had not been sat down long before he saw a crier pass by with a piece of tapestry on his arm, about six feet square, and cried at thirty purses. The Prince called to the crier, and asked to see the tapestry, which seemed to him to be valued at an exorbitant price, not only for the size of it, but the meanness of the stuff; when he had examined it well, he told the crier that he could not comprehend how so small a piece of tapestry, and of so indifferent appearance, could be set at so high a price.',
#   [['was', 'thoughts']]),
#  ('“Sir,” said the crier, giving it into his hand, “if you look at the outside of this apple, it is very worthless, but if you consider its properties, virtues, and the great use and benefit it is to mankind, you will say it is no price for it, and that he who possesses it is master of a great treasure. In short, it cures all sick persons of the most mortal diseases; and if the patient is dying it will recover him immediately and restore him to perfect health; and this is done after the easiest manner in the world, which is by the patient’s smelling the apple.”',
#   [['is', 'properties']]),
#  ('Lang she sat, and aye she grat, till she wearied. At last she rase and gaed awa’, she kedna whaur till. On she wandered till she came to a great hill o’ glass, that she tried a’ she could to climb, bat wasna able. Round the bottom o’ the hill she gaed, sabbing and seeking a passage owre, till at last she came to a smith’s house; and the smith promised, if she wad serve him seven years, he wad make her iron shoon, wherewi’ she could climb owre the glassy hill. At seven years’ end she got her iron shoon, clamb the glassy hill, and chanced to come to the auld washerwife’s habitation. There she was telled of a gallant young knight that had given in some bluidy sarks to wash, and whaever washed thae sarks was to be his wife. The auld wife had washed till she was tired, and then she set to her dochter, and baith washed, and they washed, and they better washed, in hopes of getting the young knight; but a’ they could do they couldna bring out a stain. At length they set the stranger damosel to wark; and whenever she began the stains came out pure and clean, but the auld wife made the knight believe it was her dochter had washed the sarks. So the knight and the eldest dochter were to be married, and the stranger damosel was distracted at the thought of it, for she was deeply in love wi’ him. So she bethought her of her apple, and breaking it, found it filled with gold and precious jewelry, the richest she had ever seen. “All these,” she said to the eldest dochter, “I will give you, on condition that you put off your marriage for ae day, and allow me to go into his room alone at night.” So the lady consented; but meanwhile the auld wife had prepared a sleeping-drink, and given it to the knight, wha drank it, and never wakened till next morning. The lee-lang night ther damosel sabbed and sang:',
#   [['was', 'sarks']]),
#  ('He next asked the old woman to show him where the King’s daughters lay; and the old woman took him upstairs and opened a great many doors, and out of every door came a beautiful lady who had been imprisoned there by the Etin; and ane o’ the ladies was the King’s daughter. She also took him down into a low room, and there stood two stone pillars that he had only to touch wi’ his wand, when his two friends and neighbors started into life. And the hale o’ the prisoners were overjoyed at their deliverance, which they all acknowledged to be owing to the prudent young man. Next day they a’ set out for the King’s Court, and a gallant company they made. And the King married his daughter to the young man that had delivered her, and gave a noble’s daughter to ilk ane o’ the other young men; and so they a’ lived happily a’ the rest o’ their days.(1)',
#   [['was', 'ladies']]),
#  ('“Three fields away from here lives Farmer John. He has some cows. Go there and he will give you what you want.”',
#   [['lives', 'fields']]),
#  ('ground        thumb           beads           dwarfs        crooked         crown                         worked',
#   [['dwarfs', 'beads']]),
#  ('Then he took him about everywhere, up and down, and let him see all the riches, and the magnificent apartments, only there was one room which he did not open, that in which hung the dangerous picture. The picture was, however, so placed that when the door was opened you looked straight on it, and it was so admirably painted that it seemed to breathe and live, and there was nothing more charming or more beautiful in the whole world. The young King, however, plainly remarked that Faithful John always walked past this one door, and said, “Why dost thou never open this one for me?” “There is something within it,” he replied, “which would terrify thee.” But the King answered, “I have seen all the palace, and I will know what is in this room also,” and he went and tried to break open the door by force. Then Faithful John held him back and said, “I promised thy father before his death that thou shouldst not see that which is in this chamber, it might bring the greatest misfortune on thee and on me.” “Ah, no,” replied the young King, “if I do not go in, it will be my certain destruction. I should have no rest day or night until I had seen it with my own eyes. I shall not leave the place now until thou hast unlocked the door.”',
#   [['was', 'apartments']]),
#  ('There was once a poor woman who gave birth to a little son; and as he came into the world with a caul on, it was predicted that in his fourteenth year he would have the King’s daughter for his wife. It happened that soon afterwards the King came into the village, and no one knew that he was the King, and when he asked the people what news there was, they answered, “A child has just been born with a caul on; whatever any one so born undertakes turns out well. It is prophesied, too, that in his fourteenth year he will have the King’s daughter for his wife.”',
#   [['turns', 'undertakes']]),
#  ('The mother of Hans said, “Whither away, Hans?” Hans answered, “To Grethel.” “Behave well, Hans.” “Oh, I’ll behave well. Good-bye, mother.” “Good-bye, Hans.” Hans comes to Grethel, “Good day, Grethel.”',
#   [['comes', 'Hans']])]

# %%
# target_sentences = []``
# for sentence in corpus:
#     doc = nlp(sentence)
#     if singular_plural(doc):
#         target_sentences.append(sentence)
for token in doc:
    print(token.text, token.pos_, token.tag_, [child.text for child in token.children])
# Out:
# Five  CD []
# people  NNS ['Five']
# is  VBZ ['people', 'number', '.']
# a  DT []
# not  RB []
# a  DT []
# huge  JJ []
# number  NN ['a', 'not', 'a', 'huge', 'of']
# of  IN ['attendees']
# attendees  NNS []
# .  . []

# %%
target_sentences['children_stories']
# Out:
#  'heather flowerin’, all purple bells, an’ hundreds o’ butterflies flutterin’ an’ bees hummin’ an’ skylarks soarin’ up an’ singin’. You’ll want to get out on it at sunrise an’ live out on it all day like Dickon does.”',
#  '“Well,” said Martha stoutly, “I’ve told thee that th’ very birds likes him an’ th’ rabbits an’ wild sheep an’ ponies, an’ th’ foxes themselves. I wonder,” staring at her reflectively, “what Dickon would think of thee?”',
#  'Ten years was a long time, Mary thought. She had been born ten years ago.',
#  '“I got up slow,” he explained, “because if tha’ makes a quick move it startles ’em. A body ’as to move gentle an’ speak low when wild things is about.”',
#  '“He wouldn’t come near thee if he didn’t,” answered Dickon. “Birds is rare choosers an’ a robin can flout a body worse than a man. See, he’s making up to thee now. ‘Cannot tha’ see a chap?’ he’s sayin’.”',
#  '“They’ve run wild,” he said, “but th’ strongest ones has fair thrived on it. The delicatest ones has died out, but th’ others has growed an’',
#  'snowdrops, an’ these here is narcissuses,” turning to another patch, “an here’s daffydowndillys. Eh! they will be a sight.”',
#  '“Not me,” he said, grinning. “I never ketched cold since I was born. I wasn’t brought up nesh enough. I’ve chased about th’ moor in all weathers same as th’ rabbits does. Mother says I’ve sniffed up too much fresh air for twelve year’ to ever get to sniffin’ with cold. I’m as tough as a white-thorn knobstick.”',
#  'Th’ other ones takes two years to bloom from seed, but I can bring you some bits o’ plants from our cottage garden. Why does tha’ want ’em?”',
#  '“An’ his eyes is so round,” said Martha, a trifle doubtful. “Though they’re a nice color.”',
#  '“One of th’ worst fits he ever had,” said Martha, “was one time they took him out where the roses is by the fountain. He’d been readin’ in a paper about people gettin’ somethin’ he called ‘rose cold’ an’ he began to sneeze an’ said he’d got it an’ then a new gardener as didn’t know th’ rules passed by an’ looked at him curious. He threw himself into a passion an’ he said he’d looked at him because he was going to be a hunchback. He cried himself into a fever an’ was ill all night.”',
#  '“It’s part o’ th’ springtime, this nest-buildin’ is,” he said. “I warrant it’s been goin’ on in th’ same way every year since th’ world was begun. They’ve got their way o’ thinkin’ and doin’ things an’ a body had better not meddle. You can lose a friend in springtime easier than any other season if you’re too curious.”',
#  '“Everybody as knowed about Mester Craven knowed there was a little lad as was like to be a cripple, an’ they knowed Mester Craven didn’t like him to be talked about. Folks is sorry for Mester Craven because Mrs.',
#  '“Them’s just like his mother’s eyes, only hers was always laughin’, they say,” he said. “They say as Mr. Craven can’t bear to see him when he’s awake an’ it’s because his eyes is so like his mother’s an’ yet looks so different in his miserable bit of a face.”',
# ...
#  '‘She lives near to the river, ma’am,’ replied Toad. ‘Close to a fine house called Toad Hall, that’s somewheres hereabouts in these parts.',
#  '‘O, I have girls,’ said Toad lightly: ‘twenty girls or thereabouts, always at work. But you know what GIRLS are, ma’am! Nasty little hussies, that’s what I call ‘em!’',
#  '“Good morning, gentlemen!” says I, very respectful. “Want any washing done to-day?”',
#  '"If papa was here, he would let me go. I shall not play; I shall sit here and make some plans for my poor boy."',
#  'Not finding his mother at home, Perseus went straight to the palace, and was immediately ushered into the presence of the king. Polydectes was by no means rejoiced to see him; for he had felt almost certain, in his own evil mind, that the Gorgons would have torn the poor young man to pieces, and have eaten him up, out of the way. However, seeing him safely returned, he put the best face he could upon the matter and asked Perseus how he had succeeded.',
#  'And, what was very singular, all the flowers and dewy blossoms on earth, not one of which had hitherto faded, now began to droop and shed their leaves, after a day or two. The children, moreover, who before seemed immortal in their childhood, now grew older, day by day, and came soon to be youths and maidens, and men and women by and by, and aged people, before they dreamed of such a thing.',
#  "Thus the old couple lived in their palace a great, great while, and grew older and older, and very old indeed. At length, however, there came a summer morning when Philemon and Baucis failed to make their appearance, as on other mornings, with one hospitable smile overspreading both their pleasant faces, to invite the guests of over-night to breakfast. The guests searched everywhere, from top to bottom of the spacious palace, and all to no purpose. But, after a great deal of perplexity, they espied, in front of the portal, two venerable trees, which nobody could remember to have seen there the day before. Yet there they stood, with their roots fastened deep into the soil, and a huge breadth of foliage overshadowing the whole front of the edifice. One was an oak, and the other a linden-tree. Their boughs it was strange and beautiful to see were intertwined together, and embraced one another, so that each tree seemed to live in the other tree's bosom much more than in its own.",
#  "I remember my first visit to Tartarin of Tarascon as clearly as if it had been yesterday, though it is now more than a dozen years ago. When you had passed into his back garden, you would never have fancied yourself in France. Every tree and plant had been brought from foreign climes; he was such a fellow for collecting the curiosities of Nature, this wonderful Tartarin. His garden boasted, for instance, an example of the baobab, that giant of the vegetable world, but Tartarin's specimen was only big enough to occupy a mignonette pot. He was mightily proud of it, all the same.",
#  '"O yonder, there," says he; "one, two, three canoes!"',
#  "And the little girl I saw on that first day at Mr. Wickfield's, where is she? Gone also. In her stead, the perfect likeness of the picture, a child likeness no more, moves about the house; and Agnes my sweet sister, as I call her in my thoughts, my counsellor and friend the better angel of the lives of all who come within her calm, good, self-denying influence is quite a woman.",
#  '"I ha\' not come here, sir, to complain. I were sent for. Indeed, we are in a muddle, sir. Look round town so rich as \'tis. Look how we live, and where we live, an\' in what numbers; and look how the mills is always a-goin\', and how they never works us no nigher to any distant object, \'cepting always, death. Sir, I cannot, wi\' my little learning, tell the gentleman what will better this; though some working men o\' this town could. But the strong hand will never do\'t; nor yet lettin\' alone will never do\'t. Ratin\' us as so much power and reg\'latin\' us as if we was figures in a sum, will never do\'t."',
#  '"I\'m sorry for it, governor, with all my heart!" said Mark. "The goods is safe enough," he added, turning to Martin, and pointing to their boxes. "There ain\'t many people about to make away with \'em. What a comfort that is!"',
#  '"That\'s because they damped the straw afore they lit it in the chimbley to make \'em come down again," said Gamfield. "That\'s all smoke, and no blaze; vereas smoke only sinds him to sleep, and that ain\'t no use in making a boy come down. Boys is wery obstinite and wery lazy, gen\'l\'men, and there\'s nothink like a good hot blaze to make \'em come down with a run. It\'s humane, too, gen\'l\'men, acause, even if they\'ve stuck in the chimbley, roasting their feet makes \'em struggle to hextricate theirselves."',
#  '"What is the odds so long as the fire of soul is kindled at the taper of conviviality, and the wing of friendship never moults a feather! But, only one little whisper, Fred is the old min friendly?"',
#  'boy in my shop, and I know that he thinks Epsom salts means oxalic acid, and syrup of senna, laudanum; that\'s all, my lord."',
#  'arms, so precocious was the passion for tarts in this singular country.',
#  '"Blue blazes!" he muttered. "Bennett\'s a good fellow all right, and he\'s hurt; but if he hadn\'t nigh saved my life twice he could get this critter back himself fer all of me!" He glanced at the dark woods and drew up suddenly. "The road forks here, and Turner\'s is yonder less than a mile. I\'ll hitch in his barn a spell and go on later," and he took the Turner fork.',
#  'Miltiades was a big gobbler now, and had a right to be named Ishmael, for his hand was against all men. He took care of himself, was never shut up nor handled, and led a wild, nomadic life.',
#  'Now the salmagundi was (to some palates) a most appetizing mixture, compounded of salted mackerel, or sometimes of chopped meat, seasoned with oil and vinegar, pepper and raw onions not an altogether attractive dish to read of, but welcome to and dearly loved by many an old Knickerbocker even up to a recent date. Its name, too, as most of you bright boys and girls doubtless know, furnished the title for one of the works of Washington Irving, best loved of all the Knickerbockers.',
#  '"Ach, so," cried young Teuny Vanderbreets, as the disgusted and disconsolate six gathered in the roadway and looked at one another ruefully. "Here is a fine mix-up a regular salmagundi, Patem Onderdonk, and no question. And you did say that this Thanksgiving was all our work. Out upon you, say I! Here are we to be saddled with a worse master than before. Hermanus Smeeman did tell me that Nick Stuyvesant did tell him that Dominie Luyck is a most hard and worryful master."',
#  'In short, it was one of those intervals when sorrow vanishes in its own depth of shadow, and joy starts forth in transitory brightness.',
#  '"It leaves Thanksgiving out in the cold, doesn\'t it, Bub? But we\'ll make it up at Christmas, maybe," said Mr. Waddle, as Obadiah turned to go. "Here\'s three cents for a bite of candy for Sis, and take good care of mother. I\'ll be home day after to-morrow, likely."',
#  '"And now," said Ezra softly, "the pictur\' changes: seems as if I could see the pond. The ice is like a black lookin\'-glass, and Hiram Peabody slips up the first thing, an\' down he comes, lickety-split, an\' we all laugh except Sister Mary, an\' she says it is very imp\'lite to laugh at other folks\' misfortunes. Ough! how cold it is, and how my fingers ache with the frost when I take off my mittens to strap on Laura\'s skates! But, oh, how my cheeks burn! And how careful I am not to hurt Laura, an\' how I ask her if that\'s \'tight enough,\' an\' how she tells me \'jist a little tighter\' and how we two keep foolin\' along till the others hev gone an\' we are left alone! An\' how quick I get my own skates strapped on none o\' your new-fangled skates with springs an\'',
#  '"Seems now," continued Ezra musingly, "seems now as if I could see us all at breakfast. The race on the pond has made us hungry, and Mother says she never knew anybody else\'s boys that had such capac\'ties as hers. It is the Yankee Thanksgivin\' breakfast sausages an\' fried potatoes, an\' buckwheat cakes, an\' syrup maple syrup, mind ye, for Father has his own sugar bush, and there was a big run o\' sap last season. Mother says, \'Ezry an\' Amos, won\'t you never get through eatin\'? We want to clear off the table, fer there\'s pies to make, and nuts to crack, and laws sakes alive! The turkey\'s got to be stuffed yet!\' Then how we all fly around! Mother sends Helen up into the attic to get a squash while Mary\'s makin\' the pie crust. Amos an\' I crack the walnuts they call \'em hickory nuts out in this pesky country of sagebrush and pasture land. The walnuts are hard, and it\'s all we can do to crack \'em. Ev\'ry once\'n a while one on \'em slips outer our fingers and goes dancin\' over the floor or flies into the pan Helen is squeezin\' pumpkin into through the col\'nder. Helen says we\'re shif\'less an\' good for nothin\' but frivolin\'; but Mother tells us how to crack the walnuts so\'s not to let \'em fly all over the room, an\' so\'s not to be all jammed to pieces like the walnuts was down at the party at the Peasleys\' last winter. An\' now here comes Tryphena Foster, with her gingham gown an\' muslin apron on; her folks have gone up to Amherst for Thanksgivin\', an\' Tryphena has come over to help our folks get dinner. She thinks a great deal o\' Mother, \'cause Mother teaches her Sunday-school class an\' says Tryphena oughter marry a missionary. There is bustle everywhere, the rattle uv pans an\' the clatter of dishes; an\'',
#  "Amos and I get the drumsticks; Mary wants the wishbone to put over the door for Hiram, but Helen gets it. Poor Mary, she always did have to give up to 'rushin' Helen,' as we call her. The pies oh, what pies Mother makes; no dyspepsia in 'em, but good nature an' good health an' hospitality! Pumpkin pies, mince, an' apple, too, and then a big dish of pippins an' russets an' bellflowers, an', last of all, walnuts with cider from the Zebrina Dickerson farm! I tell ye, there's a Thanksgivin' dinner for ye! that's what we get in old Belchertown; an'",
#  '"Likely not!" said the man, with a knowing look, "but folks has a mighty queer way of findin\' out," and he shut the door and left.',
#  "There were gentlemen there for dinner gentlemen Polly was very fond of and she had a nice time visiting with one of them. He could change his table napkin into a white rabbit, and she forgot all about the dolls' Thanksgiving dinner until it was dessert-time, and the nuts and raisins came in."]

# %%
target_sentences
# Out:
# ["and here's some apples .",
#  'fun facts is a book .',
#  "it's time those guys yikes they better be getting in the bathtub !",
#  "theo where's your toes ?",
#  'yes the pretend person is not going to find the blocks is he .',
#  "theo where's the fishies .",
#  'here comes more tummy kisses .',
#  "carrots keeps warm and dry in kim's coat .",
#  "avery's got dolls doesn't she .",
#  "the bunny has big ears doesn't he .",
#  "yay father whistles sometimes doesn't he !",
#  "where's your teeth ?",
#  "zachary likes police boats doesn't he .",
#  "where's the fishies ?",
#  'guys guys guys guys .',
#  "where's his eyes ?",
#  "where's mama's eyes ?",
#  'bears bears bears .',
#  "where's nicholas ?",
#  "where's the cows ?",
#  "where's your shoes ?",
#  "where's roy's shoes ?",
#  "where's the shoes ?",
#  "where's the monkey's eyes ?",
#  "where's the monkey's eyes ?",
#  "oh here's some pictures of babies that we know .",
#  "here's some apples and blueberries mm .",
#  "where's the chickie's eyes ?",
#  "where's bert's eyes ?",
#  "where's bert's eyes ?",
#  "where's the baby's eyes ?",
#  "where's your shoes aha you gonna take your shoes off ?",
#  "where's her eyes ?",
#  "here's hands .",
#  "here's your feet .",
#  "where's the baby's eyes ?",
#  "where's the baby's eyes ?",
#  "here's the people .",
#  "here's the people .",
#  'oops bubbles !',
#  "here's the bubbles right here right ?",
#  "where's your cheerios ?",
#  "here's two books about bears .",
#  'rustles and bustles and squishes and zings what wonderful noises a thunderstorm brings .',
#  "carrots keeps warm and dry in kim's coat .",
#  "here's some balls .",
#  "where's the legos ?",
#  "where's the legos ?",
#  "where's the birds ?",
#  "where's the birds ?",
#  'ashes ashes we all fall .',
#  'kittie cats meow .',
#  "aw and where's the toes ?",
#  "see carrots keeps warm and dry in kim's coat when it rains .",
#  "here's some cars .",
#  "here's some toys you haven't seen for a few days .",
#  "here's the blocks .",
#  "chewy isn't it ?",
#  'yeah the sheep has a bottle .',
#  'bubbles bubbles bubbles ?',
#  'bubbles bubbles bubbles .',
#  "where's bubbles ?",
#  'hm hm bubbles is over here honey .',
#  "yeah babies except that's a big girl .",
#  "two balls stays on mommy's shirt .",
#  'then little birds mommy brings that baby right up close .',
#  "here's some blocks in here .",
#  'blocks blocks blocks ?',
#  "where's the dogs ?",
#  "where's the owls ?",
#  "where's the pigs ?",
#  "where's the clown's eyes ?",
#  "she'll sleep as long as i don't get up with them and when my feet hits the floor she hears them !",
#  'thirty seconds is a long time .',
#  'thirty seconds is a long time .',
#  'i know you want to see where all the noises comes from .',
#  "and then uses it when she doesn't have the other ones like belly is becky so !",
#  "where's the crayons ?",
#  "where's the crayons ?",
#  "where's her eyes ?",
#  "where's the ducks ?",
#  "where's the birdies ?",
#  "where's the ducks ?",
#  "where's the ducks ?",
#  'and kittie cats meow .',
#  'snuffles is in the basket ?',
#  'snuffles is just a little too big !',
#  "here's baby's abcs .",
#  "where's the socks ?",
#  'more animals and animal sounds uh .',
#  "oh here's plums bananas and rice mm .",
#  'tastes like yogurt does it ?',
#  "here's the rings .",
#  "here's more books .",
#  "it doesn't have any words except for the name of the food but they have different like green beans just goes green beans green beans green beans and macaroni goes macaroni macaroni .",
#  'witzi is a fluffy duck .',
#  'patches is a giraffe of many colors what colors do you see .',
#  'patches is yellow .',
#  'caterpillar crawls along my hand this butterfly flutters down to land .',
#  "where's the shoes ?",
#  'booties on naima naima has booties on .',
#  "come here here's the crayons .",
#  "here's some other ones .",
#  "what's that teeth ?",
#  "where's your shoes ?",
#  'where is your toes ?',
#  'where is your shoes ?',
#  'where is your shoes ?',
#  'if no shoes then that means poor seth come barefooted huh .',
#  "here's the black raspberries .",
#  'kazoos is that that funny word you made up .',
#  'where is your toes ?',
#  'i hope you really like my useful engines says sir toppumhat ?',
#  "where's the wheels on the bus ?",
#  "and here's the workers loading the ship .",
#  "where's yer toes ?",
#  "where's william's toes ?",
#  "where's the crayons ?",
#  "where's the crayons ?",
#  "here's some crayons .",
#  "here's her arms .",
#  "here's her eyes .",
#  "and here's her feet and there's her shiny shoes .",
#  "here's some almonds we could put these in for daddy .",
#  'here is crumbs .',
#  'here is crumbs .',
#  "where's the birds ?",
#  'kids loves toys burt loves pigeons and pigeons love to coo can you guess who elmo loves ?',
#  'elmo whispers quietly elmo loves you .',
#  "chicks peep crickets cheep horses neigh donkeys spray but rubber duckies don't say quack .",
#  "oh here's your colors .",
#  "oh here's some animals .",
#  "here's some balls .",
#  'crabs and donkeys seagulls boat .',
#  "here's some baby pigs ?",
#  'shoes like alice has .',
#  "here's his shoes and then his what ?",
#  "well this kinda bites too doesn't it .",
#  "cups chairs chickies duckies here's a kittie !",
#  'crayons ducks a boy .',
#  "here's some more blue ones two more blue ones .",
#  "here's three blue ones .",
#  "here's some blue ones ?",
#  "okay here's the dominoes .",
#  "here's more dominoes .",
#  "here's some animals .",
#  "here's the feet .",
#  'what is it worms ?',
#  "where's my babies ?",
#  "where's her babies ?",
#  "eddy's hot too maisy shares the lemonade eddy takes a big drink .",
#  'where is the scales ?',
#  'oh here is our friends .',
#  'do you see birds elephants squirrels what else ?',
#  "look look over here here's some monkeys ?",
#  "here's two black legos and here are two green legos and here are two red legos and here are two friends .",
#  "here's your bubbles .",
#  "alex where's your other toys .",
#  "where's your other toys ?",
#  "where's your other toys ?",
#  "where's your bubbles ?",
#  "where's your bubbles ?",
#  "where's your bubbles ?",
#  "where's your sticks ?",
#  'here is your jammies !',
#  "where is daddy's shoes ?",
#  'where is the towels ?',
#  "here's some shoes .",
#  "here's a pencil julia .",
#  'julia how was your day .',
#  "here's yours mr bear ?",
#  "how's the biscuits ?",
#  'bye bye nighttime animals is that when we say night night .',
#  "here's the cat's eyes !",
#  "and here's some numbers there's a five and a nine .",
#  "here's some pieces .",
#  "where's elmo's boots ?",
#  "elmo's guessing game where's elmo's boots ?",
#  'where is the scales ?',
#  'where is the towels ?',
#  "the design comes from uh men houses men's house men's club houses in the pacific ?",
#  "where's the puppies ?",
#  "where's her feet ?",
#  "he's brushing his teeth isn't he ?",
#  "here's the circus animals ?",
#  "where's the baby's eyes ?",
#  "where's the eyes ?",
#  "where's the feet ?",
#  "here's the dog here's the comb here's the two hair elastics where's the baby's head and the hair where's the hair ?",
#  'okay oops oops oops .',
#  'it fits you but you know your legs are so long that the pants part of the suit is short on you .',
#  'nonsense rhyme there was an old man with a beard who said it is just as i feared ?',
#  "where's mommy's eyes ?",
#  "where's yer toes ?",
#  "where's yer toes ?",
#  "touch yer toes where's yer toes .",
#  "open yer eyes where's yer eyes ?",
#  "where's yer eyes ?",
#  "where's yer feet ?",
#  "here's the grey ones ?",
#  "and here's the socks .",
#  'on their cheeks on their ears their fingers their nose their tops of their wrists their tummies their toes .',
#  "where's the where's your rocks ?",
#  "where's the little pigs ?",
#  "where's the little piggies ?",
#  "here's the turtles ?",
#  "where's your other books ?",
#  "where's bubbles ?",
#  "where's the eyes ?",
#  "where's the eyes on that phone ?",
#  "where's his eyes ?",
#  "where's his eyes ?",
#  "where's the bags ?",
#  "where's peanuts ?",
#  "where's the baby's feet ?",
#  "no more crackers inside it's empty .",
#  "okay here's some blocks .",
#  'here is some more leaves .',
#  'where is your chichi buttons ?',
#  'peanuts was in a bag yesterday .',
#  "here's the mice !",
#  "yeh bug crawls doesn't he .",
#  "you slipped on the cards all the rattles and the shaky egg and this star fish is kind of a rattle too then i'm gonna put all the animals that move around in another spot ?",
#  "oh triceratops goes right there that's right triceratops .",
#  "and here's some blocks .",
#  "that sounds good to me now how is your um issues going over there i've been thinking about you ?",
#  "okay here's the clothes that we're sending out .",
#  'alls you have to do is wreck them .',
#  "and here's your keys your keys .",
#  "where's your bubble wands ?",
#  "where's the wands ?",
#  "where's the fingers ?",
#  "where's yer fingers ?",
#  "where's his eyes ?",
#  "where's his eyes ?",
#  "where's his eyes ?",
#  'and bingo was her .',
#  'and bingo was her name o .',
#  'and zingo was his name oh .',
#  "here's the pandas on it ?",
#  'oops oops a daisy !',
#  "how's our pliers ?",
#  "where's jesse's shoes ?",
#  "where's jesse's shoes ?",
#  "where's matthew's shoes ?",
#  "flowers and there's .",
#  "oh look at here's some pictures we haven't seen .",
#  "where's carrots ?",
#  "carrots is in the bird bath oh no she's going to get wet .",
#  'oops oops oops oops oops .',
#  'oh no the cars is right here .',
#  'you remember what ducks is ?',
#  'plums pears melons strawberries .',
#  "here's some baby clothes .",
#  "my lips where's my lips ?",
#  "looks like broccoli doesn't it ?",
#  "squigglies squigglies no not squirrels they're squigglies .",
#  'i think spirals is right .',
#  "where's your muscles ?",
#  "the bunny hops doesn't he .",
#  "the elephant squeaks doesn't it .",
#  "his ears he has big ears doesn't he .",
#  "here's some blocks beads ?",
#  "here's some chairs ?",
#  "where's the chickens ?",
#  "here's some little chairs ?",
#  "here's some chairs ?",
#  "here's some stairs .",
#  "where's some people ?",
#  "oh here's some beds nan .",
#  "here's some chairs too .",
#  "yeah here's some more people .",
#  "where's the doll house beds ?",
#  "here's bunk beds ?",
#  "now here's the doors ?",
#  "yeah where's big birds eyes .",
#  'what was the nursies ?',
#  "aren't there pigs isn't there a pig who wears a pajamas in that book .",
#  'where is the jelly beans ?',
#  "where's his eyes ?",
#  "where's julia's shoes ?",
#  "where's your shoes julia ?",
#  "where's your shoes ?",
#  "what's this jules ?",
#  "yeah that one has pandas on it doesn't it ?",
#  "where's his ears ?",
#  "look here's some suitcases .",
#  'where is the another airplanes ?',
#  "what's their names ?",
#  "oh where's his eyes .",
#  "okay where's his whiskers !",
#  "where's his feet ?",
#  "okay here's the bubbles .",
#  "where's your mittens ?",
#  "here's a few fishsticks i mean fishies on the table .",
#  "where's that baby's shoes ?",
#  "yes where's his feet ?",
#  "here's some mushrooms and there's a chair like you chair that you're on .",
#  'goldilocks is her real name yeah .',
#  "that's the same word that goldilocks starts with .",
#  "and here's your beads i'll givya beads .",
#  "you're funny where's your fishies .",
#  'elmo whispers quietly elmo loves you .',
#  'chicks peep crickets cheep horses neigh donkeys bray .',
#  "here's some crayons ?",
#  "where's all the toys ?",
#  'i think frances is a skunk ?',
#  'the doctors checks your ears and mouth .',
#  "the plane lands and the truck takes the mail to the post office near molly's house .",
#  "here's some more letters .",
#  'where is the spoons ?',
#  "here's the spoons .",
#  "where's your shoes ?",
#  "where's your hands ?",
#  "where is that teddy's ears ?",
#  "where is daddy's teeth ?",
#  "mama mama i don't know where the people is .",
#  "where's the other people ?",
#  'how many kittie cats is that ?',
#  'three animals is on that page .',
#  'the little beds goes in here ?',
#  "and the owl says hello pooh how's things ?",
#  "how's things ?",
#  "here's the sesame seeds ?",
#  'where is the flowers ?',
#  "and where's his ears !",
#  "where's his hands ?",
#  "where's the balloons ?",
#  "where's the balloons ?",
#  "where's elmo's eyes ?",
#  "where's your drums ?",
#  'max cleans up is that what you were saying .',
#  'do you rodents thinks you think you can handle a semicircle ?',
#  "here's the eggs ?",
#  "here's some socks nomi ?",
#  'here comes peanuts .',
#  "where's your crayons ?",
#  "where's the grapes ?",
#  "where's the grapes ?",
#  "where's the grapes ?",
#  "where's your eyes ?",
#  "j j where's your eyes ?",
#  "where's your eyes ?",
#  "where's mommy's eyes ?",
#  "where's your ears ?",
#  "here's one little boy where's his eyes ?",
#  "oh here's the pumpkins .",
#  "yeah the bell rings doesn't it .",
#  "where's the boots ?",
#  "where's lynette's shoes ?",
#  "he makes all kinds of noises doesn't he ?",
#  "where's his feathers ?",
#  "where's his wings ?",
#  'where is his owie ?',
#  'says romeo ?',
#  'bears bears bears bears bears ?',
#  "here's nine cookies with cookie monster .",
#  "and here's twelve tweedle bugs ?",
#  "where's your eights ?",
#  "here's eight scoops of ice cream ?",
#  "and here's three hats on oscar .",
#  "here's two prairie dawns .",
#  "okay where's your cards .",
#  'and how many many points is that .',
#  'and is the italian two slices a point .',
#  'yeah polly pockets has a rather strange sense of fashion .',
#  "here's your directions .",
#  "where's your eyes ?",
#  "where's your eyes ?",
#  'oops is right ?',
#  "two packets already i'm sure ?",
#  "where's his ears ?",
#  "here's the green one oops .",
#  "roses daisies four o'clocks .",
#  "mommy vacuums that's right w is for wagon ?",
#  "here comes uncle larry's chickens .",
#  'here comes the chickens .',
#  "where's the diapers ?",
#  "here's the diapers for those babies ?",
#  'here is two cups .',
#  'ducks in the mill pond is that next ?',
#  'a pigs the pigs pigs pigs .',
#  'where is ducks in the mill pond ?',
#  "where's lucille where did she go ?",
#  "here's your other train pieces .",
#  "and here's the little here's the balloons .",
#  "where's the balloons ?",
#  'boots is a monkey right !',
#  'i think so boots is .',
#  "where's douglas there's douglas ?",
#  "come on let's see what else is in the bag let's see what else is in the bag look at this you never saw that before oops oops oops that's a funny man .",
#  "the sun is very bright it hurts your eyes doesn't it ?",
#  "well this woman yeah here's her legs .",
#  "yeah stars all over that's right .",
#  "where's men that goes to this ?",
#  "where's the other cars ?",
#  "where's the suitcases ?",
#  "where's the suitcases ?",
#  "where's the other dinosaurs i want mama ?",
#  "that's mr fix it let's find i think dr bones is in the raccoon story ah what's the matter with dr bones can't he see where he's going .",
#  "here's the oranges ?",
#  "oh look melissa here's the people .",
#  "melissa here's some beads that ?",
#  "where's his hands ?",
#  "where's his feet ?",
#  "where's his legs ?",
#  "where's the lights ?",
#  "where's the flowers ?",
#  "here's some more books .",
#  "do you remember what color daddy's football teams wears ?",
#  'but as soon as one melts another takes its place .',
#  "here's the doorknobs .",
#  'chicks peep crickets cheep horses neigh donkeys bray .',
#  "here here's your other cars .",
#  'and the people goes like this see him sitting down .',
#  "here's your mans right here here's one ?",
#  'here is the bottoms .',
#  'and bingo was his name oh .',
#  "an' here's the cookies .",
#  'whatchamacallits not hatchamacallits ?',
#  "where's the jelly beans ?",
#  "where's the boys eyes ?",
#  "where's christine's eyes ?",
#  "where's your eyes ?",
#  "where's your ears ?",
#  "where's your teeth ?",
#  "where's mommy's flowers ?",
#  "and moe's bagels too that's right ?",
#  "so here's a blue steps .",
#  "an apple where's the apples .",
#  "where's your blocks ?",
#  'yes one has the cheerios and one has .',
#  "that's what goldilocks does ?",
#  'goldilocks breaks the chair to bits .',
#  "that's a hundred scrumptious lumps of porridge is what it is .",
#  "here's the tissues .",
#  "the kangaroo hops doesn't he .",
#  "where's your blocks ?",
#  "oh no we're not gonna elmo is taking a break right now let's let's do this look at this where's your blocks .",
#  'okay thank you now we both have rings peter has a ring and lois has ring .',
#  "here's the wheels ?",
#  "what's that numbers ?",
#  "where's your teeth ?",
#  "where's your fingers ?",
#  "where's your toes ?",
#  "where's the baby's eyes ?",
#  "where's the baby's eyes ?",
#  "where's the big old where's the flies ?",
#  'while wendy waters fights the flames billy has a job to do .',
#  "and here's some cutters to make shapes with the playdoh .",
#  "and here's some baby ones ?",
#  "here's their babies ?",
#  "where's the zebras ?",
#  "where's my cars ?",
#  "oh here's some pictures of things .",
#  'four dollars for the ear rings one dollar ?',
#  "dragon tales has a dragon named cassie you're right .",
#  "oh my goodness i don't know if polly pockets wants to go in the water in her dress does she .",
#  "here's some curved train tracks .",
#  "there now'e has some tea .",
#  "where's the animals ?",
#  "where's your eyeglasses ?",
#  "here's some new ones !",
#  "he's got pretty blue eyes doesn't he .",
#  "oh no olives then that's too bad ?",
#  "they've been out walking so they're hungry too just like goldilocks was ?",
#  'yes i think goldilocks was the one eating his porridge .',
#  "here's people ?",
#  "where's all where's all ari's blocks ?",
#  'like two reds or two whites or something goes in the same thing in the same box .',
#  "here's two blues ?",
#  "here's birds in the nest .",
#  "here's some birds in the nest ?",
#  "no pete mama said no pretzels now no cookies now that's what mama said .",
#  "watching the sea lions is always fun but today there's some monkey business going on at the zoo .",
#  "where's his toes ?",
#  "he has funny eyes doesn't he ?",
#  "where's the owie ?",
#  'two weeks is time .',
#  'where is eve cummings ?',
#  "here's some crunchy bits of waffle crunchy waffle .",
#  "grummies is definitely one of naima's swear words ?",
#  "where's your little people ?",
#  "where's all your little people ?",
#  "where's all your blues ?",
#  "right here here's the other people !",
#  "here's some words though .",
#  "here's one two three cars ?",
#  "look here's baby mooky eating noodles .",
#  "here's the scissors that we need to open the thing ?",
#  "and here's your shoes here ?",
#  'three eggs and on the back is a rooster ?',
#  'letting mommy brush your teeth is the right thing to do .',
#  "oh rats is something people say when they're frustrated or when they've forgotten to do something .",
#  'rats rats rats .',
#  'blossoms is another word you can use for flowers .',
#  'rats rats rats ?',
#  "what's the matter peanuts ?",
#  "mama what's two cowboys ?",
#  "mama where's where's two chicken nuggets ?",
#  "it was all different colors wasn't it ?",
#  'when he says his messages he snaps snaps snaps ?',
#  'when he says his messages he snaps snaps snaps ?',
#  'when he goes to school by day he roars roars roars ?',
#  'when he goes to school by day he roars roars roars ?',
#  'ashes ashes we all fall down .',
#  'ashes ashes we all fall down .',
#  "where's your little people ?",
#  "eve what's that your papa has in his hand .",
#  "here's the people .",
#  "here's your reins .",
#  "here's all different parts of an animal .",
#  'oops is right ?',
#  'the hives is just now it has something to do with something he ate now ?']
